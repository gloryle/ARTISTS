# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import numpy  as np
import seaborn as sns
# %matplotlib inline

from sklearn.ensemble import RandomForestClassifier
path = './data/'
pd.options.display.max_rows = 150
pd.options.display.max_columns = 350
plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
sido = pd.read_csv(path+'sido_imp_10.csv', encoding='cp949')

# %% [markdown]
# ## 데이터모양확인 및 split

# %%
sido.shape
# Out:
# ((17, 173), (226, 311))

# %%
sido_y = sido.iloc[:,-7:]
sido_x = sido.iloc[:,3:-7]
sido_name = sido.iloc[:,:3]

# %%
sido_y.shape, sido_x.shape,sido_name.shape
# Out:
# ((17, 7), (17, 163), (17, 3))

# %% [markdown]
# ## 표준화 (MinmaxScaler)
# * 다른 스케일러 robust_scale(), maxabs_scale(), scale(),
# * minmaxscaler() 범위조정(0,1)
# * 로 만들어진 데이터셋도 시도해봐야한다.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
#독립변수에 일괄적용
sido_x_scaled = scaler.fit_transform(sido_x)
#sigungu_x_scaled = scaler.fit_transform(sigungu_x)

# %%
#scale결과 array를 데이터프레임으로 만들고 열이름을 새로 지정해준다.
#sigungu_x_scaled = pd.DataFrame(data = sigungu_x_scaled)
#sigungu_x_scaled.columns = sigungu_x.columns
sido_x_scaled = pd.DataFrame(data = sido_x_scaled)
sido_x_scaled.columns = sido_x.columns

# %%
sido_x_scaled.shape#, sigungu_x_scaled.shape
# Out:
# (17, 163)

# %% [markdown]
# ## Feature Importance

# %%
#importance
rf = RandomForestClassifier(n_estimators=10).fit(sido_x_scaled, sido.화재)
feature_importance_rf = pd.DataFrame(data=np.c_[sido_x_scaled.columns.values,rf.feature_importances_],
                                     columns=['feature','FI'])
#feature_importance_rf.sort_values('FI',ascending=False,inplace=True)
feature_importance_rf
# Out:
#                    feature          FI
# 0                    1인가구수           0
# 1                5대범죄 발생건수           0
# 2                가스공급설비 면적           0
# 3                 가스사고발생건수   0.0377778
# 4              가해(타살) 사망자수   0.0303571
# 5                 감염병 발생건수           0
# 6                 감염병 사망자수           0
# 7                 건강보험급여실적           0
# 8                  건설업 업체수           0
# 9                 건설업 종사자수           0
# 10                 건축용지 면적           0
# 11                   경찰관서수           0
# 12                   고령인구수           0
# 13          공공질서 및 안전예산 비율           0
# 14                공무원수(정원)           0
# 15                 공업지역 면적           0
# 16                  교통문화지수           0
# 17               교통사고 발생건수           0
# 18               교통사고 부상자수           0
# 19               교통사고 사망자수           0
# 20          교통사고사망자수(고속도로)           0
# 21                    구거면적           0
# 22                 구거면적 비율           0
# 23                  구급발생건수           0
# 24               구조구급 발생건수   0.0623571
# 25                 구조구급대원수           0
# 26                  구조발생건수           0
# 27                  기초수급자수           0
# 28           기초수급자수(65세이상)   0.0485714
# 29            노인 교통사고 부상자수           0
# 30            노인 교통사고 사망자수           0
# 31                 다중이용업소수           0
# 32           대기배출시설 점검 위반율           0
# 33                   대기오염도           0
# 34                    도로면적           0
# 35                 도로면적 비율           0
# 36                    도로연장           0
# 37                 도시지역 면적           0
# 38              도시지역 면적 비율           0
# 39                   독거노인수           0
# 40            무면허교통사고 발생건수           0
# 41                 방재지구 면적           0
# 42                 방화지구 면적   0.0514286
# 43         범죄발생건수(강간.강제추행)           0
# 44              범죄발생건수(강도)           0
# 45              범죄발생건수(도박)           0
# 46              범죄발생건수(마약)   0.0220779
# 47              범죄발생건수(방화)           0
# 48              범죄발생건수(살인)           0
# 49           범죄발생건수(약취.유인)           0
# 50              범죄발생건수(절도)           0
# 51              범죄발생건수(폭력)           0
# 52                     병상수           0
# 53     보건업 및 사회복지서비스업 종사자수           0
# 54                  보행사상자수   0.0514286
# 55           보행자전용·우선도로 면적           0
# 56           보행자전용·우선도로 연장           0
# 57                     빈집수   0.0473098
# 58                    산림면적           0
# 59                 산림면적 비율           0
# 60                  산불발생건수           0
# 61                  산불피해면적           0
# 62                 상업지역 면적           0
# 63                성폭력 발생건수           0
# 64                   순이동자수           0
# 65                 스트레스인지율           0
# 66                    시가화율           0
# 67               시군구내 전입자수           0
# 68               시군구외 전입자수           0
# 69                시도간 전입자수           0
# 70           시도내-시군구간 전입자수           0
# 71                식중독 발생건수   0.0220779
# 72                식중독 발생자수           0
# 73           식품제조가공업체 위반건수           0
# 74                     실업률           0
# 75                   야간인구수           0
# 76        양호한 주관적 건강수준 인지율           0
# 77           어린이 교통사고 부상자수   0.0188889
# 78           어린이 교통사고 사망자수           0
# 79           어린이 식품안전보호구역수           0
# 80                 어린이 아토피           0
# 81                  어린이 천식           0
# 82                열공급설비 면적           0
# 83                    외국인수   0.0485714
# 84                  우울감경험률           0
# 85            운전시 안전벨트 착용률           0
# 86                   월간음주율           0
# 87                위험물 제조소수         0.1
# 88          유류저장 및 송유설비 면적           0
# 89                    유지면적           0
# 90                 유지면적 비율   0.0263095
# 91                   유치원생수           0
# 92           음식점 및 주점업 업체수           0
# 93          음식점 및 주점업 종사자수           0
# 94             음주교통사고 발생건수           0
# 95             의료기관수(요양기관)           0
# 96           의료보장 공.교 가입자수           0
# 97           의료보장 근로자 사업장수           0
# 98               의료보장 사업장수           0
# 99                   의료보험료           0
# 100                   의료인력   0.0622222
# 101                   이혼건수           0
# 102                   익사자수           0
# 103                   인구밀도           0
# 104            인플루엔자 예방접종률   0.0433333
# 105              일반주거지역 면적           0
# 106                  임야 면적           0
# 107                자동차등록대수           0
# 108                자살 사망자수           0
# 109       자연재해 발생건수(10년평균)           0
# 110              자연재해 사망자수           0
# 111       자연재해 사망자수(10년평균)           0
# 112        자연재해 피해액(10년평균)   0.0306122
# 113       자연재해 피해자수(10년평균)           0
# 114              자원봉사자 등록률           0
# 115                   장애인수           0
# 116              재난심리지원센터수           0
# 117                  재난약자수   0.0418462
# 118                  재정자립도           0
# 119                  재정자주도           0
# 120               전기화재발생건수           0
# 121                   제방면적   0.0182143
# 122                제방면적 비율           0
# 123                제조업 업체수           0
# 124               제조업 종사자수           0
# 125                 주간인구지수   0.0327857
# 126                주거지역 면적           0
# 127                 주민등록인구           0
# 128          주민등록인구(14세이하)           0
# 129          주민등록인구(60세이상)           0
# 130             주민등록인구(여자)   0.0696429
# 131            주민등록인구(청소년)    0.033966
# 132              지역별 부도업체수           0
# 133            지역안전도(관리능력)           0
# 134              지역안전도(등급)           0
# 135            지역안전도(방재성능)           0
# 136            지역안전도(위험환경)           0
# 137              지역안전도(점수)           0
# 138  질병이환 및 사망외인으로 인한 사망자수           0
# 139     창고 및 운송관련 서비스업 업체수           0
# 140                  초등학생수           0
# 141                 총 사업체수           0
# 142                  총전입자수           0
# 143                추락 사망자수           0
# 144                특수의료장비수           0
# 145              폐기물 처리시설수           0
# 146          폐수배출시설 점검 위반율           0
# 147                   하천면적           0
# 148                하천면적 비율           0
# 149                   하천연장           0
# 150              학교수(고등학교)           0
# 151               학교수(중학교)           0
# 152              학교수(초등학교)           0
# 153                행정구역 면적           0
# 154                 혼인귀화자수           0
# 155                화재 발생건수           0
# 156                화재 사망자수       0.049
# 157                 화재 피해액           0
# 158                화재 피해자수           0
# 159                 화재구조실적  0.00726496
# 160              화재사망자(환산)           0
# 161               화재피해 경감액           0
# 162                황사 발생건수    0.043956

# %% [markdown]
# # RFE

# %%
#importance
from sklearn.feature_selection import RFE
select = RFE(RandomForestClassifier(n_estimators=10),n_features_to_select =20)
select.fit(sido_x_scaled, sido.화재)
feature_importance_rfe = pd.DataFrame(data=np.c_[sido_x_scaled.columns.values,select.get_support()],
                                     columns=['feature','RFE'])
#feature_importance_rfe.sort_values('RFE',ascending=False,inplace=True)
feature_importance_rfe
# Out:
#                    feature    RFE
# 0                    1인가구수  False
# 1                5대범죄 발생건수  False
# 2                가스공급설비 면적  False
# 3                 가스사고발생건수  False
# 4              가해(타살) 사망자수  False
# 5                 감염병 발생건수  False
# 6                 감염병 사망자수  False
# 7                 건강보험급여실적  False
# 8                  건설업 업체수  False
# 9                 건설업 종사자수  False
# 10                 건축용지 면적  False
# 11                   경찰관서수  False
# 12                   고령인구수  False
# 13          공공질서 및 안전예산 비율  False
# 14                공무원수(정원)  False
# 15                 공업지역 면적  False
# 16                  교통문화지수  False
# 17               교통사고 발생건수  False
# 18               교통사고 부상자수  False
# 19               교통사고 사망자수  False
# 20          교통사고사망자수(고속도로)  False
# 21                    구거면적  False
# 22                 구거면적 비율  False
# 23                  구급발생건수  False
# 24               구조구급 발생건수  False
# 25                 구조구급대원수  False
# 26                  구조발생건수  False
# 27                  기초수급자수  False
# 28           기초수급자수(65세이상)  False
# 29            노인 교통사고 부상자수  False
# 30            노인 교통사고 사망자수  False
# 31                 다중이용업소수  False
# 32           대기배출시설 점검 위반율  False
# 33                   대기오염도  False
# 34                    도로면적  False
# 35                 도로면적 비율  False
# 36                    도로연장  False
# 37                 도시지역 면적  False
# 38              도시지역 면적 비율  False
# 39                   독거노인수  False
# 40            무면허교통사고 발생건수  False
# 41                 방재지구 면적  False
# 42                 방화지구 면적  False
# 43         범죄발생건수(강간.강제추행)  False
# 44              범죄발생건수(강도)  False
# 45              범죄발생건수(도박)  False
# 46              범죄발생건수(마약)  False
# 47              범죄발생건수(방화)  False
# 48              범죄발생건수(살인)  False
# 49           범죄발생건수(약취.유인)  False
# 50              범죄발생건수(절도)  False
# 51              범죄발생건수(폭력)  False
# 52                     병상수  False
# 53     보건업 및 사회복지서비스업 종사자수  False
# 54                  보행사상자수  False
# 55           보행자전용·우선도로 면적  False
# 56           보행자전용·우선도로 연장  False
# 57                     빈집수  False
# 58                    산림면적  False
# 59                 산림면적 비율  False
# 60                  산불발생건수  False
# 61                  산불피해면적  False
# 62                 상업지역 면적  False
# 63                성폭력 발생건수  False
# 64                   순이동자수  False
# 65                 스트레스인지율  False
# 66                    시가화율  False
# 67               시군구내 전입자수  False
# 68               시군구외 전입자수  False
# 69                시도간 전입자수  False
# 70           시도내-시군구간 전입자수  False
# 71                식중독 발생건수  False
# 72                식중독 발생자수  False
# 73           식품제조가공업체 위반건수  False
# 74                     실업률  False
# 75                   야간인구수  False
# 76        양호한 주관적 건강수준 인지율  False
# 77           어린이 교통사고 부상자수  False
# 78           어린이 교통사고 사망자수  False
# 79           어린이 식품안전보호구역수  False
# 80                 어린이 아토피  False
# 81                  어린이 천식  False
# 82                열공급설비 면적  False
# 83                    외국인수  False
# 84                  우울감경험률  False
# 85            운전시 안전벨트 착용률  False
# 86                   월간음주율  False
# 87                위험물 제조소수  False
# 88          유류저장 및 송유설비 면적  False
# 89                    유지면적  False
# 90                 유지면적 비율  False
# 91                   유치원생수  False
# 92           음식점 및 주점업 업체수  False
# 93          음식점 및 주점업 종사자수  False
# 94             음주교통사고 발생건수  False
# 95             의료기관수(요양기관)  False
# 96           의료보장 공.교 가입자수  False
# 97           의료보장 근로자 사업장수  False
# 98               의료보장 사업장수  False
# 99                   의료보험료  False
# 100                   의료인력  False
# 101                   이혼건수  False
# 102                   익사자수  False
# 103                   인구밀도  False
# 104            인플루엔자 예방접종률  False
# 105              일반주거지역 면적  False
# 106                  임야 면적  False
# 107                자동차등록대수  False
# 108                자살 사망자수  False
# 109       자연재해 발생건수(10년평균)  False
# 110              자연재해 사망자수  False
# 111       자연재해 사망자수(10년평균)  False
# 112        자연재해 피해액(10년평균)  False
# 113       자연재해 피해자수(10년평균)  False
# 114              자원봉사자 등록률  False
# 115                   장애인수  False
# 116              재난심리지원센터수  False
# 117                  재난약자수  False
# 118                  재정자립도  False
# 119                  재정자주도  False
# 120               전기화재발생건수   True
# 121                   제방면적  False
# 122                제방면적 비율   True
# 123                제조업 업체수   True
# 124               제조업 종사자수   True
# 125                 주간인구지수  False
# 126                주거지역 면적  False
# 127                 주민등록인구  False
# 128          주민등록인구(14세이하)  False
# 129          주민등록인구(60세이상)  False
# 130             주민등록인구(여자)   True
# 131            주민등록인구(청소년)  False
# 132              지역별 부도업체수  False
# 133            지역안전도(관리능력)  False
# 134              지역안전도(등급)  False
# 135            지역안전도(방재성능)  False
# 136            지역안전도(위험환경)  False
# 137              지역안전도(점수)  False
# 138  질병이환 및 사망외인으로 인한 사망자수   True
# 139     창고 및 운송관련 서비스업 업체수  False
# 140                  초등학생수  False
# 141                 총 사업체수   True
# 142                  총전입자수   True
# 143                추락 사망자수   True
# 144                특수의료장비수   True
# 145              폐기물 처리시설수   True
# 146          폐수배출시설 점검 위반율   True
# 147                   하천면적   True
# 148                하천면적 비율   True
# 149                   하천연장   True
# 150              학교수(고등학교)   True
# 151               학교수(중학교)   True
# 152              학교수(초등학교)  False
# 153                행정구역 면적  False
# 154                 혼인귀화자수   True
# 155                화재 발생건수   True
# 156                화재 사망자수   True
# 157                 화재 피해액  False
# 158                화재 피해자수  False
# 159                 화재구조실적  False
# 160              화재사망자(환산)  False
# 161               화재피해 경감액  False
# 162                황사 발생건수  False

# %% [markdown]
# # Logistic Regression
# regression coefficient

# %%
from sklearn.linear_model import LinearRegression
model_fire = LinearRegression().fit(sido_x_scaled, sido.화재)

# %%
#coefficient
feature_importance_lr = pd.DataFrame(np.c_[sido_x_scaled.columns.values,model_fire.coef_.ravel()],
                                    columns=['feature','lr'])
#feature_importance_lr.sort_values('lr', ascending=False, inplace=True)
feature_importance_lr
# Out:
#                    feature          lr
# 0                    1인가구수  -0.0773959
# 1                5대범죄 발생건수  -0.0195941
# 2                가스공급설비 면적  -0.0584446
# 3                 가스사고발생건수   -0.119737
# 4              가해(타살) 사망자수   0.0345255
# 5                 감염병 발생건수    0.082391
# 6                 감염병 사망자수  -0.0548124
# 7                 건강보험급여실적   0.0688554
# 8                  건설업 업체수   0.0185448
# 9                 건설업 종사자수   0.0560857
# 10                 건축용지 면적  0.00743036
# 11                   경찰관서수   -0.076968
# 12                   고령인구수 -0.00165689
# 13          공공질서 및 안전예산 비율  -0.0626012
# 14                공무원수(정원)   0.0206104
# 15                 공업지역 면적     0.13323
# 16                  교통문화지수  -0.0369738
# 17               교통사고 발생건수   0.0966486
# 18               교통사고 부상자수   0.0928122
# 19               교통사고 사망자수   0.0414846
# 20          교통사고사망자수(고속도로)   -0.156596
# 21                    구거면적  -0.0129422
# 22                 구거면적 비율  -0.0158849
# 23                  구급발생건수  -0.0462149
# 24               구조구급 발생건수  -0.0111664
# 25                 구조구급대원수   0.0191682
# 26                  구조발생건수    0.061695
# 27                  기초수급자수   -0.029259
# 28           기초수급자수(65세이상)  -0.0459587
# 29            노인 교통사고 부상자수   0.0941884
# 30            노인 교통사고 사망자수  -0.0277158
# 31                 다중이용업소수   0.0231094
# 32           대기배출시설 점검 위반율  -0.0295357
# 33                   대기오염도   -0.185677
# 34                    도로면적   -0.016518
# 35                 도로면적 비율  -0.0244037
# 36                    도로연장  -0.0178874
# 37                 도시지역 면적  -0.0265955
# 38              도시지역 면적 비율  -0.0363147
# 39                   독거노인수  -0.0445279
# 40            무면허교통사고 발생건수   0.0420896
# 41                 방재지구 면적  -0.0155639
# 42                 방화지구 면적    0.047469
# 43         범죄발생건수(강간.강제추행)   0.0533028
# 44              범죄발생건수(강도)  -0.0436467
# 45              범죄발생건수(도박)   0.0160578
# 46              범죄발생건수(마약)   0.0933674
# 47              범죄발생건수(방화)  -0.0455755
# 48              범죄발생건수(살인)  0.00657941
# 49           범죄발생건수(약취.유인)    0.123923
# 50              범죄발생건수(절도)   -0.055112
# 51              범죄발생건수(폭력)  0.00704207
# 52                     병상수   -0.120504
# 53     보건업 및 사회복지서비스업 종사자수  -0.0762297
# 54                  보행사상자수   0.0108032
# 55           보행자전용·우선도로 면적   0.0164571
# 56           보행자전용·우선도로 연장   0.0474372
# 57                     빈집수   0.0573621
# 58                    산림면적   0.0243728
# 59                 산림면적 비율   0.0143655
# 60                  산불발생건수   0.0169845
# 61                  산불피해면적  -0.0249598
# 62                 상업지역 면적   0.0046989
# 63                성폭력 발생건수    0.108191
# 64                   순이동자수   0.0137311
# 65                 스트레스인지율  -0.0997435
# 66                    시가화율  0.00425032
# 67               시군구내 전입자수   -0.126746
# 68               시군구외 전입자수   0.0438978
# 69                시도간 전입자수   0.0214028
# 70           시도내-시군구간 전입자수   0.0875126
# 71                식중독 발생건수   0.0433025
# 72                식중독 발생자수  0.00638665
# 73           식품제조가공업체 위반건수   0.0253661
# 74                     실업률     0.13039
# 75                   야간인구수  -0.0273497
# 76        양호한 주관적 건강수준 인지율    0.185086
# 77           어린이 교통사고 부상자수   0.0916979
# 78           어린이 교통사고 사망자수   0.0882744
# 79           어린이 식품안전보호구역수    0.093377
# 80                 어린이 아토피   -0.037324
# 81                  어린이 천식    0.119729
# 82                열공급설비 면적  -0.0363163
# 83                    외국인수  -0.0846026
# 84                  우울감경험률  -0.0405534
# 85            운전시 안전벨트 착용률   0.0542294
# 86                   월간음주율   0.0597445
# 87                위험물 제조소수    0.123326
# 88          유류저장 및 송유설비 면적  -0.0330381
# 89                    유지면적  -0.0251903
# 90                 유지면적 비율  -0.0152971
# 91                   유치원생수  -0.0421193
# 92           음식점 및 주점업 업체수  0.00398957
# 93          음식점 및 주점업 종사자수 -0.00334599
# 94             음주교통사고 발생건수   0.0420896
# 95             의료기관수(요양기관)   0.0226994
# 96           의료보장 공.교 가입자수   0.0371046
# 97           의료보장 근로자 사업장수  -0.0916905
# 98               의료보장 사업장수  -0.0915168
# 99                   의료보험료     0.05433
# 100                   의료인력   0.0214797
# 101                   이혼건수  -0.0211852
# 102                   익사자수  -0.0903026
# 103                   인구밀도  -0.0318427
# 104            인플루엔자 예방접종률    0.202478
# 105              일반주거지역 면적  -0.0247984
# 106                  임야 면적   0.0187306
# 107                자동차등록대수  -0.0201223
# 108                자살 사망자수   0.0545551
# 109       자연재해 발생건수(10년평균)    -0.14009
# 110              자연재해 사망자수  -0.0458297
# 111       자연재해 사망자수(10년평균)  -0.0629153
# 112        자연재해 피해액(10년평균)  -0.0742954
# 113       자연재해 피해자수(10년평균)  -0.0593506
# 114              자원봉사자 등록률 -0.00245245
# 115                   장애인수  -0.0204452
# 116              재난심리지원센터수   0.0219476
# 117                  재난약자수  -0.0296693
# 118                  재정자립도   0.0130758
# 119                  재정자주도   0.0420836
# 120               전기화재발생건수    0.108736
# 121                   제방면적   0.0777137
# 122                제방면적 비율   0.0699925
# 123                제조업 업체수 -0.00707135
# 124               제조업 종사자수   0.0285946
# 125                 주간인구지수  -0.0534493
# 126                주거지역 면적  -0.0139419
# 127                 주민등록인구  -0.0484856
# 128          주민등록인구(14세이하)  -0.0054503
# 129          주민등록인구(60세이상)  -0.0100839
# 130             주민등록인구(여자)   -0.119126
# 131            주민등록인구(청소년)   0.0342387
# 132              지역별 부도업체수  -0.0307312
# 133            지역안전도(관리능력)    0.227567
# 134              지역안전도(등급)  -0.0552839
# 135            지역안전도(방재성능)   -0.194786
# 136            지역안전도(위험환경)   -0.157785
# 137              지역안전도(점수)    0.148537
# 138  질병이환 및 사망외인으로 인한 사망자수   0.0290745
# 139     창고 및 운송관련 서비스업 업체수  -0.0481039
# 140                  초등학생수 -0.00702253
# 141                 총 사업체수 -0.00214461
# 142                  총전입자수   0.0189486
# 143                추락 사망자수    0.137503
# 144                특수의료장비수   0.0536849
# 145              폐기물 처리시설수  0.00848639
# 146          폐수배출시설 점검 위반율  -0.0386164
# 147                   하천면적   0.0170843
# 148                하천면적 비율   0.0287238
# 149                   하천연장  -0.0608359
# 150              학교수(고등학교)  -0.0447856
# 151               학교수(중학교)  -0.0178131
# 152              학교수(초등학교)  0.00788251
# 153                행정구역 면적  -0.0994671
# 154                 혼인귀화자수  -0.0464281
# 155                화재 발생건수    0.193108
# 156                화재 사망자수    0.238133
# 157                 화재 피해액  -0.0467765
# 158                화재 피해자수    0.108001
# 159                 화재구조실적   0.0214214
# 160              화재사망자(환산)     0.22249
# 161               화재피해 경감액  -0.0864151
# 162                황사 발생건수  -0.0824813

# %% [markdown]
# # SelectKBest

# %%
from sklearn.feature_selection import SelectKBest, chi2
k_best = SelectKBest(chi2, k=20)
k_best.fit(sido_x_scaled, sido.화재)
feature_importance_k = pd.DataFrame(np.c_[sido_x_scaled.columns.values,k_best.get_support()],
                                    columns=['feature','Kbest'])
#feature_importance_k.sort_values('Kbest', ascending=False, inplace=True)

feature_importance_k
# Out:
#                    feature  Kbest
# 0                    1인가구수  False
# 1                5대범죄 발생건수  False
# 2                가스공급설비 면적  False
# 3                 가스사고발생건수  False
# 4              가해(타살) 사망자수  False
# 5                 감염병 발생건수  False
# 6                 감염병 사망자수  False
# 7                 건강보험급여실적  False
# 8                  건설업 업체수  False
# 9                 건설업 종사자수  False
# 10                 건축용지 면적  False
# 11                   경찰관서수  False
# 12                   고령인구수  False
# 13          공공질서 및 안전예산 비율  False
# 14                공무원수(정원)  False
# 15                 공업지역 면적  False
# 16                  교통문화지수  False
# 17               교통사고 발생건수  False
# 18               교통사고 부상자수  False
# 19               교통사고 사망자수  False
# 20          교통사고사망자수(고속도로)  False
# 21                    구거면적  False
# 22                 구거면적 비율  False
# 23                  구급발생건수  False
# 24               구조구급 발생건수  False
# 25                 구조구급대원수  False
# 26                  구조발생건수  False
# 27                  기초수급자수  False
# 28           기초수급자수(65세이상)  False
# 29            노인 교통사고 부상자수  False
# 30            노인 교통사고 사망자수  False
# 31                 다중이용업소수  False
# 32           대기배출시설 점검 위반율  False
# 33                   대기오염도  False
# 34                    도로면적  False
# 35                 도로면적 비율  False
# 36                    도로연장  False
# 37                 도시지역 면적   True
# 38              도시지역 면적 비율   True
# 39                   독거노인수  False
# 40            무면허교통사고 발생건수  False
# 41                 방재지구 면적  False
# 42                 방화지구 면적  False
# 43         범죄발생건수(강간.강제추행)  False
# 44              범죄발생건수(강도)  False
# 45              범죄발생건수(도박)  False
# 46              범죄발생건수(마약)  False
# 47              범죄발생건수(방화)  False
# 48              범죄발생건수(살인)  False
# 49           범죄발생건수(약취.유인)  False
# 50              범죄발생건수(절도)  False
# 51              범죄발생건수(폭력)  False
# 52                     병상수  False
# 53     보건업 및 사회복지서비스업 종사자수  False
# 54                  보행사상자수  False
# 55           보행자전용·우선도로 면적   True
# 56           보행자전용·우선도로 연장   True
# 57                     빈집수   True
# 58                    산림면적  False
# 59                 산림면적 비율  False
# 60                  산불발생건수  False
# 61                  산불피해면적  False
# 62                 상업지역 면적  False
# 63                성폭력 발생건수  False
# 64                   순이동자수   True
# 65                 스트레스인지율  False
# 66                    시가화율  False
# 67               시군구내 전입자수  False
# 68               시군구외 전입자수   True
# 69                시도간 전입자수   True
# 70           시도내-시군구간 전입자수  False
# 71                식중독 발생건수  False
# 72                식중독 발생자수  False
# 73           식품제조가공업체 위반건수  False
# 74                     실업률  False
# 75                   야간인구수  False
# 76        양호한 주관적 건강수준 인지율  False
# 77           어린이 교통사고 부상자수  False
# 78           어린이 교통사고 사망자수   True
# 79           어린이 식품안전보호구역수  False
# 80                 어린이 아토피  False
# 81                  어린이 천식  False
# 82                열공급설비 면적  False
# 83                    외국인수  False
# 84                  우울감경험률  False
# 85            운전시 안전벨트 착용률  False
# 86                   월간음주율  False
# 87                위험물 제조소수   True
# 88          유류저장 및 송유설비 면적  False
# 89                    유지면적  False
# 90                 유지면적 비율  False
# 91                   유치원생수  False
# 92           음식점 및 주점업 업체수  False
# 93          음식점 및 주점업 종사자수  False
# 94             음주교통사고 발생건수  False
# 95             의료기관수(요양기관)  False
# 96           의료보장 공.교 가입자수   True
# 97           의료보장 근로자 사업장수  False
# 98               의료보장 사업장수  False
# 99                   의료보험료  False
# 100                   의료인력  False
# 101                   이혼건수  False
# 102                   익사자수  False
# 103                   인구밀도  False
# 104            인플루엔자 예방접종률  False
# 105              일반주거지역 면적  False
# 106                  임야 면적  False
# 107                자동차등록대수  False
# 108                자살 사망자수  False
# 109       자연재해 발생건수(10년평균)   True
# 110              자연재해 사망자수  False
# 111       자연재해 사망자수(10년평균)   True
# 112        자연재해 피해액(10년평균)  False
# 113       자연재해 피해자수(10년평균)  False
# 114              자원봉사자 등록률  False
# 115                   장애인수  False
# 116              재난심리지원센터수   True
# 117                  재난약자수  False
# 118                  재정자립도  False
# 119                  재정자주도  False
# 120               전기화재발생건수   True
# 121                   제방면적  False
# 122                제방면적 비율  False
# 123                제조업 업체수  False
# 124               제조업 종사자수  False
# 125                 주간인구지수  False
# 126                주거지역 면적  False
# 127                 주민등록인구  False
# 128          주민등록인구(14세이하)  False
# 129          주민등록인구(60세이상)  False
# 130             주민등록인구(여자)  False
# 131            주민등록인구(청소년)  False
# 132              지역별 부도업체수  False
# 133            지역안전도(관리능력)  False
# 134              지역안전도(등급)  False
# 135            지역안전도(방재성능)  False
# 136            지역안전도(위험환경)  False
# 137              지역안전도(점수)  False
# 138  질병이환 및 사망외인으로 인한 사망자수  False
# 139     창고 및 운송관련 서비스업 업체수  False
# 140                  초등학생수  False
# 141                 총 사업체수  False
# 142                  총전입자수  False
# 143                추락 사망자수   True
# 144                특수의료장비수  False
# 145              폐기물 처리시설수   True
# 146          폐수배출시설 점검 위반율  False
# 147                   하천면적  False
# 148                하천면적 비율  False
# 149                   하천연장  False
# 150              학교수(고등학교)  False
# 151               학교수(중학교)  False
# 152              학교수(초등학교)  False
# 153                행정구역 면적  False
# 154                 혼인귀화자수  False
# 155                화재 발생건수   True
# 156                화재 사망자수   True
# 157                 화재 피해액  False
# 158                화재 피해자수  False
# 159                 화재구조실적  False
# 160              화재사망자(환산)   True
# 161               화재피해 경감액  False
# 162                황사 발생건수  False

# %% [markdown]
# # corr

# %%
sumdf = pd.concat([sido_x_scaled, sido.화재], axis=1)
corr_df = pd.DataFrame(sumdf.corr(method='pearson')['화재']).reset_index()
corr_df.sort_values(by='화재', ascending=False).drop(163, axis=0)
corr_df.rename(columns={'화재':'corr','index':'feature'},inplace=True)
corr_df
# Out:
#                    feature      corr
# 0                    1인가구수 -0.035845
# 1                5대범죄 발생건수 -0.347625
# 2                가스공급설비 면적 -0.208023
# 3                 가스사고발생건수 -0.008319
# 4              가해(타살) 사망자수  0.247751
# 5                 감염병 발생건수  0.070277
# 6                 감염병 사망자수  0.267476
# 7                 건강보험급여실적  0.246755
# 8                  건설업 업체수  0.375513
# 9                 건설업 종사자수  0.317350
# 10                 건축용지 면적 -0.273333
# 11                   경찰관서수  0.233750
# 12                   고령인구수  0.197347
# 13          공공질서 및 안전예산 비율  0.100757
# 14                공무원수(정원)  0.176858
# 15                 공업지역 면적 -0.007841
# 16                  교통문화지수 -0.195563
# 17               교통사고 발생건수 -0.145364
# 18               교통사고 부상자수 -0.036113
# 19               교통사고 사망자수  0.368102
# 20          교통사고사망자수(고속도로) -0.083289
# 21                    구거면적  0.108173
# 22                 구거면적 비율  0.108180
# 23                  구급발생건수 -0.078231
# 24               구조구급 발생건수 -0.046161
# 25                 구조구급대원수  0.280066
# 26                  구조발생건수  0.388458
# 27                  기초수급자수 -0.079786
# 28           기초수급자수(65세이상)  0.046815
# 29            노인 교통사고 부상자수  0.226949
# 30            노인 교통사고 사망자수  0.206537
# 31                 다중이용업소수 -0.155925
# 32           대기배출시설 점검 위반율 -0.253370
# 33                   대기오염도 -0.375281
# 34                    도로면적 -0.366008
# 35                 도로면적 비율 -0.366030
# 36                    도로연장 -0.257033
# 37                 도시지역 면적 -0.366410
# 38              도시지역 면적 비율 -0.366407
# 39                   독거노인수  0.159178
# 40            무면허교통사고 발생건수  0.000190
# 41                 방재지구 면적 -0.023682
# 42                 방화지구 면적 -0.238683
# 43         범죄발생건수(강간.강제추행) -0.291304
# 44              범죄발생건수(강도) -0.406703
# 45              범죄발생건수(도박) -0.023460
# 46              범죄발생건수(마약) -0.035020
# 47              범죄발생건수(방화) -0.172302
# 48              범죄발생건수(살인) -0.135837
# 49           범죄발생건수(약취.유인)  0.078693
# 50              범죄발생건수(절도) -0.345192
# 51              범죄발생건수(폭력) -0.257070
# 52                     병상수 -0.162039
# 53     보건업 및 사회복지서비스업 종사자수 -0.319170
# 54                  보행사상자수 -0.250848
# 55           보행자전용·우선도로 면적  0.339517
# 56           보행자전용·우선도로 연장  0.441935
# 57                     빈집수  0.412073
# 58                    산림면적  0.259049
# 59                 산림면적 비율  0.259052
# 60                  산불발생건수 -0.147392
# 61                  산불피해면적  0.256245
# 62                 상업지역 면적 -0.242619
# 63                성폭력 발생건수 -0.248563
# 64                   순이동자수  0.334261
# 65                 스트레스인지율 -0.351877
# 66                    시가화율 -0.225492
# 67               시군구내 전입자수 -0.071356
# 68               시군구외 전입자수  0.316493
# 69                시도간 전입자수  0.351246
# 70           시도내-시군구간 전입자수 -0.251640
# 71                식중독 발생건수  0.224221
# 72                식중독 발생자수  0.006388
# 73           식품제조가공업체 위반건수  0.288809
# 74                     실업률 -0.019041
# 75                   야간인구수 -0.350460
# 76        양호한 주관적 건강수준 인지율  0.346401
# 77           어린이 교통사고 부상자수  0.041310
# 78           어린이 교통사고 사망자수  0.496330
# 79           어린이 식품안전보호구역수  0.435810
# 80                 어린이 아토피 -0.082572
# 81                  어린이 천식  0.158727
# 82                열공급설비 면적 -0.008657
# 83                    외국인수 -0.138032
# 84                  우울감경험률 -0.160411
# 85            운전시 안전벨트 착용률 -0.110648
# 86                   월간음주율 -0.160829
# 87                위험물 제조소수  0.586647
# 88          유류저장 및 송유설비 면적 -0.184059
# 89                    유지면적  0.014894
# 90                 유지면적 비율  0.015021
# 91                   유치원생수 -0.146501
# 92           음식점 및 주점업 업체수  0.194533
# 93          음식점 및 주점업 종사자수 -0.005880
# 94             음주교통사고 발생건수  0.000190
# 95             의료기관수(요양기관) -0.189641
# 96           의료보장 공.교 가입자수  0.395683
# 97           의료보장 근로자 사업장수 -0.464243
# 98               의료보장 사업장수 -0.469800
# 99                   의료보험료 -0.080815
# 100                   의료인력 -0.035171
# 101                   이혼건수 -0.137112
# 102                   익사자수 -0.004141
# 103                   인구밀도 -0.264007
# 104            인플루엔자 예방접종률  0.482848
# 105              일반주거지역 면적 -0.258247
# 106                  임야 면적  0.331084
# 107                자동차등록대수  0.081625
# 108                자살 사망자수  0.092872
# 109       자연재해 발생건수(10년평균) -0.405251
# 110              자연재해 사망자수 -0.184637
# 111       자연재해 사망자수(10년평균) -0.288999
# 112        자연재해 피해액(10년평균) -0.240314
# 113       자연재해 피해자수(10년평균) -0.245891
# 114              자원봉사자 등록률 -0.208036
# 115                   장애인수  0.235267
# 116              재난심리지원센터수  0.349923
# 117                  재난약자수  0.178027
# 118                  재정자립도 -0.175566
# 119                  재정자주도 -0.098182
# 120               전기화재발생건수  0.468529
# 121                   제방면적  0.011345
# 122                제방면적 비율  0.010744
# 123                제조업 업체수 -0.116022
# 124               제조업 종사자수  0.249799
# 125                 주간인구지수  0.242335
# 126                주거지역 면적 -0.247354
# 127                 주민등록인구 -0.344176
# 128          주민등록인구(14세이하)  0.109378
# 129          주민등록인구(60세이상)  0.181175
# 130             주민등록인구(여자) -0.455361
# 131            주민등록인구(청소년) -0.100090
# 132              지역별 부도업체수 -0.396810
# 133            지역안전도(관리능력)  0.268057
# 134              지역안전도(등급) -0.103597
# 135            지역안전도(방재성능) -0.133863
# 136            지역안전도(위험환경) -0.079423
# 137              지역안전도(점수)  0.256489
# 138  질병이환 및 사망외인으로 인한 사망자수  0.341563
# 139     창고 및 운송관련 서비스업 업체수 -0.215251
# 140                  초등학생수 -0.142848
# 141                 총 사업체수 -0.067882
# 142                  총전입자수  0.298027
# 143                추락 사망자수  0.539047
# 144                특수의료장비수 -0.157131
# 145              폐기물 처리시설수  0.442094
# 146          폐수배출시설 점검 위반율 -0.285917
# 147                   하천면적 -0.071548
# 148                하천면적 비율 -0.071618
# 149                   하천연장 -0.284525
# 150              학교수(고등학교)  0.295159
# 151               학교수(중학교)  0.320893
# 152              학교수(초등학교)  0.338017
# 153                행정구역 면적  0.089276
# 154                 혼인귀화자수 -0.003541
# 155                화재 발생건수  0.607419
# 156                화재 사망자수  0.582798
# 157                 화재 피해액  0.017453
# 158                화재 피해자수  0.431779
# 159                 화재구조실적 -0.214017
# 160              화재사망자(환산)  0.638885
# 161               화재피해 경감액 -0.277228
# 162                황사 발생건수 -0.326735
# 163                     화재  1.000000

# %% [markdown]
# # 합치기

# %%
df=feature_importance_lr.merge(corr_df)
#df.sort_values('Kbest', ascending=False, inplace=True)
df.lr
# Out:
# 0      -0.0773959
# 1      -0.0195941
# 2      -0.0584446
# 3       -0.119737
# 4       0.0345255
# 5        0.082391
# 6      -0.0548124
# 7       0.0688554
# 8       0.0185448
# 9       0.0560857
# 10     0.00743036
# 11      -0.076968
# 12    -0.00165689
# 13     -0.0626012
# 14      0.0206104
# 15        0.13323
# 16     -0.0369738
# 17      0.0966486
# 18      0.0928122
# 19      0.0414846
# 20      -0.156596
# 21     -0.0129422
# 22     -0.0158849
# 23     -0.0462149
# 24     -0.0111664
# 25      0.0191682
# 26       0.061695
# 27      -0.029259
# 28     -0.0459587
# 29      0.0941884
# 30     -0.0277158
# 31      0.0231094
# 32     -0.0295357
# 33      -0.185677
# 34      -0.016518
# 35     -0.0244037
# 36     -0.0178874
# 37     -0.0265955
# 38     -0.0363147
# 39     -0.0445279
# 40      0.0420896
# 41     -0.0155639
# 42       0.047469
# 43      0.0533028
# 44     -0.0436467
# 45      0.0160578
# 46      0.0933674
# 47     -0.0455755
# 48     0.00657941
# 49       0.123923
# 50      -0.055112
# 51     0.00704207
# 52      -0.120504
# 53     -0.0762297
# 54      0.0108032
# 55      0.0164571
# 56      0.0474372
# 57      0.0573621
# 58      0.0243728
# 59      0.0143655
# 60      0.0169845
# 61     -0.0249598
# 62      0.0046989
# 63       0.108191
# 64      0.0137311
# 65     -0.0997435
# 66     0.00425032
# 67      -0.126746
# 68      0.0438978
# 69      0.0214028
# 70      0.0875126
# 71      0.0433025
# 72     0.00638665
# 73      0.0253661
# 74        0.13039
# 75     -0.0273497
# 76       0.185086
# 77      0.0916979
# 78      0.0882744
# 79       0.093377
# 80      -0.037324
# 81       0.119729
# 82     -0.0363163
# 83     -0.0846026
# 84     -0.0405534
# 85      0.0542294
# 86      0.0597445
# 87       0.123326
# 88     -0.0330381
# 89     -0.0251903
# 90     -0.0152971
# 91     -0.0421193
# 92     0.00398957
# 93    -0.00334599
# 94      0.0420896
# 95      0.0226994
# 96      0.0371046
# 97     -0.0916905
# 98     -0.0915168
# 99        0.05433
# 100     0.0214797
# 101    -0.0211852
# 102    -0.0903026
# 103    -0.0318427
# 104      0.202478
# 105    -0.0247984
# 106     0.0187306
# 107    -0.0201223
# 108     0.0545551
# 109      -0.14009
# 110    -0.0458297
# 111    -0.0629153
# 112    -0.0742954
# 113    -0.0593506
# 114   -0.00245245
# 115    -0.0204452
# 116     0.0219476
# 117    -0.0296693
# 118     0.0130758
# 119     0.0420836
# 120      0.108736
# 121     0.0777137
# 122     0.0699925
# 123   -0.00707135
# 124     0.0285946
# 125    -0.0534493
# 126    -0.0139419
# 127    -0.0484856
# 128    -0.0054503
# 129    -0.0100839
# 130     -0.119126
# 131     0.0342387
# 132    -0.0307312
# 133      0.227567
# 134    -0.0552839
# 135     -0.194786
# 136     -0.157785
# 137      0.148537
# 138     0.0290745
# 139    -0.0481039
# 140   -0.00702253
# 141   -0.00214461
# 142     0.0189486
# 143      0.137503
# 144     0.0536849
# 145    0.00848639
# 146    -0.0386164
# 147     0.0170843
# 148     0.0287238
# 149    -0.0608359
# 150    -0.0447856
# 151    -0.0178131
# 152    0.00788251
# 153    -0.0994671
# 154    -0.0464281
# 155      0.193108
# 156      0.238133
# 157    -0.0467765
# 158      0.108001
# 159     0.0214214
# 160       0.22249
# 161    -0.0864151
# 162    -0.0824813
# Name: lr, dtype: object

# %%
df=feature_importance_rf.merge(feature_importance_rfe).merge(feature_importance_k)
#df.sort_values(['Kbest'], ascending=False, inplace=True)
df
df.loc[(df.RFE==True)|(df.Kbest==True)].sort_values(['RFE'],ascending=False)
# Out:
#                    feature         FI    RFE  Kbest
# 124               제조업 종사자수          0   True  False
# 141                 총 사업체수          0   True  False
# 130             주민등록인구(여자)  0.0696429   True  False
# 142                  총전입자수          0   True  False
# 123                제조업 업체수          0   True  False
# 122                제방면적 비율          0   True  False
# 120               전기화재발생건수          0   True   True
# 143                추락 사망자수          0   True   True
# 144                특수의료장비수          0   True  False
# 145              폐기물 처리시설수          0   True   True
# 146          폐수배출시설 점검 위반율          0   True  False
# 147                   하천면적          0   True  False
# 148                하천면적 비율          0   True  False
# 149                   하천연장          0   True  False
# 150              학교수(고등학교)          0   True  False
# 151               학교수(중학교)          0   True  False
# 154                 혼인귀화자수          0   True  False
# 155                화재 발생건수          0   True   True
# 156                화재 사망자수      0.049   True   True
# 138  질병이환 및 사망외인으로 인한 사망자수          0   True  False
# 37                 도시지역 면적          0  False   True
# 38              도시지역 면적 비율          0  False   True
# 116              재난심리지원센터수          0  False   True
# 111       자연재해 사망자수(10년평균)          0  False   True
# 109       자연재해 발생건수(10년평균)          0  False   True
# 96           의료보장 공.교 가입자수          0  False   True
# 87                위험물 제조소수        0.1  False   True
# 78           어린이 교통사고 사망자수          0  False   True
# 69                시도간 전입자수          0  False   True
# 68               시군구외 전입자수          0  False   True
# 64                   순이동자수          0  False   True
# 57                     빈집수  0.0473098  False   True
# 56           보행자전용·우선도로 연장          0  False   True
# 55           보행자전용·우선도로 면적          0  False   True
# 160              화재사망자(환산)          0  False   True

# %%
# sns.pairplot(sumdf, hue='화재')
# plt.savefig(path+'corr2.png',transparent=True)

# %%
# plt.figure(figsize=(100,100))
# sns.heatmap(data = sido_x_scaled.corr(method='pearson'),
#             annot=True, fmt = '.2f', linewidths=.1, cmap='Reds')
# plt.savefig(path+'corr.png',transparent=True)
