# %%
#소년범죄는 134건이라 유의미하지 않을꺼라고 생각해서 안함
import pandas as pd

# %% [markdown]
# # 데이터 임포트

# %%
범죄웹크롤링 = 'C:/Users/COM/Desktop/범죄웹크롤링/'
keywords = ['범죄','이혼','가정폭력','우범']
df = pd.read_csv(범죄웹크롤링+'범죄_1.csv', encoding='cp949')
df.head(1)
# Out:
#          뉴스 식별자        일자   언론사                     기고자                  제목  \
# 0  1.600501e+06  20150331  무등일보  영광=정병환기자  zmd@chol.com  영광경찰, 개인택시지부와 업무협약
#
#   통합 분류1     통합 분류2          통합 분류3 사건/사고 분류1 사건/사고 분류2 사건/사고 분류3   인물   위치  \
# 0  지역>경기   사회>사건_사고   IT_과학>IT_과학일반       NaN       NaN       NaN  한창훈  영광군
#
#           기관                                                키워드  \
# 0  영광경찰서,경찰서  영광경찰,개인택시지부,업무협약,영광경찰서,서장,한창훈,영광군지부,개인택시,영광군,지...
#
#                                                 특성추출  \
# 0  개인택시,피해자,업무협약,한창훈,영광,경찰서,피해자들,수사기관,개인택시지부,그동안,...
#
#                                                   본문  \
# 0  영광경찰서(서장 한창훈)는 지난 27일 개인택시 영광군지부와 강력범죄 피해자를 보호...
#
#                                                  URL 분석제외 여부
# 0  http://www.honam.co.kr/news_view.php?n=463678&...     NaN

# %% [markdown]
# # 크롤링데이터 모양확인

# %%
#뉴스크롤링 열
df.columns
# Out:
# Index(['뉴스 식별자', '일자', '언론사', '기고자', '제목', '통합 분류1', '통합 분류2', '통합 분류3',
#        '사건/사고 분류1', '사건/사고 분류2', '사건/사고 분류3', '인물', '위치', '기관', '키워드', '특성추출',
#        '본문', 'URL', '분석제외 여부'],
#       dtype='object')

# %% [markdown]
# 어떤값들이 들어있는지 다 확인한 후 응용가능한 열을 뽑아내었다.
# 응용가능한열:
# 제목
# 통합분류(필터링할 수 있을것)
# 사건사고분류
# 키워드
# 특성추출
# 본문

# %%
#사건사고분류열에 속한 모든 종류
사건사고분류리스트=[]
#각각의 열의 중복집단제거
for i in range(3):
    row = '사건/사고 분류'+f'{i+1}'
    사건사고분류리스트 = 사건사고분류리스트+list(set(df[row].dropna().values))
#공백을 지우고
for i in range(len(사건사고분류리스트)):
    사건사고분류리스트[i] = 사건사고분류리스트[i].strip()
#다시 중복집단제거
사건사고분류 = set(사건사고분류리스트)
사건사고분류
# Out:
# {'범죄>기업범죄>거래제한',
#  '범죄>기업범죄>계약위반',
#  '범죄>기업범죄>내부자거래',
#  '범죄>기업범죄>반독점범죄',
#  '범죄>기업범죄>횡령',
#  '범죄>범죄일반>마약',
#  '범죄>범죄일반>방화',
#  '범죄>범죄일반>사기',
#  '범죄>범죄일반>살인',
#  '범죄>범죄일반>유괴/납치',
#  '범죄>범죄일반>절도',
#  '범죄>범죄일반>폭행',
#  '범죄>성범죄>성매매',
#  '범죄>성범죄>성추행',
#  '범죄>성범죄>성폭행',
#  '범죄>성범죄>성희롱',
#  '범죄>성범죄>음란물',
#  '범죄>정치>뇌물수수',
#  '사고>교통사고>노상사고',
#  '사고>교통사고>철도사고',
#  '사고>교통사고>항공사고',
#  '사고>교통사고>해상사고',
#  '사고>산업사고>붕괴',
#  '사고>산업사고>원자력사고',
#  '사고>산업사고>폭발',
#  '사고>산업사고>화재',
#  '사회>사회갈등>대량학살',
#  '사회>사회갈등>반란_혁명_폭동',
#  '사회>사회갈등>시위',
#  '사회>사회갈등>전쟁',
#  '사회>사회갈등>테러행위',
#  '사회>사회문제>노예',
#  '사회>사회문제>미성년범죄',
#  '사회>사회문제>자살',
#  '사회>사회문제>중독',
#  '사회>사회문제>학대',
#  '재해>자연재해>가뭄',
#  '재해>자연재해>눈사태_산사태',
#  '재해>자연재해>지진',
#  '재해>자연재해>태풍',
#  '재해>자연재해>홍수',
#  '재해>자연재해>화산폭발'}

# %%
#통합분류열에 속한 모든 종류
통합분류리스트=[]
#각각의 열의 중복집단제거
for i in range(3):
    row = '통합 분류'+f'{i+1}'
    통합분류리스트 = 통합분류리스트+list(set(df[row].dropna().values))
#공백을 지우고
for i in range(len(통합분류리스트)):
    통합분류리스트[i] = 통합분류리스트[i].strip()
#다시 중복집단제거
통합분류 = set(통합분류리스트)
통합분류
# Out:
# {'IT_과학>IT_과학일반',
#  'IT_과학>과학',
#  'IT_과학>모바일',
#  'IT_과학>보안',
#  'IT_과학>인터넷_SNS',
#  'IT_과학>콘텐츠',
#  '경제>경제일반',
#  '경제>국제경제',
#  '경제>금융_재테크',
#  '경제>무역',
#  '경제>반도체',
#  '경제>부동산',
#  '경제>산업_기업',
#  '경제>서비스_쇼핑',
#  '경제>외환',
#  '경제>유통',
#  '경제>자동차',
#  '경제>자원',
#  '경제>증권_증시',
#  '경제>취업_창업',
#  '국제>국제일반',
#  '국제>러시아',
#  '국제>미국_북미',
#  '국제>아시아',
#  '국제>유럽_EU',
#  '국제>일본',
#  '국제>중국',
#  '국제>중남미',
#  '국제>중동_아프리카',
#  '문화>문화일반',
#  '문화>미술_건축',
#  '문화>방송_연예',
#  '문화>생활',
#  '문화>영화',
#  '문화>요리_여행',
#  '문화>음악',
#  '문화>전시_공연',
#  '문화>종교',
#  '문화>출판',
#  '문화>학술_문화재',
#  '미분류',
#  '사회>교육_시험',
#  '사회>날씨',
#  '사회>노동_복지',
#  '사회>미디어',
#  '사회>사건_사고',
#  '사회>사회일반',
#  '사회>여성',
#  '사회>의료_건강',
#  '사회>장애인',
#  '사회>환경',
#  '스포츠>농구_배구',
#  '스포츠>스포츠일반',
#  '스포츠>야구',
#  '스포츠>올림픽_아시안게임',
#  '스포츠>월드컵',
#  '스포츠>축구',
#  '스포츠>축구>국가대표팀',
#  '스포츠>축구>한국프로축구',
#  '스포츠>축구>해외축구',
#  '정치>국회_정당',
#  '정치>북한',
#  '정치>선거',
#  '정치>외교',
#  '정치>정치일반',
#  '정치>청와대',
#  '정치>행정_자치',
#  '지역>강원',
#  '지역>경기',
#  '지역>경남',
#  '지역>경북',
#  '지역>광주',
#  '지역>대구',
#  '지역>대전',
#  '지역>부산',
#  '지역>울산',
#  '지역>전남',
#  '지역>전북',
#  '지역>제주',
#  '지역>지역일반',
#  '지역>충남',
#  '지역>충북'}

# %% [markdown]
# # 실제크롤링내용 확인

# %%
# 분류의 세트를 확인해볼 필요

# %% [markdown]
# # 크롤링데이터 로드

# %%
범죄웹크롤링 = 'C:/Users/COM/Desktop/범죄웹크롤링/'
keywords = ['범죄','이혼','가정폭력','우범']
범죄1=pd.read_csv(범죄웹크롤링+'범죄_1.csv', encoding='cp949')
범죄2=pd.read_csv(범죄웹크롤링+'범죄_2.csv', encoding='cp949')
범죄3=pd.read_csv(범죄웹크롤링+'범죄_3.csv', encoding='cp949')
범죄4=pd.read_csv(범죄웹크롤링+'범죄_4.csv', encoding='cp949')
범죄5=pd.read_csv(범죄웹크롤링+'범죄_5.csv', encoding='cp949')
# 범죄뉴스 = pd.concat([df1,df2,df3,df4,df5])
범죄뉴스 = pd.concat([범죄1,범죄2,범죄3,범죄4,범죄5])
범죄뉴스.reset_index(inplace=True)
범죄뉴스.index
# Out:
# RangeIndex(start=0, stop=77630, step=1)

# %%
df1=pd.read_csv(범죄웹크롤링+'이혼_1.csv', encoding='cp949')
df2=pd.read_csv(범죄웹크롤링+'이혼_2.csv', encoding='cp949')
이혼뉴스 = pd.concat([df1,df2])
이혼뉴스.reset_index(inplace=True)
이혼뉴스.shape
# Out:
# (26775, 20)

# %%
가정폭력뉴스=pd.read_csv(범죄웹크롤링+'가정폭력.csv', encoding='cp949')
가정폭력뉴스.shape
# Out:
# (2984, 19)

# %%
우범뉴스=pd.read_csv(범죄웹크롤링+'우범.csv', encoding='cp949')
우범뉴스.shape
# Out:
# (1283, 19)

# %% [markdown]
# # 필터링메뉴(함수)

# %%
#주어진데이터프레임에 대해 분류의 집합을 구해주는 함수들
def 사건사고분류(df):
    사건사고분류리스트=[]
    for i in range(3):
        row = '사건/사고 분류'+f'{i+1}'
        사건사고분류리스트 = 사건사고분류리스트+list(set(df[row].dropna().values))
    for i in range(len(사건사고분류리스트)):
        사건사고분류리스트[i] = 사건사고분류리스트[i].strip()
    사건사고분류 = set(사건사고분류리스트)
    return 사건사고분류

def 통합분류(df):
    통합분류리스트=[]
    for i in range(3):
        row = '통합 분류'+f'{i+1}'
        통합분류리스트 = 통합분류리스트+list(set(df[row].dropna().values))
    for i in range(len(통합분류리스트)):
        통합분류리스트[i] = 통합분류리스트[i].strip()
    통합분류 = set(통합분류리스트)
    return 통합분류

# %%
사건사고분류(범죄뉴스)
# Out:
# {'범죄>기업범죄>거래제한',
#  '범죄>기업범죄>계약위반',
#  '범죄>기업범죄>내부자거래',
#  '범죄>기업범죄>반독점범죄',
#  '범죄>기업범죄>횡령',
#  '범죄>범죄일반>마약',
#  '범죄>범죄일반>방화',
#  '범죄>범죄일반>사기',
#  '범죄>범죄일반>살인',
#  '범죄>범죄일반>유괴/납치',
#  '범죄>범죄일반>절도',
#  '범죄>범죄일반>폭행',
#  '범죄>성범죄>성매매',
#  '범죄>성범죄>성추행',
#  '범죄>성범죄>성폭행',
#  '범죄>성범죄>성희롱',
#  '범죄>성범죄>음란물',
#  '범죄>정치>뇌물수수',
#  '사고>교통사고>노상사고',
#  '사고>교통사고>우주사고',
#  '사고>교통사고>철도사고',
#  '사고>교통사고>항공사고',
#  '사고>교통사고>해상사고',
#  '사고>산업사고>붕괴',
#  '사고>산업사고>원자력사고',
#  '사고>산업사고>폭발',
#  '사고>산업사고>화재',
#  '사회>사회갈등>대량학살',
#  '사회>사회갈등>반란_혁명_폭동',
#  '사회>사회갈등>시위',
#  '사회>사회갈등>전쟁',
#  '사회>사회갈등>테러행위',
#  '사회>사회문제>노예',
#  '사회>사회문제>미성년범죄',
#  '사회>사회문제>자살',
#  '사회>사회문제>중독',
#  '사회>사회문제>학대',
#  '재해>자연재해>가뭄',
#  '재해>자연재해>눈사태_산사태',
#  '재해>자연재해>지진',
#  '재해>자연재해>태풍',
#  '재해>자연재해>폭염',
#  '재해>자연재해>홍수',
#  '재해>자연재해>화산폭발'}

# %%
통합분류(범죄뉴스)
# Out:
# {'IT_과학>IT_과학일반',
#  'IT_과학>과학',
#  'IT_과학>모바일',
#  'IT_과학>보안',
#  'IT_과학>인터넷_SNS',
#  'IT_과학>콘텐츠',
#  '경제>경제일반',
#  '경제>국제경제',
#  '경제>금융_재테크',
#  '경제>무역',
#  '경제>반도체',
#  '경제>부동산',
#  '경제>산업_기업',
#  '경제>서비스_쇼핑',
#  '경제>외환',
#  '경제>유통',
#  '경제>자동차',
#  '경제>자원',
#  '경제>증권_증시',
#  '경제>취업_창업',
#  '국제>국제일반',
#  '국제>러시아',
#  '국제>미국_북미',
#  '국제>아시아',
#  '국제>유럽_EU',
#  '국제>일본',
#  '국제>중국',
#  '국제>중남미',
#  '국제>중동_아프리카',
#  '문화>문화일반',
#  '문화>미술_건축',
#  '문화>방송_연예',
#  '문화>생활',
#  '문화>영화',
#  '문화>요리_여행',
#  '문화>음악',
#  '문화>전시_공연',
#  '문화>종교',
#  '문화>출판',
#  '문화>학술_문화재',
#  '미분류',
#  '사회>교육_시험',
#  '사회>날씨',
#  '사회>노동_복지',
#  '사회>미디어',
#  '사회>사건_사고',
#  '사회>사회일반',
#  '사회>여성',
#  '사회>의료_건강',
#  '사회>장애인',
#  '사회>환경',
#  '스포츠>골프',
#  '스포츠>농구_배구',
#  '스포츠>스포츠일반',
#  '스포츠>야구',
#  '스포츠>야구>메이저리그',
#  '스포츠>야구>일본프로야구',
#  '스포츠>야구>한국프로야구',
#  '스포츠>올림픽_아시안게임',
#  '스포츠>월드컵',
#  '스포츠>축구',
#  '스포츠>축구>국가대표팀',
#  '스포츠>축구>한국프로축구',
#  '스포츠>축구>해외축구',
#  '정치>국회_정당',
#  '정치>북한',
#  '정치>선거',
#  '정치>외교',
#  '정치>정치일반',
#  '정치>청와대',
#  '정치>행정_자치',
#  '지역>강원',
#  '지역>경기',
#  '지역>경남',
#  '지역>경북',
#  '지역>광주',
#  '지역>대구',
#  '지역>대전',
#  '지역>부산',
#  '지역>울산',
#  '지역>전남',
#  '지역>전북',
#  '지역>제주',
#  '지역>지역일반',
#  '지역>충남',
#  '지역>충북'}

# %% [markdown]
# # 빈도분석 및 워드클라우드

# %%
import pandas as pd
import nltk
from konlpy.tag import Komoran
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
komoran = Komoran()
plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
# Out:
# C:\Anaconda3\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %% [markdown]
# ## - 제목으로 빈도분석

# %%
#제목으로 빈도분석할때 계속 추가시키려고
nouns=[]

# %%
#파일을 읽어온다.
lst = 범죄1.제목.tolist() #전체기사를 리스트로, 리스트의 한 요소는 한 기사
#전체제목을 리스트로, 리스트의 한 요소는 한 제목

# %%
len(lst),len(list(set(lst)))
# Out:
# (18188, 17077)

# %%
#나중에 본문일때 문단별로 쪼개주는 과정 필요
# spl_lst = []
# for i in nse_lst:
#     for a in i.split('\n\n'):
#         spl_lst.append(a)

# %%
lst
# Out:
# ['영광경찰, 개인택시지부와 업무협약',
#  '독자투고- CPTED를 통한 범죄예방',
#  '기고- 에코(Echo)도시 조성에 한걸음씩 발걸음을 보태자',
#  "야후재팬 '사생활 침해 정보' 지운다[수정][수정]",
#  '삼성 LG, 글로벌 주도권 확보 위한 대승적 결단[수정]',
#  '울산경찰, 폭력배 강도 절도 집중단속',
#  '종교시설서 어린 남매 성추행한 20대 실형',
#  '일광공영 이규태 회장 기소',
#  '박수범 대전 대덕구청장, 자율방범대원과 손잡고 안전 도시 만든다',
#  '4 29 재 보선, 유권자 선택이 중요하다',
#  '국토부, 주차장 CCTV 조명 설치 의무화',
#  '[e-웃음 바이러스]',
#  "삼성 LG 법적분쟁 종결 합의 불구 '세탁기 파손' 공방 불가피",
#  '만우절 장난전화 처벌...적발시 벌금-구류 처분',
#  '연쇄살인범 아동성폭력범 등 출소 후에도 최장 7년간 사회 격리',
#  '무기중개상 이규태 회장, 500억원대 방산장비 납품 사기혐의로 기소',
#  '성범죄 교수 교사 교단서 영구 추방',
#  '성범죄 교수 교사 교단서 영구 추방',
#  '금감원 직원 사칭 보이스피싱 유도 문자 주의',
#  '흉악범 최장 7년 격리 보호수용법 국무회의 의결',
#  '불황에 사기 횡령범 전락하는 변호사들',
#  '‘박원순법’ 시행 6개월, 핫라인 신고 5배 증가',
#  '금감원 직원 사칭 보이스피싱 유도 문자 주의',
#  '성범죄로 형 확정받은 교사나 교수, 교단에서 영구퇴출키로',
#  '오바마, 오는 7월 취임후 처음 아버지의 나라 케냐 방문',
#  '檢, 자원외교 비리 관련 경남기업 한모 부사장 소환조사',
#  '“아베, 잔혹한 日과거사 인정해야”',
#  "검찰, '장경욱 김인숙 변호사 징계' 법무부에 직접 신청할 듯",
#  '15억원 상품권 사기 간 큰 40대 주부 붙잡혀',
#  '만우절 장난전화 처벌...아무 생각없이 했다간 형사처벌',
#  '‘창원 감계 힐스테이트 2차’, 지역 랜드마크로 우뚝',
#  "불혹 앞두고 사시 붙은 변호사, 법률시장 불황 속에 '사기꾼' 전락",
#  '양대노총 제조부문 "노사정위 일방합의 강요하고 강행처리시 총파업"',
#  "필리핀 관광위장 '황제성매매'한 교수 등 56명 검거",
#  '“ILO도 ‘北 해외노동자 인권침해’ 검토”',
#  "아버지가 용돈 줄이자 동네형과 짜고 '가짜 도둑'된 아들",
#  '가이드가 밤엔 성매매 파트너로 필리핀 ‘황제관광’무더기 적발',
#  '연쇄 살인 등 흉악범 형종료후 최장 7년간 사회격리안 국무회의 통과',
#  '만우절 장난전화 처벌, 식당 불평부터 불효자식 체포까지? "허위신고는 안돼요!"',
#  '이규태 농간에 ‘엉터리 EWTS’ 두배 주고 사',
#  '[WT논평] Destruction in civilization’s cradle',
#  '만우절, 장난전화 적발되면 공무집행방해죄 처벌',
#  "천안 외국인도움센터 '무용지물'",
#  '가정폭력 사기 혼자 아파하지 마세요',
#  '가짜 검찰청 사이트에 카카오톡 악성앱까지 ',
#  '출근하듯 입원 35억 타낸 보험사기단',
#  "'거리뷰'로 범행 장소 사전 답사 교묘한 절도범 검거",
#  "[뉴스플러스] 남한 드라마 인기에 北 '비상' 단속도 무용지물",
#  '도 넘은 폭행에도 주변 무관심 곳곳에서 개탄의 목소리',
#  '아파트 오피스텔, 범죄자 침입 못하게 짓는다 설계 기준 마련',
#  "재범 우려 강력범죄자, 최장 7년 격리 '보호수용법' 통과",
#  '내달부터 아파트 오피스텔, 범죄자 침입 못하게 해야',
#  '도 넘은 폭행에도 무관심 곳곳에서 개탄의 목소리',
#  '도 넘은 폭행에도 무관심 곳곳에서 개탄의 목소리',
#  '만우절 장난전화, “동물 죽어있는데 치워달라” 어떤 처벌 가능할까?',
#  '[TV 하이라이트]',
#  '만우절 장난전화, “만원만 입금해 달라” 황당 신고 여전..처벌은?',
#  '만우절 장난전화, 어떤 장난전화 하길래..',
#  '전국 ‘집창촌’ 24곳 폐쇄 박차 수익 몰수 추징 강화',
#  '거기 학생, 집으로 돌아가세요',
#  "포스코건설 비자금 '한 갈래' 더..檢, 20억 추가 포착",
#  '만우절 장난전화 처벌, 경찰청 “경찰력 낭비 않도록 동참 부탁”',
#  "'박원순法' 그 후.. 서울시 공무원 비리 확 줄었다",
#  '군산경찰서, 업무 유공자 6명에 표창 수여',
#  '전주지역 성매매 집결지 폐쇄 속도낸다',
#  "'전자전 훈련장비 1100억 사기 혐의' 이규태 회장 등 재판에",
#  '檢, 포스코건설 추가 비자금 정황 포착',
#  "경찰청, 만우절 앞두고 '장난전화' 자제 요청",
#  "합수단, '500억원대 군납사기' 이규태 회장 구속 기소",
#  '대포통장 판매 30대 벌금 500만원',
#  '장애 청소년과 성관계 촬영 20대 징역형',
#  '500가구 이상 주택에 주차장 CCTV 의무화',
#  '무관심에 병드는 아이들',
#  '아파트 단지 나무, 창문에서 1.5m 거리 두고 심어야 한다',
#  '옥천경찰서, 체감치안 향상 맞춤형 캠페인(사진)',
#  '알기쉬운 부동산 - 부동산 투자와 투기',
#  '경찰 금융기관 3대악성사기 공동대응 협약',
#  '충북기협, 2015년 1분기 이달의 기자상 선정',
#  '[여의나루] 빅데이터가 열어줄 새 세상',
#  '"금융감독원 직원 박선영을 주의하세요"',
#  '강진경찰-개인택시조합 MOU',
#  '‘性범죄’ 교육공무원 교수, 교단서 퇴출',
#  '‘흉악범 최장 7년 격리’ 보호수용법안 국무회의 의결',
#  '‘흉악범 최장 7년 격리’ 보호수용법안 국무회의 의결',
#  '<세상 만사-나라 안>40대여성 투자미끼 24억 사기',
#  '낮엔 가이드 밤엔 섹스파트너 100만원대 ‘황제 性매매’',
#  '낮엔 가이드 밤엔 섹스파트너 100만원대 ‘황제 性매매’',
#  '산업스파이, 北 무기거래國에 포탄기술도 빼돌려',
#  '<포럼>노동시장 改革 성공 위한 3가지 提言',
#  '멕시코, 불법 무기류 1500만 정 유통...멕시코 성인 남자 3명당 한명꼴 총기 소지하는 셈',
#  '울진경찰서-지역아동센터 범죄예방 협약',
#  '이근용 대구대학교 대외협력부총장, 대구 장애우권익연구소서 특강',
#  '檢, 조희팔 은닉재산 420억 ‘추징 보전’ 행보 피해자에 상환 지체될 수도',
#  '불법체류외국인과 피해자 보호 원년',
#  '경산경찰서 합동순찰 “외국인 밀집지역 범죄 예방해요”',
#  '검찰 조희팔 은닉자금 추징보전 논란',
#  '영천경찰서, 첫 청소년 선도심사위 개최',
#  '보성경찰, 범죄피해자 교통편의 제공 협약',
#  '양치기소년과 만우절',
#  'LGU+, 가입자 서명 도용으로 검찰 고발 당해',
#  '국내 최대라이벌 삼성ㆍLG간 법적 분쟁 일지는?',
#  '원창묵 원주시장 항소심 ‘벌금 90만원’ 선고',
#  '상습 거짓신고 피의자 잇따라 검거',
#  '교통사고 피해자 지원제도 아시나요?',
#  '교통사고 피해자 지원제도 아시나요?',
#  "경미한 범죄 '시민심사위원'이 판단",
#  "경미한 범죄 '시민심사위원'이 판단",
#  '진해 한 고등학교 앞에서 음란행위 하던 30대 체포',
#  '구미署-고용노동부 구미지청 범죄피해자 취업지원 업무협약',
#  '조희팔 자금 420억, 檢 피해자 처리 이견',
#  '[채널] 한국에 온 외국인 근로자, 공존의 조건은?',
#  '"칠곡 성장 이끄는데 생활불편은 모른 척" 석적읍 홀대 분통',
#  '인구 쑥쑥 석적읍 "기반 시설은 미흡"',
#  '경기 경찰청, 국악 마술 수화로 톡톡 튀는 범죄예방 홍보 인기',
#  '“10달러 유통 때 2~3달러 검은돈 변신?”美 특수부대, 업무 영역 확대',
#  '“모략소굴 남조선 둥지틀면 무자비한 징벌”北,인권현장사무소 서울 개설 반발',
#  '아동 성폭력범 최장 7년간 사회 격리...연쇄살인범 등 흉악범도',
#  '“성추행 영예군인,영웅일까 조폭일까?”北,영예군인 범죄 골머리',
#  '[여의도포럼-김창준] 싱가포르의 곤장제도',
#  '살인범 등 이중처벌 보호수용법 국무회의 통과',
#  '"\'널 기다리며\' 촬영 끝났어요. 하반기 개봉 기대하세요" 심은경 주연 범죄 스릴러',
#  '인터넷서 모의총기 판매 40대 벌금형',
#  '美 코리아코커스 의장 “아베, 과거 잔혹행위 분명히 인정하라”',
#  '가출 여중생 살인사건 용의자 “기절시키려고만 했다”',
#  '“통나무에 치마만 둘러도 여자로 본다?”北, 군인 성범죄 천국',
#  '전자발찌 차고도 3차례나 성범죄 20대 검거',
#  '“투자하면 돈 벌어주겠다” 24억 사기 40대 주부의 말로',
#  '“직원 통해 상품권 싸게 사주겠다” 아직도 이런 말에 속으시나요?',
#  '미 국무부 “위안부는 성을 목적으로 한 여성 매매 행위”',
#  '“김정은,외국인 상대 여대생 성매매 총살 지시” 나선지구 여대생 가격 50~80 달러',
#  '佛 상원, 성매수자 처벌 법안 부결 하원서 최종 결정',
#  '이규태 회장, 방사청 속여 1100억원 예산 가로채 기소',
#  '“자살하게 해드려요?” 살벌한 몸캠 협박 음성파일 유포 파문',
#  '필리핀 원정 성매매 ‘황제관광’ 56명 검거',
#  '아이템베이-더치트, 온라인 사기범죄 예방 업무협약 체결',
#  "내달부터 '범죄예방 건축기준' 시행",
#  '경찰, 만우절 장난전화 엄중 처벌한다 업무 방해하는 민원신고도 자제 당부',
#  "'성매매 가출소녀 살인사건' 용의자 범행자백 과거 20대女에게도",
#  "[분석+] 삼성-LG 극적 화해 왜? 검찰 법원 '판단' 남아",
#  '검찰, 동국제강 수상한 해외송금 추적',
#  '법무부 법사랑 부산동지역연합회 하형주 동아대 교수 홍보대사 위촉',
#  "아동음란물 처벌, 미국선 '무기형' 우린 '벌금'",
#  "필리핀 '황제 관광' 알선 브로커 성매수자 56명 무더기 검거",
#  '성범죄로 형 확정된 교사 교수, 교단서 영구 추방',
#  '[이준영의 세상 속으로] 두 섬나라의 다른 처신',
#  '필리핀서 ‘원정 성매매’ 한 대학교수들 황제관광 일당 검거',
#  '필리핀 원정 성매매 황제관광 55명 수년후...경찰에 ‘딱’ 망신살',
#  "'고양이에게 생선 맡긴 꼴 '",
#  "'공직선거법 위반' 원주시장 2심서 벌금 90만원..직위유지",
#  '어른들의 검은 욕망, 결국 목숨까지 ',
#  '괴산경찰서, 민 경 유기적 협력체계 구축 간담회',
#  '보은경찰서 농협군지부장 등 협약체결',
#  '충북 이달의 기자상 선정',
#  '아파트 등 건축물 범죄예방 설계해야 허가 받는다',
#  '성범죄로 형 확정된 교사 교수, 교단서 영구 추방',
#  '흉악범 출소후 최장 7년 격리',
#  "시민단체, '고객정보 도용 유출 의혹' LGU+ 고발",
#  "오바마, 취임후 처음 '아버지의 나라' 케냐 간다",
#  "만우절, 112 허위 신고시 최대 벌금 '1,000만원'",
#  '구글 보안전문가가 알려준 ‘손쉬운 온라인 보안 5계명’',
#  '[전국 패트롤] 서울시 박원순법 시행 6개월만에 공무원 비리 86% 감소 外',
#  '흉악범 형기 마쳐도 격리, 보호수용법안 국무회의 통과',
#  "서울시 '박원순법 그후' 공무원범죄 86% 급감 비리신고 384건",
#  "흉악범 최대 7년 수용 '보호수용법안' 통과",
#  "'아프리카 난민' 오해 편견? 억울함 벗은 사연",
#  '만우절, 112로 장난전화했다간 \'큰코\'....경찰 "엄정 대응" 엄포',
#  '[간추린 단신] 내일부터 음식점 PC방서 흡연 시 과태료 외',
#  '만우절 장난전화, 공무집행방해죄 처벌',
#  '대전지검 범죄피해자지원센터 3가정에 1224만원 지원',
#  '안전한 세종시 완성위한 세종경찰의 노력',
#  "'형기 끝난 흉악범 최대 7년간 격리' 법안..국무회의 통과",
#  '무인빨래방 골라턴 30대 좀도둑 덜미',
#  '흉악범 최장 7년 보호수용으로 격리 이중처벌 논란 예상',
#  '울산경찰, 폭력배 강도 절도 집중단속',
#  '종교시설서 어린 남매 성추행한 20대 실형',
#  '필리핀 성매매 ‘황제관광’ 56명 검거 교수 포함',
#  '성범죄 형 확정 교사 교수, 교단서 영구 추방',
#  '보이스피싱 조직 등 친 ‘2차사기’ 극성',
#  '피해자 코디네이터를 아시나요',
#  '지능형 범죄 ‘조폭과의 전쟁’',
#  '깨진 유리창과 콩나물시루',
#  '수사망 피해 ‘페이스오프’ 꼬리 밟힌 아파트털이범',
#  '검찰, 동국제강 비자금 총수일가 유입 증거 확보 주력',
#  '검찰, 동국제강 비자금 의혹 증거 확보 주력',
#  '[내일시론] 권력자 인사전횡이 부패의 뿌리',
#  '112에 전화해 "식당음식이 맛없다"',
#  '순천시, 순천경찰서 기관단체간 업무협약 체결',
#  '국토부, 범죄예방 건축기준 고시 조명 CCTV 등 설치 의무화',
#  '김문수 “유엔 북한인권 현장사무소, 동북아 전체에 밝은 등불 될 것”',
#  "윌스기념병원 박춘근 병원장, 지역사회발전 유공 '표창'",
#  '개 훔쳐놓고, 보상 전단지 보고 연락했다 덜미',
#  "'흉악범 출소 후 7년 격리' 보호수용법안 국무회의 통과",
#  '도둑 단골 침입로 아파트 배관들 외벽 속에 설치',
#  "'박원순법' 6개월 공무원 비리 크게 줄었다",
#  "필리핀 성매매 '황제 관광' 교수ㆍ회계사 등 55명 입건",
#  '美 코리아코커스 의장 “아베, 과거 잔혹행위 분명히 인정하라”',
#  '만우절 핑계 112 허위전화 장난 아닌 처벌, 아십니까',
#  '성매매 여중생 살해 피의자, 3주전 유사 범행',
#  '잊혀질 권리 보호에 나선 야후 재팬 성적 동영상 집단 괴롭힘 피해 등 삭제',
#  '[특별기고] 제주4ㆍ3의 아픔과 치유 그리고 상생',
#  "'야누스 얼굴' 상속자와 뒷골목 사내 넘나들다",
#  "교수 회계사도 못 견딘 유혹 필리핀 '황제 관광' 뭐길래?",
#  '하드보일드 뜻, 폭력적 주제를 냉철하게 한국형 하드보일드는 ‘복수는 나의 것’',
#  '[범죄의 재구성] 바람 쐬고 온다더니 ‘롤리타의 제물’된 14세 소녀',
#  '포스코건설 비자금 20억 추가 포착',
#  '500가구 이상 공공주택 `범죄 사각지대` 없앤다',
#  '"보험업계 자율ㆍ책임 검사체계 구축"',
#  '“상품권 싸게 구입해 줄게” 40대 주부 15억 꿀꺽',
#  '애완견 훔친 50대 남성 이유가 “외로워서”',
#  '4월부터 아파트 등 범죄예방 기준 따라야 허가',
#  "박원순法 시행 반년 신고 10배 늘고 공무원 범죄 '급감'",
#  "경기경찰, '애완견 절도 주의보'",
#  '500가구 이상 공동주택, 학교, 오피스텔 등 건축물 범죄예방 기준 맞아야 허가난다',
#  '툭하면 입원 보험사기 무더기 검거 ‘수법’ 경악',
#  "경기도 '애완견' 도난사고 잇따라",
#  "CGV아트하우스, 4월 '라이브톡'으로 '모스트 바이어런트' 선정",
#  '친구와 짜고 아버지 사기친 10대, 호된(?) 훈육으로 덜미',
#  '친구와 짜고 아버지 사기친 10대, 호된(?) 훈육으로 덜미',
#  '새벽 시간대 무인 빨래방만 노린 절도범',
#  '벌금 내려고 또다시 차량 턴 대학생',
#  '훔친 노트북 추적 빈집털이범 덜미',
#  "'흉악범 최대 7년 추가 격리' 법안 통과 이중처벌 논란",
#  '"범죄발생시 피해자 즉시 지원"',
#  '하드보일드 뜻, 감정 드러내지 않는 냉담한 태도 영화 소재로도 활용?',
#  '국정원, 첨단무기 핵심기술 등 유출사고 지난해 최다 적발',
#  '[범죄수사의 세계] 흉포해지는 인질극, 대한민국도 안전지대 아니다',
#  '원주시장 항소심서 벌금 90만원 공직 유지',
#  "CGV아트하우스 4월 라이브톡'모스트 바이어런트' 선정",
#  '\'봉천동 10대女살인\' 용의자 범행자백 "수면마취제 이용"',
#  "'1100억원대 사기' 이규태 일광공영 회장 기소",
#  "새누리당, 지역일꾼 '새줌마' 공약 '안전관악' '예산불독'",
#  '상품권 싸게 사준다며 교회지인 상대로 수십억대 사기',
#  "연쇄살인범 아동성폭력범 형기 끝난 뒤 최대 7년간 '격리'",
#  "중고거래 구매자에게 판매자 가장 '삼각사기'친 일당",
#  "'박원순법' 6개월, 서울시 공무원 범죄 7분의 1로 줄어",
#  "아파트도 범죄예방 시설 반드시 갖춰야 '건축허가'",
#  '장난전화했다간 112허위신고 10건 중 7건 처벌받았다',
#  "미리보는 4월 국회...기재 교문 환노위 '화약고'",
#  '"딸이 불효자식, 잡아가달라" 만우절 112 장난전화 했다간 ',
#  '바다에 버린 살인 흉기, 그들의 눈을 피할 순 없다',
#  "단통법, 6개월째 제자리걸음 국회 논의는 '안갯속'",
#  '"정보화시대의 파수꾼 \'화이트해커\', 정부 차원서 관리해야"',
#  '문 열린 고급차만 노려 금품 600만원 훔친 30대男 구속',
#  '가정주부가 투자 미끼로 4년간 24억대 사기 행각',
#  "'훈남 경찰'부터 '고양고양이'까지 네티즌 눈길잡은 공공기관 SNS",
#  '‘애완견 도난주의보’ ‘외로워서’ 훔쳐(?) 키울려고 했다',
#  '미 국무부, “위안부는 성 목적으로 여성 매매한 행위”',
#  '강력범 형기 마쳐도 최대 7년 격리한다',
#  '강력범 형기 마쳐도 최대 7년 격리',
#  '방위사업비리 합수단 이규태회장 기소 1천억 부풀려',
#  '행정자치부, 대구지역 공무원 성폭력 범죄 2011년 이후 매년 발생',
#  '“상품권 싸게 구입해줄게” 15억 챙긴 40대 주부 ‘쇠고랑’',
#  '인천시, 아동안전지도 제작 사업 추진',
#  '모텔서 숨진 女중생, 알고보니 세남성이 손톱에는 "충격!"',
#  '모텔서 숨진 女중생, 알고보니 세남성이 손톱에는 "충격!"',
#  '검찰, 포스코 20억원대 비자금 추가 포착',
#  '500가구 이상 아파트 CCTV 의무화',
#  "'흉악범 최장 7년 격리' 보호수용법안 국무회의 통과",
#  '보호수용법안 국무회의 통과 이중처벌 논란일 듯',
#  '하드보일드 뜻, 감정 드러내지 않는 냉담한 태도 하드보일드 영화의 대표작은?',
#  "필리핀서 '황제 관광'한 대학교수, 대기업 회사원 원정 성매매 일당 검거",
#  '필리핀 관광 위장 성매매 56명 검거 대학교수 등 포함',
#  '교수 회계사 필리핀 ‘성매매 황제관광’ 56명 딱 걸려',
#  '하드보일드 뜻, 감정에 좌우되지 않는 냉담한 태도 ‘1차 세계대전서 유래’',
#  '500가구 이상 아파트 내달부터 CCTV 의무 설치',
#  '[M+기획 ‘청불 영화’①] ‘킹스맨’ 흥행으로 본 성공 요소는?',
#  '[M+기획 ‘청불 영화’①] ‘킹스맨’ 흥행으로 본 성공 요소는?',
#  '노인 대상 사기등 범죄 극성',
#  '군산시 옥서면 전 지역 CCTV 설치',
#  '전북경찰, 강 절도 6월 말까지 고강도 단속',
#  '하드보일드 뜻, 감정에 좌우되지 않는 냉담한 태도 한국영화 대표작은?',
#  '성범죄 교수 교사, 교단서 영구 퇴출',
#  '필리핀 원정 성매매단 56명 검거',
#  '하드보일드 뜻, 폭력적 주제를 냉철+무감한 태도로 묘사하는 특징',
#  '2만弗 덫',
#  '4월부터 범죄 예방 기준 맞춰 건축해야 건축허가 받는다',
#  '[박광규의 미스터리 산책]뛰는 놈 위에 나는 놈, 그 위에 컴퓨터',
#  '‘제2 오원춘 막자’ /수원시 고육지책',
#  "야후 재팬, 개인의 성적 화상, 병력, 범죄피해사실 등은 '삭제'...새로운 기준 발표",
#  '흉악범, 출소 후 최대 7년 수용소 격리',
#  '[케이블 위성 TV하이라이트]2015년 3월 31일',
#  '4월 1일 오늘의 하이라이트',
#  '멕시코, 불법무기 3명당 1명꼴 유통',
#  '억대 사기 전 경기노점상 회장 기소',
#  '교수 회계사 등 필리핀 원정 성매매 무더기 적발',
#  '만우절 112 황당 장난전화 안돼요',
#  '출소 후 성형 키높이 수술 전국서 빈집털이',
#  '취업알선 미끼 7억원 꿀꺽 20대 신종 사기범',
#  '"외로워서" 공원서 애완견 훔친 50대 입건',
#  '필리핀 원정 성매매 55명 적발  대학교수 공인회계사 등',
#  '여성 청소년보호시설 ‘나사로의 집’ 폐쇄 위기 자활 꿈꾸던 소녀들 어디로 가나',
#  '흉악범 최장 7년 격리 ‘보호수용법’ 통과  이중처벌 논란',
#  '오바마, 취임 뒤 처음 ‘아버지 나라’ 간다',
#  '야후재팬 ‘잊혀질 권리’ 기준 발표',
#  '‘황제노역 판결’ 판사, 부적절한 수임 논란',
#  '“식당 음식 맛없다” 112 황당 신고',
#  '미국 코널리 하원의원 “아베 잔혹행위 명확히 인정해야”',
#  '포스코건설 비자금 새 줄기 드러나 베트남 공사 과정 20억 조성 포착',
#  '‘잠룡’ 김문수 “유엔 北인권사무소, 중국 러시아에 등불 밝힐 것”',
#  '[사설]인권위의 ‘역주행’ 언제까지 지켜봐야 하나',
#  '필리핀 세부 관광 위장 성매매  교수 등 56명 검거',
#  '[박상미의 공감 스토리텔링]사람을 죽이는 일, 사람을 살리는 일',
#  '양주 소년범 보호시설 문닫을 위기 /“여기 나가면 또 방황할까 걱정돼요”',
#  '박범훈 ‘전방위 외압’ 교육부 휘저어 당시 청와대서도 논란',
#  '훈육 차원 체벌해도 ‘처벌’받아요',
#  '[이창근의 두드림]두드림의 육하원칙',
#  '마이클 브라운 사건과 구조적 인권침해',
#  '[시대의 창]싼 게 비지떡: 선별복지의 함정',
#  '[조찬제 선임기자의 월드프리즘]미국은 왜 MH17기 피격 자료 공개 않나',
#  "정부, 성매매 원천봉쇄 나선다 전국 '집창촌' 폐쇄",
#  '건설사 회장 사칭 수천만원 꿀꺽 50대 징역형',
#  '성남중원경찰서, 피해자 멘토위원회 ‘희망의 등대’ 발대식 개최',
#  '[법률 플러스] 증인출석요구 받으면 출석해야 하나',
#  '잠들어 있던 문화관광자원을 깨우다',
#  '자전거 구리 등 훔친 생활형 절도범 줄줄이 검거',
#  '끈기 깡으로 사기범 잡은 여경',
#  '■ 경남신문 제12기 독자위원회 2차 회의',
#  '장성 북하파출소, 절도 아동범죄예방 활동',
#  '충북기협 이달의 기자상',
#  '옥천지역 서민금융 왜 이러나',
#  '"한국터보기계 이헌석 대표 미국 인도 재고 해달라"',
#  'AP통신 사장 “언론인 납치ㆍ살해, 국제법상 전쟁 범죄에 포함해야”',
#  '전과 59범, 경찰 지구대에서 남의 물건 슬쩍했다가 또 경찰신세',
#  '외국인 근로자 밀물 공존의 해법 모색',
#  '[청년 해외취업 허와 실]‘절박한 구직자’ 두 번 울리는 취업사기',
#  "KBS1 '시사기획 창' 외국인 근로자, 공존의 조건",
#  '호기심 살빠지는 약에 학생 마약사범 67% 급증',
#  '엘리트 법대교수, 심야 열차간에서 30대女 허벅지 더듬다 체포',
#  '금융당국, 보이스피싱 막기 ‘칼빼들었다’',
#  '[황종택의新온고지신]연무마모(鍊武磨矛）',
#  "실종느와르M 강하늘, '미생' 잊게하는 소름돋는 연기력...김강우와 두뇌대결 시작",
#  '타인 카드 사용한 중학생, 형사처벌 대신 즉결심판',
#  '충북경찰청 무심천 공원 자전거순찰대 운영',
#  '권시장 항소심 재판부, 선거범죄 과거 판결 살펴보니 ',
#  '대전 고화질CCTV 52개교에 2억 지원',
#  "성폭행 사건에 '들끓는 논산' CCTV도 4대 중 3대 고장",
#  "'휴대폰점에 휴대폰이 없다' 절도범 머리위에 있는 업주",
#  '오늘의 대전 세종 충남 충북-중도일보(3월30일 월요일자)',
#  "진화하는 보이스피싱 '검찰총장 공문' 위조 수억 편취",
#  '[이브닝 이슈] "채림 남매 폭언" 모욕 혐의로 피소 모욕죄란?',
#  '통장, 모르고 빌려줘도 범죄 악용 시 무조건 형사처벌',
#  '[뉴스 플러스] 도박업자에 ‘수뢰’ 경찰 간부 수사',
#  '2000억대 판돈 주무른 한 중 합작 도박조직',
#  '“아베, 美 연설서 위안부 문제 직시하고 사과해야”',
#  '[글로벌 시대] 영국 신사는 케이팝을 좋아해?/이에스더 아리랑TV 글로벌네트워크부장',
#  '檢, 조희팔 은닉재산 환수 위해 이례적 추징금 구형',
#  '남원 순창 장수범죄피해자지원센터, 정기총회 개최',
#  '남원 공공기관 민간단체, 법질서 실천 협약',
#  '진안경찰서, 보이스피싱예방 홍보영상 제작',
#  '황금대사헌 황희와 이완구 총리',
#  '"위헌소지 분명한데 판단 안했다면.."',
#  'SNS 타고 10대 마약범죄 74% 급증',
#  '흔들리는 청소년들 - 청소년 범죄 위험수위',
#  '영동서, 금산서와 112 총력대응체계 구축 간담회',
#  '옥천경찰서, 체감치안 향상 맞춤형 캠페인',
#  '-충북경찰청 무심천 자전거순찰대 운영',
#  '상습적으로 가정폭력을 행사한 40대 검거',
#  '충북기협, 2015년 1분기 이달의 기자상 선정',
#  '전국 24개 ‘집창촌’ 폐쇄 여가부 경찰 등 TF 구성',
#  '<세상 만사-나라 안>전과 59범 경찰지구대서 현금 훔쳐 또 입건',
#  '‘조건만남’ 미끼로 유인해 강도질 한 10대 4명 구속',
#  '집창촌서 유흥업소까지 샅샅이 性매매 전방위 단속',
#  '“제2 이해인 막아라” ‘피싱’과의 전쟁',
#  '합수단, 1154억 사기 혐의 이규태 今明 구속기소',
#  '美의원들 ‘과거사 반성’ 촉구하지만 아베 ‘형식적 언급’ 그칠듯',
#  '<시론>경제는 ‘명령’으로 움직이지 않는다',
#  '달서구 “범죄 피해자 지원” 경찰과 상시네트워크 구축',
#  '경일대, 해외건설 현장 체험 전문가 특강 “특성화사업단 순항”',
#  '구미경찰서-고용노동부...범죄피해자 취업지원 MOU',
#  '달서구청_달서 성서경찰서 ‘긴급지원 네트워크’ MOU',
#  '만우절 장난전화 이제 그만',
#  '대포통장의 덫',
#  '여수경찰서 전남 최초 ‘경미 범죄 심사위원회’ 개최',
#  "대법원 '긴급조치' 판결에 담긴 정치화법",
#  '옥천경찰서, 4대 사회악 근절 홍보 활동',
#  '스마트폰 카메라 이용 촬영 성범죄 연루되면 전문변호사 조력 구해야',
#  '성폭력 근절 대책 현장 실천이 우선',
#  '성폭력 근절 대책 현장 실천이 우선',
#  '‘장발장법’ 폐지 혜택 볼까',
#  '‘장발장법’ 폐지 혜택 볼까',
#  "국내외)'920곳 매장서 2천억 판돈' 韓中합작 도박조직 적발",
#  '필로폰 대마 등 마약사범 22명 무더기 검거',
#  '투탑시티 더 이상 외면방치는 안된다',
#  '투탑시티 더 이상 외면방치는 안된다',
#  '[지역의 갈길을 묻다] 4. 박선규 영월군수',
#  '[지역의 갈길을 묻다] 4. 박선규 영월군수',
#  '귀금속 절취한 이삿짐센터 직원 구속',
#  '기고',
#  '[기고]대출해 주겠다는 전화 "속지 마세요"',
#  '대구경찰청-대구숙련기술협 범죄 피해 외국인 보호 협약',
#  '최면진정제 \'졸피뎀\' 남용 많아 이철우 의원 "범죄 악용" 경고',
#  '[야고부] 확신범',
#  '편의점 바닥 비상벨로 신고 1분만에 잡힌 강도',
#  '제2의 ‘오원춘 박춘풍’ 없다 수원시, 범죄예방 위해 가로등 전면 교체',
#  '‘은행 털고 도망가는 법’ 구글 검색으로 익힌 부부 체포',
#  '간 큰 40대 경찰지구대에서 남의 금품 훔쳤다가 덜미',
#  "리콴유 일본과의 '특별한' 관계 공포의 대상에서 벤치마킹, 훈수까지",
#  '“北 강원도는 강간도?”군인, 성폭행 통제불능 상태',
#  '조희팔 은닉재산 환수, "측근에 추징금 구형"',
#  '‘장기 복역에 감 잃어’ 어설픈 도둑들 결국 철창행',
#  '[사설] 아베 총리 ‘인신매매론’ 위안부 문제 물타기일 뿐',
#  '“중국 말단 경찰간부 집에서 현금 180억원 나와”',
#  '도봉산 기슭서 열린 ‘판도라 컨테이너’ ‘방산 비리’ 이규태 회장 비밀 자료 무더기 발견',
#  '검찰, 동국제강 해외송금 추적 비자금 조성 증거 확보',
#  "'와우', 공식소설 특별 한정판 '골드 에디션' 선보여",
#  '[한경에세이] 천안함 5주기를 보내며',
#  '"119 신고 후 현장 떠나면 뺑소니 아니다"',
#  '[시사人] 하계열 부산진구청장',
#  "시민 체감 높은 '생활 범죄' 꼼짝마!",
#  '[셉테드의 진화] "비행 청소년은 가라" 10대만 골라 내쫓는 신기한 경보음',
#  '주차 차량 창문깨고 금품 훔친 50대 구속',
#  '감쪽같은 검사 연기, 젊은 여성도 속인 보이스피싱',
#  '[셉테드의 진화] 전문가의 지적은? "벽화 일색 부산 셉테드 이젠 마을 맞춤형으로"',
#  '베트남 신부 결혼 실패 60대 결혼중개업체 방화 살인',
#  "단속 기관도 두 손 든 '멸치 포획금지 법'",
#  "현직 경찰 간부, '뇌물수수 혐의' 수사 시작되자 휴가낸 뒤 한달째 잠적",
#  '영동경찰서-금산경찰서 지휘관 간담회 개최',
#  "[사설] 솜방망이 처벌이 키워온 '보험사기 공화국'",
#  '전국 24개 집창촌 폐쇄 돌입',
#  '檢, 동국제강 비정상적 해외송금 추적 실무자 소환',
#  '"중국 하급 경찰간부 집에서 현금 180억원 나와 게임업자로부터 뇌물 챙겨"',
#  '상인 지원금 가로챈 전통시장 회장 입건',
#  '성형수술과 가발로 변장해 아파트 턴 전문털이범 덜미',
#  '[단독] ‘하베스트’ 평가 보고서 입수 곳곳 왜곡 과장',
#  '1분여 만에 뚝딱 간이 금고 통째로 훔쳐',
#  '충북지방경찰청 10월 말까지 무심천 자전거 순찰대 운영',
#  '‘마을방송’ 유익한 매체로 자리매김하길',
#  '“학폭 예방 위한 제도적 방안과 전사회적 관심 협력 필요”',
#  '소년재판 8000번의 결론 "아이들에게 \'아버지\'가 필요합니다"',
#  '‘제2의 이해인 피해 막아라’ 금감원, 전쟁선포',
#  '이발해주며 갱생 길 걷는 ‘사형수 이발사’',
#  "CCTV 관제탑서 '청소년 선도'",
#  '보험사기와 대책',
#  '[인터뷰] 황재덕 경기도선관위 상임위원',
#  '보육교사 가짜 위탁교육 국가보조금 6억원 ‘꿀꺽’',
#  "?'이해인 사건' 도마 위 금감원, 보이스피싱 근절 나선다",
#  "'장기 복역에 감 잃어' 어설픈 도둑들 결국 철창행",
#  '"욕설과 협박에 시달려도..나이롱 귀신 끝까지 추적한다"',
#  "월드 오브 워크래프트 소설, 특별 한정판 '골드 에디션' 출시",
#  '[TV] OCN ‘실종느와르 M’ 강하늘-김강우ㆍ박희순 숨막히는 연기경쟁 첫 방부터 터졌다',
#  '울산대 스마트벤처학교, ICT 창업기지로',
#  '독재와 결별한 스리랑카, 100일 계획은 성공할까',
#  '대법 "위헌소지 분명한데 판단 안했다면 재판 다시해야"',
#  '[보험 상품]‘무배당 롯데 Only 여성보험’ 여성 고객 특화 후유장해땐 매월 100만원',
#  '창원 집값 끝없는 오름세, 가격 경쟁력 갖춘 창원 감계 힐스테이트 2차 분양',
#  '명문대 출신 법학과 교수, 열차서 성추행하다 덜미',
#  "수억 갈취해 '15년간 해외 도피' 조폭, 실형 선고",
#  '한국첨단안전산업협회 창립총회',
#  '[디지털산책] 주민등록번호제도 고칠 때 됐다',
#  '네시삼십삼분, 퓨전 RPG FPS 등 새로운 장르 차별화',
#  '마곡지구 대형건설사 오피스텔이 이 가격? `마곡 아이파크` 분양 마감 코앞',
#  '10대 학생 등 젊은층 마약범죄 급증..인터넷 통한 유통 증가 등이 원인',
#  '금감원“제2 이해인 나오지 않게 ”',
#  '[보험상품-NH농협손해보험] ‘재해 범죄 사고 질병’한번에 걱정 뚝',
#  '[Nationwide]‘경찰서를 털어라?’ 지구대서 금품 훔친 40대',
#  '논산 대형마트 화장실서 여중생 성폭행',
#  '[박석흥 세상보기] 전 근대 제국주의 극복한 리더십시대의 종언',
#  '처벌 대신 즉결심판 전과자 전락 예방',
#  '이해득실 맞선 사행산업 전자카드제',
#  '여가부, 성매매집결지 폐쇄 추진 현황 공유 집결지 폐쇄 박차',
#  '이조로 변호사의 작품 속 법률산책 - ‘스물’의 강요죄',
#  '안행위, 4월국회서 총기단속 누리과정 지방채 논의',
#  "'뇌물 혐의' 경찰 간부, 수사 시작되자 잠적",
#  '김희정 장관 "불법 성매매업소 범죄수익 몰수 추징"',
#  '대법, 지적장애 10대女 성관계 촬영한 20대 실형 확정',
#  '젊은층 SNS로 마약접촉↑...경찰 "온라인 공급 집중단속"',
#  '檢, 유사수신 사기범 조희팔 은닉재산 환수',
#  '경찰서에서 가방 훔친 간큰 40대',
#  '`집창촌` 뿌리뽑는다 여가부, 24곳 폐쇄 추진',
#  '집창촌 뿌리뽑는다 여가부, 24곳 폐쇄 추진',
#  '이해인 씨 사건에 금감원 보이스피싱 근절 나섰다',
#  '키 늘리고 얼굴까지 고친 절도범',
#  '키 늘리고 얼굴 고친 절도범',
#  '[독자칼럼] `사이버데이`를 제안합니다',
#  '대법 "청소년 성관계 촬영, 원칙적으로 아청법 위반"',
#  '북한의 ‘강원도’는 ‘강간도’? 그 수위를 보니',
#  '[MIT] 스마트시티②',
#  '[MIT] 스마트시티①',
#  '[포토] 윤진서, 드라마 속 범죄 프로파일러',
#  'CCTV 진화...이젠 청소년 선도까지',
#  '동대문구, 친절운동 한방타운 복지 등 7대 전략과제 선정',
#  '아직 남아있는 전국 성매매집결지 24곳 폐쇄 본격 추진',
#  '완전범죄 꿈 꾼 30대 男, 수술로 키 늘리고 양약까지',
#  "명문대 출신 법학과 교수가 열차서 성추행 '현행범으로 체포'",
#  '진화하는 거짓말탐지기 이젠 뇌까지 본다',
#  '[M+예능전망대] 파일럿 예능, 대거 정규行 판도 급변할까',
#  '스릴러 SF로 재탄생하는 제인 오스틴의 고전들',
#  "잠복 끝에 교통카드 훔쳐 간 범인 잡고 보니 '환경미화원'",
#  '명문대 출신 법학과 교수, 열차서 성추행하다 그만 ',
#  '위험한 노인들 각종 범죄의 표적',
#  '완주서 성 가정폭력 예방 모의훈련',
#  '덕진지구대, 맞춤형 범죄예방 위해 지역민과 소통',
#  '익산 오산파출소, 점심 문안순찰 호응 좋아',
#  '[홍기영칼럼] 분노조절장애의 심리학',
#  '[Special Report 1]환경규제 세제혜택 등에 업고 하이브리드카 ‘붕붕’',
#  '[US REPORT]공직자 문건 스캔들 ‘이메일’ 다음은 ‘텍스트 게이트’?',
#  '[US REPORT]공직자 문건 스캔들 ‘이메일’ 다음은 ‘텍스트 게이트’?',
#  '[신병주의 ‘왕으로 산다는 것’](3) 우리가 잘 몰랐던 ‘세종’의 시련 불행한 가족사에 걸어다니는 ‘病주머니’',
#  '염태영 수원시장 “햇빛정책 펴겠다”',
#  '‘제2 오원춘 막자’ 수원시 고육지책',
#  '아베 “위안부, 인신매매에 의해 괴롭힘” /일 정부 책임 회피 ‘꼼수’ 눈총',
#  '출소 후 성형 키높이 수술 전국서 빈집털이',
#  '[케이블 위성 TV하이라이트]2015년 3월 31일',
#  '탕웨이 이해인도 당한 보이스피싱  금감원, 금융사기와 전쟁 선포',
#  '여성 청소년보호시설 ‘나사로의 집’ 폐쇄 위기 자활 꿈꾸던 소녀들 어디로 가나',
#  '“모두가 날 알게 될 거야” 저먼윙스 부기장 ‘문제’ 속속 발견',
#  '“모두가 날 알게 될 거야” 저먼윙스 부기장 ‘문제’ 속속 발견 ‘정신질환자 차별’ 우려도 증폭',
#  '도봉산 인근 컨테이너에 꼭꼭 숨긴 ‘방산비리 자료’',
#  '“모두가 날 알게 될 거야” 저먼윙스 부기장 ‘문제’ 속속 발견',
#  '박종철, 박종운, 박상옥',
#  '양주 소년범 보호시설 문 닫을 위기 “여기 나가면 또 방황할까 걱정돼요”',
#  '[아침을 열며]돼지라도 돼달라',
#  '[기고]사행산업감독위는 빅브러더가 되려 하나',
#  '동국제강 압수수색 장세주 회장 출국금지',
#  '[군 이대론 안된다]기밀 빼주고, 불량부품 눈감고 “패망 직전 월남군 보는 듯”',
#  '기밀 빼주고, 불량부품 눈감고 “패망 직전 월남군 보는 듯”',
#  "'제2의 이해인 막아라' 금감원, 금융사기와 전쟁선포",
#  '경찰지구대에서 남의 금품 훔친 40대 덜미',
#  '‘제2의 이해인 막아라’ 금감원, 연예인協 등에 일제 공문',
#  '“119에 사고 신고후 현장 떠났으면 뺑소니 아니다”',
#  '사이버 명예경찰 ‘누리캅스’ 회원 모집',
#  '버스정류장 ‘묻지마 살인범’ 항소심도 징역 25년',
#  '성관계 장면 여성 신체 몰카 남성 3명 집유 벌금형',
#  '중부暑 경찰관 3명, 성신고서 1박 2일 고교생 체험 ‘스쿨폴리스 학교 속으로’ \n ‘폭력예방’ 부모걱정 덜어 준다',
#  '7살 여아 성추행한 60대 경비원, 징역 2년 6월로 감형',
#  '평택 안성 범죄피해자지원센터 등...기금마련 감자심기 행사 구슬땀',
#  '구리경찰서, 전국 최초 ‘드론’ 치안서비스 떴다',
#  '7세 여아 성추행 한 아파트 경비원, 항소심서 감형',
#  '‘짜고 친’ 어린이집 원장-평생교육원 국고보조금 6억 빼돌려',
#  'FDS, 보안 만능 솔루션으로 떠오르나?[수정]',
#  '[신간도서]누가 진짜 범인인가',
#  '권선택 항소심 재판부 확정',
#  '음성서, 40대 절도범 구속',
#  '무심천 자전거순찰대 운영',
#  '원룸 밀집지역 안전택배함 설치',
#  '대전시교육청, 24시간 학교안전 강화',
#  '천안동남서 업준섭 순경 보이스 피싱 피해 2억 8500만원 막아',
#  '119 신고뒤 현장이탈, 법원 “뺑소니 아니다”',
#  '교복입은 경찰들의 ‘기숙사 삼시세끼’',
#  '퇴직공직자 10명중 4명 방산업체서 모셔가',
#  "'살해된 가출 여중생에 성매매 알선 혐의' 2인조 구속영장 발부",
#  '성관계 여성신체 촬영한 남성3명 ‘집유 벌금’',
#  '헤어지자는 내연녀 흉기로 위협한 40대 실형',
#  '피해자 보호 전담경찰관의 아침 단상(斷想)',
#  '경찰, 자전거 스마트폰 절도 생활범죄 1400여건 단속',
#  '절도 최다 생활범죄 1419건 해결',
#  '中 거점 2000억대 인터넷 도박 적발',
#  "1000여 매장서 '2천억' 주무른 한 중 합작 도박조직",
#  '"통장 빌려주면 50만원 줄께" 대포통장 모집 콜센터 조직 검거',
#  '[기고] 법질서 선의 미학',
#  "실종느와르 M, '엘리트 형사' 김강우-'사이코패스' 강하늘 긴장감 넘치는 두뇌대결...'게임 스타트'",
#  "합수단, '방위사업 비리' 은폐 가담 일광공영 직원 2명 구속",
#  '‘선불폰 불법 유통’ 이통 3사 제재 착수',
#  "'7세 여아 성추행' 60대 경비원, 항소심서 감형  솜방망이처벌",
#  '"이거 먹으면 " 항암버섯으로 난치병 환자 등친 사기꾼',
#  "방통위, 선불폰 '불법 유통' 관련 이통 3사 제재할 듯",
#  "실종느와르M 강하늘, 단 2회 촬영위해 5kg감량...소름돋는 연기력에 네티즌 '극찬세례'",
#  "실종느와르M 강하늘, '미생'은 잊어라...역대급 사이코패스 연기 '소름'",
#  '이번엔 동국제강 檢 수사 전방위 확대',
#  '실종느와르M 강하늘, \'천재형사\' 김강우와 두뇌대결 "게임을 준비했다"...긴장감 \'최고\'',
#  '[이슈분석]전방위로 확산되는 ‘부정부패 척결’[수정]',
#  '[이슈분석]고발요청권 첫 발동 산업계 파장은[수정]',
#  '살해된 가출 여중생에 성매매 알선 2인조 영장 발부',
#  "英, 조세회피처에 '페이퍼컴퍼니 실소유주 등기' 압박",
#  '민간경비업체와 손잡고 치안 사각지대 해소 나서',
#  '일광공영 숨긴 방산자료 1톤 발견',
#  '생활범죄수사팀, 두달간 729명 검거',
#  "2000억대 '한 중 도박조직' 적발",
#  '오늘의 주요뉴스',
#  "'무심코 넘긴 통장' 대가성 없어도 처벌 받는다",
#  '실종느와르M 강하늘, 신들린 사이코패스 연기 “더 죽을 사람 없을까요?”',
#  '실종느와르M 강하늘, 일주일 5kg 감량 “섬뜩한 사이코패스 미소”',
#  '실종느와르M 강하늘, 신들린 사이코패스 연기 “체중감량 영향?”',
#  '실종느와르M 강하늘, 섬뜩한 미소 뒤 두뇌게임 ‘대박’',
#  "'뇌물수수 혐의' 현직 경찰 간부, 휴가낸 뒤 한달째 잠적",
#  '[데스크 칼럼] 기업수사 칼날 비틀진 말아야',
#  "NH농협銀 '대포통장과의 전쟁' 1년새 20% → 2%로 대폭 감소",
#  '충북경찰청 무심천 자전거순찰대 운영',
#  '상장사 "임원 규제 강화 법안 반대"',
#  '교복입은 경찰들의 ‘기숙사 삼시세끼’',
#  '민간경비업체와 손잡고 치안 사각지대 해소 나서',
#  '귀금속 절취한 이삿짐센터 직원 구속',
#  '할머니 영정사진 담긴 여대생 카메라 실종사건',
#  '중앙지법 형사법관 "법정 언행 신중히 해야" 의견 모아',
#  '욕정 못이긴 경비원, 일곱살 지하계단 성추행 법원은 왜 감형?',
#  '"남는 항암버섯 나눠줄게" 애타는 난치병 환자 등쳐',
#  '입연 일광공영 ‘금고지기’ 판도라의 컨테이너 열렸다',
#  '[포토뉴스] 범죄피해자 교통편의 제공 협약',
#  "관리는 허술 범죄엔 무방비 사람 잡는 '졸피뎀(수면 유도제)'",
#  '생활범죄 대상 1호는? 자동차',
#  '[포럼] 벌금형과 사회적 약자 배려',
#  '[보험사기 공화국, 특별법이 시급하다] 처벌수위 높여야 보험금 사냥꾼 막는다',
#  '[보험사기 공화국, 특별법이 시급하다] 특별법 발의한 박대동 의원 "흉포화하는 보험사기 못막으면 사회 신뢰기반 무너질 수 있다"',
#  '지자체 "나 떨고있니" 지역안전지수 5월 첫 공표',
#  '‘간통죄 위헌’ 결정 이후 한달 달라진 新풍속도',
#  '119 신고뒤 현장이탈, 법원 “뺑소니 아니다”',
#  '성관계 여성신체 촬영한 남성3명 ‘집유 벌금’',
#  '헤어지자는 내연녀 흉기로 위협한 40대 실형',
#  '中 인터넷 도박장 900여곳 차린 한 중 도박조직 적발',
#  '방산비리 증거 인멸한 일광공영 직원 2명 구속',
#  '"세무조사 편의 봐달라" 전 현직 세무공무원 뒷돈',
#  '일광공영이 숨긴 1t 사업자료 도봉산서 발견.. 직원 2명 구속',
#  '500억대 공군 장비 비리 등 일광공영 1톤 넘는 은닉자료, 도봉산 밑 컨테이너서 발견',
#  "'중국 매장 920곳서 판돈 2000억' 한중 합작 도박조직",
#  '[날줄씨줄]적반하장',
#  "느슨한 봄 타고 '피싱 사기' 꿈틀",
#  "'방산비리 자료 증거인멸' 일광공영 직원 2명 구속",
#  "'모텔 피살 10대女'에 성매매 알선한 20대男 2명 구속",
#  'ESPN "맨유, 생각하고 돈 써야" 부진 선수 줄줄이 비판',
#  'UNHRC, "北의 장성택 처형...국제인권법 위반"',
#  '일광공영 방위사업 자료, 컨테이너에서 무더기 발견',
#  '중국에 콜센터 차려두고 대포통장 모집한 일당 구속',
#  '檢, 중국과 공조 통해 2000억대 도박장 운영한 한국인 총책 검거',
#  "'이규태 비리' 증거인멸한 일광공영 직원 2명 구속",
#  "'봄철 몰카 주의보' 지하철서 자동차키를 주목해야하는 이유",
#  '"장기이식 해주겠다"고 환자 8명 속여 돈뜯어낸 20대男 구속',
#  '경찰 생활범죄수사팀 두 달 간 1400건 넘는 사건 해결',
#  '사이버범죄 스미싱은 줄고, 파밍은 늘고',
#  '동국제강 장세주 회장 25년만에 또 해외도박 혐의 자금흐름 추적',
#  "대법, 위조달러 처벌 제동? 법조항 '위헌' 우려",
#  '중국서 900개 도박장 운영하던 국내 도박조직 검거 판돈만 2000억',
#  '"20세부터 80세까지 도박" 국제 도박판 벌인 일당 재판에',
#  "고법, '7세 여아 성추행' 60대 경비원에 징역 2년6월 실형",
#  '외환위기때 같은 생계형 좀도둑 기승',
#  '외환위기때 같은 생계형 좀도둑 기승',
#  '판돈 무려 2000억 한 중도박단 검거',
#  '2000억대 한 중 도박조직 적발',
#  '"동국제강 다음은 " 재계 사정확산 촉각',
#  '"동국제강 다음은 " 재계 사정확산 촉각',
#  '"통장 빌려주면 1주일에 50만원 주겠다" 꼬드기더니 ',
#  '자전거 휴대폰 쌀 커피믹스 등 ‘생계형 좀도둑’ 기승',
#  '920곳에서 2천억 판돈 도박 국제 도박 조직 적발',
#  '[M+리뷰] ‘코블러’, 일상에 찌든 미생을 위한 판타지',
#  '[M+인터뷰] “차실장” 외치던 김상경 ‘살인의뢰’서 울부짖다',
#  '첫 방송에 화제 ‘실종느와르 M’ 포인트는 ‘리얼함’',
#  '[‘실종느와르M’ 첫방②] ‘해맑은’ 강하늘의 무서운 변신',
#  '[‘실종느와르M’ 첫방①] 짜릿한 두뇌싸움의 향연 ‘진짜가 나타났다’',
#  '도박과 머니게임',
#  '첫 방송만에 화제 ‘실종느와르 M’만의 ‘리얼함’',
#  '7세 여아 성추행 60대 경비원, 항소심서 징역 2년6월로 감형',
#  '대법원 “위헌 소지 다분한 법 그대로 적용한 판결 파기환송”',
#  '검, 도박업자에게서 ‘뇌물 혐의’ 경찰 간부 수사',
#  '도봉산 인근 컨테이너에 꼭꼭 숨긴 ‘방산비리 자료’',
#  '“모두가 날 알게 될 거야” 저먼윙스 부기장 ‘문제’ 속속 발견 ‘정신질환자 차별’ 우려도 증폭',
#  '‘7살 여자어린이 성추행’ 60대 경비원, 항소심서 징역 2년6월로 감형',
#  '[편집국에서] 박종철, 박종운, 박상옥 / 권태호',
#  '[아침을 열며]돼지라도 돼달라',
#  '동국제강 압수수색 장세주 회장 출국금지',
#  '[기고]사행산업감독위는 빅브러더가 되려 하나',
#  '[군 이대론 안된다]기밀 빼주고, 불량부품 눈감고 “패망 직전 월남군 보는 듯”',
#  '첫 방송에 핫이슈 된 ‘실종느와르 M’ ‘리얼함’이 살렸다',
#  '북한 "탈북자들 고향으로 돌아와라"',
#  '아베 "위안부는 인신매매 희생자" 日 책임 회피 위한 교묘한 \'꼼수\'',
#  '성관계 여성신체 몰래 촬영한 3명 집행유예 벌금',
#  '범죄 단속, 민 관 따로 없다 주민 모두가 참여',
#  '성범죄 공무원 벌금형 땐 퇴출',
#  '[주말 하이라이트]',
#  '[독자의 소리] 강제 전학, 학폭 근절 대책 아니다/최주원 군산경찰서 여성청소년계장 경감',
#  '[뉴스 분석] 아베 “위안부, 인신매매 가슴 아파”',
#  '아베에 멍석 깔아준 美 경제 실리 챙기는 日 ‘新밀월’',
#  '20대 기사,운전교습女와 눈맞아 여관 갔다가..',
#  '공무원 군인 성범죄 벌금형만 받아도 바로 퇴출',
#  '간통죄 위헌 결정 후 도내 첫 무죄 선고',
#  '도내 75개 도로서 주1회 동시 검문검색',
#  "국내외'공무원 군인, 성범죄로 벌금형 받으면 당연 퇴직' 추진",
#  '상습절도범 장발장법 위헌 결정 구제 가능?',
#  '軍 "성추행.성폭행 범죄자 퇴출 성희롱 땐 진급금지"',
#  '밀반입 대마씨 재배한 후 흡입 우즈벡 불법체류자 2명 구속',
#  "'맞춤형 보이스피싱' 알면서 당할 판",
#  "'산통' 깨는 사회, '진통' 겪는 부부 『가족의 실패』",
#  '[2015년 주목할 신기술] 사물인터넷',
#  '법원, 119에 사고 신고 후 현장이탈했다면 뺑소니 아니다',
#  '터키, 게양대 올라 국기 제거한 청년에 13년9개월형',
#  '헌재 간통죄 위헌 결정 후 강원 재심서 첫 ‘무죄’ 선고',
#  '“장성택 처형은 국제법 위반”유엔,北에 답변 요구',
#  '北,"간첩 혐의 국민 2명 자체법 따라 엄중 처벌”-10년 이상 노동교화형 예상',
#  '“김정은 비자금 관리 정찰총국 공작원 프랑스 추방?”北,美강력 비판',
#  '보육교사 7260명 훈련기록 조작 국가보조금 6억 챙긴 평생교육원',
#  '성폭력 군인 공무원 ‘원 스트라이크 아웃’ 정부, 성폭력 근절 대책 발표',
#  '공무원 군인 성범죄, 벌금형만 받아도 퇴출',
#  "SNS 무장한 경찰 시민들 '좋아요'",
#  '[경찰팀 리포트] 변관수 남대문경찰서장 "서울역 노숙인 재활 돕고 집회 마찰 최소화할 것"',
#  '[경찰팀 리포트] 나이지리아서 온 메일, 중기를 발칵 뒤집다',
#  '"복지는 당연히 받아야 하는 권리? 남의 주머니서 나오는 \'강요된 자선\'일 뿐"',
#  '공무원 군인 성범죄 중징계, 벌금형에도 당연 퇴직 추진',
#  '[사건사고] 음성경찰서, 상습 가정폭력 행사한 40대 검거',
#  "간통죄 위헌 결정 이후, 강원도내서 재심 재판 첫 '무죄' 판결",
#  '유엔 "북한 장성택 처형, 명백한 국제법 위반"',
#  '법원 "119 신고 후 현장 떠났으면 뺑소니 아니다"',
#  '"北, 장성택 처형은 국제법 위반" 유엔인권이사회 규정',
#  '유엔, "北 장성택 처형은 국제법 위반"',
#  '"댁의 부모님 안녕하십니까" 어르신 \'금융사기\' 활개',
#  '교통사고 가해자, 119신고 후 현장이탈..法 "뺑소니 아냐"',
#  "'혐오스러워서' 레즈비언을 살인했다? 죄 경감 사유 될까?",
#  '동작구, 주민참여로 범죄없는 마을 만든다',
#  "간통죄 위헌 결정 후 강원 재심서 첫 '무죄' 선고",
#  '유엔 "북한 장성택 처형은 국제법 위반"',
#  '“공무원 군인, 앞으로 성폭력 걸리면 지위 가리지 않고 무조건 옷 벗는다”',
#  '권력형 성폭력 공무원 군인 /벌금형만 받아도 바로 퇴출',
#  '공무원 군인, 성범죄 벌금형만 받아도 영구 퇴출',
#  '성관계 모습 여성 치마속 촬영한 3명 재판 받아',
#  '[책과 삶]은둔형 외톨이 묻지마 범죄의 공통점',
#  '유엔 “북한 장성택 처형, 국제법 위반”',
#  '아베 “위안부는 인신매매 희생자” 가해자 언급 ‘생략’',
#  'MB 측근중 ‘고위급’ 첫 겨냥 ‘전 정권 수사’ 본격화',
#  '"\'베트남 신부\' 어딨어?" 결혼정보업체에 불 지른 60대',
#  '간통죄 위헌 결정 후 강원 재심서 첫 `무죄` 선고',
#  '공무원 군인, 성폭력 범죄를 저지르면 퇴직 교사도 교단에서 즉각 퇴출',
#  '[사설] 아베 美의회 연설에서 日우경화 망동 사과하라',
#  '공무원 군인, 성폭력 범죄 저지르면 벌금형 선고에 퇴직 교사도 즉각 퇴출',
#  '독자투고- 신종 신용카드위조 대책 서둘러야',
#  '프리즘- 조영택 “요양보호사 처우개선 이뤄져야"',
#  '독자투고- 산림절도는 중대한 범죄',
#  '검찰, 담양펜션화재 피해자 생계비 등 지원',
#  '[슈퍼리치] 제임스 패터슨 댄 브라운 책 한권으로 ‘인세 갑부’ 되다',
#  '순창 팔덕파출소, 농축산물 도난 예방위한 CCTV 일제점검',
#  '진안경찰, 보이스피싱 대처 적극 홍보',
#  '주차문제에 야구방망이로 위협한 50대 징역형',
#  '김제경찰서 부정부패 척결 T/F 팀 구성',
#  '검찰, 보훈급여 부정수급자 3명 기소',
#  '[포토]중랑구, 범죄피해자 보호 지원 업무협약 체결',
#  '울산 중부서, 성신고에서 ‘스쿨폴리스 학교속으로’',
#  '공무원 군인, 성범죄로 벌금형만 받아도 퇴출',
#  '"우월적 지위 이용 성범죄 더이상 무관용"',
#  '공무원 군인, 성폭력 근절 대책 실시..."벌금형 선고시 당연 퇴직"',
#  '[사설] 권력형 성범죄엔 관용 없다',
#  '보육교사 출석부 조작 국가보조금 6억 챙겨',
#  '남고생 2명, 영업중인 대형마트 화장실서 여중생 성폭행',
#  '아동등장 음란물 퍼뜨린 대학교 외국인 영어강사 붙잡혀',
#  '성폭력 공무원 군인 벌금형만 받아도 퇴출',
#  '32억원 투자사기 친 황장엽 수양딸, 징역 5년',
#  '귀걸이 삼킨 뒤 2층에서 뛰어내린 30대女, 징역 2년6월',
#  "고 김태촌 양아들, '기업사냥꾼' 변신해 전횡 일삼다 덜미",
#  '‘투자 사기’ 황장엽 수양딸 징역 5년 확정',
#  '‘방산 비리’ 일광공영 직원 2명 영장',
#  '음주단속 피하려다 경찰관 치고 달아난 美군무원 구속',
#  '[뉴스 브리핑] 프로야구 개막전 암표거래 집중단속 外',
#  '軍, 성범죄 가해자 퇴출 진급 금지  제대군인 복지 박탈',
#  '인천지검, 세무조사 편의 수뢰 전ㆍ현 국세청 공무원 6명 기소',
#  "[슈퍼리치] 살인 사기 횡령 법정 선 갑부들 '추락 그 순간'",
#  "[집중취재]모바일 금융혁신의 키 '핀테크'",
#  '日경찰, 북한산 송이버섯 밀수 혐의 조총련 의장 압수수색',
#  '男 1000만, 女 3200만원? 흉터 보험금 차별 없앤다',
#  '쇼핑몰서 여중생 성폭행당해, 매장 CCTV 고장 관리 소홀',
#  '[현장 행정] 돈의동 쪽방촌에 행복과 희망 꽃피운다',
#  '[격동의 한 일 70년] “위안부 문제 해결이 관건 정상회담 통한 연대로 극복해야”',
#  '군인 공무원 성범죄 강력 대응 벌금형만 받아도 퇴출',
#  '北 "남한 간첩 2명 체포" 정부 "간첩 아니다, 즉시 송환"',
#  '성범죄 공직자, 벌금형만 받아도 퇴출',
#  "군대 대학 내 성폭력 범죄자 '벌금형'만 받아도 퇴출",
#  '아베 日 총리, 4월 29일 사상 첫 상 하원 합동 연설',
#  '"끝까지 추적해 붙잡는다" 자전거 도둑보다 더 끈질긴 경찰',
#  '강동성심병원, 강동경찰서와 업무협약 체결',
#  '[포토뉴스]해피홈 메신저 정기간담회',
#  '[책]내 안의 끔찍한 괴물을 꺾고 스스로 구원하리라',
#  "충주서, 노인들 대상 '전화금융사기발생 피해 예방활동'벌여",
#  '음성경찰, 동료 지갑 휴대폰 절취 피의자 구속',
#  '상습적으로 가정폭력을 행사한 40대 검거',
#  "제천경찰서-세명대학교 '캠퍼스 지킴이' 발대식",
#  '북한 "남한 간첩 두명 체포 극악한 테러분자"',
#  '공무원 벌금형 받으면 당연퇴직 ‘권력형 性범죄’ 뿌리 뽑는다',
#  '공무원 벌금형 받으면 당연퇴직 ‘권력형 性범죄’뿌리 뽑는다',
#  '警 대대적 단속 칼 빼드는데 性매매 여성 자립지원은 줄어',
#  '警 대대적 단속 칼 빼드는데 性매매 여성 자립지원은 줄어',
#  '교수 공무원 軍 性범죄 ‘원스트라이크 아웃’',
#  '교수 공무원 軍 性범죄 ‘원스트라이크 아웃’',
#  '‘투자 사기 혐의’ 故황장엽 수양딸 징역 5년 확정',
#  '보조금 빼돌린 어린이집 원장 무더기 적발',
#  '‘담양 펜션 화재’ 유족 도운 광주지검',
#  '속초범죄피해자지원센터 간담회',
#  '사진뉴스=해피 홈 메신저 정기 간담회',
#  '시간 지배하는 경찰이 범죄도 제압',
#  '[투고] 가볍게 건넨 통장 무겁게 받는 수갑',
#  '[투고]가볍게 건넨 통장 무겁게 받는 수갑',
#  "최보경 교사(산청 간디학교) '국보법 위반' 굴레 벗었다",
#  "산청 간디학교 최보경 교사 '국보법' 굴레 벗어",
#  '최보경 교사 국가보안법 굴레 벗다',
#  '[열린마당]근린치안, 맞춤형순찰, 안전한 제주',
#  "'공무원 성범죄로 벌금형 받으면 당연 퇴직' 추진",
#  '[동정] 김시택 예천경찰서장',
#  '[친절한 쿡기자] “총 맞았다” 셀카 올리고 실연 여성 자살 과정 생중계 SNS ‘생명 불감증’ 확산',
#  '“국정원에 매수돼 정보 제공?”北,남한 간첩 2명 체포 주장',
#  '아동 음란동영상 유포한 외국인 영어강사 입건',
#  '‘투자 사기’ 황장엽 수양딸 징역 5년 확정',
#  '“대형마트 화장실서 고교생이 여중생 성폭행”',
#  '황장엽 수양딸 징역 5년',
#  '정부, 우월적 지위를 이용한 성범죄 처벌 대폭 강화',
#  '성폭행 군인, ‘원아웃’ 퇴출 성희롱 가해자는 진급금지',
#  '예멘 대규모 공습 이어 지상전도 임박',
#  '"표현의 자유면에서 한국은 사법파쇼" NCCK토론회',
#  '[단독] “세월호 1년 디지털은 사람을 기다린다”',
#  "'깨진 유리창'에 숨겨진 두 가지 이야기",
#  '공무원 군인, 성폭력 범죄시 바로 퇴출 교원 역시 적용',
#  '(구청브리프)서울 동작구, “주민참여로 범죄없는 청정마을 만들어요”',
#  '북한, \'남한 간첩\' 두명 체포 발표 "극악 테러분자" 주장',
#  "[생글기자 코너] '생글생글' 아직도 모르는 사람 있나요? 등",
#  '아동청소년 음란물 유포한 부산 사립대 영어강사 검거',
#  "'공무원 군인, 성범죄로 벌금형 선고시 당연 퇴직' 추진",
#  '성폭력 군인 공무원 벌금형에도 바로 퇴직',
#  '북한 "남한 간첩 두명 체포 국정원이 매수"',
#  '[책] 안중근, 1909년 10월 26일 세발의 총성',
#  '軍 “성추행.성폭행 범죄자 퇴출 성희롱 땐 진급금지”',
#  '"소말리아 해적에 피랍위험 선박은 한국 아닌 태국"',
#  '“섹시는 NO” ‘레이디 가가 노출’ 가리는 중동',
#  "유병언 '벽장' 뺨치는 이규태 회장 '비밀의 방' 어떻게 생겼나보니",
#  "'공무원 군인, 성범죄로 벌금형 받으면 당연 퇴직' 추진",
#  '울산 중부서, 성신고에서 ‘스쿨폴리스 학교속으로’',
#  '아동 음란동영상 유포 외국인 강사 입건',
#  '북한 “남한 간첩 두명 체포 극악한 테러분자”',
#  '공무원 군인, 성범죄로 벌금형 받으면 ‘당연 퇴직’',
#  '꺾일 줄 모르는 창원 아파트 매매가 창원 시내 전세가로 내 집 마련 가능한 아파트는 어디?',
#  '공정위, 대기업 불공정행위 감시 강화',
#  '남한은 종북몰이, 북한은 간첩몰이?',
#  "성폭력 공직자 벌금형부터 '퇴출'",
#  '북한 "남한 간첩 두명 체포 北 보위부 주장 \'국정원 간첩\' 기자회견',
#  '해수부 "소말리아 해적에 피랍위험 선박 2척은 한국 아닌 태국"',
#  '11번가, 31일까지 ‘아이디어 생쇼’ 기획전 최대 50% 할인, 보너스 할인 쿠폰 발급',
#  '군 "성추행.성폭행 가해자 퇴출, 성희롱 가해자는 진급금지"',
#  '2015년 3월27일자 전국 주요 신문 사설',
#  '“마약류 중계밀수 및 신종마약 밀수 차단 강화”',
#  "'무자본 기업사냥' 김태촌 양아들 구속",
#  '공무원 군인, 성범죄로 벌금형만 받아도 `당연 퇴직` 추진',
#  '‘마약 혐의’ 김성민, 26일 구속 기소 재판일 미정',
#  '북한 "남한 간첩 두명 체포" 진술서 시인',
#  '성범죄 공무원 군인, 벌금형 받아도 ‘즉각 퇴출’',
#  '검찰, 좌석 승급 특혜 국토부 공무원 대가성 여부 수사 착수',
#  '군인 공무원, 甲질 성폭력 벌금형만으로도 퇴출',
#  '공무원-군인, 앞으로 성폭력 범죄 저지르면 즉각 퇴출된다',
#  '군인ㆍ공무원, 甲지위 악용 성폭력시 벌금형만 받아도 퇴출',
#  '‘갑질 성폭행’ 군인ㆍ공무원, 벌금형만 받아도 ‘퇴출’',
#  '군인 공무원, 甲질 성폭력 벌금형만으로도 퇴출',
#  '北 “남한 간첩 두명 체포”, 우리 정부 “터무니없는 주장 즉각 송환하라”',
#  '[이 사람-안성회 NH농협은행 전화사기예방환급팀장]“창구직원 반복교육 대포통장 근절”',
#  "성폭력 벌금형 군인 공무원 '원 스트라이크 아웃'",
#  '대형마트 화장실서 여중생 성폭행 "친구사이 고교생이 몹쓸짓"',
#  '대법, 황장엽 수양딸 ‘투자사기’ 징역 5년',
#  '軍내 성폭행자 퇴출된다',
#  '성범죄 저지른 공무원-군인, 어떻게 될까 벌금형만 받아도 ‘퇴직’',
#  '權시장사무소 관계자들 항소심 7형사부로 배정',
#  '수렵야화 어느 유배수 얘기 ⑩',
#  '"\'베트남 신부\' 어딨어?" 결혼정보업체에 불 지른 60대',
#  '북 "남한 간첩 2명 체포" 남 "즉각 송환해야"',
#  "'청소업체 위탁비 횡령' 천안시 책임론 대두",
#  '"범죄피해자 살뜰히 보살필 것"',
#  "홍성경찰 '찾아가는 이동경찰서' 운영",
#  '스포츠토토 "잘못된 명칭의 불법스포츠도박 조심하세요"',
#  '[기고]"주민등록증, 소중하게 간직하자"',
#  "성폭력 군인 공무원 '퇴출'",
#  '북한 "남한 간첩 두명 체포 극악한 테러분자"',
#  '사물인터넷 활용한 스마트 무인경비 솔루션 ‘이지워치’',
#  '[더벨]법원, 황귀남씨 등 보유 주식 의결권 제한',
#  '만삭 15세 소녀 납치 성추행한 10대 2명 구속',
#  "'세탁기 파손 분쟁' 조성진 사장 재판, 내달 17일로 연기",
#  "'이규태 비리' 증거인멸한 일광공영 직원 2명 영장",
#  "군인,공무원 성범죄 벌금형도 공직 '영구 퇴출'",
#  '北 "한국 간첩 2명 체포" 주장 美CNN "국정원, 사실 부인"',
#  "故황장엽 수양딸, '투자사기' 혐의로 징역 5년 확정",
#  '음주단속 경찰 차로 치고 달아난 前 미 군무원 구속',
#  '軍 "성추행 성폭행 범죄자 퇴출 성범죄 묵인 방관도 처벌"',
#  '공무원 군인, 성폭력 벌금형 선고만 받아도 ‘즉각 퇴출’',
#  '공무원 군인, 성폭력 범죄 저지르면 절차 없이 옷 벗는다',
#  '‘성폭행’ 공무원 군인, 절차없이 바로 옷 벗는다 ',
#  '세무조사 편의 수뢰 전 현 국세청 공무원 6명 기소',
#  '어린이집 보조금 6억 가로채 151명 적발',
#  '군인 공무원 性범죄, 벌금형만 받아도 퇴출',
#  '박범훈 前 靑수석 압수수색, 또 MB 겨냥?',
#  '박범훈 前 靑수석 압수수색, 또 MB 겨냥?',
#  '박범훈 前 靑수석 압수수색, 또 MB 겨냥?',
#  '‘힐스테이트 기흥’에 대규모 복합 커뮤니티 들어간다',
#  '"소말리아 해적에 피랍위험 선박은 한국 아닌 태국"',
#  '‘공무원 군인, 성범죄로 벌금형 받으면 당연 퇴직’ 추진',
#  '관세청, 전국 세관 첫 마약 수사정보 교류회',
#  "'공무원 군인, 성범죄로 벌금형 받으면 당연 퇴직' 추진",
#  '軍, 단 한번의 성폭력 성추행만으로도 퇴출한다',
#  '軍성폭력 근절 종합대책 발표 "성추행. 성폭행 범죄자 퇴출"',
#  '성폭행 군인 공무원, 벌금형만 받아도 퇴출',
#  '북한 “남한 간첩 두명 체포 극악한 테러분자”',
#  '‘짜고 친’ 어린이집 원장-교육원 국고보조금 6억 빼돌려',
#  "'투자 사기' 황장엽 수양딸 징역 5년",
#  '권력형 성폭력 공무원 군인, 벌금형만 받아도 바로 퇴출',
#  '‘권력형 성폭행’ 벌금형만 선고받아도 ‘당연 퇴직’',
#  '공무원 군인, 성범죄 벌금형만 받아도 영구 퇴출',
#  '[책과 삶]은둔형 외톨이 묻지마 범죄의 공통점',
#  '이규태 회장 ‘증거인멸’ 일광공영 직원 2명 구속영장',
#  '‘천황주의자’였던 아버지에 대한 소설',
#  '軍 “성추행 성폭행 가해자 퇴출 원칙”',
#  '세무컨설팅 용역 가장해 ‘세무조사 편의’ 수뢰 전 현 국세청 공무원 6명 기소',
#  '친구에게 회삿돈 8억 빌려주고 같이 도박해 날린 유명 입시업체 대표',
#  '흉터 보험금 남녀차별 없앤다',
#  '중국, 4월부터 반부패 스카이넷 작전 개시',
#  '억대 국가보조금 횡령한 평생교육원과 어린이집 원장 무더기 적발',
#  'MB 측근 중 ‘고위급’ 첫 겨냥 ‘전 정권 수사’ 본격화',
#  '지금 집필중 /④ 임옥희 경희대 후마니타스 칼리지 교수 /지금, 여기, 다시 페미니즘을 말하다',
#  'MB 측근 중 ‘고위급’ 첫 겨냥 ‘전 정권 수사’ 본격화',
#  '‘투자 사기’ 황장엽 수양딸 징역 5년 확정',
#  '북한 “남한 간첩 두명 체포 극악한 테러분자”',
#  "'무자본 기업사냥' 김태촌 양아들 구속",
#  '북 "한국 간첩 2명 체포" 기자회견 열어',
#  '[사설] 더 교묘해진 보이스피싱, 美처럼 이체지연 시간 늘려야',
#  "'사무장 병원' 요양 급여 300억원 부정 수급",
#  '공유해야 할 다문화와 외국인 범죄- 허충호(사회부 김해본부장)',
#  '진해경찰서 중고생 봉사단 30여명 “담벼락에 희망 그렸어요”',
#  '범죄피해자 경제적 지원 ‘첫 발’',
#  '다가오는 만우절, 허위 장난신고 하지 말아야',
#  '"회장님 지켜라" 압수수색 방해한 일광공영 직원 2명 영장',
#  '사감위 전자카드 도입, 불법사행산업 근절 중점 둬야',
#  '[경찰의 눈]장난전화, 위급한 생명 잃게 할 수도',
#  '옥천경찰-다문화센터 MOU',
#  "홍성 범피센터 '사랑의 집수리' 봉사",
#  '이희용 총재 "孝가 가진 따뜻한 힘, 전세계에 전합니다"',
#  "'110억 꿀꺽' 청소업체 대표 징역 2년",
#  '쿠바 공무원 부패 심각...달걀까지 빼돌려 ‘무더기 중형’',
#  '“김영란법 입법 과정 정치권 한계 적절히 지적”',
#  '“다 가려!” 레이디 가가 ‘중동버전’ 이미지 보니',
#  '저먼윙스 사고기 미스터리 시나리오 셋, 그리고 반론',
#  '48. 한 마을 다섯집에 불지른 신부 [선데이서울로 보는 그때 그 시절]',
#  '끈질긴 자전거 도둑, 더 끈질긴 경찰 CCTV 70대 추적',
#  '밀린 월세 50만 원 독촉하자 주인집에 불 지른 50대 구속',
#  '경찰병원 전화 착신전환해 보이스피싱 경찰 수사',
#  '일본 경찰, 조선총련 의장 자택 압수수색',
#  '[아침 신문 보기] 코스닥 100일간의 질주 外',
#  "음주 단속 피해 시속 100킬로미터로 도주 '아찔'",
#  '[이슈 투데이] 점점 교묘해지는 노인 대상 사기 범죄',
#  "음주 단속 피해 시속 100킬로미터로 도주 '아찔'",
#  '알몸 채팅의 달콤한 함정',
#  '[강원포럼]천안함 5주기 안보의식 재정립하자',
#  '-충북경찰청, 셉테드 교육',
#  '충북도교육청, 부패 척결 위한 계획 방안 추진',
#  "술집 박사 많은 대전 유성구, '성범죄 위험' 대도시 자치구 중",
#  '범죄피해자 경제적 지원 잇따라 담양 펜션화재 피해자에도 1960만원',
#  '<세상 만사-나라 안>대마초 키워 피운 불법체류자',
#  'ATM 카드복제기 설치한 중국동포 2명 구속',
#  '<사설>軍服 태극기, 이벤트 넘어 정신戰力 강화 계기돼야',
#  '<사설>朴대통령 司正의지 비웃다시피 하는 권력기관 非理',
#  '자전거 18㎞ 끌고간 도둑 더 독한 경찰',
#  '복지사각지대 몰린 경제적 약자 탈출구 ‘시급’',
#  '김천경찰서 ‘주민 현장 간담회’ 호응',
#  '동두천경찰서-중앙성모병원, 범죄피해자 치료 업무협약',
#  ' 평창경찰서 해피 홈 메신저 6명 위촉 간담회 열어-사진',
#  '원주 초등생 방과후 안전사고 줄인다',
#  '[기고] 블랙박스의 장점과 단점',
#  '[기고]블랙박스의 장점과 단점',
#  "'도로명 상세주소' 응급상황 생명줄",
#  '교통사고 보험사기, 직장인 가담도 늘어',
#  '대구 경찰, 대마 재배해 흡입한 우즈베키스탄인 등 2명 구속',
#  "[친절한 쿡기자] SNS '생명 불감증' 확산 우려...기독교계, SNS윤리 교육 적극 나서자",
#  '[폭로]北여성 죄수들의 교도소 성상납 보고서',
#  '일본 경찰 북한산 송이 불법 수입 관련 조총련 허종만 의장 자택 등 압수수색',
#  '“하루에 5명도...北교도소,女죄수 성상납 다반사”모범수 되기위해 먼저 성상납도',
#  '일본경찰, 조선총련 의장 자택 압수수색 송이 불법수입 사건 관련',
#  '“지구끝까지라도 쫓아갈 기세” 자전거 18㎞ 끌고간 도둑 결국 잡아낸 경찰',
#  "저먼윙스 '자살비행' 가능성 부각 조종사 1명 조종실 이탈",
#  '서울국세청 일선 세무서 5곳 동시다발 압수수색',
#  '“윗선 지시로 비자금 조성해 전달했다” 포스코건설 前 베트남 법인장 진술 확보',
#  '[2015 대한민국 명품브랜드 대상] 해외서도 명품 문구 인정 매년 신제품 개발',
#  '\'천안함 5주기\' 북한 "미군 잠수함과 충돌" 음모론 제기',
#  '천안함 5주기, 가라앉은 남북관계 북한 반응은?',
#  '천종호 부장판사 "자나 깨나 소년 생각, \'만사(萬事)소년\' 별명 붙었죠"',
#  "'독일 여객기 추락' 조종사 1명 이탈 '자살비행' 가능성 제기",
#  '범죄 피해자 경제적 보상, 검찰 주민단체가 돕는다',
#  '장난꾸러기 매력 발산 반항아 김우빈은 잊어라',
#  "[브리핑] 영도署, 범죄 피해자 '안심귀가' 협약",
#  "창원 '사무장 병원' 불법 요양급여 300억 '꿀꺽'",
#  "구리경찰서, 실종수색 '골든타임' 확보...전국 첫 '드론' 띄운다",
#  '부지 매각 대가 뒷돈 학교이사장 항소심도 실형',
#  '렌터카 이용 불법운송 무더기 검거',
#  '대전유성구, 성범죄 위험도 낮은 안전도시',
#  '[보험사기 공화국, 특별법 시급하다] 해외에선',
#  "[시론] '유령수술' 근절하려면",
#  '[보험사기 공화국, 특별법 시급하다] 무서운 범죄에 관대한 사회',
#  '일본 경찰, 조총련 의장 자택 압수수색',
#  '"한국 어선 두 척 소말리아 해적에 피랍 위험"',
#  '환전상이 피싱조직 가담해 환치기까지',
#  "[서경 하우징 페어] 두산건설 '위브' 60가지 기술로 '80% 에너지 절감' 휴먼 아파트",
#  "조종사 이탈 독일 여객기 '자살비행' 가능성 부각",
#  '정치인 사칭 착신 전환, 보이스피싱 이렇게까지 ',
#  "'권력형' 성범죄 4년새 2배 늘었다",
#  '여주경찰서 차재학 신임대장 "소통 화합 통해 범죄 없는 市 도약"',
#  "'간통죄' 위헌 판결...50대男 무죄 선고",
#  "국세청 직원 100여명 '뇌물수수 리스트' 나왔다",
#  '[단독] 한국인이 미사일부품 이란에 밀매',
#  '대청도서 수억대 도박판 벌인 공무원 등 21명 검거',
#  '시만텍, 사이버 범죄수사 협력시스템 구축',
#  '`누리작명소` 정용현 소장, 영향력 있는 인기작명가로 선정',
#  '온주완이 반한 조보아, 드라마 `실종느와르M`서 맡은 배역은?',
#  '천안시 위탁비 횡령 청소업체 대표 징역',
#  '백석대-천안서북경찰 관 학협력 체결',
#  '수렵야화 어느 유배수 얘기 ⑨',
#  "'김태촌 양아들' 수백억대 횡령 혐의로 구속",
#  "'이규태 회장 비자금 창구 의혹' 교회 건물 추가 압수수색",
#  "독일 여객기 추락 사고, '자살비행' 가능성 제기",
#  "'국가보안법 위반' 혐의 간디학교 교사 무죄 확정",
#  "'보이스피싱' 원천봉쇄법 나온다",
#  'IQ 80 조금 느린 내아이, 학교가 보듬어줄까',
#  "군인 '성매매' 처벌 수위 세진다",
#  "'살인 성폭력' 장기미제 1516건 해결한 DNA의 힘",
#  "훔친 음향기기로 개인 감상실 만든 '음향 마니아' 입건",
#  '중국 해커 돈 받고 디도스 공격 못 믿을 방어업체 대표들',
#  "9호선 2단계 '신논현~종합운동장' 28일 5시31분 첫 운행",
#  '그리스 포르투갈 재정위기 맞게 한 검은돈',
#  ...]

# %%
#특수문자제거
import re
for i,elem in enumerate(lst):
    elem = re.sub('[^0-9a-zA-Zㄱ-힗]', ' ', str(elem))
    #e.sub() 함수는 문자열에서 매치된 텍스트를 다른 텍스트로 치환할 때 사용
lst
# Out:
# ['영광경찰, 개인택시지부와 업무협약',
#  '독자투고- CPTED를 통한 범죄예방',
#  '기고- 에코(Echo)도시 조성에 한걸음씩 발걸음을 보태자',
#  "야후재팬 '사생활 침해 정보' 지운다[수정][수정]",
#  '삼성 LG, 글로벌 주도권 확보 위한 대승적 결단[수정]',
#  '울산경찰, 폭력배 강도 절도 집중단속',
#  '종교시설서 어린 남매 성추행한 20대 실형',
#  '일광공영 이규태 회장 기소',
#  '박수범 대전 대덕구청장, 자율방범대원과 손잡고 안전 도시 만든다',
#  '4 29 재 보선, 유권자 선택이 중요하다',
#  '국토부, 주차장 CCTV 조명 설치 의무화',
#  '[e-웃음 바이러스]',
#  "삼성 LG 법적분쟁 종결 합의 불구 '세탁기 파손' 공방 불가피",
#  '만우절 장난전화 처벌...적발시 벌금-구류 처분',
#  '연쇄살인범 아동성폭력범 등 출소 후에도 최장 7년간 사회 격리',
#  '무기중개상 이규태 회장, 500억원대 방산장비 납품 사기혐의로 기소',
#  '성범죄 교수 교사 교단서 영구 추방',
#  '성범죄 교수 교사 교단서 영구 추방',
#  '금감원 직원 사칭 보이스피싱 유도 문자 주의',
#  '흉악범 최장 7년 격리 보호수용법 국무회의 의결',
#  '불황에 사기 횡령범 전락하는 변호사들',
#  '‘박원순법’ 시행 6개월, 핫라인 신고 5배 증가',
#  '금감원 직원 사칭 보이스피싱 유도 문자 주의',
#  '성범죄로 형 확정받은 교사나 교수, 교단에서 영구퇴출키로',
#  '오바마, 오는 7월 취임후 처음 아버지의 나라 케냐 방문',
#  '檢, 자원외교 비리 관련 경남기업 한모 부사장 소환조사',
#  '“아베, 잔혹한 日과거사 인정해야”',
#  "검찰, '장경욱 김인숙 변호사 징계' 법무부에 직접 신청할 듯",
#  '15억원 상품권 사기 간 큰 40대 주부 붙잡혀',
#  '만우절 장난전화 처벌...아무 생각없이 했다간 형사처벌',
#  '‘창원 감계 힐스테이트 2차’, 지역 랜드마크로 우뚝',
#  "불혹 앞두고 사시 붙은 변호사, 법률시장 불황 속에 '사기꾼' 전락",
#  '양대노총 제조부문 "노사정위 일방합의 강요하고 강행처리시 총파업"',
#  "필리핀 관광위장 '황제성매매'한 교수 등 56명 검거",
#  '“ILO도 ‘北 해외노동자 인권침해’ 검토”',
#  "아버지가 용돈 줄이자 동네형과 짜고 '가짜 도둑'된 아들",
#  '가이드가 밤엔 성매매 파트너로 필리핀 ‘황제관광’무더기 적발',
#  '연쇄 살인 등 흉악범 형종료후 최장 7년간 사회격리안 국무회의 통과',
#  '만우절 장난전화 처벌, 식당 불평부터 불효자식 체포까지? "허위신고는 안돼요!"',
#  '이규태 농간에 ‘엉터리 EWTS’ 두배 주고 사',
#  '[WT논평] Destruction in civilization’s cradle',
#  '만우절, 장난전화 적발되면 공무집행방해죄 처벌',
#  "천안 외국인도움센터 '무용지물'",
#  '가정폭력 사기 혼자 아파하지 마세요',
#  '가짜 검찰청 사이트에 카카오톡 악성앱까지 ',
#  '출근하듯 입원 35억 타낸 보험사기단',
#  "'거리뷰'로 범행 장소 사전 답사 교묘한 절도범 검거",
#  "[뉴스플러스] 남한 드라마 인기에 北 '비상' 단속도 무용지물",
#  '도 넘은 폭행에도 주변 무관심 곳곳에서 개탄의 목소리',
#  '아파트 오피스텔, 범죄자 침입 못하게 짓는다 설계 기준 마련',
#  "재범 우려 강력범죄자, 최장 7년 격리 '보호수용법' 통과",
#  '내달부터 아파트 오피스텔, 범죄자 침입 못하게 해야',
#  '도 넘은 폭행에도 무관심 곳곳에서 개탄의 목소리',
#  '도 넘은 폭행에도 무관심 곳곳에서 개탄의 목소리',
#  '만우절 장난전화, “동물 죽어있는데 치워달라” 어떤 처벌 가능할까?',
#  '[TV 하이라이트]',
#  '만우절 장난전화, “만원만 입금해 달라” 황당 신고 여전..처벌은?',
#  '만우절 장난전화, 어떤 장난전화 하길래..',
#  '전국 ‘집창촌’ 24곳 폐쇄 박차 수익 몰수 추징 강화',
#  '거기 학생, 집으로 돌아가세요',
#  "포스코건설 비자금 '한 갈래' 더..檢, 20억 추가 포착",
#  '만우절 장난전화 처벌, 경찰청 “경찰력 낭비 않도록 동참 부탁”',
#  "'박원순法' 그 후.. 서울시 공무원 비리 확 줄었다",
#  '군산경찰서, 업무 유공자 6명에 표창 수여',
#  '전주지역 성매매 집결지 폐쇄 속도낸다',
#  "'전자전 훈련장비 1100억 사기 혐의' 이규태 회장 등 재판에",
#  '檢, 포스코건설 추가 비자금 정황 포착',
#  "경찰청, 만우절 앞두고 '장난전화' 자제 요청",
#  "합수단, '500억원대 군납사기' 이규태 회장 구속 기소",
#  '대포통장 판매 30대 벌금 500만원',
#  '장애 청소년과 성관계 촬영 20대 징역형',
#  '500가구 이상 주택에 주차장 CCTV 의무화',
#  '무관심에 병드는 아이들',
#  '아파트 단지 나무, 창문에서 1.5m 거리 두고 심어야 한다',
#  '옥천경찰서, 체감치안 향상 맞춤형 캠페인(사진)',
#  '알기쉬운 부동산 - 부동산 투자와 투기',
#  '경찰 금융기관 3대악성사기 공동대응 협약',
#  '충북기협, 2015년 1분기 이달의 기자상 선정',
#  '[여의나루] 빅데이터가 열어줄 새 세상',
#  '"금융감독원 직원 박선영을 주의하세요"',
#  '강진경찰-개인택시조합 MOU',
#  '‘性범죄’ 교육공무원 교수, 교단서 퇴출',
#  '‘흉악범 최장 7년 격리’ 보호수용법안 국무회의 의결',
#  '‘흉악범 최장 7년 격리’ 보호수용법안 국무회의 의결',
#  '<세상 만사-나라 안>40대여성 투자미끼 24억 사기',
#  '낮엔 가이드 밤엔 섹스파트너 100만원대 ‘황제 性매매’',
#  '낮엔 가이드 밤엔 섹스파트너 100만원대 ‘황제 性매매’',
#  '산업스파이, 北 무기거래國에 포탄기술도 빼돌려',
#  '<포럼>노동시장 改革 성공 위한 3가지 提言',
#  '멕시코, 불법 무기류 1500만 정 유통...멕시코 성인 남자 3명당 한명꼴 총기 소지하는 셈',
#  '울진경찰서-지역아동센터 범죄예방 협약',
#  '이근용 대구대학교 대외협력부총장, 대구 장애우권익연구소서 특강',
#  '檢, 조희팔 은닉재산 420억 ‘추징 보전’ 행보 피해자에 상환 지체될 수도',
#  '불법체류외국인과 피해자 보호 원년',
#  '경산경찰서 합동순찰 “외국인 밀집지역 범죄 예방해요”',
#  '검찰 조희팔 은닉자금 추징보전 논란',
#  '영천경찰서, 첫 청소년 선도심사위 개최',
#  '보성경찰, 범죄피해자 교통편의 제공 협약',
#  '양치기소년과 만우절',
#  'LGU+, 가입자 서명 도용으로 검찰 고발 당해',
#  '국내 최대라이벌 삼성ㆍLG간 법적 분쟁 일지는?',
#  '원창묵 원주시장 항소심 ‘벌금 90만원’ 선고',
#  '상습 거짓신고 피의자 잇따라 검거',
#  '교통사고 피해자 지원제도 아시나요?',
#  '교통사고 피해자 지원제도 아시나요?',
#  "경미한 범죄 '시민심사위원'이 판단",
#  "경미한 범죄 '시민심사위원'이 판단",
#  '진해 한 고등학교 앞에서 음란행위 하던 30대 체포',
#  '구미署-고용노동부 구미지청 범죄피해자 취업지원 업무협약',
#  '조희팔 자금 420억, 檢 피해자 처리 이견',
#  '[채널] 한국에 온 외국인 근로자, 공존의 조건은?',
#  '"칠곡 성장 이끄는데 생활불편은 모른 척" 석적읍 홀대 분통',
#  '인구 쑥쑥 석적읍 "기반 시설은 미흡"',
#  '경기 경찰청, 국악 마술 수화로 톡톡 튀는 범죄예방 홍보 인기',
#  '“10달러 유통 때 2~3달러 검은돈 변신?”美 특수부대, 업무 영역 확대',
#  '“모략소굴 남조선 둥지틀면 무자비한 징벌”北,인권현장사무소 서울 개설 반발',
#  '아동 성폭력범 최장 7년간 사회 격리...연쇄살인범 등 흉악범도',
#  '“성추행 영예군인,영웅일까 조폭일까?”北,영예군인 범죄 골머리',
#  '[여의도포럼-김창준] 싱가포르의 곤장제도',
#  '살인범 등 이중처벌 보호수용법 국무회의 통과',
#  '"\'널 기다리며\' 촬영 끝났어요. 하반기 개봉 기대하세요" 심은경 주연 범죄 스릴러',
#  '인터넷서 모의총기 판매 40대 벌금형',
#  '美 코리아코커스 의장 “아베, 과거 잔혹행위 분명히 인정하라”',
#  '가출 여중생 살인사건 용의자 “기절시키려고만 했다”',
#  '“통나무에 치마만 둘러도 여자로 본다?”北, 군인 성범죄 천국',
#  '전자발찌 차고도 3차례나 성범죄 20대 검거',
#  '“투자하면 돈 벌어주겠다” 24억 사기 40대 주부의 말로',
#  '“직원 통해 상품권 싸게 사주겠다” 아직도 이런 말에 속으시나요?',
#  '미 국무부 “위안부는 성을 목적으로 한 여성 매매 행위”',
#  '“김정은,외국인 상대 여대생 성매매 총살 지시” 나선지구 여대생 가격 50~80 달러',
#  '佛 상원, 성매수자 처벌 법안 부결 하원서 최종 결정',
#  '이규태 회장, 방사청 속여 1100억원 예산 가로채 기소',
#  '“자살하게 해드려요?” 살벌한 몸캠 협박 음성파일 유포 파문',
#  '필리핀 원정 성매매 ‘황제관광’ 56명 검거',
#  '아이템베이-더치트, 온라인 사기범죄 예방 업무협약 체결',
#  "내달부터 '범죄예방 건축기준' 시행",
#  '경찰, 만우절 장난전화 엄중 처벌한다 업무 방해하는 민원신고도 자제 당부',
#  "'성매매 가출소녀 살인사건' 용의자 범행자백 과거 20대女에게도",
#  "[분석+] 삼성-LG 극적 화해 왜? 검찰 법원 '판단' 남아",
#  '검찰, 동국제강 수상한 해외송금 추적',
#  '법무부 법사랑 부산동지역연합회 하형주 동아대 교수 홍보대사 위촉',
#  "아동음란물 처벌, 미국선 '무기형' 우린 '벌금'",
#  "필리핀 '황제 관광' 알선 브로커 성매수자 56명 무더기 검거",
#  '성범죄로 형 확정된 교사 교수, 교단서 영구 추방',
#  '[이준영의 세상 속으로] 두 섬나라의 다른 처신',
#  '필리핀서 ‘원정 성매매’ 한 대학교수들 황제관광 일당 검거',
#  '필리핀 원정 성매매 황제관광 55명 수년후...경찰에 ‘딱’ 망신살',
#  "'고양이에게 생선 맡긴 꼴 '",
#  "'공직선거법 위반' 원주시장 2심서 벌금 90만원..직위유지",
#  '어른들의 검은 욕망, 결국 목숨까지 ',
#  '괴산경찰서, 민 경 유기적 협력체계 구축 간담회',
#  '보은경찰서 농협군지부장 등 협약체결',
#  '충북 이달의 기자상 선정',
#  '아파트 등 건축물 범죄예방 설계해야 허가 받는다',
#  '성범죄로 형 확정된 교사 교수, 교단서 영구 추방',
#  '흉악범 출소후 최장 7년 격리',
#  "시민단체, '고객정보 도용 유출 의혹' LGU+ 고발",
#  "오바마, 취임후 처음 '아버지의 나라' 케냐 간다",
#  "만우절, 112 허위 신고시 최대 벌금 '1,000만원'",
#  '구글 보안전문가가 알려준 ‘손쉬운 온라인 보안 5계명’',
#  '[전국 패트롤] 서울시 박원순법 시행 6개월만에 공무원 비리 86% 감소 外',
#  '흉악범 형기 마쳐도 격리, 보호수용법안 국무회의 통과',
#  "서울시 '박원순법 그후' 공무원범죄 86% 급감 비리신고 384건",
#  "흉악범 최대 7년 수용 '보호수용법안' 통과",
#  "'아프리카 난민' 오해 편견? 억울함 벗은 사연",
#  '만우절, 112로 장난전화했다간 \'큰코\'....경찰 "엄정 대응" 엄포',
#  '[간추린 단신] 내일부터 음식점 PC방서 흡연 시 과태료 외',
#  '만우절 장난전화, 공무집행방해죄 처벌',
#  '대전지검 범죄피해자지원센터 3가정에 1224만원 지원',
#  '안전한 세종시 완성위한 세종경찰의 노력',
#  "'형기 끝난 흉악범 최대 7년간 격리' 법안..국무회의 통과",
#  '무인빨래방 골라턴 30대 좀도둑 덜미',
#  '흉악범 최장 7년 보호수용으로 격리 이중처벌 논란 예상',
#  '울산경찰, 폭력배 강도 절도 집중단속',
#  '종교시설서 어린 남매 성추행한 20대 실형',
#  '필리핀 성매매 ‘황제관광’ 56명 검거 교수 포함',
#  '성범죄 형 확정 교사 교수, 교단서 영구 추방',
#  '보이스피싱 조직 등 친 ‘2차사기’ 극성',
#  '피해자 코디네이터를 아시나요',
#  '지능형 범죄 ‘조폭과의 전쟁’',
#  '깨진 유리창과 콩나물시루',
#  '수사망 피해 ‘페이스오프’ 꼬리 밟힌 아파트털이범',
#  '검찰, 동국제강 비자금 총수일가 유입 증거 확보 주력',
#  '검찰, 동국제강 비자금 의혹 증거 확보 주력',
#  '[내일시론] 권력자 인사전횡이 부패의 뿌리',
#  '112에 전화해 "식당음식이 맛없다"',
#  '순천시, 순천경찰서 기관단체간 업무협약 체결',
#  '국토부, 범죄예방 건축기준 고시 조명 CCTV 등 설치 의무화',
#  '김문수 “유엔 북한인권 현장사무소, 동북아 전체에 밝은 등불 될 것”',
#  "윌스기념병원 박춘근 병원장, 지역사회발전 유공 '표창'",
#  '개 훔쳐놓고, 보상 전단지 보고 연락했다 덜미',
#  "'흉악범 출소 후 7년 격리' 보호수용법안 국무회의 통과",
#  '도둑 단골 침입로 아파트 배관들 외벽 속에 설치',
#  "'박원순법' 6개월 공무원 비리 크게 줄었다",
#  "필리핀 성매매 '황제 관광' 교수ㆍ회계사 등 55명 입건",
#  '美 코리아코커스 의장 “아베, 과거 잔혹행위 분명히 인정하라”',
#  '만우절 핑계 112 허위전화 장난 아닌 처벌, 아십니까',
#  '성매매 여중생 살해 피의자, 3주전 유사 범행',
#  '잊혀질 권리 보호에 나선 야후 재팬 성적 동영상 집단 괴롭힘 피해 등 삭제',
#  '[특별기고] 제주4ㆍ3의 아픔과 치유 그리고 상생',
#  "'야누스 얼굴' 상속자와 뒷골목 사내 넘나들다",
#  "교수 회계사도 못 견딘 유혹 필리핀 '황제 관광' 뭐길래?",
#  '하드보일드 뜻, 폭력적 주제를 냉철하게 한국형 하드보일드는 ‘복수는 나의 것’',
#  '[범죄의 재구성] 바람 쐬고 온다더니 ‘롤리타의 제물’된 14세 소녀',
#  '포스코건설 비자금 20억 추가 포착',
#  '500가구 이상 공공주택 `범죄 사각지대` 없앤다',
#  '"보험업계 자율ㆍ책임 검사체계 구축"',
#  '“상품권 싸게 구입해 줄게” 40대 주부 15억 꿀꺽',
#  '애완견 훔친 50대 남성 이유가 “외로워서”',
#  '4월부터 아파트 등 범죄예방 기준 따라야 허가',
#  "박원순法 시행 반년 신고 10배 늘고 공무원 범죄 '급감'",
#  "경기경찰, '애완견 절도 주의보'",
#  '500가구 이상 공동주택, 학교, 오피스텔 등 건축물 범죄예방 기준 맞아야 허가난다',
#  '툭하면 입원 보험사기 무더기 검거 ‘수법’ 경악',
#  "경기도 '애완견' 도난사고 잇따라",
#  "CGV아트하우스, 4월 '라이브톡'으로 '모스트 바이어런트' 선정",
#  '친구와 짜고 아버지 사기친 10대, 호된(?) 훈육으로 덜미',
#  '친구와 짜고 아버지 사기친 10대, 호된(?) 훈육으로 덜미',
#  '새벽 시간대 무인 빨래방만 노린 절도범',
#  '벌금 내려고 또다시 차량 턴 대학생',
#  '훔친 노트북 추적 빈집털이범 덜미',
#  "'흉악범 최대 7년 추가 격리' 법안 통과 이중처벌 논란",
#  '"범죄발생시 피해자 즉시 지원"',
#  '하드보일드 뜻, 감정 드러내지 않는 냉담한 태도 영화 소재로도 활용?',
#  '국정원, 첨단무기 핵심기술 등 유출사고 지난해 최다 적발',
#  '[범죄수사의 세계] 흉포해지는 인질극, 대한민국도 안전지대 아니다',
#  '원주시장 항소심서 벌금 90만원 공직 유지',
#  "CGV아트하우스 4월 라이브톡'모스트 바이어런트' 선정",
#  '\'봉천동 10대女살인\' 용의자 범행자백 "수면마취제 이용"',
#  "'1100억원대 사기' 이규태 일광공영 회장 기소",
#  "새누리당, 지역일꾼 '새줌마' 공약 '안전관악' '예산불독'",
#  '상품권 싸게 사준다며 교회지인 상대로 수십억대 사기',
#  "연쇄살인범 아동성폭력범 형기 끝난 뒤 최대 7년간 '격리'",
#  "중고거래 구매자에게 판매자 가장 '삼각사기'친 일당",
#  "'박원순법' 6개월, 서울시 공무원 범죄 7분의 1로 줄어",
#  "아파트도 범죄예방 시설 반드시 갖춰야 '건축허가'",
#  '장난전화했다간 112허위신고 10건 중 7건 처벌받았다',
#  "미리보는 4월 국회...기재 교문 환노위 '화약고'",
#  '"딸이 불효자식, 잡아가달라" 만우절 112 장난전화 했다간 ',
#  '바다에 버린 살인 흉기, 그들의 눈을 피할 순 없다',
#  "단통법, 6개월째 제자리걸음 국회 논의는 '안갯속'",
#  '"정보화시대의 파수꾼 \'화이트해커\', 정부 차원서 관리해야"',
#  '문 열린 고급차만 노려 금품 600만원 훔친 30대男 구속',
#  '가정주부가 투자 미끼로 4년간 24억대 사기 행각',
#  "'훈남 경찰'부터 '고양고양이'까지 네티즌 눈길잡은 공공기관 SNS",
#  '‘애완견 도난주의보’ ‘외로워서’ 훔쳐(?) 키울려고 했다',
#  '미 국무부, “위안부는 성 목적으로 여성 매매한 행위”',
#  '강력범 형기 마쳐도 최대 7년 격리한다',
#  '강력범 형기 마쳐도 최대 7년 격리',
#  '방위사업비리 합수단 이규태회장 기소 1천억 부풀려',
#  '행정자치부, 대구지역 공무원 성폭력 범죄 2011년 이후 매년 발생',
#  '“상품권 싸게 구입해줄게” 15억 챙긴 40대 주부 ‘쇠고랑’',
#  '인천시, 아동안전지도 제작 사업 추진',
#  '모텔서 숨진 女중생, 알고보니 세남성이 손톱에는 "충격!"',
#  '모텔서 숨진 女중생, 알고보니 세남성이 손톱에는 "충격!"',
#  '검찰, 포스코 20억원대 비자금 추가 포착',
#  '500가구 이상 아파트 CCTV 의무화',
#  "'흉악범 최장 7년 격리' 보호수용법안 국무회의 통과",
#  '보호수용법안 국무회의 통과 이중처벌 논란일 듯',
#  '하드보일드 뜻, 감정 드러내지 않는 냉담한 태도 하드보일드 영화의 대표작은?',
#  "필리핀서 '황제 관광'한 대학교수, 대기업 회사원 원정 성매매 일당 검거",
#  '필리핀 관광 위장 성매매 56명 검거 대학교수 등 포함',
#  '교수 회계사 필리핀 ‘성매매 황제관광’ 56명 딱 걸려',
#  '하드보일드 뜻, 감정에 좌우되지 않는 냉담한 태도 ‘1차 세계대전서 유래’',
#  '500가구 이상 아파트 내달부터 CCTV 의무 설치',
#  '[M+기획 ‘청불 영화’①] ‘킹스맨’ 흥행으로 본 성공 요소는?',
#  '[M+기획 ‘청불 영화’①] ‘킹스맨’ 흥행으로 본 성공 요소는?',
#  '노인 대상 사기등 범죄 극성',
#  '군산시 옥서면 전 지역 CCTV 설치',
#  '전북경찰, 강 절도 6월 말까지 고강도 단속',
#  '하드보일드 뜻, 감정에 좌우되지 않는 냉담한 태도 한국영화 대표작은?',
#  '성범죄 교수 교사, 교단서 영구 퇴출',
#  '필리핀 원정 성매매단 56명 검거',
#  '하드보일드 뜻, 폭력적 주제를 냉철+무감한 태도로 묘사하는 특징',
#  '2만弗 덫',
#  '4월부터 범죄 예방 기준 맞춰 건축해야 건축허가 받는다',
#  '[박광규의 미스터리 산책]뛰는 놈 위에 나는 놈, 그 위에 컴퓨터',
#  '‘제2 오원춘 막자’ /수원시 고육지책',
#  "야후 재팬, 개인의 성적 화상, 병력, 범죄피해사실 등은 '삭제'...새로운 기준 발표",
#  '흉악범, 출소 후 최대 7년 수용소 격리',
#  '[케이블 위성 TV하이라이트]2015년 3월 31일',
#  '4월 1일 오늘의 하이라이트',
#  '멕시코, 불법무기 3명당 1명꼴 유통',
#  '억대 사기 전 경기노점상 회장 기소',
#  '교수 회계사 등 필리핀 원정 성매매 무더기 적발',
#  '만우절 112 황당 장난전화 안돼요',
#  '출소 후 성형 키높이 수술 전국서 빈집털이',
#  '취업알선 미끼 7억원 꿀꺽 20대 신종 사기범',
#  '"외로워서" 공원서 애완견 훔친 50대 입건',
#  '필리핀 원정 성매매 55명 적발  대학교수 공인회계사 등',
#  '여성 청소년보호시설 ‘나사로의 집’ 폐쇄 위기 자활 꿈꾸던 소녀들 어디로 가나',
#  '흉악범 최장 7년 격리 ‘보호수용법’ 통과  이중처벌 논란',
#  '오바마, 취임 뒤 처음 ‘아버지 나라’ 간다',
#  '야후재팬 ‘잊혀질 권리’ 기준 발표',
#  '‘황제노역 판결’ 판사, 부적절한 수임 논란',
#  '“식당 음식 맛없다” 112 황당 신고',
#  '미국 코널리 하원의원 “아베 잔혹행위 명확히 인정해야”',
#  '포스코건설 비자금 새 줄기 드러나 베트남 공사 과정 20억 조성 포착',
#  '‘잠룡’ 김문수 “유엔 北인권사무소, 중국 러시아에 등불 밝힐 것”',
#  '[사설]인권위의 ‘역주행’ 언제까지 지켜봐야 하나',
#  '필리핀 세부 관광 위장 성매매  교수 등 56명 검거',
#  '[박상미의 공감 스토리텔링]사람을 죽이는 일, 사람을 살리는 일',
#  '양주 소년범 보호시설 문닫을 위기 /“여기 나가면 또 방황할까 걱정돼요”',
#  '박범훈 ‘전방위 외압’ 교육부 휘저어 당시 청와대서도 논란',
#  '훈육 차원 체벌해도 ‘처벌’받아요',
#  '[이창근의 두드림]두드림의 육하원칙',
#  '마이클 브라운 사건과 구조적 인권침해',
#  '[시대의 창]싼 게 비지떡: 선별복지의 함정',
#  '[조찬제 선임기자의 월드프리즘]미국은 왜 MH17기 피격 자료 공개 않나',
#  "정부, 성매매 원천봉쇄 나선다 전국 '집창촌' 폐쇄",
#  '건설사 회장 사칭 수천만원 꿀꺽 50대 징역형',
#  '성남중원경찰서, 피해자 멘토위원회 ‘희망의 등대’ 발대식 개최',
#  '[법률 플러스] 증인출석요구 받으면 출석해야 하나',
#  '잠들어 있던 문화관광자원을 깨우다',
#  '자전거 구리 등 훔친 생활형 절도범 줄줄이 검거',
#  '끈기 깡으로 사기범 잡은 여경',
#  '■ 경남신문 제12기 독자위원회 2차 회의',
#  '장성 북하파출소, 절도 아동범죄예방 활동',
#  '충북기협 이달의 기자상',
#  '옥천지역 서민금융 왜 이러나',
#  '"한국터보기계 이헌석 대표 미국 인도 재고 해달라"',
#  'AP통신 사장 “언론인 납치ㆍ살해, 국제법상 전쟁 범죄에 포함해야”',
#  '전과 59범, 경찰 지구대에서 남의 물건 슬쩍했다가 또 경찰신세',
#  '외국인 근로자 밀물 공존의 해법 모색',
#  '[청년 해외취업 허와 실]‘절박한 구직자’ 두 번 울리는 취업사기',
#  "KBS1 '시사기획 창' 외국인 근로자, 공존의 조건",
#  '호기심 살빠지는 약에 학생 마약사범 67% 급증',
#  '엘리트 법대교수, 심야 열차간에서 30대女 허벅지 더듬다 체포',
#  '금융당국, 보이스피싱 막기 ‘칼빼들었다’',
#  '[황종택의新온고지신]연무마모(鍊武磨矛）',
#  "실종느와르M 강하늘, '미생' 잊게하는 소름돋는 연기력...김강우와 두뇌대결 시작",
#  '타인 카드 사용한 중학생, 형사처벌 대신 즉결심판',
#  '충북경찰청 무심천 공원 자전거순찰대 운영',
#  '권시장 항소심 재판부, 선거범죄 과거 판결 살펴보니 ',
#  '대전 고화질CCTV 52개교에 2억 지원',
#  "성폭행 사건에 '들끓는 논산' CCTV도 4대 중 3대 고장",
#  "'휴대폰점에 휴대폰이 없다' 절도범 머리위에 있는 업주",
#  '오늘의 대전 세종 충남 충북-중도일보(3월30일 월요일자)',
#  "진화하는 보이스피싱 '검찰총장 공문' 위조 수억 편취",
#  '[이브닝 이슈] "채림 남매 폭언" 모욕 혐의로 피소 모욕죄란?',
#  '통장, 모르고 빌려줘도 범죄 악용 시 무조건 형사처벌',
#  '[뉴스 플러스] 도박업자에 ‘수뢰’ 경찰 간부 수사',
#  '2000억대 판돈 주무른 한 중 합작 도박조직',
#  '“아베, 美 연설서 위안부 문제 직시하고 사과해야”',
#  '[글로벌 시대] 영국 신사는 케이팝을 좋아해?/이에스더 아리랑TV 글로벌네트워크부장',
#  '檢, 조희팔 은닉재산 환수 위해 이례적 추징금 구형',
#  '남원 순창 장수범죄피해자지원센터, 정기총회 개최',
#  '남원 공공기관 민간단체, 법질서 실천 협약',
#  '진안경찰서, 보이스피싱예방 홍보영상 제작',
#  '황금대사헌 황희와 이완구 총리',
#  '"위헌소지 분명한데 판단 안했다면.."',
#  'SNS 타고 10대 마약범죄 74% 급증',
#  '흔들리는 청소년들 - 청소년 범죄 위험수위',
#  '영동서, 금산서와 112 총력대응체계 구축 간담회',
#  '옥천경찰서, 체감치안 향상 맞춤형 캠페인',
#  '-충북경찰청 무심천 자전거순찰대 운영',
#  '상습적으로 가정폭력을 행사한 40대 검거',
#  '충북기협, 2015년 1분기 이달의 기자상 선정',
#  '전국 24개 ‘집창촌’ 폐쇄 여가부 경찰 등 TF 구성',
#  '<세상 만사-나라 안>전과 59범 경찰지구대서 현금 훔쳐 또 입건',
#  '‘조건만남’ 미끼로 유인해 강도질 한 10대 4명 구속',
#  '집창촌서 유흥업소까지 샅샅이 性매매 전방위 단속',
#  '“제2 이해인 막아라” ‘피싱’과의 전쟁',
#  '합수단, 1154억 사기 혐의 이규태 今明 구속기소',
#  '美의원들 ‘과거사 반성’ 촉구하지만 아베 ‘형식적 언급’ 그칠듯',
#  '<시론>경제는 ‘명령’으로 움직이지 않는다',
#  '달서구 “범죄 피해자 지원” 경찰과 상시네트워크 구축',
#  '경일대, 해외건설 현장 체험 전문가 특강 “특성화사업단 순항”',
#  '구미경찰서-고용노동부...범죄피해자 취업지원 MOU',
#  '달서구청_달서 성서경찰서 ‘긴급지원 네트워크’ MOU',
#  '만우절 장난전화 이제 그만',
#  '대포통장의 덫',
#  '여수경찰서 전남 최초 ‘경미 범죄 심사위원회’ 개최',
#  "대법원 '긴급조치' 판결에 담긴 정치화법",
#  '옥천경찰서, 4대 사회악 근절 홍보 활동',
#  '스마트폰 카메라 이용 촬영 성범죄 연루되면 전문변호사 조력 구해야',
#  '성폭력 근절 대책 현장 실천이 우선',
#  '성폭력 근절 대책 현장 실천이 우선',
#  '‘장발장법’ 폐지 혜택 볼까',
#  '‘장발장법’ 폐지 혜택 볼까',
#  "국내외)'920곳 매장서 2천억 판돈' 韓中합작 도박조직 적발",
#  '필로폰 대마 등 마약사범 22명 무더기 검거',
#  '투탑시티 더 이상 외면방치는 안된다',
#  '투탑시티 더 이상 외면방치는 안된다',
#  '[지역의 갈길을 묻다] 4. 박선규 영월군수',
#  '[지역의 갈길을 묻다] 4. 박선규 영월군수',
#  '귀금속 절취한 이삿짐센터 직원 구속',
#  '기고',
#  '[기고]대출해 주겠다는 전화 "속지 마세요"',
#  '대구경찰청-대구숙련기술협 범죄 피해 외국인 보호 협약',
#  '최면진정제 \'졸피뎀\' 남용 많아 이철우 의원 "범죄 악용" 경고',
#  '[야고부] 확신범',
#  '편의점 바닥 비상벨로 신고 1분만에 잡힌 강도',
#  '제2의 ‘오원춘 박춘풍’ 없다 수원시, 범죄예방 위해 가로등 전면 교체',
#  '‘은행 털고 도망가는 법’ 구글 검색으로 익힌 부부 체포',
#  '간 큰 40대 경찰지구대에서 남의 금품 훔쳤다가 덜미',
#  "리콴유 일본과의 '특별한' 관계 공포의 대상에서 벤치마킹, 훈수까지",
#  '“北 강원도는 강간도?”군인, 성폭행 통제불능 상태',
#  '조희팔 은닉재산 환수, "측근에 추징금 구형"',
#  '‘장기 복역에 감 잃어’ 어설픈 도둑들 결국 철창행',
#  '[사설] 아베 총리 ‘인신매매론’ 위안부 문제 물타기일 뿐',
#  '“중국 말단 경찰간부 집에서 현금 180억원 나와”',
#  '도봉산 기슭서 열린 ‘판도라 컨테이너’ ‘방산 비리’ 이규태 회장 비밀 자료 무더기 발견',
#  '검찰, 동국제강 해외송금 추적 비자금 조성 증거 확보',
#  "'와우', 공식소설 특별 한정판 '골드 에디션' 선보여",
#  '[한경에세이] 천안함 5주기를 보내며',
#  '"119 신고 후 현장 떠나면 뺑소니 아니다"',
#  '[시사人] 하계열 부산진구청장',
#  "시민 체감 높은 '생활 범죄' 꼼짝마!",
#  '[셉테드의 진화] "비행 청소년은 가라" 10대만 골라 내쫓는 신기한 경보음',
#  '주차 차량 창문깨고 금품 훔친 50대 구속',
#  '감쪽같은 검사 연기, 젊은 여성도 속인 보이스피싱',
#  '[셉테드의 진화] 전문가의 지적은? "벽화 일색 부산 셉테드 이젠 마을 맞춤형으로"',
#  '베트남 신부 결혼 실패 60대 결혼중개업체 방화 살인',
#  "단속 기관도 두 손 든 '멸치 포획금지 법'",
#  "현직 경찰 간부, '뇌물수수 혐의' 수사 시작되자 휴가낸 뒤 한달째 잠적",
#  '영동경찰서-금산경찰서 지휘관 간담회 개최',
#  "[사설] 솜방망이 처벌이 키워온 '보험사기 공화국'",
#  '전국 24개 집창촌 폐쇄 돌입',
#  '檢, 동국제강 비정상적 해외송금 추적 실무자 소환',
#  '"중국 하급 경찰간부 집에서 현금 180억원 나와 게임업자로부터 뇌물 챙겨"',
#  '상인 지원금 가로챈 전통시장 회장 입건',
#  '성형수술과 가발로 변장해 아파트 턴 전문털이범 덜미',
#  '[단독] ‘하베스트’ 평가 보고서 입수 곳곳 왜곡 과장',
#  '1분여 만에 뚝딱 간이 금고 통째로 훔쳐',
#  '충북지방경찰청 10월 말까지 무심천 자전거 순찰대 운영',
#  '‘마을방송’ 유익한 매체로 자리매김하길',
#  '“학폭 예방 위한 제도적 방안과 전사회적 관심 협력 필요”',
#  '소년재판 8000번의 결론 "아이들에게 \'아버지\'가 필요합니다"',
#  '‘제2의 이해인 피해 막아라’ 금감원, 전쟁선포',
#  '이발해주며 갱생 길 걷는 ‘사형수 이발사’',
#  "CCTV 관제탑서 '청소년 선도'",
#  '보험사기와 대책',
#  '[인터뷰] 황재덕 경기도선관위 상임위원',
#  '보육교사 가짜 위탁교육 국가보조금 6억원 ‘꿀꺽’',
#  "?'이해인 사건' 도마 위 금감원, 보이스피싱 근절 나선다",
#  "'장기 복역에 감 잃어' 어설픈 도둑들 결국 철창행",
#  '"욕설과 협박에 시달려도..나이롱 귀신 끝까지 추적한다"',
#  "월드 오브 워크래프트 소설, 특별 한정판 '골드 에디션' 출시",
#  '[TV] OCN ‘실종느와르 M’ 강하늘-김강우ㆍ박희순 숨막히는 연기경쟁 첫 방부터 터졌다',
#  '울산대 스마트벤처학교, ICT 창업기지로',
#  '독재와 결별한 스리랑카, 100일 계획은 성공할까',
#  '대법 "위헌소지 분명한데 판단 안했다면 재판 다시해야"',
#  '[보험 상품]‘무배당 롯데 Only 여성보험’ 여성 고객 특화 후유장해땐 매월 100만원',
#  '창원 집값 끝없는 오름세, 가격 경쟁력 갖춘 창원 감계 힐스테이트 2차 분양',
#  '명문대 출신 법학과 교수, 열차서 성추행하다 덜미',
#  "수억 갈취해 '15년간 해외 도피' 조폭, 실형 선고",
#  '한국첨단안전산업협회 창립총회',
#  '[디지털산책] 주민등록번호제도 고칠 때 됐다',
#  '네시삼십삼분, 퓨전 RPG FPS 등 새로운 장르 차별화',
#  '마곡지구 대형건설사 오피스텔이 이 가격? `마곡 아이파크` 분양 마감 코앞',
#  '10대 학생 등 젊은층 마약범죄 급증..인터넷 통한 유통 증가 등이 원인',
#  '금감원“제2 이해인 나오지 않게 ”',
#  '[보험상품-NH농협손해보험] ‘재해 범죄 사고 질병’한번에 걱정 뚝',
#  '[Nationwide]‘경찰서를 털어라?’ 지구대서 금품 훔친 40대',
#  '논산 대형마트 화장실서 여중생 성폭행',
#  '[박석흥 세상보기] 전 근대 제국주의 극복한 리더십시대의 종언',
#  '처벌 대신 즉결심판 전과자 전락 예방',
#  '이해득실 맞선 사행산업 전자카드제',
#  '여가부, 성매매집결지 폐쇄 추진 현황 공유 집결지 폐쇄 박차',
#  '이조로 변호사의 작품 속 법률산책 - ‘스물’의 강요죄',
#  '안행위, 4월국회서 총기단속 누리과정 지방채 논의',
#  "'뇌물 혐의' 경찰 간부, 수사 시작되자 잠적",
#  '김희정 장관 "불법 성매매업소 범죄수익 몰수 추징"',
#  '대법, 지적장애 10대女 성관계 촬영한 20대 실형 확정',
#  '젊은층 SNS로 마약접촉↑...경찰 "온라인 공급 집중단속"',
#  '檢, 유사수신 사기범 조희팔 은닉재산 환수',
#  '경찰서에서 가방 훔친 간큰 40대',
#  '`집창촌` 뿌리뽑는다 여가부, 24곳 폐쇄 추진',
#  '집창촌 뿌리뽑는다 여가부, 24곳 폐쇄 추진',
#  '이해인 씨 사건에 금감원 보이스피싱 근절 나섰다',
#  '키 늘리고 얼굴까지 고친 절도범',
#  '키 늘리고 얼굴 고친 절도범',
#  '[독자칼럼] `사이버데이`를 제안합니다',
#  '대법 "청소년 성관계 촬영, 원칙적으로 아청법 위반"',
#  '북한의 ‘강원도’는 ‘강간도’? 그 수위를 보니',
#  '[MIT] 스마트시티②',
#  '[MIT] 스마트시티①',
#  '[포토] 윤진서, 드라마 속 범죄 프로파일러',
#  'CCTV 진화...이젠 청소년 선도까지',
#  '동대문구, 친절운동 한방타운 복지 등 7대 전략과제 선정',
#  '아직 남아있는 전국 성매매집결지 24곳 폐쇄 본격 추진',
#  '완전범죄 꿈 꾼 30대 男, 수술로 키 늘리고 양약까지',
#  "명문대 출신 법학과 교수가 열차서 성추행 '현행범으로 체포'",
#  '진화하는 거짓말탐지기 이젠 뇌까지 본다',
#  '[M+예능전망대] 파일럿 예능, 대거 정규行 판도 급변할까',
#  '스릴러 SF로 재탄생하는 제인 오스틴의 고전들',
#  "잠복 끝에 교통카드 훔쳐 간 범인 잡고 보니 '환경미화원'",
#  '명문대 출신 법학과 교수, 열차서 성추행하다 그만 ',
#  '위험한 노인들 각종 범죄의 표적',
#  '완주서 성 가정폭력 예방 모의훈련',
#  '덕진지구대, 맞춤형 범죄예방 위해 지역민과 소통',
#  '익산 오산파출소, 점심 문안순찰 호응 좋아',
#  '[홍기영칼럼] 분노조절장애의 심리학',
#  '[Special Report 1]환경규제 세제혜택 등에 업고 하이브리드카 ‘붕붕’',
#  '[US REPORT]공직자 문건 스캔들 ‘이메일’ 다음은 ‘텍스트 게이트’?',
#  '[US REPORT]공직자 문건 스캔들 ‘이메일’ 다음은 ‘텍스트 게이트’?',
#  '[신병주의 ‘왕으로 산다는 것’](3) 우리가 잘 몰랐던 ‘세종’의 시련 불행한 가족사에 걸어다니는 ‘病주머니’',
#  '염태영 수원시장 “햇빛정책 펴겠다”',
#  '‘제2 오원춘 막자’ 수원시 고육지책',
#  '아베 “위안부, 인신매매에 의해 괴롭힘” /일 정부 책임 회피 ‘꼼수’ 눈총',
#  '출소 후 성형 키높이 수술 전국서 빈집털이',
#  '[케이블 위성 TV하이라이트]2015년 3월 31일',
#  '탕웨이 이해인도 당한 보이스피싱  금감원, 금융사기와 전쟁 선포',
#  '여성 청소년보호시설 ‘나사로의 집’ 폐쇄 위기 자활 꿈꾸던 소녀들 어디로 가나',
#  '“모두가 날 알게 될 거야” 저먼윙스 부기장 ‘문제’ 속속 발견',
#  '“모두가 날 알게 될 거야” 저먼윙스 부기장 ‘문제’ 속속 발견 ‘정신질환자 차별’ 우려도 증폭',
#  '도봉산 인근 컨테이너에 꼭꼭 숨긴 ‘방산비리 자료’',
#  '“모두가 날 알게 될 거야” 저먼윙스 부기장 ‘문제’ 속속 발견',
#  '박종철, 박종운, 박상옥',
#  '양주 소년범 보호시설 문 닫을 위기 “여기 나가면 또 방황할까 걱정돼요”',
#  '[아침을 열며]돼지라도 돼달라',
#  '[기고]사행산업감독위는 빅브러더가 되려 하나',
#  '동국제강 압수수색 장세주 회장 출국금지',
#  '[군 이대론 안된다]기밀 빼주고, 불량부품 눈감고 “패망 직전 월남군 보는 듯”',
#  '기밀 빼주고, 불량부품 눈감고 “패망 직전 월남군 보는 듯”',
#  "'제2의 이해인 막아라' 금감원, 금융사기와 전쟁선포",
#  '경찰지구대에서 남의 금품 훔친 40대 덜미',
#  '‘제2의 이해인 막아라’ 금감원, 연예인協 등에 일제 공문',
#  '“119에 사고 신고후 현장 떠났으면 뺑소니 아니다”',
#  '사이버 명예경찰 ‘누리캅스’ 회원 모집',
#  '버스정류장 ‘묻지마 살인범’ 항소심도 징역 25년',
#  '성관계 장면 여성 신체 몰카 남성 3명 집유 벌금형',
#  '중부暑 경찰관 3명, 성신고서 1박 2일 고교생 체험 ‘스쿨폴리스 학교 속으로’ \n ‘폭력예방’ 부모걱정 덜어 준다',
#  '7살 여아 성추행한 60대 경비원, 징역 2년 6월로 감형',
#  '평택 안성 범죄피해자지원센터 등...기금마련 감자심기 행사 구슬땀',
#  '구리경찰서, 전국 최초 ‘드론’ 치안서비스 떴다',
#  '7세 여아 성추행 한 아파트 경비원, 항소심서 감형',
#  '‘짜고 친’ 어린이집 원장-평생교육원 국고보조금 6억 빼돌려',
#  'FDS, 보안 만능 솔루션으로 떠오르나?[수정]',
#  '[신간도서]누가 진짜 범인인가',
#  '권선택 항소심 재판부 확정',
#  '음성서, 40대 절도범 구속',
#  '무심천 자전거순찰대 운영',
#  '원룸 밀집지역 안전택배함 설치',
#  '대전시교육청, 24시간 학교안전 강화',
#  '천안동남서 업준섭 순경 보이스 피싱 피해 2억 8500만원 막아',
#  '119 신고뒤 현장이탈, 법원 “뺑소니 아니다”',
#  '교복입은 경찰들의 ‘기숙사 삼시세끼’',
#  '퇴직공직자 10명중 4명 방산업체서 모셔가',
#  "'살해된 가출 여중생에 성매매 알선 혐의' 2인조 구속영장 발부",
#  '성관계 여성신체 촬영한 남성3명 ‘집유 벌금’',
#  '헤어지자는 내연녀 흉기로 위협한 40대 실형',
#  '피해자 보호 전담경찰관의 아침 단상(斷想)',
#  '경찰, 자전거 스마트폰 절도 생활범죄 1400여건 단속',
#  '절도 최다 생활범죄 1419건 해결',
#  '中 거점 2000억대 인터넷 도박 적발',
#  "1000여 매장서 '2천억' 주무른 한 중 합작 도박조직",
#  '"통장 빌려주면 50만원 줄께" 대포통장 모집 콜센터 조직 검거',
#  '[기고] 법질서 선의 미학',
#  "실종느와르 M, '엘리트 형사' 김강우-'사이코패스' 강하늘 긴장감 넘치는 두뇌대결...'게임 스타트'",
#  "합수단, '방위사업 비리' 은폐 가담 일광공영 직원 2명 구속",
#  '‘선불폰 불법 유통’ 이통 3사 제재 착수',
#  "'7세 여아 성추행' 60대 경비원, 항소심서 감형  솜방망이처벌",
#  '"이거 먹으면 " 항암버섯으로 난치병 환자 등친 사기꾼',
#  "방통위, 선불폰 '불법 유통' 관련 이통 3사 제재할 듯",
#  "실종느와르M 강하늘, 단 2회 촬영위해 5kg감량...소름돋는 연기력에 네티즌 '극찬세례'",
#  "실종느와르M 강하늘, '미생'은 잊어라...역대급 사이코패스 연기 '소름'",
#  '이번엔 동국제강 檢 수사 전방위 확대',
#  '실종느와르M 강하늘, \'천재형사\' 김강우와 두뇌대결 "게임을 준비했다"...긴장감 \'최고\'',
#  '[이슈분석]전방위로 확산되는 ‘부정부패 척결’[수정]',
#  '[이슈분석]고발요청권 첫 발동 산업계 파장은[수정]',
#  '살해된 가출 여중생에 성매매 알선 2인조 영장 발부',
#  "英, 조세회피처에 '페이퍼컴퍼니 실소유주 등기' 압박",
#  '민간경비업체와 손잡고 치안 사각지대 해소 나서',
#  '일광공영 숨긴 방산자료 1톤 발견',
#  '생활범죄수사팀, 두달간 729명 검거',
#  "2000억대 '한 중 도박조직' 적발",
#  '오늘의 주요뉴스',
#  "'무심코 넘긴 통장' 대가성 없어도 처벌 받는다",
#  '실종느와르M 강하늘, 신들린 사이코패스 연기 “더 죽을 사람 없을까요?”',
#  '실종느와르M 강하늘, 일주일 5kg 감량 “섬뜩한 사이코패스 미소”',
#  '실종느와르M 강하늘, 신들린 사이코패스 연기 “체중감량 영향?”',
#  '실종느와르M 강하늘, 섬뜩한 미소 뒤 두뇌게임 ‘대박’',
#  "'뇌물수수 혐의' 현직 경찰 간부, 휴가낸 뒤 한달째 잠적",
#  '[데스크 칼럼] 기업수사 칼날 비틀진 말아야',
#  "NH농협銀 '대포통장과의 전쟁' 1년새 20% → 2%로 대폭 감소",
#  '충북경찰청 무심천 자전거순찰대 운영',
#  '상장사 "임원 규제 강화 법안 반대"',
#  '교복입은 경찰들의 ‘기숙사 삼시세끼’',
#  '민간경비업체와 손잡고 치안 사각지대 해소 나서',
#  '귀금속 절취한 이삿짐센터 직원 구속',
#  '할머니 영정사진 담긴 여대생 카메라 실종사건',
#  '중앙지법 형사법관 "법정 언행 신중히 해야" 의견 모아',
#  '욕정 못이긴 경비원, 일곱살 지하계단 성추행 법원은 왜 감형?',
#  '"남는 항암버섯 나눠줄게" 애타는 난치병 환자 등쳐',
#  '입연 일광공영 ‘금고지기’ 판도라의 컨테이너 열렸다',
#  '[포토뉴스] 범죄피해자 교통편의 제공 협약',
#  "관리는 허술 범죄엔 무방비 사람 잡는 '졸피뎀(수면 유도제)'",
#  '생활범죄 대상 1호는? 자동차',
#  '[포럼] 벌금형과 사회적 약자 배려',
#  '[보험사기 공화국, 특별법이 시급하다] 처벌수위 높여야 보험금 사냥꾼 막는다',
#  '[보험사기 공화국, 특별법이 시급하다] 특별법 발의한 박대동 의원 "흉포화하는 보험사기 못막으면 사회 신뢰기반 무너질 수 있다"',
#  '지자체 "나 떨고있니" 지역안전지수 5월 첫 공표',
#  '‘간통죄 위헌’ 결정 이후 한달 달라진 新풍속도',
#  '119 신고뒤 현장이탈, 법원 “뺑소니 아니다”',
#  '성관계 여성신체 촬영한 남성3명 ‘집유 벌금’',
#  '헤어지자는 내연녀 흉기로 위협한 40대 실형',
#  '中 인터넷 도박장 900여곳 차린 한 중 도박조직 적발',
#  '방산비리 증거 인멸한 일광공영 직원 2명 구속',
#  '"세무조사 편의 봐달라" 전 현직 세무공무원 뒷돈',
#  '일광공영이 숨긴 1t 사업자료 도봉산서 발견.. 직원 2명 구속',
#  '500억대 공군 장비 비리 등 일광공영 1톤 넘는 은닉자료, 도봉산 밑 컨테이너서 발견',
#  "'중국 매장 920곳서 판돈 2000억' 한중 합작 도박조직",
#  '[날줄씨줄]적반하장',
#  "느슨한 봄 타고 '피싱 사기' 꿈틀",
#  "'방산비리 자료 증거인멸' 일광공영 직원 2명 구속",
#  "'모텔 피살 10대女'에 성매매 알선한 20대男 2명 구속",
#  'ESPN "맨유, 생각하고 돈 써야" 부진 선수 줄줄이 비판',
#  'UNHRC, "北의 장성택 처형...국제인권법 위반"',
#  '일광공영 방위사업 자료, 컨테이너에서 무더기 발견',
#  '중국에 콜센터 차려두고 대포통장 모집한 일당 구속',
#  '檢, 중국과 공조 통해 2000억대 도박장 운영한 한국인 총책 검거',
#  "'이규태 비리' 증거인멸한 일광공영 직원 2명 구속",
#  "'봄철 몰카 주의보' 지하철서 자동차키를 주목해야하는 이유",
#  '"장기이식 해주겠다"고 환자 8명 속여 돈뜯어낸 20대男 구속',
#  '경찰 생활범죄수사팀 두 달 간 1400건 넘는 사건 해결',
#  '사이버범죄 스미싱은 줄고, 파밍은 늘고',
#  '동국제강 장세주 회장 25년만에 또 해외도박 혐의 자금흐름 추적',
#  "대법, 위조달러 처벌 제동? 법조항 '위헌' 우려",
#  '중국서 900개 도박장 운영하던 국내 도박조직 검거 판돈만 2000억',
#  '"20세부터 80세까지 도박" 국제 도박판 벌인 일당 재판에',
#  "고법, '7세 여아 성추행' 60대 경비원에 징역 2년6월 실형",
#  '외환위기때 같은 생계형 좀도둑 기승',
#  '외환위기때 같은 생계형 좀도둑 기승',
#  '판돈 무려 2000억 한 중도박단 검거',
#  '2000억대 한 중 도박조직 적발',
#  '"동국제강 다음은 " 재계 사정확산 촉각',
#  '"동국제강 다음은 " 재계 사정확산 촉각',
#  '"통장 빌려주면 1주일에 50만원 주겠다" 꼬드기더니 ',
#  '자전거 휴대폰 쌀 커피믹스 등 ‘생계형 좀도둑’ 기승',
#  '920곳에서 2천억 판돈 도박 국제 도박 조직 적발',
#  '[M+리뷰] ‘코블러’, 일상에 찌든 미생을 위한 판타지',
#  '[M+인터뷰] “차실장” 외치던 김상경 ‘살인의뢰’서 울부짖다',
#  '첫 방송에 화제 ‘실종느와르 M’ 포인트는 ‘리얼함’',
#  '[‘실종느와르M’ 첫방②] ‘해맑은’ 강하늘의 무서운 변신',
#  '[‘실종느와르M’ 첫방①] 짜릿한 두뇌싸움의 향연 ‘진짜가 나타났다’',
#  '도박과 머니게임',
#  '첫 방송만에 화제 ‘실종느와르 M’만의 ‘리얼함’',
#  '7세 여아 성추행 60대 경비원, 항소심서 징역 2년6월로 감형',
#  '대법원 “위헌 소지 다분한 법 그대로 적용한 판결 파기환송”',
#  '검, 도박업자에게서 ‘뇌물 혐의’ 경찰 간부 수사',
#  '도봉산 인근 컨테이너에 꼭꼭 숨긴 ‘방산비리 자료’',
#  '“모두가 날 알게 될 거야” 저먼윙스 부기장 ‘문제’ 속속 발견 ‘정신질환자 차별’ 우려도 증폭',
#  '‘7살 여자어린이 성추행’ 60대 경비원, 항소심서 징역 2년6월로 감형',
#  '[편집국에서] 박종철, 박종운, 박상옥 / 권태호',
#  '[아침을 열며]돼지라도 돼달라',
#  '동국제강 압수수색 장세주 회장 출국금지',
#  '[기고]사행산업감독위는 빅브러더가 되려 하나',
#  '[군 이대론 안된다]기밀 빼주고, 불량부품 눈감고 “패망 직전 월남군 보는 듯”',
#  '첫 방송에 핫이슈 된 ‘실종느와르 M’ ‘리얼함’이 살렸다',
#  '북한 "탈북자들 고향으로 돌아와라"',
#  '아베 "위안부는 인신매매 희생자" 日 책임 회피 위한 교묘한 \'꼼수\'',
#  '성관계 여성신체 몰래 촬영한 3명 집행유예 벌금',
#  '범죄 단속, 민 관 따로 없다 주민 모두가 참여',
#  '성범죄 공무원 벌금형 땐 퇴출',
#  '[주말 하이라이트]',
#  '[독자의 소리] 강제 전학, 학폭 근절 대책 아니다/최주원 군산경찰서 여성청소년계장 경감',
#  '[뉴스 분석] 아베 “위안부, 인신매매 가슴 아파”',
#  '아베에 멍석 깔아준 美 경제 실리 챙기는 日 ‘新밀월’',
#  '20대 기사,운전교습女와 눈맞아 여관 갔다가..',
#  '공무원 군인 성범죄 벌금형만 받아도 바로 퇴출',
#  '간통죄 위헌 결정 후 도내 첫 무죄 선고',
#  '도내 75개 도로서 주1회 동시 검문검색',
#  "국내외'공무원 군인, 성범죄로 벌금형 받으면 당연 퇴직' 추진",
#  '상습절도범 장발장법 위헌 결정 구제 가능?',
#  '軍 "성추행.성폭행 범죄자 퇴출 성희롱 땐 진급금지"',
#  '밀반입 대마씨 재배한 후 흡입 우즈벡 불법체류자 2명 구속',
#  "'맞춤형 보이스피싱' 알면서 당할 판",
#  "'산통' 깨는 사회, '진통' 겪는 부부 『가족의 실패』",
#  '[2015년 주목할 신기술] 사물인터넷',
#  '법원, 119에 사고 신고 후 현장이탈했다면 뺑소니 아니다',
#  '터키, 게양대 올라 국기 제거한 청년에 13년9개월형',
#  '헌재 간통죄 위헌 결정 후 강원 재심서 첫 ‘무죄’ 선고',
#  '“장성택 처형은 국제법 위반”유엔,北에 답변 요구',
#  '北,"간첩 혐의 국민 2명 자체법 따라 엄중 처벌”-10년 이상 노동교화형 예상',
#  '“김정은 비자금 관리 정찰총국 공작원 프랑스 추방?”北,美강력 비판',
#  '보육교사 7260명 훈련기록 조작 국가보조금 6억 챙긴 평생교육원',
#  '성폭력 군인 공무원 ‘원 스트라이크 아웃’ 정부, 성폭력 근절 대책 발표',
#  '공무원 군인 성범죄, 벌금형만 받아도 퇴출',
#  "SNS 무장한 경찰 시민들 '좋아요'",
#  '[경찰팀 리포트] 변관수 남대문경찰서장 "서울역 노숙인 재활 돕고 집회 마찰 최소화할 것"',
#  '[경찰팀 리포트] 나이지리아서 온 메일, 중기를 발칵 뒤집다',
#  '"복지는 당연히 받아야 하는 권리? 남의 주머니서 나오는 \'강요된 자선\'일 뿐"',
#  '공무원 군인 성범죄 중징계, 벌금형에도 당연 퇴직 추진',
#  '[사건사고] 음성경찰서, 상습 가정폭력 행사한 40대 검거',
#  "간통죄 위헌 결정 이후, 강원도내서 재심 재판 첫 '무죄' 판결",
#  '유엔 "북한 장성택 처형, 명백한 국제법 위반"',
#  '법원 "119 신고 후 현장 떠났으면 뺑소니 아니다"',
#  '"北, 장성택 처형은 국제법 위반" 유엔인권이사회 규정',
#  '유엔, "北 장성택 처형은 국제법 위반"',
#  '"댁의 부모님 안녕하십니까" 어르신 \'금융사기\' 활개',
#  '교통사고 가해자, 119신고 후 현장이탈..法 "뺑소니 아냐"',
#  "'혐오스러워서' 레즈비언을 살인했다? 죄 경감 사유 될까?",
#  '동작구, 주민참여로 범죄없는 마을 만든다',
#  "간통죄 위헌 결정 후 강원 재심서 첫 '무죄' 선고",
#  '유엔 "북한 장성택 처형은 국제법 위반"',
#  '“공무원 군인, 앞으로 성폭력 걸리면 지위 가리지 않고 무조건 옷 벗는다”',
#  '권력형 성폭력 공무원 군인 /벌금형만 받아도 바로 퇴출',
#  '공무원 군인, 성범죄 벌금형만 받아도 영구 퇴출',
#  '성관계 모습 여성 치마속 촬영한 3명 재판 받아',
#  '[책과 삶]은둔형 외톨이 묻지마 범죄의 공통점',
#  '유엔 “북한 장성택 처형, 국제법 위반”',
#  '아베 “위안부는 인신매매 희생자” 가해자 언급 ‘생략’',
#  'MB 측근중 ‘고위급’ 첫 겨냥 ‘전 정권 수사’ 본격화',
#  '"\'베트남 신부\' 어딨어?" 결혼정보업체에 불 지른 60대',
#  '간통죄 위헌 결정 후 강원 재심서 첫 `무죄` 선고',
#  '공무원 군인, 성폭력 범죄를 저지르면 퇴직 교사도 교단에서 즉각 퇴출',
#  '[사설] 아베 美의회 연설에서 日우경화 망동 사과하라',
#  '공무원 군인, 성폭력 범죄 저지르면 벌금형 선고에 퇴직 교사도 즉각 퇴출',
#  '독자투고- 신종 신용카드위조 대책 서둘러야',
#  '프리즘- 조영택 “요양보호사 처우개선 이뤄져야"',
#  '독자투고- 산림절도는 중대한 범죄',
#  '검찰, 담양펜션화재 피해자 생계비 등 지원',
#  '[슈퍼리치] 제임스 패터슨 댄 브라운 책 한권으로 ‘인세 갑부’ 되다',
#  '순창 팔덕파출소, 농축산물 도난 예방위한 CCTV 일제점검',
#  '진안경찰, 보이스피싱 대처 적극 홍보',
#  '주차문제에 야구방망이로 위협한 50대 징역형',
#  '김제경찰서 부정부패 척결 T/F 팀 구성',
#  '검찰, 보훈급여 부정수급자 3명 기소',
#  '[포토]중랑구, 범죄피해자 보호 지원 업무협약 체결',
#  '울산 중부서, 성신고에서 ‘스쿨폴리스 학교속으로’',
#  '공무원 군인, 성범죄로 벌금형만 받아도 퇴출',
#  '"우월적 지위 이용 성범죄 더이상 무관용"',
#  '공무원 군인, 성폭력 근절 대책 실시..."벌금형 선고시 당연 퇴직"',
#  '[사설] 권력형 성범죄엔 관용 없다',
#  '보육교사 출석부 조작 국가보조금 6억 챙겨',
#  '남고생 2명, 영업중인 대형마트 화장실서 여중생 성폭행',
#  '아동등장 음란물 퍼뜨린 대학교 외국인 영어강사 붙잡혀',
#  '성폭력 공무원 군인 벌금형만 받아도 퇴출',
#  '32억원 투자사기 친 황장엽 수양딸, 징역 5년',
#  '귀걸이 삼킨 뒤 2층에서 뛰어내린 30대女, 징역 2년6월',
#  "고 김태촌 양아들, '기업사냥꾼' 변신해 전횡 일삼다 덜미",
#  '‘투자 사기’ 황장엽 수양딸 징역 5년 확정',
#  '‘방산 비리’ 일광공영 직원 2명 영장',
#  '음주단속 피하려다 경찰관 치고 달아난 美군무원 구속',
#  '[뉴스 브리핑] 프로야구 개막전 암표거래 집중단속 外',
#  '軍, 성범죄 가해자 퇴출 진급 금지  제대군인 복지 박탈',
#  '인천지검, 세무조사 편의 수뢰 전ㆍ현 국세청 공무원 6명 기소',
#  "[슈퍼리치] 살인 사기 횡령 법정 선 갑부들 '추락 그 순간'",
#  "[집중취재]모바일 금융혁신의 키 '핀테크'",
#  '日경찰, 북한산 송이버섯 밀수 혐의 조총련 의장 압수수색',
#  '男 1000만, 女 3200만원? 흉터 보험금 차별 없앤다',
#  '쇼핑몰서 여중생 성폭행당해, 매장 CCTV 고장 관리 소홀',
#  '[현장 행정] 돈의동 쪽방촌에 행복과 희망 꽃피운다',
#  '[격동의 한 일 70년] “위안부 문제 해결이 관건 정상회담 통한 연대로 극복해야”',
#  '군인 공무원 성범죄 강력 대응 벌금형만 받아도 퇴출',
#  '北 "남한 간첩 2명 체포" 정부 "간첩 아니다, 즉시 송환"',
#  '성범죄 공직자, 벌금형만 받아도 퇴출',
#  "군대 대학 내 성폭력 범죄자 '벌금형'만 받아도 퇴출",
#  '아베 日 총리, 4월 29일 사상 첫 상 하원 합동 연설',
#  '"끝까지 추적해 붙잡는다" 자전거 도둑보다 더 끈질긴 경찰',
#  '강동성심병원, 강동경찰서와 업무협약 체결',
#  '[포토뉴스]해피홈 메신저 정기간담회',
#  '[책]내 안의 끔찍한 괴물을 꺾고 스스로 구원하리라',
#  "충주서, 노인들 대상 '전화금융사기발생 피해 예방활동'벌여",
#  '음성경찰, 동료 지갑 휴대폰 절취 피의자 구속',
#  '상습적으로 가정폭력을 행사한 40대 검거',
#  "제천경찰서-세명대학교 '캠퍼스 지킴이' 발대식",
#  '북한 "남한 간첩 두명 체포 극악한 테러분자"',
#  '공무원 벌금형 받으면 당연퇴직 ‘권력형 性범죄’ 뿌리 뽑는다',
#  '공무원 벌금형 받으면 당연퇴직 ‘권력형 性범죄’뿌리 뽑는다',
#  '警 대대적 단속 칼 빼드는데 性매매 여성 자립지원은 줄어',
#  '警 대대적 단속 칼 빼드는데 性매매 여성 자립지원은 줄어',
#  '교수 공무원 軍 性범죄 ‘원스트라이크 아웃’',
#  '교수 공무원 軍 性범죄 ‘원스트라이크 아웃’',
#  '‘투자 사기 혐의’ 故황장엽 수양딸 징역 5년 확정',
#  '보조금 빼돌린 어린이집 원장 무더기 적발',
#  '‘담양 펜션 화재’ 유족 도운 광주지검',
#  '속초범죄피해자지원센터 간담회',
#  '사진뉴스=해피 홈 메신저 정기 간담회',
#  '시간 지배하는 경찰이 범죄도 제압',
#  '[투고] 가볍게 건넨 통장 무겁게 받는 수갑',
#  '[투고]가볍게 건넨 통장 무겁게 받는 수갑',
#  "최보경 교사(산청 간디학교) '국보법 위반' 굴레 벗었다",
#  "산청 간디학교 최보경 교사 '국보법' 굴레 벗어",
#  '최보경 교사 국가보안법 굴레 벗다',
#  '[열린마당]근린치안, 맞춤형순찰, 안전한 제주',
#  "'공무원 성범죄로 벌금형 받으면 당연 퇴직' 추진",
#  '[동정] 김시택 예천경찰서장',
#  '[친절한 쿡기자] “총 맞았다” 셀카 올리고 실연 여성 자살 과정 생중계 SNS ‘생명 불감증’ 확산',
#  '“국정원에 매수돼 정보 제공?”北,남한 간첩 2명 체포 주장',
#  '아동 음란동영상 유포한 외국인 영어강사 입건',
#  '‘투자 사기’ 황장엽 수양딸 징역 5년 확정',
#  '“대형마트 화장실서 고교생이 여중생 성폭행”',
#  '황장엽 수양딸 징역 5년',
#  '정부, 우월적 지위를 이용한 성범죄 처벌 대폭 강화',
#  '성폭행 군인, ‘원아웃’ 퇴출 성희롱 가해자는 진급금지',
#  '예멘 대규모 공습 이어 지상전도 임박',
#  '"표현의 자유면에서 한국은 사법파쇼" NCCK토론회',
#  '[단독] “세월호 1년 디지털은 사람을 기다린다”',
#  "'깨진 유리창'에 숨겨진 두 가지 이야기",
#  '공무원 군인, 성폭력 범죄시 바로 퇴출 교원 역시 적용',
#  '(구청브리프)서울 동작구, “주민참여로 범죄없는 청정마을 만들어요”',
#  '북한, \'남한 간첩\' 두명 체포 발표 "극악 테러분자" 주장',
#  "[생글기자 코너] '생글생글' 아직도 모르는 사람 있나요? 등",
#  '아동청소년 음란물 유포한 부산 사립대 영어강사 검거',
#  "'공무원 군인, 성범죄로 벌금형 선고시 당연 퇴직' 추진",
#  '성폭력 군인 공무원 벌금형에도 바로 퇴직',
#  '북한 "남한 간첩 두명 체포 국정원이 매수"',
#  '[책] 안중근, 1909년 10월 26일 세발의 총성',
#  '軍 “성추행.성폭행 범죄자 퇴출 성희롱 땐 진급금지”',
#  '"소말리아 해적에 피랍위험 선박은 한국 아닌 태국"',
#  '“섹시는 NO” ‘레이디 가가 노출’ 가리는 중동',
#  "유병언 '벽장' 뺨치는 이규태 회장 '비밀의 방' 어떻게 생겼나보니",
#  "'공무원 군인, 성범죄로 벌금형 받으면 당연 퇴직' 추진",
#  '울산 중부서, 성신고에서 ‘스쿨폴리스 학교속으로’',
#  '아동 음란동영상 유포 외국인 강사 입건',
#  '북한 “남한 간첩 두명 체포 극악한 테러분자”',
#  '공무원 군인, 성범죄로 벌금형 받으면 ‘당연 퇴직’',
#  '꺾일 줄 모르는 창원 아파트 매매가 창원 시내 전세가로 내 집 마련 가능한 아파트는 어디?',
#  '공정위, 대기업 불공정행위 감시 강화',
#  '남한은 종북몰이, 북한은 간첩몰이?',
#  "성폭력 공직자 벌금형부터 '퇴출'",
#  '북한 "남한 간첩 두명 체포 北 보위부 주장 \'국정원 간첩\' 기자회견',
#  '해수부 "소말리아 해적에 피랍위험 선박 2척은 한국 아닌 태국"',
#  '11번가, 31일까지 ‘아이디어 생쇼’ 기획전 최대 50% 할인, 보너스 할인 쿠폰 발급',
#  '군 "성추행.성폭행 가해자 퇴출, 성희롱 가해자는 진급금지"',
#  '2015년 3월27일자 전국 주요 신문 사설',
#  '“마약류 중계밀수 및 신종마약 밀수 차단 강화”',
#  "'무자본 기업사냥' 김태촌 양아들 구속",
#  '공무원 군인, 성범죄로 벌금형만 받아도 `당연 퇴직` 추진',
#  '‘마약 혐의’ 김성민, 26일 구속 기소 재판일 미정',
#  '북한 "남한 간첩 두명 체포" 진술서 시인',
#  '성범죄 공무원 군인, 벌금형 받아도 ‘즉각 퇴출’',
#  '검찰, 좌석 승급 특혜 국토부 공무원 대가성 여부 수사 착수',
#  '군인 공무원, 甲질 성폭력 벌금형만으로도 퇴출',
#  '공무원-군인, 앞으로 성폭력 범죄 저지르면 즉각 퇴출된다',
#  '군인ㆍ공무원, 甲지위 악용 성폭력시 벌금형만 받아도 퇴출',
#  '‘갑질 성폭행’ 군인ㆍ공무원, 벌금형만 받아도 ‘퇴출’',
#  '군인 공무원, 甲질 성폭력 벌금형만으로도 퇴출',
#  '北 “남한 간첩 두명 체포”, 우리 정부 “터무니없는 주장 즉각 송환하라”',
#  '[이 사람-안성회 NH농협은행 전화사기예방환급팀장]“창구직원 반복교육 대포통장 근절”',
#  "성폭력 벌금형 군인 공무원 '원 스트라이크 아웃'",
#  '대형마트 화장실서 여중생 성폭행 "친구사이 고교생이 몹쓸짓"',
#  '대법, 황장엽 수양딸 ‘투자사기’ 징역 5년',
#  '軍내 성폭행자 퇴출된다',
#  '성범죄 저지른 공무원-군인, 어떻게 될까 벌금형만 받아도 ‘퇴직’',
#  '權시장사무소 관계자들 항소심 7형사부로 배정',
#  '수렵야화 어느 유배수 얘기 ⑩',
#  '"\'베트남 신부\' 어딨어?" 결혼정보업체에 불 지른 60대',
#  '북 "남한 간첩 2명 체포" 남 "즉각 송환해야"',
#  "'청소업체 위탁비 횡령' 천안시 책임론 대두",
#  '"범죄피해자 살뜰히 보살필 것"',
#  "홍성경찰 '찾아가는 이동경찰서' 운영",
#  '스포츠토토 "잘못된 명칭의 불법스포츠도박 조심하세요"',
#  '[기고]"주민등록증, 소중하게 간직하자"',
#  "성폭력 군인 공무원 '퇴출'",
#  '북한 "남한 간첩 두명 체포 극악한 테러분자"',
#  '사물인터넷 활용한 스마트 무인경비 솔루션 ‘이지워치’',
#  '[더벨]법원, 황귀남씨 등 보유 주식 의결권 제한',
#  '만삭 15세 소녀 납치 성추행한 10대 2명 구속',
#  "'세탁기 파손 분쟁' 조성진 사장 재판, 내달 17일로 연기",
#  "'이규태 비리' 증거인멸한 일광공영 직원 2명 영장",
#  "군인,공무원 성범죄 벌금형도 공직 '영구 퇴출'",
#  '北 "한국 간첩 2명 체포" 주장 美CNN "국정원, 사실 부인"',
#  "故황장엽 수양딸, '투자사기' 혐의로 징역 5년 확정",
#  '음주단속 경찰 차로 치고 달아난 前 미 군무원 구속',
#  '軍 "성추행 성폭행 범죄자 퇴출 성범죄 묵인 방관도 처벌"',
#  '공무원 군인, 성폭력 벌금형 선고만 받아도 ‘즉각 퇴출’',
#  '공무원 군인, 성폭력 범죄 저지르면 절차 없이 옷 벗는다',
#  '‘성폭행’ 공무원 군인, 절차없이 바로 옷 벗는다 ',
#  '세무조사 편의 수뢰 전 현 국세청 공무원 6명 기소',
#  '어린이집 보조금 6억 가로채 151명 적발',
#  '군인 공무원 性범죄, 벌금형만 받아도 퇴출',
#  '박범훈 前 靑수석 압수수색, 또 MB 겨냥?',
#  '박범훈 前 靑수석 압수수색, 또 MB 겨냥?',
#  '박범훈 前 靑수석 압수수색, 또 MB 겨냥?',
#  '‘힐스테이트 기흥’에 대규모 복합 커뮤니티 들어간다',
#  '"소말리아 해적에 피랍위험 선박은 한국 아닌 태국"',
#  '‘공무원 군인, 성범죄로 벌금형 받으면 당연 퇴직’ 추진',
#  '관세청, 전국 세관 첫 마약 수사정보 교류회',
#  "'공무원 군인, 성범죄로 벌금형 받으면 당연 퇴직' 추진",
#  '軍, 단 한번의 성폭력 성추행만으로도 퇴출한다',
#  '軍성폭력 근절 종합대책 발표 "성추행. 성폭행 범죄자 퇴출"',
#  '성폭행 군인 공무원, 벌금형만 받아도 퇴출',
#  '북한 “남한 간첩 두명 체포 극악한 테러분자”',
#  '‘짜고 친’ 어린이집 원장-교육원 국고보조금 6억 빼돌려',
#  "'투자 사기' 황장엽 수양딸 징역 5년",
#  '권력형 성폭력 공무원 군인, 벌금형만 받아도 바로 퇴출',
#  '‘권력형 성폭행’ 벌금형만 선고받아도 ‘당연 퇴직’',
#  '공무원 군인, 성범죄 벌금형만 받아도 영구 퇴출',
#  '[책과 삶]은둔형 외톨이 묻지마 범죄의 공통점',
#  '이규태 회장 ‘증거인멸’ 일광공영 직원 2명 구속영장',
#  '‘천황주의자’였던 아버지에 대한 소설',
#  '軍 “성추행 성폭행 가해자 퇴출 원칙”',
#  '세무컨설팅 용역 가장해 ‘세무조사 편의’ 수뢰 전 현 국세청 공무원 6명 기소',
#  '친구에게 회삿돈 8억 빌려주고 같이 도박해 날린 유명 입시업체 대표',
#  '흉터 보험금 남녀차별 없앤다',
#  '중국, 4월부터 반부패 스카이넷 작전 개시',
#  '억대 국가보조금 횡령한 평생교육원과 어린이집 원장 무더기 적발',
#  'MB 측근 중 ‘고위급’ 첫 겨냥 ‘전 정권 수사’ 본격화',
#  '지금 집필중 /④ 임옥희 경희대 후마니타스 칼리지 교수 /지금, 여기, 다시 페미니즘을 말하다',
#  'MB 측근 중 ‘고위급’ 첫 겨냥 ‘전 정권 수사’ 본격화',
#  '‘투자 사기’ 황장엽 수양딸 징역 5년 확정',
#  '북한 “남한 간첩 두명 체포 극악한 테러분자”',
#  "'무자본 기업사냥' 김태촌 양아들 구속",
#  '북 "한국 간첩 2명 체포" 기자회견 열어',
#  '[사설] 더 교묘해진 보이스피싱, 美처럼 이체지연 시간 늘려야',
#  "'사무장 병원' 요양 급여 300억원 부정 수급",
#  '공유해야 할 다문화와 외국인 범죄- 허충호(사회부 김해본부장)',
#  '진해경찰서 중고생 봉사단 30여명 “담벼락에 희망 그렸어요”',
#  '범죄피해자 경제적 지원 ‘첫 발’',
#  '다가오는 만우절, 허위 장난신고 하지 말아야',
#  '"회장님 지켜라" 압수수색 방해한 일광공영 직원 2명 영장',
#  '사감위 전자카드 도입, 불법사행산업 근절 중점 둬야',
#  '[경찰의 눈]장난전화, 위급한 생명 잃게 할 수도',
#  '옥천경찰-다문화센터 MOU',
#  "홍성 범피센터 '사랑의 집수리' 봉사",
#  '이희용 총재 "孝가 가진 따뜻한 힘, 전세계에 전합니다"',
#  "'110억 꿀꺽' 청소업체 대표 징역 2년",
#  '쿠바 공무원 부패 심각...달걀까지 빼돌려 ‘무더기 중형’',
#  '“김영란법 입법 과정 정치권 한계 적절히 지적”',
#  '“다 가려!” 레이디 가가 ‘중동버전’ 이미지 보니',
#  '저먼윙스 사고기 미스터리 시나리오 셋, 그리고 반론',
#  '48. 한 마을 다섯집에 불지른 신부 [선데이서울로 보는 그때 그 시절]',
#  '끈질긴 자전거 도둑, 더 끈질긴 경찰 CCTV 70대 추적',
#  '밀린 월세 50만 원 독촉하자 주인집에 불 지른 50대 구속',
#  '경찰병원 전화 착신전환해 보이스피싱 경찰 수사',
#  '일본 경찰, 조선총련 의장 자택 압수수색',
#  '[아침 신문 보기] 코스닥 100일간의 질주 外',
#  "음주 단속 피해 시속 100킬로미터로 도주 '아찔'",
#  '[이슈 투데이] 점점 교묘해지는 노인 대상 사기 범죄',
#  "음주 단속 피해 시속 100킬로미터로 도주 '아찔'",
#  '알몸 채팅의 달콤한 함정',
#  '[강원포럼]천안함 5주기 안보의식 재정립하자',
#  '-충북경찰청, 셉테드 교육',
#  '충북도교육청, 부패 척결 위한 계획 방안 추진',
#  "술집 박사 많은 대전 유성구, '성범죄 위험' 대도시 자치구 중",
#  '범죄피해자 경제적 지원 잇따라 담양 펜션화재 피해자에도 1960만원',
#  '<세상 만사-나라 안>대마초 키워 피운 불법체류자',
#  'ATM 카드복제기 설치한 중국동포 2명 구속',
#  '<사설>軍服 태극기, 이벤트 넘어 정신戰力 강화 계기돼야',
#  '<사설>朴대통령 司正의지 비웃다시피 하는 권력기관 非理',
#  '자전거 18㎞ 끌고간 도둑 더 독한 경찰',
#  '복지사각지대 몰린 경제적 약자 탈출구 ‘시급’',
#  '김천경찰서 ‘주민 현장 간담회’ 호응',
#  '동두천경찰서-중앙성모병원, 범죄피해자 치료 업무협약',
#  ' 평창경찰서 해피 홈 메신저 6명 위촉 간담회 열어-사진',
#  '원주 초등생 방과후 안전사고 줄인다',
#  '[기고] 블랙박스의 장점과 단점',
#  '[기고]블랙박스의 장점과 단점',
#  "'도로명 상세주소' 응급상황 생명줄",
#  '교통사고 보험사기, 직장인 가담도 늘어',
#  '대구 경찰, 대마 재배해 흡입한 우즈베키스탄인 등 2명 구속',
#  "[친절한 쿡기자] SNS '생명 불감증' 확산 우려...기독교계, SNS윤리 교육 적극 나서자",
#  '[폭로]北여성 죄수들의 교도소 성상납 보고서',
#  '일본 경찰 북한산 송이 불법 수입 관련 조총련 허종만 의장 자택 등 압수수색',
#  '“하루에 5명도...北교도소,女죄수 성상납 다반사”모범수 되기위해 먼저 성상납도',
#  '일본경찰, 조선총련 의장 자택 압수수색 송이 불법수입 사건 관련',
#  '“지구끝까지라도 쫓아갈 기세” 자전거 18㎞ 끌고간 도둑 결국 잡아낸 경찰',
#  "저먼윙스 '자살비행' 가능성 부각 조종사 1명 조종실 이탈",
#  '서울국세청 일선 세무서 5곳 동시다발 압수수색',
#  '“윗선 지시로 비자금 조성해 전달했다” 포스코건설 前 베트남 법인장 진술 확보',
#  '[2015 대한민국 명품브랜드 대상] 해외서도 명품 문구 인정 매년 신제품 개발',
#  '\'천안함 5주기\' 북한 "미군 잠수함과 충돌" 음모론 제기',
#  '천안함 5주기, 가라앉은 남북관계 북한 반응은?',
#  '천종호 부장판사 "자나 깨나 소년 생각, \'만사(萬事)소년\' 별명 붙었죠"',
#  "'독일 여객기 추락' 조종사 1명 이탈 '자살비행' 가능성 제기",
#  '범죄 피해자 경제적 보상, 검찰 주민단체가 돕는다',
#  '장난꾸러기 매력 발산 반항아 김우빈은 잊어라',
#  "[브리핑] 영도署, 범죄 피해자 '안심귀가' 협약",
#  "창원 '사무장 병원' 불법 요양급여 300억 '꿀꺽'",
#  "구리경찰서, 실종수색 '골든타임' 확보...전국 첫 '드론' 띄운다",
#  '부지 매각 대가 뒷돈 학교이사장 항소심도 실형',
#  '렌터카 이용 불법운송 무더기 검거',
#  '대전유성구, 성범죄 위험도 낮은 안전도시',
#  '[보험사기 공화국, 특별법 시급하다] 해외에선',
#  "[시론] '유령수술' 근절하려면",
#  '[보험사기 공화국, 특별법 시급하다] 무서운 범죄에 관대한 사회',
#  '일본 경찰, 조총련 의장 자택 압수수색',
#  '"한국 어선 두 척 소말리아 해적에 피랍 위험"',
#  '환전상이 피싱조직 가담해 환치기까지',
#  "[서경 하우징 페어] 두산건설 '위브' 60가지 기술로 '80% 에너지 절감' 휴먼 아파트",
#  "조종사 이탈 독일 여객기 '자살비행' 가능성 부각",
#  '정치인 사칭 착신 전환, 보이스피싱 이렇게까지 ',
#  "'권력형' 성범죄 4년새 2배 늘었다",
#  '여주경찰서 차재학 신임대장 "소통 화합 통해 범죄 없는 市 도약"',
#  "'간통죄' 위헌 판결...50대男 무죄 선고",
#  "국세청 직원 100여명 '뇌물수수 리스트' 나왔다",
#  '[단독] 한국인이 미사일부품 이란에 밀매',
#  '대청도서 수억대 도박판 벌인 공무원 등 21명 검거',
#  '시만텍, 사이버 범죄수사 협력시스템 구축',
#  '`누리작명소` 정용현 소장, 영향력 있는 인기작명가로 선정',
#  '온주완이 반한 조보아, 드라마 `실종느와르M`서 맡은 배역은?',
#  '천안시 위탁비 횡령 청소업체 대표 징역',
#  '백석대-천안서북경찰 관 학협력 체결',
#  '수렵야화 어느 유배수 얘기 ⑨',
#  "'김태촌 양아들' 수백억대 횡령 혐의로 구속",
#  "'이규태 회장 비자금 창구 의혹' 교회 건물 추가 압수수색",
#  "독일 여객기 추락 사고, '자살비행' 가능성 제기",
#  "'국가보안법 위반' 혐의 간디학교 교사 무죄 확정",
#  "'보이스피싱' 원천봉쇄법 나온다",
#  'IQ 80 조금 느린 내아이, 학교가 보듬어줄까',
#  "군인 '성매매' 처벌 수위 세진다",
#  "'살인 성폭력' 장기미제 1516건 해결한 DNA의 힘",
#  "훔친 음향기기로 개인 감상실 만든 '음향 마니아' 입건",
#  '중국 해커 돈 받고 디도스 공격 못 믿을 방어업체 대표들',
#  "9호선 2단계 '신논현~종합운동장' 28일 5시31분 첫 운행",
#  '그리스 포르투갈 재정위기 맞게 한 검은돈',
#  ...]

# %%
len(lst)
# Out:
# 18188

# %%
#리스트의 한elem단위로 토크나이징
transaction = []
for n in lst:
    transelem = komoran.nouns(str(n))
    transaction.append(transelem)
transaction
transaction
# Out:
# [['영광', '경찰', '개인택시', '지부', '업무', '협약'],
#  ['독자', '투고', '범죄', '예방'],
#  ['기고', '에코', '도시', '조성', '한걸음', '발걸음'],
#  ['야후', '재팬', '사생활 침해', '정보', '수정', '수정'],
#  ['삼성', '글로벌', '주도', '확보', '대승', '결단', '수정'],
#  ['울산', '경찰', '폭력배', '강도', '절도', '집중', '단속'],
#  ['종교', '시설', '남매', '성추행', '20대', '실형'],
#  ['일광', '공영', '이규태', '회장', '기소'],
#  ['박수범', '대전', '대덕구청장', '자율', '방범대원', '안전', '도시'],
#  ['보선', '유권자', '선택'],
#  ['국토부', '주차장', '조명', '설치', '의무'],
#  ['웃음', '바이러스'],
#  ['삼성', '법적', '분쟁', '종결', '합의', '세탁기', '파손', '공방'],
#  ['만우절', '장난', '전화', '처벌', '적발', '벌금', '구류', '처분'],
#  ['연쇄살인범', '아동', '성폭력범', '등', '출소', '후', '최장', '7년', '간', '사회', '격리'],
#  ['무기', '중개상', '이규태', '회장', '원', '대', '방산', '장비', '납품', '사기', '혐의', '기소'],
#  ['성범죄', '교수', '교사', '교단', '영구', '추방'],
#  ['성범죄', '교수', '교사', '교단', '영구', '추방'],
#  ['금감원', '직원', '사칭', '보이스', '피싱', '유도', '문자', '주의'],
#  ['흉악범', '최장', '년', '격리', '보호', '수용', '법', '국무회의', '의결'],
#  ['불황', '사기', '횡령', '범', '전락', '변호사들'],
#  ['박원순', '법', '시행', '개월', '핫라인', '신고', '배', '증가'],
#  ['금감원', '직원', '사칭', '보이스', '피싱', '유도', '문자', '주의'],
#  ['성범죄', '형', '확정', '교사', '교수', '교단', '영구', '퇴출'],
#  ['오바마', '7월', '취임', '후', '처음', '아버지', '나라', '케냐', '방문'],
#  ['자원외교', '비리', '관련', '경남기업', '모', '부사장', '소환', '조사'],
#  ['아베', '잔혹', '과거사', '인정'],
#  ['검찰', '장경욱', '김인숙', '변호사', '징계', '법무부', '신청', '듯'],
#  ['원', '상품권', '사기', '간', '대', '주부'],
#  ['만우절', '장난', '전화', '처벌', '생각', '형사', '처벌'],
#  ['창원', '감', '힐스테이트', '차', '지역', '랜드마크'],
#  ['불혹', '사시', '변호사', '법률', '시장', '불황', '속', '사기', '전락'],
#  ['노총', '제조', '부문', '노사정위', '일방', '합의', '강요', '강행', '처리', '시', '총파업'],
#  ['필리핀', '관광', '위장', '황제성', '매매', '교수', '등', '명', '검거'],
#  ['해외', '노동자', '인권', '침해', '검토'],
#  ['아버지', '용돈', '동네', '가짜', '도둑', '아들'],
#  ['가이드', '밤', '성매매', '파트너', '필리핀', '황제', '관광', '무더기', '적발'],
#  ['연쇄',
#   '살인',
#   '등',
#   '흉악범',
#   '형',
#   '종료',
#   '후',
#   '최장',
#   '7년',
#   '간',
#   '사회',
#   '격리',
#   '안',
#   '국무회의',
#   '통과'],
#  ['만우절', '장난', '전화', '처벌', '식당', '불평', '불효', '자식', '체포', '허위', '신고', '안'],
#  ['이규태', '농간', '엉터리', '배', '사'],
#  ['논평'],
#  ['만우절', '장난', '전화', '적발', '공무집행방해죄', '처벌'],
#  ['천안', '외국인', '도움', '센터', '무용지물'],
#  ['가정폭력', '사기', '혼자', '마', '세'],
#  ['가짜', '검찰청', '사이트', '카카오톡'],
#  ['출근', '입원', '보험사', '기단'],
#  ['것', '리뷰', '범행', '장소', '사전', '답사', '절', '도범', '검거'],
#  ['뉴스', '플러스', '남한', '드라마', '인기', '비상', '단속', '무용지물'],
#  ['도', '폭행', '주변', '무관심', '곳곳', '개탄', '목소리'],
#  ['아파트', '오피스텔', '범죄자', '침입', '설계', '기준', '마련'],
#  ['재범', '우려', '강력범죄', '자', '최장', '년', '격리', '보호', '수용', '법', '통과'],
#  ['내달', '아파트', '오피스텔', '범죄자', '침입'],
#  ['도', '폭행', '무관심', '곳곳', '개탄', '목소리'],
#  ['도', '폭행', '무관심', '곳곳', '개탄', '목소리'],
#  ['만우절', '장난', '전화', '동물', '처벌'],
#  ['하이라이트'],
#  ['만우절', '장난', '전화', '만원', '입금', '신고', '처벌'],
#  ['만우절', '장난', '전화', '장난', '전화'],
#  ['전국', '집', '창', '촌', '곳', '폐쇄', '박차', '수익', '몰수', '추징', '강화'],
#  ['학생', '집'],
#  ['포스코건설', '비자금', '갈래', '추가', '포착'],
#  ['만우절', '장난', '전화', '처벌', '경찰청', '경찰력', '낭비', '동참', '부탁'],
#  ['박원순', '그 후', '서울시', '공무원', '비리'],
#  ['군산경찰서', '업무', '유공자', '명', '표창', '수'],
#  ['전주', '지역', '성매매', '집결지', '폐쇄', '속도'],
#  ['전자전', '훈련', '장비', '사기', '혐의', '이규태', '회장', '등', '재판'],
#  ['포스코건설', '추가', '비자금', '정황', '포착'],
#  ['경찰청', '만우절', '장난', '전화', '자제', '요청'],
#  ['합', '수단', '원', '대', '군납', '사기', '이규태', '회장', '구속', '기소'],
#  ['대포통장', '판매', '30대', '벌금', '만원'],
#  ['장애', '청소년', '성', '관계', '촬영', '20대', '징역형'],
#  ['가구', '이상', '주택', '주차장', '의무'],
#  ['무관심', '아이들'],
#  ['아파트', '나무', '창문', '거리'],
#  ['옥천경찰서', '체감', '치안', '향상', '맞춤', '캠페인', '사진'],
#  ['부동산', '부동산', '투자', '투기'],
#  ['경찰', '금융', '기관', '대', '악성', '사기', '공동', '대응', '협약'],
#  ['충북', '기협', '년', '분기', '이달의 기자상', '선정'],
#  ['여의', '나루', '빅', '데이터', '세상'],
#  ['금융감독원', '직원', '박선영', '주의'],
#  ['강진', '경찰', '개인', '택시', '조합'],
#  ['범죄', '교육', '공무원', '교수', '교단', '퇴출'],
#  ['흉악범', '최장', '년', '격리', '보호', '수용', '법안', '국무회의', '의결'],
#  ['흉악범', '최장', '년', '격리', '보호', '수용', '법안', '국무회의', '의결'],
#  ['세상', '만사', '나라', '안', '대', '여성', '투자', '미끼', '사기'],
#  ['낮', '가이드', '밤', '섹스', '파트너', '만원', '대', '황제', '매매'],
#  ['낮', '가이드', '밤', '섹스', '파트너', '만원', '대', '황제', '매매'],
#  ['산업', '스파이', '무기', '거래', '포탄', '기술'],
#  ['포럼', '노동', '시장', '성공', '가지'],
#  ['멕시코',
#   '불법 무기',
#   '류',
#   '정',
#   '유통',
#   '멕시코',
#   '성인',
#   '남자',
#   '명당',
#   '명',
#   '총기',
#   '소지',
#   '셈'],
#  ['울진경찰서', '지역', '아동', '센터', '범죄', '예방', '협약'],
#  ['이근', '대구대학교', '대외', '협력', '부총장', '대구', '장애우', '권익', '연구소', '특강'],
#  ['조희팔', '은닉', '재산', '추징', '보전', '행보', '피해자', '상환', '지체', '수'],
#  ['불법체류', '외국인', '피해자', '보호', '원년'],
#  ['경산경찰서', '합동', '순찰', '외국인', '밀집', '지역', '범죄', '예방'],
#  ['검찰', '조희팔', '은닉', '자금', '추징', '보전', '논란'],
#  ['영천경찰서', '청소년', '선도', '심사위', '개최'],
#  ['보성', '경찰', '범죄', '피해자', '교통편', '제공', '협약'],
#  ['양치기', '소년', '만우절'],
#  ['가입자', '서명', '도용', '검찰', '고발'],
#  ['국내', '최대', '라이벌', '삼성', 'LG', '간', '법', '분쟁', '일지'],
#  ['원창묵', '원주시', '장', '항소심', '벌금', '만원', '선고'],
#  ['상습', '거짓', '신고', '피의자', '검거'],
#  ['교통사고', '피해자', '지원', '제도'],
#  ['교통사고', '피해자', '지원', '제도'],
#  ['범죄', '시민', '심사', '위원', '판단'],
#  ['범죄', '시민', '심사', '위원', '판단'],
#  ['진해', '고등학교', '앞', '음란', '행위', '30대', '체포'],
#  ['구미', '고용', '노동부', '구미', '지청', '범죄', '피해자', '취업', '지원', '업무', '협약'],
#  ['조희팔', '자금', '피해자', '처리', '이견'],
#  ['채널', '한국', '외국인', '근로자', '공존', '조건'],
#  ['칠곡', '성장', '생활', '불편', '척', '석적읍', '홀대', '분통'],
#  ['인구', '석적읍', '기반 시설'],
#  ['경기', '경찰청', '국악', '마술', '수화', '범죄', '예방', '홍보', '인기'],
#  ['달러', '유통', '때', '달러', '검은돈', '변신', '특수부대', '업무', '영역', '확대'],
#  ['모략',
#   '소굴',
#   '남조선',
#   '둥지',
#   '틀',
#   '자비',
#   '징벌',
#   '인권',
#   '현장',
#   '사무소',
#   '서울',
#   '개설',
#   '반발'],
#  ['아동', '성폭력범', '최장', '7년', '간', '사회', '격리', '연쇄살인범', '등', '흉악범'],
#  ['성추행', '영예', '군인', '영웅', '폭', '영예', '군인', '범죄', '골머리'],
#  ['여의도', '포럼', '김창준', '싱가포르', '곤장', '제도'],
#  ['살인범', '등', '이중', '처벌', '보호', '수용', '법', '국무회의', '통과'],
#  ['널 기다리며', '촬영', '하반기', '개봉', '기대', '심은경', '주연', '범죄', '스릴러'],
#  ['인터넷', '모의', '총기', '판매', '대', '벌금형'],
#  ['코리아', '코커스', '의장', '아베', '과거', '잔혹', '행위', '인정'],
#  ['가출', '여', '중생', '살인', '사건', '용의자', '기절'],
#  ['통나무', '치마', '여자', '군인', '성범죄', '천국'],
#  ['전자', '발', '찌', '차고', '차례', '성범죄', '20대', '검거'],
#  ['투자', '돈', '사기', '대', '주부', '말'],
#  ['직원', '상품권', '말'],
#  ['미', '국무부', '위안부', '성', '목적', '여성', '매매', '행위'],
#  ['김정은', '외국인', '상대', '여대', '성매매', '총살', '지시', '나선', '지구', '여대', '가격', '달러'],
#  ['상원', '성', '매수', '자', '처벌', '법안', '부결', '하원', '최종', '결정'],
#  ['이규태', '회장', '방사', '청', '원', '예산', '기소'],
#  ['자살', '몸캠', '협박', '음성', '파일', '유포', '파문'],
#  ['필리핀', '원정', '성매매', '황제', '관광', '명', '검거'],
#  ['아이템베이', '더치트', '온라인', '사기', '범죄', '예방', '업무', '협약', '체결'],
#  ['내달', '범죄', '예방', '건축', '기준', '시행'],
#  ['경찰', '만우절', '장난', '전화', '처벌', '업무', '방해', '민원', '신고', '자제', '당부'],
#  ['성매매', '가출', '소녀', '살인', '사건', '용의자', '범행', '자백', '과거', '20대'],
#  ['분석', '삼성', '극', '화해', '검찰', '법원', '판단'],
#  ['검찰', '동국제강', '해외', '송금', '추적'],
#  ['법무부',
#   '법',
#   '사랑',
#   '부산',
#   '동지',
#   '역',
#   '연합회',
#   '하형주',
#   '동아대',
#   '교수',
#   '홍보',
#   '대사',
#   '위촉'],
#  ['아동', '음란물', '처벌', '미국', '선', '무기', '형', '벌금'],
#  ['필리핀', '황제', '관광', '알선', '브로커', '성', '매수', '자', '명', '무더기', '검거'],
#  ['성범죄', '형', '확정', '교사', '교수', '교단', '영구', '추방'],
#  ['이준영', '세상 속으로', '섬나라', '처신'],
#  ['필리핀', '원정', '성매매', '대학교수', '황제', '관광', '일당', '검거'],
#  ['필리핀', '원정', '성매매', '황제', '관광', '명', '수년', '후', '경찰', '망신살'],
#  ['고양이', '생선', '꼴'],
#  ['공직', '선거법', '위반', '원주시', '장', '심', '벌금', '만원', '직위', '유지'],
#  ['어른', '욕망', '목숨'],
#  ['괴산경찰서', '민', '경', '유기', '협력', '체계', '구축', '간담회'],
#  ['보은경찰서', '농협', '군', '지부장', '등', '협약', '체결'],
#  ['충북', '이달의 기자상', '선정'],
#  ['아파트', '등', '건축물', '범죄', '예방', '설계', '허가'],
#  ['성범죄', '형', '확정', '교사', '교수', '교단', '영구', '추방'],
#  ['흉악범', '출소', '후', '최장', '년', '격리'],
#  ['시민', '단체', '고객', '정보', '도용', '유출', '의혹', '고발'],
#  ['오바마', '취임', '후', '처음', '아버지', '나라', '케냐', '간다'],
#  ['만우절', '허위', '고시', '최대', '벌금', '만원'],
#  ['구글', '보안', '전문가', '온라인', '보안', '계명'],
#  ['전국', '패', '트롤', '서울시', '박원순', '법', '시행', '개월', '공무원', '비리', '감소'],
#  ['흉악범', '형기', '격리', '보호', '수용', '법안', '국무회의', '통과'],
#  ['서울시', '박원순', '법', '후', '공무원범죄', '급감', '비리', '신고', '건'],
#  ['흉악범', '최대', '년', '수용', '보호', '수용', '법안', '통과'],
#  ['아프리카', '난민', '오해', '편견', '사연'],
#  ['만우절', '장난', '전화', '코', '경찰', '엄정', '대응', '엄포'],
#  ['단신', '내일', '음식점', '방', '흡연', '시', '과태료', '외'],
#  ['만우절', '장난', '전화', '공무집행방해죄', '처벌'],
#  ['대전', '지검', '범죄', '피해자', '지원', '센터', '가정', '만원', '지원'],
#  ['안전', '세종', '시', '완성', '세종', '경찰', '노력'],
#  ['형기', '흉악범', '최대', '7년', '간', '격리', '법안', '국무회의', '통과'],
#  ['무인', '빨래', '방', '30대', '좀도둑', '덜미'],
#  ['흉악범', '최장', '년', '보호', '수용', '격리', '이중', '처벌', '논란', '예상'],
#  ['울산', '경찰', '폭력배', '강도', '절도', '집중', '단속'],
#  ['종교', '시설', '남매', '성추행', '20대', '실형'],
#  ['필리핀', '성매매', '황제', '관광', '명', '검거', '교수', '포함'],
#  ['성범죄', '형', '확정', '교사', '교수', '교단', '영구', '추방'],
#  ['보이스', '피싱', '조직', '등', '차', '사기', '극성'],
#  ['피해자', '코디네이터'],
#  ['지능', '범죄', '조', '폭', '전쟁'],
#  ['유리창', '콩나물', '시루'],
#  ['수사망', '피해', '페이스', '오프', '꼬리', '아파트', '털', '이범'],
#  ['검찰', '동국제강', '비자금', '총수', '일가', '유입', '증거', '확보', '주력'],
#  ['검찰', '동국제강', '비자금', '의혹', '증거', '확보', '주력'],
#  ['내일', '시론', '권력자', '인사', '전횡', '부패', '뿌리'],
#  ['전화', '식당', '음식'],
#  ['순천시', '순천경찰서', '기관', '단체', '간', '업무', '협약', '체결'],
#  ['국토부', '범죄', '예방', '건축', '기준', '고시', '조명', '등', '설치', '의무'],
#  ['김문수', '유엔', '북한', '인권', '현장', '사무소', '동북아', '전체', '등불', '것'],
#  ['박', '근', '병원장', '지역', '사회', '발전', '유공', '표창'],
#  ['개', '보상', '전단지', '연락', '덜미'],
#  ['흉악범', '출소', '후', '년', '격리', '보호', '수용', '법안', '국무회의', '통과'],
#  ['도둑', '단골', '침입', '아파트', '배관', '외벽', '속', '설치'],
#  ['박원순', '법', '개월', '공무원', '비리'],
#  ['필리핀', '성매매', '황제', '관광', '교수', '회계사', '등', '명', '입건'],
#  ['코리아', '코커스', '의장', '아베', '과거', '잔혹', '행위', '인정'],
#  ['만우절', '핑계', '허위', '전화', '장난', '처벌'],
#  ['성매매', '여', '중생', '살해', '피의자', '주전', '유사', '범행'],
#  ['권리', '보호', '야후', '재팬', '성적', '동영상', '집단', '괴롭힘', '피해', '등', '삭제'],
#  ['특별기', '제주', '아픔', '치유', '상생'],
#  ['야누스', '얼굴', '상속자', '뒷골목', '사내'],
#  ['교수', '회계사', '유혹', '필리핀', '황제', '관광'],
#  ['하드보일드', '뜻', '폭력', '주제', '한국', '형', '하드보일드', '복수는 나의 것'],
#  ['범죄의 재구성', '바람', '롤리타', '제물', '세', '소녀'],
#  ['포스코건설', '비자금', '추가', '포착'],
#  ['가구', '이상', '공공', '주택', '범죄', '사각지대'],
#  ['보험', '업계', '자율', '책임', '검사', '체계', '구축'],
#  ['상품권', '구입', '대', '주부'],
#  ['애완견', '대', '남성', '이유'],
#  ['4월', '아파트', '등', '범죄', '예방', '기준', '허가'],
#  ['박원순', '시행', '반년', '신고', '배', '공무원', '범죄', '급감'],
#  ['경기', '경찰', '애완견', '절도', '주의보'],
#  ['가구', '이상', '공동', '주택', '학교', '오피스텔', '등', '건축물', '범죄', '예방', '기준', '허가'],
#  ['입원', '보험', '사기', '무더기', '검거', '수법', '경악'],
#  ['경기도', '애완견', '도난', '사고'],
#  ['아트', '하우스', '4월', '라이브', '모스트 바이어런트', '선정'],
#  ['친구', '아버지', '사기', '친', '10대', '훈육', '덜미'],
#  ['친구', '아버지', '사기', '친', '10대', '훈육', '덜미'],
#  ['새벽', '시간대', '무인', '빨래', '방', '절', '도범'],
#  ['벌금', '차량', '대학생'],
#  ['노트북', '추적', '빈집', '털', '이범', '덜미'],
#  ['흉악범', '최대', '년', '추가', '격리', '법안', '통과', '이중', '처벌', '논란'],
#  ['범죄', '발생', '시', '피해자', '지원'],
#  ['하드보일드', '뜻', '감정', '냉담', '태도', '영화', '소재', '활용'],
#  ['국정원', '첨단', '무기', '핵심', '기술', '등', '유출', '사고', '지난해', '최다', '적발'],
#  ['범죄', '수사', '세계', '인질극', '대한민국', '안전지대'],
#  ['원주시', '장', '항소심', '벌금', '만원', '공직', '유지'],
#  ['아트', '하우스', '4월', '라이브', '모스트 바이어런트', '선정'],
#  ['봉천동', '10대', '살인', '용의자', '범행', '자백', '수면', '마취제', '이용'],
#  ['원', '대', '사기', '이규태', '일광', '공영', '회장', '기소'],
#  ['새누리당', '지역', '일꾼', '줌', '마', '공약', '안전', '관악', '예산', '불독'],
#  ['상품권', '교회', '지인', '상대로', '대', '사기'],
#  ['연쇄살인범', '아동', '성폭력범', '형기', '뒤', '최대', '7년', '간', '격리'],
#  ['중고', '거래', '구매자', '판매자', '삼각', '사기', '일당'],
#  ['박원순', '법', '개월', '서울시', '공무원', '범죄', '분'],
#  ['아파트', '범죄', '예방', '시설', '건축', '허가'],
#  ['장난', '전화', '허위', '신고', '건', '중', '건', '처벌'],
#  ['미', '리보', '4월', '국회', '기재', '교문', '환', '노', '위', '화약고'],
#  ['딸', '불효', '자식', '만우절', '장난', '전화'],
#  ['바다', '살인', '흉기', '눈'],
#  ['통', '법', '개월', '제자리걸음', '국회', '논의'],
#  ['정보화', '시대', '파수꾼', '화이트', '해커', '정부', '차원', '관리'],
#  ['문', '고급', '차만', '금품', '만원', '30대', '구속'],
#  ['가정주부', '투자', '미끼', '4년', '간', '대', '사기', '행각'],
#  ['훈', '남', '경찰', '고양', '고양이', '네티즌', '눈길', '공공', '기관'],
#  ['애완견', '도난', '주의보'],
#  ['미', '국무부', '위안부', '성', '목적', '여성', '매매', '행위'],
#  ['강력범', '형기', '최대', '년', '격리'],
#  ['강력범', '형기', '최대', '년', '격리'],
#  ['방위', '사업', '비리', '합', '수단', '이규태', '회장', '기소'],
#  ['행정자치부', '대구', '지역', '공무원', '성폭력', '범죄', '년', '이후', '발생'],
#  ['상품권', '구입', '대', '주부', '쇠고랑'],
#  ['인천시', '아동', '안전', '지도', '제작', '사업', '추진'],
#  ['모텔', '중생', '남성', '손톱', '충격'],
#  ['모텔', '중생', '남성', '손톱', '충격'],
#  ['검찰', '포스코', '원', '대', '비자금', '추가', '포착'],
#  ['가구', '이상', '아파트', '의무'],
#  ['흉악범', '최장', '년', '격리', '보호', '수용', '법안', '국무회의', '통과'],
#  ['보호', '수용', '법안', '국무회의', '통과', '이중', '처벌', '논란', '듯'],
#  ['하드보일드', '뜻', '감정', '냉담', '태도', '하드보일드', '영화', '대표작'],
#  ['필리핀', '황제', '관광', '대학교수', '대기업', '회사원', '원정', '성매매', '일당', '검거'],
#  ['필리핀', '관광', '위장', '성매매', '명', '검거', '대학교수', '등', '포함'],
#  ['교수', '회계사', '필리핀', '성매매', '황제', '관광', '명'],
#  ['하드보일드', '뜻', '감정', '좌우', '냉담', '태도', '차', '세계', '대전', '유래'],
#  ['가구', '이상', '아파트', '내달', '의무', '설치'],
#  ['기획', '청부', '영화', '킹스', '맨', '흥행', '성공', '요소'],
#  ['기획', '청부', '영화', '킹스', '맨', '흥행', '성공', '요소'],
#  ['노인', '대상', '사기', '등', '범죄', '극성'],
#  ['군산시', '옥서면', '지역', '설치'],
#  ['전북', '경찰', '강', '절도', '6월', '말', '강도', '단속'],
#  ['하드보일드', '뜻', '감정', '좌우', '냉담', '태도', '한국', '영화', '대표작'],
#  ['성범죄', '교수', '교사', '교단', '영구', '퇴출'],
#  ['필리핀', '원정', '성매매', '명', '검거'],
#  ['하드보일드', '뜻', '폭력', '주제', '냉', '철', '감', '태도', '묘사', '특징'],
#  ['덫'],
#  ['4월', '범죄', '예방', '기준', '건축', '건축', '허가'],
#  ['박', '광', '규', '미스터리', '산책', '뛰는 놈 위에 나는 놈', '위', '컴퓨터'],
#  ['오원춘', '수원시', '고육지책'],
#  ['야후', '재팬', '개인', '성적', '화상', '병력', '범죄', '피해', '사실', '등', '삭제', '기준', '발표'],
#  ['흉악범', '출소', '후', '최대', '년', '수용소', '격리'],
#  ['케이블', '위성', '하이라이트', '2015년', '3월 31일'],
#  ['4월 1일', '오늘', '하이라이트'],
#  ['멕시코', '불법', '무기', '명당', '명', '유통'],
#  ['대', '사기', '경기', '노점상', '회장', '기소'],
#  ['교수', '회계사', '등', '필리핀', '원정', '성매매', '무더기', '적발'],
#  ['만우절', '장난', '전화', '안'],
#  ['출소', '후', '성형', '키', '높이', '수술', '전국', '빈집', '털이'],
#  ['취업', '알선', '미끼', '원', '20대', '신종', '사기범'],
#  ['공원', '애완견', '대', '입건'],
#  ['필리핀', '원정', '성매매', '명', '적발', '대학교수', '공인회계사', '등'],
#  ['여성', '청소년', '보호', '시설', '나사', '집', '폐쇄', '위기', '자활', '소녀', '가나'],
#  ['흉악범', '최장', '년', '격리', '보호', '수용', '법', '통과', '이중', '처벌', '논란'],
#  ['오바마', '취임', '뒤', '처음', '아버지', '나라', '간다'],
#  ['야후', '재팬', '권리', '기준', '발표'],
#  ['황제', '노역', '판결', '판사', '수', '논란'],
#  ['식당', '음식', '신고'],
#  ['미국', '코', '하원', '의원', '아베', '잔혹', '행위', '인정'],
#  ['포스코건설', '비자금', '줄기', '베트남', '공사', '과정', '조성', '포착'],
#  ['김문수', '유엔', '인권', '사무소', '중국', '러시아', '등불', '것'],
#  ['사설', '인권위', '역', '주행'],
#  ['필리핀', '세부', '관광', '위장', '성매매', '교수', '등', '명', '검거'],
#  ['박상', '미', '공감', '스토리텔링', '사람', '일', '사람', '일'],
#  ['양주', '소년범', '보호', '시설', '문', '위기', '방황', '걱정'],
#  ['박범훈', '전', '방위', '외압', '교육부', '당시', '청와대', '서도', '논란'],
#  ['훈육', '차원', '체벌', '해도', '처벌'],
#  ['이창근', '드림', '드림', '육하원칙'],
#  ['마이클 브라운', '사건', '구조', '인권', '침해'],
#  ['시대', '창', '게', '비지떡', '선별', '복지', '함정'],
#  ['조찬제', '선임', '기자', '월드', '프리즘', '미국', '기', '피격', '자료', '공개'],
#  ['정부', '성매매', '원천', '봉쇄', '전국', '집', '창', '촌', '폐쇄'],
#  ['건설사', '회장', '사칭', '원', '대', '징역형'],
#  ['성남중원경찰서', '피해자', '멘', '토', '위원회', '희망', '등대', '발', '대식', '개최'],
#  ['법률', '플러스', '증인', '출석', '요구', '출석'],
#  ['문화', '관광', '자원'],
#  ['자전거', '구리', '등', '생활', '절', '도범', '검거'],
#  ['끈기', '깡', '사기범', '여경'],
#  ['경남신문', '기', '독자', '위원회', '차', '회의'],
#  ['장성', '북', '하', '파출소', '절도', '아동', '범죄', '예방', '활동'],
#  ['충북', '기협', '이달의 기자상'],
#  ['옥천', '지역', '서민', '금융'],
#  ['한국', '터보', '기계', '헌', '석', '대표', '미국', '인도', '재고', '해', '달라'],
#  ['통신', '사장', '언론인', '납치', '살해', '국제법', '전쟁', '범죄', '포함'],
#  ['전과', '범', '경찰', '지구', '남', '물건', '경찰', '신세'],
#  ['외국인', '근로자', '밀물', '공존', '해법', '모색'],
#  ['청년', '해외', '취업', '허', '실', '구직', '자', '번', '취업', '사기'],
#  ['KBS1', '시사기획 창', '외국인', '근로자', '공존', '조건'],
#  ['호기심', '살', '약', '학생', '마약', '사범', '급증'],
#  ['엘리트', '법대', '교수', '심야', '열차', '간', '30대', '허벅지', '체포'],
#  ['금융', '당국', '보이스', '피싱', '칼'],
#  ['황', '종택', '의', '온', '고지', '신', '연무', '마모'],
#  ['실종', '느와르', '강하늘', '미생', '소름', '연기력', '김강우', '두뇌', '대결', '시작'],
#  ['타인', '카드', '사용', '중학생', '형사', '처벌', '대신', '즉결심판'],
#  ['충북', '경찰청', '무심천', '공원', '자전거', '순찰대', '운영'],
#  ['권시', '장', '항소심', '재판부', '선거범죄', '과거', '판결'],
#  ['대전', '화질', 'CCTV', '개교', '지원'],
#  ['성폭행', '사건', '논산', '대', '중', '대', '고장'],
#  ['휴대폰', '점', '휴대폰', '절', '도범', '머리', '위', '업주'],
#  ['오늘', '대전', '세종', '충남', '충북', '중도', '일보', '3월', '일', '월요일', '자'],
#  ['진화', '보이스', '피싱', '검찰', '총장', '공문', '위조'],
#  ['이브닝', '이슈', '채림', '남매', '폭언', '모욕', '혐의', '피소', '모욕죄'],
#  ['통장', '범죄', '악용', '시', '형사', '처벌'],
#  ['뉴스', '플러스', '도박', '업자', '수뢰', '경찰', '간부', '수사'],
#  ['대', '판돈', '중', '합작', '도박', '조직'],
#  ['아베', '연설', '위안부', '문제', '직시', '사과'],
#  ['글로벌', '시대', '영국', '신사', '케이', '팝', '아리랑', 'TV', '글로벌', '네트워크', '부장'],
#  ['조희팔', '은닉', '재산', '환수', '이례', '추징금', '구형'],
#  ['남원', '순창', '장수', '범죄', '피해자', '지원', '센터', '정기', '총회', '개최'],
#  ['남원', '공공', '기관', '민간단체', '법질서', '실천', '협약'],
#  ['진안경찰서', '보이스', '피싱', '예방', '홍보', '영상', '제작'],
#  ['황금', '대사헌', '황희', '이완구', '총리'],
#  ['위헌', '소지', '판단', '안'],
#  ['10대', '마약', '범죄', '급증'],
#  ['청소년', '청소년', '범죄', '위험수위'],
#  ['영동', '금산', '서', '총력', '대응', '체계', '구축', '간담회'],
#  ['옥천경찰서', '체감', '치안', '향상', '맞춤', '캠페인'],
#  ['충북', '경찰청', '무심천', '자전거', '순찰대', '운영'],
#  ['상습', '가정폭력', '행사', '대', '검거'],
#  ['충북', '기협', '년', '분기', '이달의 기자상', '선정'],
#  ['전국', '개', '집', '창', '촌', '폐쇄', '여', '가부', '경찰', '등', '구성'],
#  ['세상', '만사', '나라', '안', '전과', '범', '경찰', '지구', '대서', '현금', '입건'],
#  ['조건', '만남', '미끼', '유인', '강도', '10대', '명', '구속'],
#  ['집', '창', '촌', '유흥업소', '매매', '방위', '단속'],
#  ['이해인', '피싱', '전쟁'],
#  ['합', '수단', '사기', '혐의', '이규태', '구속', '기소'],
#  ['의원', '과거사', '반성', '촉구', '아베', '형식', '언급', '듯'],
#  ['시론', '경제', '명령'],
#  ['달서구', '범죄', '피해자', '지원', '경찰', '상시', '네트워크', '구축'],
#  ['경', '일대', '해외', '건설', '현장', '체험', '전문가', '특강', '특성', '사업단', '순항'],
#  ['구미경찰서', '고용', '노동부', '범죄', '피해자', '취업', '지원'],
#  ['달', '서구청', '달서', '성서', '경찰서', '긴급', '지원', '네트워크'],
#  ['만우절', '장난', '전화'],
#  ['대포통장', '덫'],
#  ['여수경찰서', '전남', '최초', '경미', '범죄', '심사', '위원회', '개최'],
#  ['대법원', '긴급조치', '판결', '정치', '화법'],
#  ['옥천경찰서', '4대 사회악', '근절', '홍보', '활동'],
#  ['스마트폰', '카메라', '이용', '촬영', '성범죄', '연루', '전문', '변호사', '조력'],
#  ['성폭력', '근절', '대책', '현장', '실천'],
#  ['성폭력', '근절', '대책', '현장', '실천'],
#  ['장발장', '법', '폐지', '혜택'],
#  ['장발장', '법', '폐지', '혜택'],
#  ['국내외', '곳', '매장', '판돈', '합작', '도박', '조직', '적발'],
#  ['필', '로', '폰', '대마', '등', '마약', '사범', '명', '무더기', '검거'],
#  ['투', '탑', '시티', '이상', '외면', '방치', '안'],
#  ['투', '탑', '시티', '이상', '외면', '방치', '안'],
#  ['지역', '길', '박선규', '영월군', '수'],
#  ['지역', '길', '박선규', '영월군', '수'],
#  ['귀금속', '절취', '이삿짐', '센터', '직원', '구속'],
#  ['기고'],
#  ['기고', '대출', '전화', '마', '세', '요'],
#  ['범죄', '피해', '외국인', '보호', '협약'],
#  ['최면', '진정제', '졸피뎀', '남용', '이철우', '의원', '범죄', '악용', '경고'],
#  ['야', '고부', '확신범'],
#  ['편의점', '바닥', '비상', '벨로', '신고', '분만', '강도'],
#  ['오원춘', '박춘풍', '수원시', '범죄', '예방', '가로등', '전면', '교체'],
#  ['은행', '법', '구글 검색', '부부', '체포'],
#  ['간', '대', '경찰', '지구', '대', '남', '금품', '덜미'],
#  ['리콴유', '일본', '관계', '공포', '대상', '벤치마킹', '훈수'],
#  ['강원도', '강간', '군인', '성폭행', '통제', '불능', '상태'],
#  ['조희팔', '은닉', '재산', '환수', '측근', '추징금', '구형'],
#  ['장기', '복역', '감', '도둑들', '철창', '행'],
#  ['사설', '아베', '총리', '인신매매', '위안부', '문제', '물타기', '뿐'],
#  ['중국', '말단', '경찰', '간부', '집', '현금', '원'],
#  ['도봉산',
#   '기슭',
#   '판도라',
#   '컨테이너',
#   '방산',
#   '비리',
#   '이규태',
#   '회장',
#   '비밀',
#   '자료',
#   '무더기',
#   '발견'],
#  ['검찰', '동국제강', '해외', '송금', '추적', '비자금', '조성', '증거', '확보'],
#  ['와우', '공식', '소설', '한정판', '골드', '에디션'],
#  ['한경', '에세이', '안함', '주기'],
#  ['신고', '후 현', '장', '뺑소니'],
#  ['시사', '하계열', '부산진', '구청장'],
#  ['시민', '체감', '생활', '범죄'],
#  ['진화', '비행', '청소년', '대만', '경보', '음'],
#  ['주차', '차량', '창문', '금품', '대', '구속'],
#  ['검사', '연기', '여성', '속', '보이스', '피싱'],
#  ['진화', '전문가', '지적', '벽화', '일색', '부산', '이제', '마을', '맞춤'],
#  ['베트남', '신부', '결혼', '실패', '대', '결혼', '중개업', '체', '방화', '살인'],
#  ['단속', '기관', '손', '멸치', '포획', '금지', '법'],
#  ['현직', '경찰', '간부', '뇌물', '수수', '혐의', '수사', '시작', '휴가', '뒤', '달', '잠적'],
#  ['영동경찰서', '금산경찰서', '지휘관', '간담회', '개최'],
#  ['사설', '솜방망이', '처벌', '보험', '사기', '공화국'],
#  ['전국', '개', '집', '창초', '폐쇄', '돌입'],
#  ['동국제강', '정상', '해외', '송금', '추적', '실무자', '소환'],
#  ['중국', '하급', '경찰', '간부', '집', '현금', '원', '게임', '업자', '뇌물'],
#  ['상인', '지원금', '전통', '시장', '회장', '입건'],
#  ['성형', '수술', '가발', '변장', '아파트', '전문', '털', '이범', '덜미'],
#  ['단독', '하', '베스트', '평가', '보고서', '입수', '곳곳', '왜곡', '과장'],
#  ['분', '만', '간', '금고', '통째'],
#  ['충북', '지방', '경찰청', '10월', '말', '무심천', '자전거', '순찰대', '운영'],
#  ['마을', '방송', '매체', '자리매김'],
#  ['학', '폭', '예방', '제도', '방안', '전', '사회', '관심', '협력', '필요'],
#  ['소년', '재판', '번', '결론', '아이들', '아버지', '필요'],
#  ['이해인', '피해', '금감원', '전쟁', '선포'],
#  ['이발', '갱생', '길', '사형수', '이발사'],
#  ['관제탑', '청소년', '선도'],
#  ['보험사', '기와', '대책'],
#  ['인터뷰', '황', '덕', '경기도', '선관위', '상임', '위원'],
#  ['보육', '교사', '가짜', '위탁', '교육', '국가', '보조금', '원'],
#  ['이해인', '사건', '도마', '위', '금감원', '보이스', '피싱', '근절'],
#  ['장기', '복역', '감', '도둑들', '철창', '행'],
#  ['욕설', '협박', '나이롱', '귀신', '끝', '추적'],
#  ['월드 오브 워크래프트', '소설', '한정판', '골드', '에디션', '출시'],
#  ['실종느와르 M', '강하늘', '김강우', '박희순', '숨', '연기', '경쟁', '방'],
#  ['울산대', '스마트', '벤처', '학교', '창업', '기지'],
#  ['독재', '결별', '스리랑카', '일', '계획', '성공'],
#  ['대법', '위헌', '소지', '판단', '안', '재판'],
#  ['보험',
#   '상품',
#   '배당',
#   '롯데',
#   '여성',
#   '보험',
#   '여성',
#   '고객',
#   '특화',
#   '후',
#   '유장',
#   '해',
#   '때',
#   '만원'],
#  ['창원', '집값', '오름세', '가격', '경쟁력', '창원', '감', '힐스테이트', '차', '분양'],
#  ['명문대', '출신', '법학', '교수', '열차', '성추행', '덜미'],
#  ['갈취', '15년', '간', '해외', '도피', '폭', '실형', '선고'],
#  ['한국', '첨단', '안전', '산업', '협회', '창립총회'],
#  ['디지털', '산책', '주민등록번호', '제도', '때'],
#  ['삼부', '퓨전', '등', '장르', '차별'],
#  ['마곡', '지구', '대형', '건설사', '오피스텔', '가격', '마곡', '아이파크', '분양', '마감', '코앞'],
#  ['10대', '학생', '등', '젊은층', '마약', '범죄', '급증', '인터넷', '유통', '증가', '등', '원인'],
#  ['금감원', '이해인'],
#  ['보험', '상품', 'NH농협손해보험', '재해', '범죄', '사고', '질병', '한', '번', '걱정'],
#  ['경찰서', '지구', '대서', '금품', '대'],
#  ['논산', '대형', '마트', '화장실', '여', '중생', '성폭행'],
#  ['박', '석', '흥', '세상보기', '근대', '제국주의', '극복', '리더십', '시대', '종언'],
#  ['처벌', '대신', '즉결심판', '전과자', '전락', '예방'],
#  ['이해득실', '맞선', '사행', '산업', '전자', '카드'],
#  ['여', '가부', '성매매', '집결지', '폐쇄', '추진', '현황', '공유', '집결지', '폐쇄', '박차'],
#  ['이조', '변호사', '작품', '속', '법률', '산책', '스물', '강요죄'],
#  ['행위', '4월', '국회', '총기', '단속', '누리', '과정', '지방채', '논의'],
#  ['뇌물', '혐의', '경찰', '간부', '수사', '시작', '잠적'],
#  ['김희정', '장관', '불법', '성매매', '업소', '범죄', '수익', '몰수', '추징'],
#  ['대법', '지적', '장애', '10대', '성', '관계', '촬영', '20대', '실형', '확정'],
#  ['젊은층', '마약', '접촉', '경찰', '온라인', '공급', '집중', '단속'],
#  ['유사', '수신', '사기범', '조희팔', '은닉', '재산', '환수'],
#  ['경찰서', '가방', '간', '대'],
#  ['집', '창', '촌', '뿌리', '여', '가부', '곳', '폐쇄', '추진'],
#  ['집', '창초', '뿌리', '여', '가부', '곳', '폐쇄', '추진'],
#  ['이해인', '씨', '사건', '금감원', '보이스', '피싱', '근절'],
#  ['키', '얼굴', '절', '도범'],
#  ['키', '얼굴', '절', '도범'],
#  ['독자', '칼럼', '사이버', '데이', '제안'],
#  ['대법', '청소년', '성', '관계', '촬영', '원칙', '아', '청', '법', '위반'],
#  ['북한', '강원도', '강', '간도', '수위', '보니'],
#  ['스마트', '시티'],
#  ['스마트', '시티'],
#  ['포토', '윤진서', '드라마', '속', '범죄', '프로파일러'],
#  ['진화', '이제', '청소년', '선도'],
#  ['동대문구', '친절', '운동', '한방', '타운', '복지', '등', '대', '전략', '과제', '선정'],
#  ['전국', '성매매', '집결지', '곳', '폐쇄', '추진'],
#  ['완전범죄', '꿈', '30대', '수술', '키', '양', '약'],
#  ['명문대', '출신', '법학', '교수', '열차', '성추행', '현행범', '체포'],
#  ['진화', '거짓말', '탐지기', '이제', '뇌'],
#  ['예능', '전망대', '파일럿', '예능', '정규', '판도', '급변'],
#  ['스릴러', '재탄생', '제인 오스틴', '고전'],
#  ['잠복', '끝', '교통카드', '간', '범인', '보니', '환경', '미', '화원'],
#  ['명문대', '출신', '법학', '교수', '열차', '성추행'],
#  ['위험', '노인', '각종', '범죄', '표적'],
#  ['완주', '성', '가정폭력', '예방', '모의', '훈련'],
#  ['덕진', '지구', '대', '맞춤', '범죄', '예방', '지역민', '소통'],
#  ['익산', '오산', '파출소', '점심', '문안', '순찰', '호응'],
#  ['홍기', '영', '칼럼', '분노', '조절', '장애', '심리학'],
#  ['환경', '규제', '세제', '혜택', '등', '하이브리드', '카'],
#  ['공직자', '문건', '스캔들', '이', '메일', '다음', '텍스트', '게이트'],
#  ['공직자', '문건', '스캔들', '이', '메일', '다음', '텍스트', '게이트'],
#  ['신병주', '왕', '것', '세종', '시련', '불행', '가족사', '주머니'],
#  ['염태영', '수원시', '장', '햇빛', '정책'],
#  ['오원춘', '수원시', '고육지책'],
#  ['아베', '위안부', '인신매매', '괴롭힘', '일', '정부', '책임', '회피', '꼼수', '눈총'],
#  ['출소', '후', '성형', '키', '높이', '수술', '전국', '빈집', '털이'],
#  ['케이블', '위성', '하이라이트', '2015년', '3월 31일'],
#  ['탕웨이', '이해인', '보이스', '피싱', '금감원', '금융', '사기', '전쟁', '선포'],
#  ['여성', '청소년', '보호', '시설', '나사', '집', '폐쇄', '위기', '자활', '소녀', '가나'],
#  ['모두', '날', '거', '저먼윙스', '기장', '문제', '발견'],
#  ['모두', '날', '거', '저먼윙스', '기장', '문제', '발견', '정신', '질환자', '차별', '우려', '증폭'],
#  ['도봉산', '인근', '컨테이너', '방산', '비리', '자료'],
#  ['모두', '날', '거', '저먼윙스', '기장', '문제', '발견'],
#  ['박종철', '박종우', '박상옥'],
#  ['양주', '소년범', '보호', '시설', '문', '위기', '방황', '걱정'],
#  ['아침', '돼지'],
#  ['기고', '사행', '산업', '감독', '위', '빅', '브러더'],
#  ['동국제강', '압수수색', '장세주', '회장', '출국', '금지'],
#  ['군', '이대로', '안', '기밀', '불량', '부품', '패망', '직전', '월', '남군', '듯'],
#  ['기밀', '불량', '부품', '패망', '직전', '월', '남군', '듯'],
#  ['이해인', '금감원', '금융', '사기', '전쟁', '선포'],
#  ['경찰', '지구', '대', '남', '금품', '대', '덜미'],
#  ['이해인', '금감원', '연예인', '등', '일제', '공문'],
#  ['119', '사고', '신고', '후 현', '장', '뺑소니'],
#  ['사이버', '명예', '경찰', '회원', '모집'],
#  ['버스', '정류장', '살인범', '항소심', '징역', '년'],
#  ['성', '관계', '장면', '여성', '신체', '카', '남성', '명', '집', '유', '벌금형'],
#  ['중부',
#   '경찰관',
#   '명',
#   '성신',
#   '1박 2일',
#   '교생',
#   '체험',
#   '스쿨',
#   '폴리스',
#   '학교',
#   '속',
#   '폭력',
#   '예방',
#   '부모',
#   '걱정'],
#  ['살', '여아', '성추행', '대', '경비원', '징역', '년', '6월', '감형'],
#  ['평택',
#   '안성',
#   '범죄',
#   '피해자',
#   '지원',
#   '센터',
#   '등',
#   '기금',
#   '마련',
#   '감자',
#   '심기',
#   '행사',
#   '구슬땀'],
#  ['구리경찰서', '전국', '최초', '드', '치안', '서비스'],
#  ['세', '여아', '성추행', '아파트', '경비원', '항소심', '감형'],
#  ['어린이집', '원장', '평생', '교육원', '국고', '보조금'],
#  ['보안', '만능', '솔루션', '수정'],
#  ['신간', '도서', '누가', '범인'],
#  ['권선택', '항소심', '재판부', '확정'],
#  ['음성서', '대', '절', '도범', '구속'],
#  ['무심천', '자전거', '순찰대', '운영'],
#  ['원룸', '밀집', '지역', '안전', '택배', '함', '설치'],
#  ['대전시', '교육청', '시간', '학교', '안전', '강화'],
#  ['안동', '남', '업', '섭', '순경', '보이스', '피싱', '피해', '만원'],
#  ['신고', '뒤', '현장', '이탈', '법원', '뺑소니'],
#  ['교복', '입', '경찰', '기숙사', '삼시세끼'],
#  ['퇴직', '공직자', '명', '중', '명', '방', '산업체'],
#  ['살해', '가출', '여중', '성매매', '알선', '혐의', '인조', '구속영장', '발부'],
#  ['성', '관계', '여성', '신체', '촬영', '남성', '명', '집', '유', '벌금'],
#  ['내연', '녀', '흉기', '위협', '대', '실형'],
#  ['피해자', '보호', '전담', '경찰관', '아침', '단상'],
#  ['경찰', '자전거', '스마트폰', '절도', '생활', '범죄', '여건', '단속'],
#  ['절도', '최다', '생활', '범죄', '건', '해결'],
#  ['거점', '대', '인터넷', '도박', '적발'],
#  ['매장', '중', '합작', '도박', '조직'],
#  ['통장', '만원', '대포통장', '모집', '콜', '센터', '조직', '검거'],
#  ['기고', '법질서', '선의', '미학'],
#  ['실종느와르 M',
#   '엘리트',
#   '형사',
#   '김강우',
#   '사이코패스',
#   '강하늘',
#   '긴장감',
#   '두뇌',
#   '대결',
#   '게임',
#   '스타트'],
#  ['합', '수단', '방위', '사업', '비리', '은폐', '가담', '일광', '공영', '직원', '명', '구속'],
#  ['선불', '폰', '불법', '유통', '이통', '제재', '착수'],
#  ['세', '여아', '성추행', '대', '경비원', '항소심', '감형', '솜방망이', '처벌'],
#  ['이거', '항암', '버섯', '난치병', '환자', '사기'],
#  ['방통', '위', '선불', '폰', '불법', '유통', '관련', '이통', '제재', '듯'],
#  ['실종', '느와르', '강하늘', '회', '촬영', '감량', '소름', '연기력', '네티즌', '극찬', '세례'],
#  ['실종', '느와르', '강하늘', '미생', '역대', '급', '사이코패스', '연기', '소름'],
#  ['이번', '동국제강', '수사', '방위', '확대'],
#  ['실종', '느와르', '강하늘', '천재', '형사', '김강우', '두뇌', '대결', '게임', '준비', '긴장감', '최고'],
#  ['이슈', '분석', '전', '방위', '확산', '부정부패', '척결', '수정'],
#  ['이슈', '분석', '고발', '요청', '발동', '산업', '파장', '수정'],
#  ['살해', '가출', '여중', '성매매', '알선', '인조', '영장', '발부'],
#  ['조세', '회피', '처', '페이퍼', '컴퍼니', '실소', '유주', '등기', '압박'],
#  ['민간', '경비', '업체', '치안', '사각지대', '해소'],
#  ['일광', '공영', '방산', '자료', '톤', '발견'],
#  ['생활', '범죄', '수사', '팀', '달', '간', '명', '검거'],
#  ['대', '중', '도박', '조직', '적발'],
#  ['오늘', '뉴스'],
#  ['통장', '가성', '처벌'],
#  ['실종', '느와르', '강하늘', '신', '사이코패스', '연기', '사람'],
#  ['실종', '느와르', '강하늘', '일주일', '감량', '사이코패스', '미소'],
#  ['실종', '느와르', '강하늘', '신', '사이코패스', '연기', '체중', '감량', '영향'],
#  ['실종', '느와르', '강하늘', '미소', '뒤', '두뇌', '게임', '대박'],
#  ['뇌물', '수수', '혐의', '현직', '경찰', '간부', '휴가', '뒤', '달', '잠적'],
#  ['데스크', '칼럼', '기업', '수사', '칼날', '비틀', '진'],
#  ['농협', '대포통장', '전쟁', '1년', '감소'],
#  ['충북', '경찰청', '무심천', '자전거', '순찰대', '운영'],
#  ['상', '장사', '임원', '규제', '강화', '법안', '반대'],
#  ['교복', '입', '경찰', '기숙사', '삼시세끼'],
#  ['민간', '경비', '업체', '치안', '사각지대', '해소'],
#  ['귀금속', '절취', '이삿짐', '센터', '직원', '구속'],
#  ['할머니', '영정', '사진', '여대', '카메라', '실종', '사건'],
#  ['중앙', '지법', '형사', '법관', '법정', '언행', '의견', '모아'],
#  ['욕정', '경비원', '살', '지하', '계단', '성추행', '법원', '감형'],
#  ['남', '항암', '버섯', '난치병', '환자'],
#  ['입', '연', '일광', '공영', '금고', '지기', '판도라', '컨테이너'],
#  ['포토', '뉴스', '범죄', '피해자', '교통편', '제공', '협약'],
#  ['관리', '범죄', '방비', '사람', '졸피뎀', '수면', '유도제'],
#  ['생활', '범죄', '대상', '호', '자동차'],
#  ['포럼', '벌금형', '사회', '약자', '배려'],
#  ['보험', '사기', '공화국', '특별법', '처벌', '수위', '보험금', '사냥'],
#  ['보험',
#   '사기',
#   '공화국',
#   '특별법',
#   '특별법',
#   '발의',
#   '박대동',
#   '의원',
#   '보험',
#   '사기',
#   '사회',
#   '신뢰',
#   '기반',
#   '수',
#   '있다'],
#  ['지자체', '지역', '안', '전지수', '5월', '공표'],
#  ['간통', '죄', '위헌', '결정', '이후', '달', '풍속'],
#  ['신고', '뒤', '현장', '이탈', '법원', '뺑소니'],
#  ['성', '관계', '여성', '신체', '촬영', '남성', '명', '집', '유', '벌금'],
#  ['내연', '녀', '흉기', '위협', '대', '실형'],
#  ['인터넷', '도박장', '여', '곳', '중', '도박', '조직', '적발'],
#  ['방산', '비리', '증거', '인멸', '일광', '공영', '직원', '명', '구속'],
#  ['세무조사', '편의', '현직', '세무', '공무원', '뒷돈'],
#  ['일광', '공영', '사업', '자료', '도봉산', '발견', '직원', '명', '구속'],
#  ['대',
#   '공군',
#   '장비',
#   '비리',
#   '등',
#   '일광',
#   '공영',
#   '톤',
#   '은닉',
#   '자료',
#   '도봉산',
#   '밑',
#   '컨테이너',
#   '발견'],
#  ['중국', '매장', '곳', '판돈', '중', '합작', '도박', '조직'],
#  ['날줄', '씨줄', '적반하장'],
#  ['봄', '피싱', '사기'],
#  ['방산', '비리', '자료', '증거', '인멸', '일광', '공영', '직원', '명', '구속'],
#  ['모텔', '피살', '10대', '성매매', '알선', '20대', '명', '구속'],
#  ['유', '생각', '돈', '부진', '선수', '비판'],
#  ['장성택', '처형', '국제인권법', '위반'],
#  ['일광', '공영', '방위', '사업', '자료', '컨테이너', '무더기', '발견'],
#  ['중국', '콜', '센터', '대포통장', '모집', '일당', '구속'],
#  ['중국', '공조', '대', '도박장', '운영', '한국인', '총책', '검거'],
#  ['이규태', '비리', '증거', '인멸', '일광', '공영', '직원', '명', '구속'],
#  ['봄철', '카', '주의보', '지하철', '자동차', '주목', '이유'],
#  ['장기', '이식', '환자', '명', '돈', '20대', '구속'],
#  ['경찰', '생활', '범죄', '수사', '팀', '달', '간', '건', '사건', '해결'],
#  ['사이버', '범죄', '스미싱', '파밍'],
#  ['동국제강', '장세주', '회장', '25년', '만', '해외', '도박', '혐의', '자금', '흐름', '추적'],
#  ['대법', '위조', '달러', '처벌', '제동', '법', '조항', '위헌', '우려'],
#  ['중국', '개', '도박장', '운영', '국내', '도박', '조직', '검거', '판돈'],
#  ['세', '세', '도박', '국제', '도박판', '일당', '재판'],
#  ['고법', '세', '여아', '성추행', '대', '경비원', '징역', '2년', '6월', '실형'],
#  ['외환', '위기', '때', '생계', '좀도둑', '기승'],
#  ['외환', '위기', '때', '생계', '좀도둑', '기승'],
#  ['판돈', '중', '도박', '검거'],
#  ['대', '중', '도박', '조직', '적발'],
#  ['동국제강', '다음', '재계', '사정', '확산', '촉각'],
#  ['동국제강', '다음', '재계', '사정', '확산', '촉각'],
#  ['통장', '주일', '만원'],
#  ['자전거', '휴대폰', '쌀', '커피믹스', '등', '생계', '좀도둑', '기승'],
#  ['곳', '판돈', '도박', '국제', '도박', '조직', '적발'],
#  ['리뷰', '코블러', '일상', '미생', '판타지'],
#  ['인터뷰', '차', '실장', '김상경', '살인의뢰'],
#  ['방송', '화제', '실종느와르 M', '포인트', '리얼'],
#  ['실종', '느와르', '방', '강하늘', '변신'],
#  ['실종', '느와르', '방', '두뇌', '싸움', '향연', '진짜가 나타났다'],
#  ['도박', '머니', '게임'],
#  ['방송', '화제', '실종느와르 M', '리얼'],
#  ['세', '여아', '성추행', '대', '경비원', '항소심', '징역', '2년', '6월', '감형'],
#  ['대법원', '위헌', '소지', '법', '적용', '판결', '파기', '환송'],
#  ['검', '도박', '업자', '뇌물', '혐의', '경찰', '간부', '수사'],
#  ['도봉산', '인근', '컨테이너', '방산', '비리', '자료'],
#  ['모두', '날', '거', '저먼윙스', '기장', '문제', '발견', '정신', '질환자', '차별', '우려', '증폭'],
#  ['살', '여자', '어린이', '성추행', '대', '경비원', '항소심', '징역', '2년', '6월', '감형'],
#  ['편집국', '박종철', '박종우', '박상옥', '권태호'],
#  ['아침', '돼지'],
#  ['동국제강', '압수수색', '장세주', '회장', '출국', '금지'],
#  ['기고', '사행', '산업', '감독', '위', '빅', '브러더'],
#  ['군', '이대로', '안', '기밀', '불량', '부품', '패망', '직전', '월', '남군', '듯'],
#  ['방송', '핫이슈', '실종느와르 M', '리얼'],
#  ['북한', '탈북자', '고향'],
#  ['아베', '위안부', '인신매매', '희생자', '책임', '회피', '꼼수'],
#  ['성', '관계', '여성', '신체', '촬영', '명', '집행유예', '벌금'],
#  ['범죄', '단속', '민', '관', '주민', '모두', '참여'],
#  ['성범죄', '공무원', '벌금형', '때', '퇴출'],
#  ['주말', '하이라이트'],
#  ['독자',
#   '소리',
#   '강제',
#   '전학',
#   '학',
#   '폭',
#   '근절',
#   '대책',
#   '최',
#   '주원',
#   '군산경찰서',
#   '여성',
#   '청소년',
#   '계장',
#   '경감'],
#  ['뉴스', '분석', '아베', '위안부', '인신매매', '가슴'],
#  ['아베', '멍석', '경제', '실리', '밀월'],
#  ['20대', '기사', '운전', '교습', '눈', '여관'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴출'],
#  ['간통', '죄', '위헌', '결정', '후', '도내', '무죄', '선고'],
#  ['도내', '개', '도', '주', '회', '동시', '검문검색'],
#  ['국내외', '공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['상습', '절', '도범', '장발장', '법', '위헌', '결정', '구제'],
#  ['성추행', '성폭행', '범죄자', '퇴출', '성희롱', '때', '진급', '금지'],
#  ['밀반입', '대마', '씨', '재배', '후', '흡입', '우즈', '벡', '불법체류', '자', '명', '구속'],
#  ['맞춤', '보이스', '피싱'],
#  ['산', '통', '사회', '진통', '부부', '가족', '실패'],
#  ['2015년', '주목', '신기술', '사물', '인터넷'],
#  ['법원', '사고', '신고', '후 현', '장', '이탈', '뺑소니'],
#  ['터키', '게양', '국기', '제거', '청년', '년', '개월'],
#  ['헌재', '간통', '죄', '위헌', '결정', '후', '강원', '재심', '무죄', '선고'],
#  ['장성택', '처형', '국제법', '위반', '유엔', '답변', '요구'],
#  ['간첩', '혐의', '국민', '명', '자체', '법', '처벌', '10년', '이상', '노동', '교화', '형', '예상'],
#  ['김정은', '비자금', '관리', '정찰', '총국', '공작원', '프랑스', '추방', '강력', '비판'],
#  ['보육', '교사', '명', '훈련', '기록', '조작', '국가', '보조금', '평생', '교육원'],
#  ['성폭력', '군인', '공무원', '스트라이크', '아웃', '정부', '성폭력', '근절', '대책', '발표'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴출'],
#  ['무장', '경찰', '시민'],
#  ['경찰',
#   '팀',
#   '리포트',
#   '변',
#   '관수',
#   '남대문',
#   '경찰서장',
#   '서울역',
#   '노숙',
#   '재활',
#   '집회',
#   '마찰',
#   '최소',
#   '것'],
#  ['경찰', '팀', '리포트', '나이지리아', '메일', '중기'],
#  ['복지', '권리', '남', '주머니', '강요', '자선', '뿐'],
#  ['공무원', '군인', '성범죄', '중징계', '벌금형', '퇴직', '추진'],
#  ['사건', '사고', '음성경찰서', '상습', '가정폭력', '행사', '대', '검거'],
#  ['간통', '죄', '위헌', '결정', '이후', '강원도', '내', '재심', '재판', '무죄', '판결'],
#  ['유엔', '북한', '장성택', '처형', '국제법', '위반'],
#  ['법원', '신고', '후 현', '장', '뺑소니'],
#  ['장성택', '처형', '국제법', '위반', '유엔', '인권', '이사회', '규정'],
#  ['유엔', '장성택', '처형', '국제법', '위반'],
#  ['댁', '부모', '안녕하십니까', '어르신', '금융', '사기', '활개'],
#  ['교통사고', '가해자', '신고', '후 현', '장', '이탈', '뺑소니', '아냐'],
#  ['혐오', '레즈비언', '살인', '죄', '경감', '사유'],
#  ['동작구', '주민', '참여', '범죄', '마을'],
#  ['간통', '죄', '위헌', '결정', '후', '강원', '재심', '무죄', '선고'],
#  ['유엔', '북한', '장성택', '처형', '국제법', '위반'],
#  ['공무원', '군인', '앞', '성폭력', '지위', '옷'],
#  ['권력', '성폭력', '공무원', '군인', '벌금형', '퇴출'],
#  ['공무원', '군인', '성범죄', '벌금형', '영구', '퇴출'],
#  ['성', '관계', '모습', '여성', '치마', '속', '촬영', '명', '재판'],
#  ['책', '삶', '은둔', '외톨이', '묻지마 범죄', '공통점'],
#  ['유엔', '북한', '장성택', '처형', '국제법', '위반'],
#  ['아베', '위안부', '인신매매', '희생자', '가해자', '언급', '생략'],
#  ['측근', '중', '고위급', '겨냥', '전', '정권', '수사'],
#  ['베트남', '신부', '결혼', '정보', '업체', '불', '대'],
#  ['간통', '죄', '위헌', '결정', '후', '강원', '재심', '무죄', '선고'],
#  ['공무원', '군인', '성폭력', '범죄', '퇴직', '교사', '교단', '퇴출'],
#  ['사설', '아베', '의회', '연설', '우경화', '망동', '사과'],
#  ['공무원', '군인', '성폭력', '범죄', '벌금형', '선고', '퇴직', '교사', '퇴출'],
#  ['독자', '투고', '신종', '신용카드', '위조', '대책'],
#  ['프리즘', '조영택', '요양보호사', '처우', '개선'],
#  ['독자', '투고', '산림', '절도', '범죄'],
#  ['검찰', '담양', '펜', '션', '화재', '피해자', '생계비', '등', '지원'],
#  ['슈퍼', '리치', '제임스 패터슨', '댄 브라운', '책', '권', '인세', '갑부'],
#  ['순창', '팔', '덕', '파출소', '농축산물', '도난', '예방', '일제', '점검'],
#  ['진안', '경찰', '보이스', '피싱', '대처', '적극', '홍보'],
#  ['주차', '문제', '야구', '방망이', '위협', '대', '징역형'],
#  ['김제경찰서', '부정부패', '척결', '팀', '구성'],
#  ['검찰', '보훈', '급여', '부정', '수급', '자', '명', '기소'],
#  ['포토', '중랑구', '범죄', '피해자', '보호', '지원', '업무', '협약', '체결'],
#  ['울산', '중', '부서', '성', '신고', '스쿨', '폴리스', '학교', '속'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴출'],
#  ['우월', '지위', '이용', '성범죄', '이상', '관용'],
#  ['공무원', '군인', '성폭력', '근절', '대책', '실시', '벌금형', '고시', '퇴직'],
#  ['사설', '권력', '성범죄', '관용'],
#  ['보육', '교사', '출석부', '조작', '국가', '보조금'],
#  ['남', '고생', '명', '영업', '중인', '대형', '마트', '화장실', '여', '중생', '성폭행'],
#  ['아동', '등장', '음란물', '대학교', '외국인', '영어', '강사'],
#  ['성폭력', '공무원', '군인', '벌금형', '퇴출'],
#  ['원', '투자', '사기', '황장엽', '수양딸', '징역', '년'],
#  ['귀걸이', '뒤', '30대', '징역', '2년', '6월'],
#  ['김태촌', '양아들', '기업', '사냥', '변신', '전횡', '덜미'],
#  ['투자', '사기', '황장엽', '수양딸', '징역', '년', '확정'],
#  ['방산', '비리', '일광', '공영', '직원', '명', '영장'],
#  ['음주', '단속', '경찰관', '군무원', '구속'],
#  ['뉴스', '브리핑', '프로', '야구', '개막전', '암표', '거래', '집중', '단속'],
#  ['성범죄', '가해자', '퇴출', '진급', '금지', '제대', '군인', '복지', '박탈'],
#  ['인천지검', '세무조사', '편의', '수뢰', '전', '현', '국세청', '공무원', '명', '기소'],
#  ['슈퍼', '리치', '살인', '사기', '횡령', '법정', '갑부', '추락', '순간'],
#  ['집중', '취재', '모바일', '금융', '혁신', '키', '핀테크'],
#  ['경찰', '북한산', '송이', '버섯', '밀수', '혐의', '조총련', '의장', '압수수색'],
#  ['만원', '흉터', '보험금', '차별'],
#  ['쇼핑몰', '여', '중생', '성폭행', '매장', '고장', '관리', '소홀'],
#  ['현장', '행정', '돈의동', '쪽', '방촌', '행복', '희망'],
#  ['격동', '일', '70년', '위안부', '문제 해결', '관건', '정상회담', '연대', '극복'],
#  ['군인', '공무원', '성범죄', '대응', '벌금형', '퇴출'],
#  ['남한', '간첩', '명', '체포', '정부', '간첩', '송환'],
#  ['성범죄', '공직자', '벌금형', '퇴출'],
#  ['군대', '대학', '성폭력', '범죄자', '벌금형', '퇴출'],
#  ['아베', '총리', '4월 29일', '사상', '상', '하원', '합동', '연설'],
#  ['끝', '추적', '자전거 도둑', '경찰'],
#  ['강동성심병원', '강동', '경찰서', '업무', '협약', '체결'],
#  ['포토', '뉴스', '해피', '홈', '메신저', '정기', '간담회'],
#  ['책', '안', '괴물', '구원'],
#  ['충주', '노인', '대상', '전화', '금융', '사기', '발생', '피해', '예방', '활동'],
#  ['음성', '경찰', '동료', '지갑', '휴대폰', '절취', '피의자', '구속'],
#  ['상습', '가정폭력', '행사', '대', '검거'],
#  ['제천경찰서', '세명대학교', '캠퍼스', '지킴이', '발', '대식'],
#  ['북한', '남한', '간첩', '명', '체포', '극악', '테러', '분자'],
#  ['공무원', '벌금형', '퇴직', '권력', '범죄', '뿌리'],
#  ['공무원', '벌금형', '퇴직', '권력', '범죄', '뿌리'],
#  ['대대적', '단속', '칼', '매매', '여성', '자립', '지원'],
#  ['대대적', '단속', '칼', '매매', '여성', '자립', '지원'],
#  ['교수', '공무원', '범죄', '원', '스트라이크', '아웃'],
#  ['교수', '공무원', '범죄', '원', '스트라이크', '아웃'],
#  ['투자', '사기', '혐의', '황장엽', '수양딸', '징역', '년', '확정'],
#  ['보조금', '어린이집', '원장', '무더기', '적발'],
#  ['담양', '펜', '션', '화재', '유족', '광주지검'],
#  ['속초', '범죄', '피해자', '지원', '센터', '간담회'],
#  ['사진', '뉴스', '해피', '홈', '메신저', '정기', '간담회'],
#  ['시간', '지배', '경찰', '범죄', '제압'],
#  ['투고', '통장', '수갑'],
#  ['투고', '통장', '수갑'],
#  ['최보경', '교사', '산청', '간디', '학교', '국보', '법', '위반', '굴레'],
#  ['산청', '간디', '학교', '최보경', '교사', '국보', '법', '굴레'],
#  ['최보경', '교사', '국가보안법', '굴레'],
#  ['열린', '마당', '린치', '안', '맞춤', '형', '순찰', '안전', '제주'],
#  ['공무원', '성범죄', '벌금형', '퇴직', '추진'],
#  ['동정', '김', '시택', '예천경찰서', '장'],
#  ['친절', '기자', '카', '실연', '여성', '자살', '과정', '중계', '생명', '불감증', '확산'],
#  ['국정원', '매수', '정보', '제공', '남한', '간첩', '명', '체포', '주장'],
#  ['아동', '음란', '동영상', '유포', '외국인', '영어', '강사', '입건'],
#  ['투자', '사기', '황장엽', '수양딸', '징역', '년', '확정'],
#  ['대형', '마트', '화장실', '고교', '여', '중생', '성폭행'],
#  ['황장엽', '수양딸', '징역', '년'],
#  ['정부', '우월', '지위', '이용한', '성범죄', '처벌', '강화'],
#  ['성폭행', '군인', '원', '아웃', '퇴출', '성희롱', '가해자', '진급', '금지'],
#  ['예멘', '규모', '공습', '지상전', '임박'],
#  ['표현의 자유', '면', '한국', '사법', '파쇼', '토론회'],
#  ['단독', '세월호', '년', '디지털', '사람'],
#  ['유리창', '가지', '이야기'],
#  ['공무원', '군인', '성폭력', '범죄', '퇴출', '교원', '적용'],
#  ['구청', '브리프', '서울', '동작구', '주민', '참여', '범죄', '청정', '마을'],
#  ['북한', '남한', '간첩', '명', '체포', '발표', '극악', '테러', '분자', '주장'],
#  ['글', '기자', '코너', '글', '글', '사람', '등'],
#  ['아동', '청소년', '음란물', '유포', '부산', '사립대', '영어', '강사', '검거'],
#  ['공무원', '군인', '성범죄', '벌금형', '고시', '퇴직', '추진'],
#  ['성폭력', '군인', '공무원', '벌금형', '퇴직'],
#  ['북한', '남한', '간첩', '명', '체포', '국정원', '매수'],
#  ['책', '안중근', '년', '10월 26일', '발', '총성'],
#  ['성추행', '성폭행', '범죄자', '퇴출', '성희롱', '때', '진급', '금지'],
#  ['소말리아', '해적', '피랍', '위험', '선박', '한국', '태국'],
#  ['섹시', '레이디 가가', '노출', '중동'],
#  ['유병언', '벽장', '이규태', '회장', '비밀', '방'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['울산', '중', '부서', '성', '신고', '스쿨', '폴리스', '학교', '속'],
#  ['아동', '음란', '동영상', '유포', '외국인', '강사', '입건'],
#  ['북한', '남한', '간첩', '명', '체포', '극악', '테러', '분자'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직'],
#  ['창원', '아파트', '매매', '창원', '시내', '전세', '가로', '집', '마련', '아파트'],
#  ['공정위', '대기업', '불공', '정', '행위', '감시', '강화'],
#  ['남한', '종', '북', '몰이', '북한', '간첩', '몰이'],
#  ['성폭력', '공직자', '벌금형', '퇴출'],
#  ['북한', '남한', '간첩', '명', '체포', '보위부', '주장', '국정원', '간첩', '기자회견'],
#  ['해수', '부', '소말리아', '해적', '피랍', '위험', '선박', '척', '한국', '태국'],
#  ['11번가', '일', '아이디어', '쇼', '기획전', '최대', '할인', '보너스', '할인', '쿠폰', '발급'],
#  ['군', '성추행', '성폭행', '가해자', '퇴출', '성희롱', '가해자', '진급', '금지'],
#  ['2015년 3월', '27', '일자', '전국', '신문', '사설'],
#  ['마약', '류', '중계', '밀수', '신종', '마약', '밀수', '차단', '강화'],
#  ['자본', '기업', '사냥', '김태촌', '양아들', '구속'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['마약', '혐의', '김성민', '일', '구속', '기소', '재판', '미정'],
#  ['북한', '남한', '간첩', '명', '체포', '진술서', '시인'],
#  ['성범죄', '공무원', '군인', '벌금형', '퇴출'],
#  ['검찰', '좌석', '승급', '특혜', '국토부', '공무원', '가성', '여부', '수사', '착수'],
#  ['군인', '공무원', '성폭력', '벌금형', '퇴출'],
#  ['공무원', '군인', '앞', '성폭력', '범죄', '퇴출'],
#  ['군인', '공무원', '지위', '악용', '성폭력', '시', '벌금형', '퇴출'],
#  ['갑지', '성폭행', '군인', '공무원', '벌금형', '퇴출'],
#  ['군인', '공무원', '성폭력', '벌금형', '퇴출'],
#  ['남한', '간첩', '명', '체포', '정부', '주장', '송환'],
#  ['사람',
#   '안성',
#   '회',
#   'NH농협은행',
#   '전화',
#   '사기',
#   '예방',
#   '환급',
#   '팀장',
#   '창구',
#   '직원',
#   '반복',
#   '교육',
#   '대포통장',
#   '근절'],
#  ['성폭력', '벌금형', '군인', '공무원', '스트라이크', '아웃'],
#  ['대형', '마트', '화장실', '여', '중생', '성폭행', '친구사이', '고교', '짓'],
#  ['대법', '황장엽', '수양딸', '투자', '사기', '징역', '년'],
#  ['내', '성폭행', '자', '퇴출'],
#  ['성범죄', '공무원', '군인', '벌금형', '퇴직'],
#  ['시장', '사무소', '관계자', '항소심', '형', '사부로', '배정'],
#  ['수렵', '야', '유배', '수', '얘기'],
#  ['베트남', '신부', '결혼', '정보', '업체', '불', '대'],
#  ['북', '남한', '간첩', '명', '체포', '남', '송환'],
#  ['청소', '업체', '위탁', '비', '횡령', '천안시', '책임', '대두'],
#  ['범죄', '피해자', '것'],
#  ['홍성', '경찰', '이동', '경찰서', '운영'],
#  ['스포츠', '토토', '잘못', '명칭', '불법', '스포츠', '도박', '조심'],
#  ['기고', '주민등록증', '간직'],
#  ['성폭력', '군인', '공무원', '퇴출'],
#  ['북한', '남한', '간첩', '명', '체포', '극악', '테러', '분자'],
#  ['사물', '인터넷', '활용', '스마트', '무인', '경비', '솔루션', '이지', '워치'],
#  ['더', '벨', '법원', '황', '귀', '남', '씨', '등', '보유', '주식', '의결권', '제한'],
#  ['만삭', '세', '소녀', '납치', '성추행', '10대', '명', '구속'],
#  ['세탁기', '파손', '분쟁', '조성진', '사장', '재판', '내달', '일', '연기'],
#  ['이규태', '비리', '증거', '인멸', '일광', '공영', '직원', '명', '영장'],
#  ['군인', '공무원', '성범죄', '벌금형', '공직', '영구', '퇴출'],
#  ['한국', '간첩', '명', '체포', '주장', 'CNN', '국정원', '사실', '부인'],
#  ['황장엽', '수양딸', '투자', '사기', '혐의', '징역', '년', '확정'],
#  ['음주', '단속', '경찰', '차로', '미', '군무원', '구속'],
#  ['성추행', '성폭행', '범죄자', '퇴출', '성범죄', '묵인', '방관', '처벌'],
#  ['공무원', '군인', '성폭력', '벌금형', '선고', '퇴출'],
#  ['공무원', '군인', '성폭력', '범죄', '절차', '옷'],
#  ['성폭행', '공무원', '군인', '절차', '옷'],
#  ['세무조사', '편의', '수뢰', '국세청', '공무원', '명', '기소'],
#  ['어린이집', '보조금', '명', '적발'],
#  ['군인', '공무원', '범죄', '벌금형', '퇴출'],
#  ['박범훈', '수석', '압수수색', '겨냥'],
#  ['박범훈', '수석', '압수수색', '겨냥'],
#  ['박범훈', '수석', '압수수색', '겨냥'],
#  ['힐스테이트', '기흥', '규모', '복합', '커뮤니티'],
#  ['소말리아', '해적', '피랍', '위험', '선박', '한국', '태국'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['관세청', '전국', '세관', '마약', '수사', '정보', '교류', '회'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['한번', '성폭력', '성추행', '퇴출'],
#  ['성폭력', '근절', '종합', '대책', '발표', '성추행', '성폭행', '범죄자', '퇴출'],
#  ['성폭행', '군인', '공무원', '벌금형', '퇴출'],
#  ['북한', '남한', '간첩', '명', '체포', '극악', '테러', '분자'],
#  ['어린이집', '원장', '교육원', '국고', '보조금'],
#  ['투자', '사기', '황장엽', '수양딸', '징역', '년'],
#  ['권력', '성폭력', '공무원', '군인', '벌금형', '퇴출'],
#  ['권력', '성폭행', '벌금형', '선고', '퇴직'],
#  ['공무원', '군인', '성범죄', '벌금형', '영구', '퇴출'],
#  ['책', '삶', '은둔', '외톨이', '묻지마 범죄', '공통점'],
#  ['이규태', '회장', '증거', '인멸', '일광', '공영', '직원', '명', '구속영장'],
#  ['천황', '주의자', '아버지', '소설'],
#  ['성추행', '성폭행', '가해자', '퇴출', '원칙'],
#  ['세무', '컨설팅', '용역', '세무조사', '편의', '수뢰', '국세청', '공무원', '명', '기소'],
#  ['친구', '회', '도박', '유명', '입시', '업체', '대표'],
#  ['흉터', '보험금', '남녀', '차별'],
#  ['중국', '4월', '부패', '스카이넷', '작전', '개시'],
#  ['대', '국가', '보조금', '횡령', '평생', '교육원', '어린이집', '원장', '무더기', '적발'],
#  ['측근', '중', '고위급', '겨냥', '전', '정권', '수사'],
#  ['집', '필중', '임옥희', '경희대', '후', '마니', '타스', '칼리지', '교수', '지금', '페미니즘', '말'],
#  ['측근', '중', '고위급', '겨냥', '전', '정권', '수사'],
#  ['투자', '사기', '황장엽', '수양딸', '징역', '년', '확정'],
#  ['북한', '남한', '간첩', '명', '체포', '극악', '테러', '분자'],
#  ['자본', '기업', '사냥', '김태촌', '양아들', '구속'],
#  ['북', '한국', '간첩', '명', '체포', '기자회견'],
#  ['사설', '보이스', '피싱', '이체', '지연', '시간'],
#  ['사무장', '병원', '요양', '급여', '원', '부정', '수급'],
#  ['공유', '다', '문화', '외국인', '범죄', '허', '충', '호', '사회부', '김해', '본부장'],
#  ['진해경찰서', '중고', '봉사단', '여명', '담벼락', '희망'],
#  ['범죄', '피해자', '경제', '지원', '발'],
#  ['만우절', '허위', '장난', '신고'],
#  ['회장', '압수수색', '방해', '일광', '공영', '직원', '명', '영장'],
#  ['사감', '위', '전자', '카드', '도입', '불법', '사행', '산업', '근절', '중점'],
#  ['경찰', '눈', '장난', '전화', '위급', '생명', '수'],
#  ['옥천', '경찰', '다', '문화', '센터'],
#  ['홍성', '범피', '센터', '사랑', '집수리', '봉사'],
#  ['이희', '총재', '힘', '전', '세계'],
#  ['청소', '업체', '대표', '징역', '년'],
#  ['쿠바', '공무원', '부패', '달걀', '무더기', '중형'],
#  ['김영란', '법', '입법', '과정', '정치', '한계', '지적'],
#  ['레이디 가가', '중동', '버전', '이미지', '보니'],
#  ['저먼윙스', '사고기', '미스터리', '시나리오', '반론'],
#  ['마을', '집', '신부', '선데이', '서울로', '그때', '시절'],
#  ['자전거 도둑', '경찰', '대', '추적'],
#  ['월세', '원', '독촉', '주인집', '불', '대', '구속'],
#  ['경찰병원', '전화', '착시', '전환', '보이스', '피싱', '경찰', '수사'],
#  ['일본', '경찰', '조선', '총련', '의장', '자택', '압수수색'],
#  ['아침', '신문', '보기', '코스닥', '일', '간의', '질주'],
#  ['음주', '단속', '피해', '시속', '킬로미터', '도주'],
#  ['이슈', '투데이', '노인', '대상', '사기', '범죄'],
#  ['음주', '단속', '피해', '시속', '킬로미터', '도주'],
#  ['알몸', '채팅', '함정'],
#  ['강원', '포럼', '안함', '주기', '안보', '의식', '정립'],
#  ['충북', '경찰청', '교육'],
#  ['충북', '도', '교육청', '부패', '척결', '계획', '방안', '추진'],
#  ['술집', '박사', '대전', '유성구', '성범죄', '위험', '도시 자치구', '중'],
#  ['범죄', '피해자', '경제', '지원', '담양', '펜', '션', '화재', '피해자', '만원'],
#  ['세상', '만사', '나라', '안', '대마초', '불법체류', '자'],
#  ['카드', '복제', '설치', '중국', '동포', '명', '구속'],
#  ['사설', '태극기', '이벤트', '정신', '강화', '계기'],
#  ['사설', '대통령', '의지', '권력', '기관'],
#  ['자전거', '도둑', '더 독', '한', '경찰'],
#  ['복지', '사각지대', '경제', '약자', '탈출구'],
#  ['김천경찰서', '주민', '현장', '간담회', '호응'],
#  ['동두천경찰서', '중앙', '성모병원', '범죄', '피해자', '치료', '업무', '협약'],
#  ['평창경찰서', '해피', '홈', '메신저', '명', '위촉', '간담회', '사진'],
#  ['원주', '초등', '방과', '후', '안전사고'],
#  ['기고', '블랙박스', '장점', '단점'],
#  ['기고', '블랙박스', '장점', '단점'],
#  ['도로', '명', '주소', '응급', '상황', '생명', '줄'],
#  ['교통사고', '보험', '사기', '직장인', '가담'],
#  ['대구', '경찰', '대마', '재배', '흡입', '우즈베키스탄', '등', '명', '구속'],
#  ['친절', '기자', '생명', '불감증', '확산', '우려', '기독교', '윤리', '교육', '적극'],
#  ['폭로', '여성', '죄수', '교도소', '성', '상납', '보고서'],
#  ['일본',
#   '경찰',
#   '북한산',
#   '송이',
#   '불법',
#   '수입',
#   '관련',
#   '조총련',
#   '허종만',
#   '의장',
#   '자택',
#   '등',
#   '압수수색'],
#  ['하루', '명도', '교도소', '죄수', '성', '상납', '다반사', '모범수', '성', '상납'],
#  ['일본', '경찰', '조선', '총련', '의장', '자택', '압수수색', '송이', '불법', '수입', '사건', '관련'],
#  ['지구', '끝', '기세', '자전거', '도둑', '경찰'],
#  ['저먼윙스', '자살비행', '부각', '조종사', '명', '조종실', '이탈'],
#  ['서울', '국세청', '일선', '세무서', '곳', '동시', '다발', '압수수색'],
#  ['윗선', '지시', '비자금', '조성', '전달', '포스코건설', '베트남', '법인', '장', '진술', '확보'],
#  ['대한민국', '명품', '브랜드', '대상', '해외', '명품', '문구', '인정', '제품 개발'],
#  ['안함', '주기', '북한', '미군', '잠수함', '충돌', '음모론', '제기'],
#  ['안함', '주기', '남북', '관계', '북한', '반응'],
#  ['천종호', '부장', '판사', '자', '소년', '생각', '만사', '소년', '별명'],
#  ['독일', '여객기', '추락', '조종사', '명', '이탈', '자살비행', '제기'],
#  ['범죄', '피해자', '경제', '보상', '검찰', '주민', '단체'],
#  ['장난꾸러기', '매력', '발산', '반항아', '김우빈'],
#  ['브리핑', '영도', '범죄', '피해자', '안심', '귀가', '협약'],
#  ['창원', '사무장', '병원', '불법', '요양', '급여'],
#  ['구리경찰서', '실종', '수색', '골든타임', '확보', '전국', '드'],
#  ['부지', '매각', '대', '뒷돈', '학교', '이사장', '항소심', '실형'],
#  ['렌터카', '이용', '불법', '운송', '무더기', '검거'],
#  ['대전', '유성구', '성범죄', '위험', '안전', '도시'],
#  ['보험', '사기', '공화국', '특별법', '해외'],
#  ['시론', '유령', '수술', '근절'],
#  ['보험', '사기', '공화국', '특별법', '범죄', '사회'],
#  ['일본', '경찰', '조총련', '의장', '자택', '압수수색'],
#  ['한국', '어선', '척', '소말리아', '해적', '피랍', '위험'],
#  ['환전상', '피싱', '조직', '가담', '환치'],
#  ['서경', '하우', '징', '페어', '두산건설', '가지', '기술', '에너지', '절감', '휴먼', '아파트'],
#  ['조종사', '이탈', '독일', '여객기', '자살비행', '부각'],
#  ['정치인', '사칭', '착시', '전환', '보이스', '피싱'],
#  ['권력', '형', '성범죄', '4년', '배'],
#  ['여주경찰서', '차', '재학', '신임', '대장', '소통', '화합', '범죄', '도약'],
#  ['간통', '죄', '위헌', '판결', '대', '무죄', '선고'],
#  ['국세청', '직원', '여명', '뇌물', '수수', '리스트'],
#  ['단독', '한국인', '미사일', '부품', '이란', '밀매'],
#  ['대청도', '대', '도박판', '공무원', '등', '명', '검거'],
#  ['시만텍', '사이버 범죄', '수사', '협력', '시스템', '구축'],
#  ['누리', '작명', '소', '정', '용', '현', '소장', '영향력', '인기', '작명', '가로', '선정'],
#  ['온주완', '조보아', '드라마', '실종', '느와르', '배역'],
#  ['천안시', '위탁', '비', '횡령', '청소', '업체', '대표', '징역'],
#  ['백석', '대', '천안', '서', '북', '경찰', '관', '학', '협력', '체결'],
#  ['수렵', '야', '유배', '수', '얘기'],
#  ['김태촌', '양아들', '대', '횡령', '혐의', '구속'],
#  ['이규태', '회장', '비자금', '창구', '의혹', '교회', '건물', '추가', '압수수색'],
#  ['독일', '여객기', '추락', '사고', '자살비행', '제기'],
#  ['국가보안법', '위반', '혐의', '간디', '학교', '교사', '무죄', '확정'],
#  ['보이스', '피싱', '원천', '봉쇄', '법'],
#  ['내', '아이', '학교'],
#  ['군인', '성매매', '처벌', '수위', '진다'],
#  ['살인', '성폭력', '장기', '미제', '건', '해결', '힘'],
#  ['음향', '기기', '개인', '감상', '실', '음향', '마니아', '입건'],
#  ['중국', '해커', '돈', '디', '도스', '공격', '방어', '업체', '대표'],
#  ['9호선', '단계', '논현', '종합운동장', '일', '시', '분', '운행'],
#  ['그리스', '포르투갈', '재정', '위기', '검은돈'],
#  ...]

# %%
fin_lst=[]
for n in transaction:
    two_lst = []
    for i in n:
        if len(i)<=1:
            pass
        else:
            two_lst.append(i)
    fin_lst.append(two_lst)
fin_lst
# Out:
# [['영광', '경찰', '개인택시', '지부', '업무', '협약'],
#  ['독자', '투고', '범죄', '예방'],
#  ['기고', '에코', '도시', '조성', '한걸음', '발걸음'],
#  ['야후', '재팬', '사생활 침해', '정보', '수정', '수정'],
#  ['삼성', '글로벌', '주도', '확보', '대승', '결단', '수정'],
#  ['울산', '경찰', '폭력배', '강도', '절도', '집중', '단속'],
#  ['종교', '시설', '남매', '성추행', '20대', '실형'],
#  ['일광', '공영', '이규태', '회장', '기소'],
#  ['박수범', '대전', '대덕구청장', '자율', '방범대원', '안전', '도시'],
#  ['보선', '유권자', '선택'],
#  ['국토부', '주차장', '조명', '설치', '의무'],
#  ['웃음', '바이러스'],
#  ['삼성', '법적', '분쟁', '종결', '합의', '세탁기', '파손', '공방'],
#  ['만우절', '장난', '전화', '처벌', '적발', '벌금', '구류', '처분'],
#  ['연쇄살인범', '아동', '성폭력범', '출소', '최장', '7년', '사회', '격리'],
#  ['무기', '중개상', '이규태', '회장', '방산', '장비', '납품', '사기', '혐의', '기소'],
#  ['성범죄', '교수', '교사', '교단', '영구', '추방'],
#  ['성범죄', '교수', '교사', '교단', '영구', '추방'],
#  ['금감원', '직원', '사칭', '보이스', '피싱', '유도', '문자', '주의'],
#  ['흉악범', '최장', '격리', '보호', '수용', '국무회의', '의결'],
#  ['불황', '사기', '횡령', '전락', '변호사들'],
#  ['박원순', '시행', '개월', '핫라인', '신고', '증가'],
#  ['금감원', '직원', '사칭', '보이스', '피싱', '유도', '문자', '주의'],
#  ['성범죄', '확정', '교사', '교수', '교단', '영구', '퇴출'],
#  ['오바마', '7월', '취임', '처음', '아버지', '나라', '케냐', '방문'],
#  ['자원외교', '비리', '관련', '경남기업', '부사장', '소환', '조사'],
#  ['아베', '잔혹', '과거사', '인정'],
#  ['검찰', '장경욱', '김인숙', '변호사', '징계', '법무부', '신청'],
#  ['상품권', '사기', '주부'],
#  ['만우절', '장난', '전화', '처벌', '생각', '형사', '처벌'],
#  ['창원', '힐스테이트', '지역', '랜드마크'],
#  ['불혹', '사시', '변호사', '법률', '시장', '불황', '사기', '전락'],
#  ['노총', '제조', '부문', '노사정위', '일방', '합의', '강요', '강행', '처리', '총파업'],
#  ['필리핀', '관광', '위장', '황제성', '매매', '교수', '검거'],
#  ['해외', '노동자', '인권', '침해', '검토'],
#  ['아버지', '용돈', '동네', '가짜', '도둑', '아들'],
#  ['가이드', '성매매', '파트너', '필리핀', '황제', '관광', '무더기', '적발'],
#  ['연쇄', '살인', '흉악범', '종료', '최장', '7년', '사회', '격리', '국무회의', '통과'],
#  ['만우절', '장난', '전화', '처벌', '식당', '불평', '불효', '자식', '체포', '허위', '신고'],
#  ['이규태', '농간', '엉터리'],
#  ['논평'],
#  ['만우절', '장난', '전화', '적발', '공무집행방해죄', '처벌'],
#  ['천안', '외국인', '도움', '센터', '무용지물'],
#  ['가정폭력', '사기', '혼자'],
#  ['가짜', '검찰청', '사이트', '카카오톡'],
#  ['출근', '입원', '보험사', '기단'],
#  ['리뷰', '범행', '장소', '사전', '답사', '도범', '검거'],
#  ['뉴스', '플러스', '남한', '드라마', '인기', '비상', '단속', '무용지물'],
#  ['폭행', '주변', '무관심', '곳곳', '개탄', '목소리'],
#  ['아파트', '오피스텔', '범죄자', '침입', '설계', '기준', '마련'],
#  ['재범', '우려', '강력범죄', '최장', '격리', '보호', '수용', '통과'],
#  ['내달', '아파트', '오피스텔', '범죄자', '침입'],
#  ['폭행', '무관심', '곳곳', '개탄', '목소리'],
#  ['폭행', '무관심', '곳곳', '개탄', '목소리'],
#  ['만우절', '장난', '전화', '동물', '처벌'],
#  ['하이라이트'],
#  ['만우절', '장난', '전화', '만원', '입금', '신고', '처벌'],
#  ['만우절', '장난', '전화', '장난', '전화'],
#  ['전국', '폐쇄', '박차', '수익', '몰수', '추징', '강화'],
#  ['학생'],
#  ['포스코건설', '비자금', '갈래', '추가', '포착'],
#  ['만우절', '장난', '전화', '처벌', '경찰청', '경찰력', '낭비', '동참', '부탁'],
#  ['박원순', '그 후', '서울시', '공무원', '비리'],
#  ['군산경찰서', '업무', '유공자', '표창'],
#  ['전주', '지역', '성매매', '집결지', '폐쇄', '속도'],
#  ['전자전', '훈련', '장비', '사기', '혐의', '이규태', '회장', '재판'],
#  ['포스코건설', '추가', '비자금', '정황', '포착'],
#  ['경찰청', '만우절', '장난', '전화', '자제', '요청'],
#  ['수단', '군납', '사기', '이규태', '회장', '구속', '기소'],
#  ['대포통장', '판매', '30대', '벌금', '만원'],
#  ['장애', '청소년', '관계', '촬영', '20대', '징역형'],
#  ['가구', '이상', '주택', '주차장', '의무'],
#  ['무관심', '아이들'],
#  ['아파트', '나무', '창문', '거리'],
#  ['옥천경찰서', '체감', '치안', '향상', '맞춤', '캠페인', '사진'],
#  ['부동산', '부동산', '투자', '투기'],
#  ['경찰', '금융', '기관', '악성', '사기', '공동', '대응', '협약'],
#  ['충북', '기협', '분기', '이달의 기자상', '선정'],
#  ['여의', '나루', '데이터', '세상'],
#  ['금융감독원', '직원', '박선영', '주의'],
#  ['강진', '경찰', '개인', '택시', '조합'],
#  ['범죄', '교육', '공무원', '교수', '교단', '퇴출'],
#  ['흉악범', '최장', '격리', '보호', '수용', '법안', '국무회의', '의결'],
#  ['흉악범', '최장', '격리', '보호', '수용', '법안', '국무회의', '의결'],
#  ['세상', '만사', '나라', '여성', '투자', '미끼', '사기'],
#  ['가이드', '섹스', '파트너', '만원', '황제', '매매'],
#  ['가이드', '섹스', '파트너', '만원', '황제', '매매'],
#  ['산업', '스파이', '무기', '거래', '포탄', '기술'],
#  ['포럼', '노동', '시장', '성공', '가지'],
#  ['멕시코', '불법 무기', '유통', '멕시코', '성인', '남자', '명당', '총기', '소지'],
#  ['울진경찰서', '지역', '아동', '센터', '범죄', '예방', '협약'],
#  ['이근', '대구대학교', '대외', '협력', '부총장', '대구', '장애우', '권익', '연구소', '특강'],
#  ['조희팔', '은닉', '재산', '추징', '보전', '행보', '피해자', '상환', '지체'],
#  ['불법체류', '외국인', '피해자', '보호', '원년'],
#  ['경산경찰서', '합동', '순찰', '외국인', '밀집', '지역', '범죄', '예방'],
#  ['검찰', '조희팔', '은닉', '자금', '추징', '보전', '논란'],
#  ['영천경찰서', '청소년', '선도', '심사위', '개최'],
#  ['보성', '경찰', '범죄', '피해자', '교통편', '제공', '협약'],
#  ['양치기', '소년', '만우절'],
#  ['가입자', '서명', '도용', '검찰', '고발'],
#  ['국내', '최대', '라이벌', '삼성', 'LG', '분쟁', '일지'],
#  ['원창묵', '원주시', '항소심', '벌금', '만원', '선고'],
#  ['상습', '거짓', '신고', '피의자', '검거'],
#  ['교통사고', '피해자', '지원', '제도'],
#  ['교통사고', '피해자', '지원', '제도'],
#  ['범죄', '시민', '심사', '위원', '판단'],
#  ['범죄', '시민', '심사', '위원', '판단'],
#  ['진해', '고등학교', '음란', '행위', '30대', '체포'],
#  ['구미', '고용', '노동부', '구미', '지청', '범죄', '피해자', '취업', '지원', '업무', '협약'],
#  ['조희팔', '자금', '피해자', '처리', '이견'],
#  ['채널', '한국', '외국인', '근로자', '공존', '조건'],
#  ['칠곡', '성장', '생활', '불편', '석적읍', '홀대', '분통'],
#  ['인구', '석적읍', '기반 시설'],
#  ['경기', '경찰청', '국악', '마술', '수화', '범죄', '예방', '홍보', '인기'],
#  ['달러', '유통', '달러', '검은돈', '변신', '특수부대', '업무', '영역', '확대'],
#  ['모략', '소굴', '남조선', '둥지', '자비', '징벌', '인권', '현장', '사무소', '서울', '개설', '반발'],
#  ['아동', '성폭력범', '최장', '7년', '사회', '격리', '연쇄살인범', '흉악범'],
#  ['성추행', '영예', '군인', '영웅', '영예', '군인', '범죄', '골머리'],
#  ['여의도', '포럼', '김창준', '싱가포르', '곤장', '제도'],
#  ['살인범', '이중', '처벌', '보호', '수용', '국무회의', '통과'],
#  ['널 기다리며', '촬영', '하반기', '개봉', '기대', '심은경', '주연', '범죄', '스릴러'],
#  ['인터넷', '모의', '총기', '판매', '벌금형'],
#  ['코리아', '코커스', '의장', '아베', '과거', '잔혹', '행위', '인정'],
#  ['가출', '중생', '살인', '사건', '용의자', '기절'],
#  ['통나무', '치마', '여자', '군인', '성범죄', '천국'],
#  ['전자', '차고', '차례', '성범죄', '20대', '검거'],
#  ['투자', '사기', '주부'],
#  ['직원', '상품권'],
#  ['국무부', '위안부', '목적', '여성', '매매', '행위'],
#  ['김정은', '외국인', '상대', '여대', '성매매', '총살', '지시', '나선', '지구', '여대', '가격', '달러'],
#  ['상원', '매수', '처벌', '법안', '부결', '하원', '최종', '결정'],
#  ['이규태', '회장', '방사', '예산', '기소'],
#  ['자살', '몸캠', '협박', '음성', '파일', '유포', '파문'],
#  ['필리핀', '원정', '성매매', '황제', '관광', '검거'],
#  ['아이템베이', '더치트', '온라인', '사기', '범죄', '예방', '업무', '협약', '체결'],
#  ['내달', '범죄', '예방', '건축', '기준', '시행'],
#  ['경찰', '만우절', '장난', '전화', '처벌', '업무', '방해', '민원', '신고', '자제', '당부'],
#  ['성매매', '가출', '소녀', '살인', '사건', '용의자', '범행', '자백', '과거', '20대'],
#  ['분석', '삼성', '화해', '검찰', '법원', '판단'],
#  ['검찰', '동국제강', '해외', '송금', '추적'],
#  ['법무부', '사랑', '부산', '동지', '연합회', '하형주', '동아대', '교수', '홍보', '대사', '위촉'],
#  ['아동', '음란물', '처벌', '미국', '무기', '벌금'],
#  ['필리핀', '황제', '관광', '알선', '브로커', '매수', '무더기', '검거'],
#  ['성범죄', '확정', '교사', '교수', '교단', '영구', '추방'],
#  ['이준영', '세상 속으로', '섬나라', '처신'],
#  ['필리핀', '원정', '성매매', '대학교수', '황제', '관광', '일당', '검거'],
#  ['필리핀', '원정', '성매매', '황제', '관광', '수년', '경찰', '망신살'],
#  ['고양이', '생선'],
#  ['공직', '선거법', '위반', '원주시', '벌금', '만원', '직위', '유지'],
#  ['어른', '욕망', '목숨'],
#  ['괴산경찰서', '유기', '협력', '체계', '구축', '간담회'],
#  ['보은경찰서', '농협', '지부장', '협약', '체결'],
#  ['충북', '이달의 기자상', '선정'],
#  ['아파트', '건축물', '범죄', '예방', '설계', '허가'],
#  ['성범죄', '확정', '교사', '교수', '교단', '영구', '추방'],
#  ['흉악범', '출소', '최장', '격리'],
#  ['시민', '단체', '고객', '정보', '도용', '유출', '의혹', '고발'],
#  ['오바마', '취임', '처음', '아버지', '나라', '케냐', '간다'],
#  ['만우절', '허위', '고시', '최대', '벌금', '만원'],
#  ['구글', '보안', '전문가', '온라인', '보안', '계명'],
#  ['전국', '트롤', '서울시', '박원순', '시행', '개월', '공무원', '비리', '감소'],
#  ['흉악범', '형기', '격리', '보호', '수용', '법안', '국무회의', '통과'],
#  ['서울시', '박원순', '공무원범죄', '급감', '비리', '신고'],
#  ['흉악범', '최대', '수용', '보호', '수용', '법안', '통과'],
#  ['아프리카', '난민', '오해', '편견', '사연'],
#  ['만우절', '장난', '전화', '경찰', '엄정', '대응', '엄포'],
#  ['단신', '내일', '음식점', '흡연', '과태료'],
#  ['만우절', '장난', '전화', '공무집행방해죄', '처벌'],
#  ['대전', '지검', '범죄', '피해자', '지원', '센터', '가정', '만원', '지원'],
#  ['안전', '세종', '완성', '세종', '경찰', '노력'],
#  ['형기', '흉악범', '최대', '7년', '격리', '법안', '국무회의', '통과'],
#  ['무인', '빨래', '30대', '좀도둑', '덜미'],
#  ['흉악범', '최장', '보호', '수용', '격리', '이중', '처벌', '논란', '예상'],
#  ['울산', '경찰', '폭력배', '강도', '절도', '집중', '단속'],
#  ['종교', '시설', '남매', '성추행', '20대', '실형'],
#  ['필리핀', '성매매', '황제', '관광', '검거', '교수', '포함'],
#  ['성범죄', '확정', '교사', '교수', '교단', '영구', '추방'],
#  ['보이스', '피싱', '조직', '사기', '극성'],
#  ['피해자', '코디네이터'],
#  ['지능', '범죄', '전쟁'],
#  ['유리창', '콩나물', '시루'],
#  ['수사망', '피해', '페이스', '오프', '꼬리', '아파트', '이범'],
#  ['검찰', '동국제강', '비자금', '총수', '일가', '유입', '증거', '확보', '주력'],
#  ['검찰', '동국제강', '비자금', '의혹', '증거', '확보', '주력'],
#  ['내일', '시론', '권력자', '인사', '전횡', '부패', '뿌리'],
#  ['전화', '식당', '음식'],
#  ['순천시', '순천경찰서', '기관', '단체', '업무', '협약', '체결'],
#  ['국토부', '범죄', '예방', '건축', '기준', '고시', '조명', '설치', '의무'],
#  ['김문수', '유엔', '북한', '인권', '현장', '사무소', '동북아', '전체', '등불'],
#  ['병원장', '지역', '사회', '발전', '유공', '표창'],
#  ['보상', '전단지', '연락', '덜미'],
#  ['흉악범', '출소', '격리', '보호', '수용', '법안', '국무회의', '통과'],
#  ['도둑', '단골', '침입', '아파트', '배관', '외벽', '설치'],
#  ['박원순', '개월', '공무원', '비리'],
#  ['필리핀', '성매매', '황제', '관광', '교수', '회계사', '입건'],
#  ['코리아', '코커스', '의장', '아베', '과거', '잔혹', '행위', '인정'],
#  ['만우절', '핑계', '허위', '전화', '장난', '처벌'],
#  ['성매매', '중생', '살해', '피의자', '주전', '유사', '범행'],
#  ['권리', '보호', '야후', '재팬', '성적', '동영상', '집단', '괴롭힘', '피해', '삭제'],
#  ['특별기', '제주', '아픔', '치유', '상생'],
#  ['야누스', '얼굴', '상속자', '뒷골목', '사내'],
#  ['교수', '회계사', '유혹', '필리핀', '황제', '관광'],
#  ['하드보일드', '폭력', '주제', '한국', '하드보일드', '복수는 나의 것'],
#  ['범죄의 재구성', '바람', '롤리타', '제물', '소녀'],
#  ['포스코건설', '비자금', '추가', '포착'],
#  ['가구', '이상', '공공', '주택', '범죄', '사각지대'],
#  ['보험', '업계', '자율', '책임', '검사', '체계', '구축'],
#  ['상품권', '구입', '주부'],
#  ['애완견', '남성', '이유'],
#  ['4월', '아파트', '범죄', '예방', '기준', '허가'],
#  ['박원순', '시행', '반년', '신고', '공무원', '범죄', '급감'],
#  ['경기', '경찰', '애완견', '절도', '주의보'],
#  ['가구', '이상', '공동', '주택', '학교', '오피스텔', '건축물', '범죄', '예방', '기준', '허가'],
#  ['입원', '보험', '사기', '무더기', '검거', '수법', '경악'],
#  ['경기도', '애완견', '도난', '사고'],
#  ['아트', '하우스', '4월', '라이브', '모스트 바이어런트', '선정'],
#  ['친구', '아버지', '사기', '10대', '훈육', '덜미'],
#  ['친구', '아버지', '사기', '10대', '훈육', '덜미'],
#  ['새벽', '시간대', '무인', '빨래', '도범'],
#  ['벌금', '차량', '대학생'],
#  ['노트북', '추적', '빈집', '이범', '덜미'],
#  ['흉악범', '최대', '추가', '격리', '법안', '통과', '이중', '처벌', '논란'],
#  ['범죄', '발생', '피해자', '지원'],
#  ['하드보일드', '감정', '냉담', '태도', '영화', '소재', '활용'],
#  ['국정원', '첨단', '무기', '핵심', '기술', '유출', '사고', '지난해', '최다', '적발'],
#  ['범죄', '수사', '세계', '인질극', '대한민국', '안전지대'],
#  ['원주시', '항소심', '벌금', '만원', '공직', '유지'],
#  ['아트', '하우스', '4월', '라이브', '모스트 바이어런트', '선정'],
#  ['봉천동', '10대', '살인', '용의자', '범행', '자백', '수면', '마취제', '이용'],
#  ['사기', '이규태', '일광', '공영', '회장', '기소'],
#  ['새누리당', '지역', '일꾼', '공약', '안전', '관악', '예산', '불독'],
#  ['상품권', '교회', '지인', '상대로', '사기'],
#  ['연쇄살인범', '아동', '성폭력범', '형기', '최대', '7년', '격리'],
#  ['중고', '거래', '구매자', '판매자', '삼각', '사기', '일당'],
#  ['박원순', '개월', '서울시', '공무원', '범죄'],
#  ['아파트', '범죄', '예방', '시설', '건축', '허가'],
#  ['장난', '전화', '허위', '신고', '처벌'],
#  ['리보', '4월', '국회', '기재', '교문', '화약고'],
#  ['불효', '자식', '만우절', '장난', '전화'],
#  ['바다', '살인', '흉기'],
#  ['개월', '제자리걸음', '국회', '논의'],
#  ['정보화', '시대', '파수꾼', '화이트', '해커', '정부', '차원', '관리'],
#  ['고급', '차만', '금품', '만원', '30대', '구속'],
#  ['가정주부', '투자', '미끼', '4년', '사기', '행각'],
#  ['경찰', '고양', '고양이', '네티즌', '눈길', '공공', '기관'],
#  ['애완견', '도난', '주의보'],
#  ['국무부', '위안부', '목적', '여성', '매매', '행위'],
#  ['강력범', '형기', '최대', '격리'],
#  ['강력범', '형기', '최대', '격리'],
#  ['방위', '사업', '비리', '수단', '이규태', '회장', '기소'],
#  ['행정자치부', '대구', '지역', '공무원', '성폭력', '범죄', '이후', '발생'],
#  ['상품권', '구입', '주부', '쇠고랑'],
#  ['인천시', '아동', '안전', '지도', '제작', '사업', '추진'],
#  ['모텔', '중생', '남성', '손톱', '충격'],
#  ['모텔', '중생', '남성', '손톱', '충격'],
#  ['검찰', '포스코', '비자금', '추가', '포착'],
#  ['가구', '이상', '아파트', '의무'],
#  ['흉악범', '최장', '격리', '보호', '수용', '법안', '국무회의', '통과'],
#  ['보호', '수용', '법안', '국무회의', '통과', '이중', '처벌', '논란'],
#  ['하드보일드', '감정', '냉담', '태도', '하드보일드', '영화', '대표작'],
#  ['필리핀', '황제', '관광', '대학교수', '대기업', '회사원', '원정', '성매매', '일당', '검거'],
#  ['필리핀', '관광', '위장', '성매매', '검거', '대학교수', '포함'],
#  ['교수', '회계사', '필리핀', '성매매', '황제', '관광'],
#  ['하드보일드', '감정', '좌우', '냉담', '태도', '세계', '대전', '유래'],
#  ['가구', '이상', '아파트', '내달', '의무', '설치'],
#  ['기획', '청부', '영화', '킹스', '흥행', '성공', '요소'],
#  ['기획', '청부', '영화', '킹스', '흥행', '성공', '요소'],
#  ['노인', '대상', '사기', '범죄', '극성'],
#  ['군산시', '옥서면', '지역', '설치'],
#  ['전북', '경찰', '절도', '6월', '강도', '단속'],
#  ['하드보일드', '감정', '좌우', '냉담', '태도', '한국', '영화', '대표작'],
#  ['성범죄', '교수', '교사', '교단', '영구', '퇴출'],
#  ['필리핀', '원정', '성매매', '검거'],
#  ['하드보일드', '폭력', '주제', '태도', '묘사', '특징'],
#  [],
#  ['4월', '범죄', '예방', '기준', '건축', '건축', '허가'],
#  ['미스터리', '산책', '뛰는 놈 위에 나는 놈', '컴퓨터'],
#  ['오원춘', '수원시', '고육지책'],
#  ['야후', '재팬', '개인', '성적', '화상', '병력', '범죄', '피해', '사실', '삭제', '기준', '발표'],
#  ['흉악범', '출소', '최대', '수용소', '격리'],
#  ['케이블', '위성', '하이라이트', '2015년', '3월 31일'],
#  ['4월 1일', '오늘', '하이라이트'],
#  ['멕시코', '불법', '무기', '명당', '유통'],
#  ['사기', '경기', '노점상', '회장', '기소'],
#  ['교수', '회계사', '필리핀', '원정', '성매매', '무더기', '적발'],
#  ['만우절', '장난', '전화'],
#  ['출소', '성형', '높이', '수술', '전국', '빈집', '털이'],
#  ['취업', '알선', '미끼', '20대', '신종', '사기범'],
#  ['공원', '애완견', '입건'],
#  ['필리핀', '원정', '성매매', '적발', '대학교수', '공인회계사'],
#  ['여성', '청소년', '보호', '시설', '나사', '폐쇄', '위기', '자활', '소녀', '가나'],
#  ['흉악범', '최장', '격리', '보호', '수용', '통과', '이중', '처벌', '논란'],
#  ['오바마', '취임', '처음', '아버지', '나라', '간다'],
#  ['야후', '재팬', '권리', '기준', '발표'],
#  ['황제', '노역', '판결', '판사', '논란'],
#  ['식당', '음식', '신고'],
#  ['미국', '하원', '의원', '아베', '잔혹', '행위', '인정'],
#  ['포스코건설', '비자금', '줄기', '베트남', '공사', '과정', '조성', '포착'],
#  ['김문수', '유엔', '인권', '사무소', '중국', '러시아', '등불'],
#  ['사설', '인권위', '주행'],
#  ['필리핀', '세부', '관광', '위장', '성매매', '교수', '검거'],
#  ['박상', '공감', '스토리텔링', '사람', '사람'],
#  ['양주', '소년범', '보호', '시설', '위기', '방황', '걱정'],
#  ['박범훈', '방위', '외압', '교육부', '당시', '청와대', '서도', '논란'],
#  ['훈육', '차원', '체벌', '해도', '처벌'],
#  ['이창근', '드림', '드림', '육하원칙'],
#  ['마이클 브라운', '사건', '구조', '인권', '침해'],
#  ['시대', '비지떡', '선별', '복지', '함정'],
#  ['조찬제', '선임', '기자', '월드', '프리즘', '미국', '피격', '자료', '공개'],
#  ['정부', '성매매', '원천', '봉쇄', '전국', '폐쇄'],
#  ['건설사', '회장', '사칭', '징역형'],
#  ['성남중원경찰서', '피해자', '위원회', '희망', '등대', '대식', '개최'],
#  ['법률', '플러스', '증인', '출석', '요구', '출석'],
#  ['문화', '관광', '자원'],
#  ['자전거', '구리', '생활', '도범', '검거'],
#  ['끈기', '사기범', '여경'],
#  ['경남신문', '독자', '위원회', '회의'],
#  ['장성', '파출소', '절도', '아동', '범죄', '예방', '활동'],
#  ['충북', '기협', '이달의 기자상'],
#  ['옥천', '지역', '서민', '금융'],
#  ['한국', '터보', '기계', '대표', '미국', '인도', '재고', '달라'],
#  ['통신', '사장', '언론인', '납치', '살해', '국제법', '전쟁', '범죄', '포함'],
#  ['전과', '경찰', '지구', '물건', '경찰', '신세'],
#  ['외국인', '근로자', '밀물', '공존', '해법', '모색'],
#  ['청년', '해외', '취업', '구직', '취업', '사기'],
#  ['KBS1', '시사기획 창', '외국인', '근로자', '공존', '조건'],
#  ['호기심', '학생', '마약', '사범', '급증'],
#  ['엘리트', '법대', '교수', '심야', '열차', '30대', '허벅지', '체포'],
#  ['금융', '당국', '보이스', '피싱'],
#  ['종택', '고지', '연무', '마모'],
#  ['실종', '느와르', '강하늘', '미생', '소름', '연기력', '김강우', '두뇌', '대결', '시작'],
#  ['타인', '카드', '사용', '중학생', '형사', '처벌', '대신', '즉결심판'],
#  ['충북', '경찰청', '무심천', '공원', '자전거', '순찰대', '운영'],
#  ['권시', '항소심', '재판부', '선거범죄', '과거', '판결'],
#  ['대전', '화질', 'CCTV', '개교', '지원'],
#  ['성폭행', '사건', '논산', '고장'],
#  ['휴대폰', '휴대폰', '도범', '머리', '업주'],
#  ['오늘', '대전', '세종', '충남', '충북', '중도', '일보', '3월', '월요일'],
#  ['진화', '보이스', '피싱', '검찰', '총장', '공문', '위조'],
#  ['이브닝', '이슈', '채림', '남매', '폭언', '모욕', '혐의', '피소', '모욕죄'],
#  ['통장', '범죄', '악용', '형사', '처벌'],
#  ['뉴스', '플러스', '도박', '업자', '수뢰', '경찰', '간부', '수사'],
#  ['판돈', '합작', '도박', '조직'],
#  ['아베', '연설', '위안부', '문제', '직시', '사과'],
#  ['글로벌', '시대', '영국', '신사', '케이', '아리랑', 'TV', '글로벌', '네트워크', '부장'],
#  ['조희팔', '은닉', '재산', '환수', '이례', '추징금', '구형'],
#  ['남원', '순창', '장수', '범죄', '피해자', '지원', '센터', '정기', '총회', '개최'],
#  ['남원', '공공', '기관', '민간단체', '법질서', '실천', '협약'],
#  ['진안경찰서', '보이스', '피싱', '예방', '홍보', '영상', '제작'],
#  ['황금', '대사헌', '황희', '이완구', '총리'],
#  ['위헌', '소지', '판단'],
#  ['10대', '마약', '범죄', '급증'],
#  ['청소년', '청소년', '범죄', '위험수위'],
#  ['영동', '금산', '총력', '대응', '체계', '구축', '간담회'],
#  ['옥천경찰서', '체감', '치안', '향상', '맞춤', '캠페인'],
#  ['충북', '경찰청', '무심천', '자전거', '순찰대', '운영'],
#  ['상습', '가정폭력', '행사', '검거'],
#  ['충북', '기협', '분기', '이달의 기자상', '선정'],
#  ['전국', '폐쇄', '가부', '경찰', '구성'],
#  ['세상', '만사', '나라', '전과', '경찰', '지구', '대서', '현금', '입건'],
#  ['조건', '만남', '미끼', '유인', '강도', '10대', '구속'],
#  ['유흥업소', '매매', '방위', '단속'],
#  ['이해인', '피싱', '전쟁'],
#  ['수단', '사기', '혐의', '이규태', '구속', '기소'],
#  ['의원', '과거사', '반성', '촉구', '아베', '형식', '언급'],
#  ['시론', '경제', '명령'],
#  ['달서구', '범죄', '피해자', '지원', '경찰', '상시', '네트워크', '구축'],
#  ['일대', '해외', '건설', '현장', '체험', '전문가', '특강', '특성', '사업단', '순항'],
#  ['구미경찰서', '고용', '노동부', '범죄', '피해자', '취업', '지원'],
#  ['서구청', '달서', '성서', '경찰서', '긴급', '지원', '네트워크'],
#  ['만우절', '장난', '전화'],
#  ['대포통장'],
#  ['여수경찰서', '전남', '최초', '경미', '범죄', '심사', '위원회', '개최'],
#  ['대법원', '긴급조치', '판결', '정치', '화법'],
#  ['옥천경찰서', '4대 사회악', '근절', '홍보', '활동'],
#  ['스마트폰', '카메라', '이용', '촬영', '성범죄', '연루', '전문', '변호사', '조력'],
#  ['성폭력', '근절', '대책', '현장', '실천'],
#  ['성폭력', '근절', '대책', '현장', '실천'],
#  ['장발장', '폐지', '혜택'],
#  ['장발장', '폐지', '혜택'],
#  ['국내외', '매장', '판돈', '합작', '도박', '조직', '적발'],
#  ['대마', '마약', '사범', '무더기', '검거'],
#  ['시티', '이상', '외면', '방치'],
#  ['시티', '이상', '외면', '방치'],
#  ['지역', '박선규', '영월군'],
#  ['지역', '박선규', '영월군'],
#  ['귀금속', '절취', '이삿짐', '센터', '직원', '구속'],
#  ['기고'],
#  ['기고', '대출', '전화'],
#  ['범죄', '피해', '외국인', '보호', '협약'],
#  ['최면', '진정제', '졸피뎀', '남용', '이철우', '의원', '범죄', '악용', '경고'],
#  ['고부', '확신범'],
#  ['편의점', '바닥', '비상', '벨로', '신고', '분만', '강도'],
#  ['오원춘', '박춘풍', '수원시', '범죄', '예방', '가로등', '전면', '교체'],
#  ['은행', '구글 검색', '부부', '체포'],
#  ['경찰', '지구', '금품', '덜미'],
#  ['리콴유', '일본', '관계', '공포', '대상', '벤치마킹', '훈수'],
#  ['강원도', '강간', '군인', '성폭행', '통제', '불능', '상태'],
#  ['조희팔', '은닉', '재산', '환수', '측근', '추징금', '구형'],
#  ['장기', '복역', '도둑들', '철창'],
#  ['사설', '아베', '총리', '인신매매', '위안부', '문제', '물타기'],
#  ['중국', '말단', '경찰', '간부', '현금'],
#  ['도봉산',
#   '기슭',
#   '판도라',
#   '컨테이너',
#   '방산',
#   '비리',
#   '이규태',
#   '회장',
#   '비밀',
#   '자료',
#   '무더기',
#   '발견'],
#  ['검찰', '동국제강', '해외', '송금', '추적', '비자금', '조성', '증거', '확보'],
#  ['와우', '공식', '소설', '한정판', '골드', '에디션'],
#  ['한경', '에세이', '안함', '주기'],
#  ['신고', '후 현', '뺑소니'],
#  ['시사', '하계열', '부산진', '구청장'],
#  ['시민', '체감', '생활', '범죄'],
#  ['진화', '비행', '청소년', '대만', '경보'],
#  ['주차', '차량', '창문', '금품', '구속'],
#  ['검사', '연기', '여성', '보이스', '피싱'],
#  ['진화', '전문가', '지적', '벽화', '일색', '부산', '이제', '마을', '맞춤'],
#  ['베트남', '신부', '결혼', '실패', '결혼', '중개업', '방화', '살인'],
#  ['단속', '기관', '멸치', '포획', '금지'],
#  ['현직', '경찰', '간부', '뇌물', '수수', '혐의', '수사', '시작', '휴가', '잠적'],
#  ['영동경찰서', '금산경찰서', '지휘관', '간담회', '개최'],
#  ['사설', '솜방망이', '처벌', '보험', '사기', '공화국'],
#  ['전국', '창초', '폐쇄', '돌입'],
#  ['동국제강', '정상', '해외', '송금', '추적', '실무자', '소환'],
#  ['중국', '하급', '경찰', '간부', '현금', '게임', '업자', '뇌물'],
#  ['상인', '지원금', '전통', '시장', '회장', '입건'],
#  ['성형', '수술', '가발', '변장', '아파트', '전문', '이범', '덜미'],
#  ['단독', '베스트', '평가', '보고서', '입수', '곳곳', '왜곡', '과장'],
#  ['금고', '통째'],
#  ['충북', '지방', '경찰청', '10월', '무심천', '자전거', '순찰대', '운영'],
#  ['마을', '방송', '매체', '자리매김'],
#  ['예방', '제도', '방안', '사회', '관심', '협력', '필요'],
#  ['소년', '재판', '결론', '아이들', '아버지', '필요'],
#  ['이해인', '피해', '금감원', '전쟁', '선포'],
#  ['이발', '갱생', '사형수', '이발사'],
#  ['관제탑', '청소년', '선도'],
#  ['보험사', '기와', '대책'],
#  ['인터뷰', '경기도', '선관위', '상임', '위원'],
#  ['보육', '교사', '가짜', '위탁', '교육', '국가', '보조금'],
#  ['이해인', '사건', '도마', '금감원', '보이스', '피싱', '근절'],
#  ['장기', '복역', '도둑들', '철창'],
#  ['욕설', '협박', '나이롱', '귀신', '추적'],
#  ['월드 오브 워크래프트', '소설', '한정판', '골드', '에디션', '출시'],
#  ['실종느와르 M', '강하늘', '김강우', '박희순', '연기', '경쟁'],
#  ['울산대', '스마트', '벤처', '학교', '창업', '기지'],
#  ['독재', '결별', '스리랑카', '계획', '성공'],
#  ['대법', '위헌', '소지', '판단', '재판'],
#  ['보험', '상품', '배당', '롯데', '여성', '보험', '여성', '고객', '특화', '유장', '만원'],
#  ['창원', '집값', '오름세', '가격', '경쟁력', '창원', '힐스테이트', '분양'],
#  ['명문대', '출신', '법학', '교수', '열차', '성추행', '덜미'],
#  ['갈취', '15년', '해외', '도피', '실형', '선고'],
#  ['한국', '첨단', '안전', '산업', '협회', '창립총회'],
#  ['디지털', '산책', '주민등록번호', '제도'],
#  ['삼부', '퓨전', '장르', '차별'],
#  ['마곡', '지구', '대형', '건설사', '오피스텔', '가격', '마곡', '아이파크', '분양', '마감', '코앞'],
#  ['10대', '학생', '젊은층', '마약', '범죄', '급증', '인터넷', '유통', '증가', '원인'],
#  ['금감원', '이해인'],
#  ['보험', '상품', 'NH농협손해보험', '재해', '범죄', '사고', '질병', '걱정'],
#  ['경찰서', '지구', '대서', '금품'],
#  ['논산', '대형', '마트', '화장실', '중생', '성폭행'],
#  ['세상보기', '근대', '제국주의', '극복', '리더십', '시대', '종언'],
#  ['처벌', '대신', '즉결심판', '전과자', '전락', '예방'],
#  ['이해득실', '맞선', '사행', '산업', '전자', '카드'],
#  ['가부', '성매매', '집결지', '폐쇄', '추진', '현황', '공유', '집결지', '폐쇄', '박차'],
#  ['이조', '변호사', '작품', '법률', '산책', '스물', '강요죄'],
#  ['행위', '4월', '국회', '총기', '단속', '누리', '과정', '지방채', '논의'],
#  ['뇌물', '혐의', '경찰', '간부', '수사', '시작', '잠적'],
#  ['김희정', '장관', '불법', '성매매', '업소', '범죄', '수익', '몰수', '추징'],
#  ['대법', '지적', '장애', '10대', '관계', '촬영', '20대', '실형', '확정'],
#  ['젊은층', '마약', '접촉', '경찰', '온라인', '공급', '집중', '단속'],
#  ['유사', '수신', '사기범', '조희팔', '은닉', '재산', '환수'],
#  ['경찰서', '가방'],
#  ['뿌리', '가부', '폐쇄', '추진'],
#  ['창초', '뿌리', '가부', '폐쇄', '추진'],
#  ['이해인', '사건', '금감원', '보이스', '피싱', '근절'],
#  ['얼굴', '도범'],
#  ['얼굴', '도범'],
#  ['독자', '칼럼', '사이버', '데이', '제안'],
#  ['대법', '청소년', '관계', '촬영', '원칙', '위반'],
#  ['북한', '강원도', '간도', '수위', '보니'],
#  ['스마트', '시티'],
#  ['스마트', '시티'],
#  ['포토', '윤진서', '드라마', '범죄', '프로파일러'],
#  ['진화', '이제', '청소년', '선도'],
#  ['동대문구', '친절', '운동', '한방', '타운', '복지', '전략', '과제', '선정'],
#  ['전국', '성매매', '집결지', '폐쇄', '추진'],
#  ['완전범죄', '30대', '수술'],
#  ['명문대', '출신', '법학', '교수', '열차', '성추행', '현행범', '체포'],
#  ['진화', '거짓말', '탐지기', '이제'],
#  ['예능', '전망대', '파일럿', '예능', '정규', '판도', '급변'],
#  ['스릴러', '재탄생', '제인 오스틴', '고전'],
#  ['잠복', '교통카드', '범인', '보니', '환경', '화원'],
#  ['명문대', '출신', '법학', '교수', '열차', '성추행'],
#  ['위험', '노인', '각종', '범죄', '표적'],
#  ['완주', '가정폭력', '예방', '모의', '훈련'],
#  ['덕진', '지구', '맞춤', '범죄', '예방', '지역민', '소통'],
#  ['익산', '오산', '파출소', '점심', '문안', '순찰', '호응'],
#  ['홍기', '칼럼', '분노', '조절', '장애', '심리학'],
#  ['환경', '규제', '세제', '혜택', '하이브리드'],
#  ['공직자', '문건', '스캔들', '메일', '다음', '텍스트', '게이트'],
#  ['공직자', '문건', '스캔들', '메일', '다음', '텍스트', '게이트'],
#  ['신병주', '세종', '시련', '불행', '가족사', '주머니'],
#  ['염태영', '수원시', '햇빛', '정책'],
#  ['오원춘', '수원시', '고육지책'],
#  ['아베', '위안부', '인신매매', '괴롭힘', '정부', '책임', '회피', '꼼수', '눈총'],
#  ['출소', '성형', '높이', '수술', '전국', '빈집', '털이'],
#  ['케이블', '위성', '하이라이트', '2015년', '3월 31일'],
#  ['탕웨이', '이해인', '보이스', '피싱', '금감원', '금융', '사기', '전쟁', '선포'],
#  ['여성', '청소년', '보호', '시설', '나사', '폐쇄', '위기', '자활', '소녀', '가나'],
#  ['모두', '저먼윙스', '기장', '문제', '발견'],
#  ['모두', '저먼윙스', '기장', '문제', '발견', '정신', '질환자', '차별', '우려', '증폭'],
#  ['도봉산', '인근', '컨테이너', '방산', '비리', '자료'],
#  ['모두', '저먼윙스', '기장', '문제', '발견'],
#  ['박종철', '박종우', '박상옥'],
#  ['양주', '소년범', '보호', '시설', '위기', '방황', '걱정'],
#  ['아침', '돼지'],
#  ['기고', '사행', '산업', '감독', '브러더'],
#  ['동국제강', '압수수색', '장세주', '회장', '출국', '금지'],
#  ['이대로', '기밀', '불량', '부품', '패망', '직전', '남군'],
#  ['기밀', '불량', '부품', '패망', '직전', '남군'],
#  ['이해인', '금감원', '금융', '사기', '전쟁', '선포'],
#  ['경찰', '지구', '금품', '덜미'],
#  ['이해인', '금감원', '연예인', '일제', '공문'],
#  ['119', '사고', '신고', '후 현', '뺑소니'],
#  ['사이버', '명예', '경찰', '회원', '모집'],
#  ['버스', '정류장', '살인범', '항소심', '징역'],
#  ['관계', '장면', '여성', '신체', '남성', '벌금형'],
#  ['중부',
#   '경찰관',
#   '성신',
#   '1박 2일',
#   '교생',
#   '체험',
#   '스쿨',
#   '폴리스',
#   '학교',
#   '폭력',
#   '예방',
#   '부모',
#   '걱정'],
#  ['여아', '성추행', '경비원', '징역', '6월', '감형'],
#  ['평택', '안성', '범죄', '피해자', '지원', '센터', '기금', '마련', '감자', '심기', '행사', '구슬땀'],
#  ['구리경찰서', '전국', '최초', '치안', '서비스'],
#  ['여아', '성추행', '아파트', '경비원', '항소심', '감형'],
#  ['어린이집', '원장', '평생', '교육원', '국고', '보조금'],
#  ['보안', '만능', '솔루션', '수정'],
#  ['신간', '도서', '누가', '범인'],
#  ['권선택', '항소심', '재판부', '확정'],
#  ['음성서', '도범', '구속'],
#  ['무심천', '자전거', '순찰대', '운영'],
#  ['원룸', '밀집', '지역', '안전', '택배', '설치'],
#  ['대전시', '교육청', '시간', '학교', '안전', '강화'],
#  ['안동', '순경', '보이스', '피싱', '피해', '만원'],
#  ['신고', '현장', '이탈', '법원', '뺑소니'],
#  ['교복', '경찰', '기숙사', '삼시세끼'],
#  ['퇴직', '공직자', '산업체'],
#  ['살해', '가출', '여중', '성매매', '알선', '혐의', '인조', '구속영장', '발부'],
#  ['관계', '여성', '신체', '촬영', '남성', '벌금'],
#  ['내연', '흉기', '위협', '실형'],
#  ['피해자', '보호', '전담', '경찰관', '아침', '단상'],
#  ['경찰', '자전거', '스마트폰', '절도', '생활', '범죄', '여건', '단속'],
#  ['절도', '최다', '생활', '범죄', '해결'],
#  ['거점', '인터넷', '도박', '적발'],
#  ['매장', '합작', '도박', '조직'],
#  ['통장', '만원', '대포통장', '모집', '센터', '조직', '검거'],
#  ['기고', '법질서', '선의', '미학'],
#  ['실종느와르 M',
#   '엘리트',
#   '형사',
#   '김강우',
#   '사이코패스',
#   '강하늘',
#   '긴장감',
#   '두뇌',
#   '대결',
#   '게임',
#   '스타트'],
#  ['수단', '방위', '사업', '비리', '은폐', '가담', '일광', '공영', '직원', '구속'],
#  ['선불', '불법', '유통', '이통', '제재', '착수'],
#  ['여아', '성추행', '경비원', '항소심', '감형', '솜방망이', '처벌'],
#  ['이거', '항암', '버섯', '난치병', '환자', '사기'],
#  ['방통', '선불', '불법', '유통', '관련', '이통', '제재'],
#  ['실종', '느와르', '강하늘', '촬영', '감량', '소름', '연기력', '네티즌', '극찬', '세례'],
#  ['실종', '느와르', '강하늘', '미생', '역대', '사이코패스', '연기', '소름'],
#  ['이번', '동국제강', '수사', '방위', '확대'],
#  ['실종', '느와르', '강하늘', '천재', '형사', '김강우', '두뇌', '대결', '게임', '준비', '긴장감', '최고'],
#  ['이슈', '분석', '방위', '확산', '부정부패', '척결', '수정'],
#  ['이슈', '분석', '고발', '요청', '발동', '산업', '파장', '수정'],
#  ['살해', '가출', '여중', '성매매', '알선', '인조', '영장', '발부'],
#  ['조세', '회피', '페이퍼', '컴퍼니', '실소', '유주', '등기', '압박'],
#  ['민간', '경비', '업체', '치안', '사각지대', '해소'],
#  ['일광', '공영', '방산', '자료', '발견'],
#  ['생활', '범죄', '수사', '검거'],
#  ['도박', '조직', '적발'],
#  ['오늘', '뉴스'],
#  ['통장', '가성', '처벌'],
#  ['실종', '느와르', '강하늘', '사이코패스', '연기', '사람'],
#  ['실종', '느와르', '강하늘', '일주일', '감량', '사이코패스', '미소'],
#  ['실종', '느와르', '강하늘', '사이코패스', '연기', '체중', '감량', '영향'],
#  ['실종', '느와르', '강하늘', '미소', '두뇌', '게임', '대박'],
#  ['뇌물', '수수', '혐의', '현직', '경찰', '간부', '휴가', '잠적'],
#  ['데스크', '칼럼', '기업', '수사', '칼날', '비틀'],
#  ['농협', '대포통장', '전쟁', '1년', '감소'],
#  ['충북', '경찰청', '무심천', '자전거', '순찰대', '운영'],
#  ['장사', '임원', '규제', '강화', '법안', '반대'],
#  ['교복', '경찰', '기숙사', '삼시세끼'],
#  ['민간', '경비', '업체', '치안', '사각지대', '해소'],
#  ['귀금속', '절취', '이삿짐', '센터', '직원', '구속'],
#  ['할머니', '영정', '사진', '여대', '카메라', '실종', '사건'],
#  ['중앙', '지법', '형사', '법관', '법정', '언행', '의견', '모아'],
#  ['욕정', '경비원', '지하', '계단', '성추행', '법원', '감형'],
#  ['항암', '버섯', '난치병', '환자'],
#  ['일광', '공영', '금고', '지기', '판도라', '컨테이너'],
#  ['포토', '뉴스', '범죄', '피해자', '교통편', '제공', '협약'],
#  ['관리', '범죄', '방비', '사람', '졸피뎀', '수면', '유도제'],
#  ['생활', '범죄', '대상', '자동차'],
#  ['포럼', '벌금형', '사회', '약자', '배려'],
#  ['보험', '사기', '공화국', '특별법', '처벌', '수위', '보험금', '사냥'],
#  ['보험',
#   '사기',
#   '공화국',
#   '특별법',
#   '특별법',
#   '발의',
#   '박대동',
#   '의원',
#   '보험',
#   '사기',
#   '사회',
#   '신뢰',
#   '기반',
#   '있다'],
#  ['지자체', '지역', '전지수', '5월', '공표'],
#  ['간통', '위헌', '결정', '이후', '풍속'],
#  ['신고', '현장', '이탈', '법원', '뺑소니'],
#  ['관계', '여성', '신체', '촬영', '남성', '벌금'],
#  ['내연', '흉기', '위협', '실형'],
#  ['인터넷', '도박장', '도박', '조직', '적발'],
#  ['방산', '비리', '증거', '인멸', '일광', '공영', '직원', '구속'],
#  ['세무조사', '편의', '현직', '세무', '공무원', '뒷돈'],
#  ['일광', '공영', '사업', '자료', '도봉산', '발견', '직원', '구속'],
#  ['공군', '장비', '비리', '일광', '공영', '은닉', '자료', '도봉산', '컨테이너', '발견'],
#  ['중국', '매장', '판돈', '합작', '도박', '조직'],
#  ['날줄', '씨줄', '적반하장'],
#  ['피싱', '사기'],
#  ['방산', '비리', '자료', '증거', '인멸', '일광', '공영', '직원', '구속'],
#  ['모텔', '피살', '10대', '성매매', '알선', '20대', '구속'],
#  ['생각', '부진', '선수', '비판'],
#  ['장성택', '처형', '국제인권법', '위반'],
#  ['일광', '공영', '방위', '사업', '자료', '컨테이너', '무더기', '발견'],
#  ['중국', '센터', '대포통장', '모집', '일당', '구속'],
#  ['중국', '공조', '도박장', '운영', '한국인', '총책', '검거'],
#  ['이규태', '비리', '증거', '인멸', '일광', '공영', '직원', '구속'],
#  ['봄철', '주의보', '지하철', '자동차', '주목', '이유'],
#  ['장기', '이식', '환자', '20대', '구속'],
#  ['경찰', '생활', '범죄', '수사', '사건', '해결'],
#  ['사이버', '범죄', '스미싱', '파밍'],
#  ['동국제강', '장세주', '회장', '25년', '해외', '도박', '혐의', '자금', '흐름', '추적'],
#  ['대법', '위조', '달러', '처벌', '제동', '조항', '위헌', '우려'],
#  ['중국', '도박장', '운영', '국내', '도박', '조직', '검거', '판돈'],
#  ['도박', '국제', '도박판', '일당', '재판'],
#  ['고법', '여아', '성추행', '경비원', '징역', '2년', '6월', '실형'],
#  ['외환', '위기', '생계', '좀도둑', '기승'],
#  ['외환', '위기', '생계', '좀도둑', '기승'],
#  ['판돈', '도박', '검거'],
#  ['도박', '조직', '적발'],
#  ['동국제강', '다음', '재계', '사정', '확산', '촉각'],
#  ['동국제강', '다음', '재계', '사정', '확산', '촉각'],
#  ['통장', '주일', '만원'],
#  ['자전거', '휴대폰', '커피믹스', '생계', '좀도둑', '기승'],
#  ['판돈', '도박', '국제', '도박', '조직', '적발'],
#  ['리뷰', '코블러', '일상', '미생', '판타지'],
#  ['인터뷰', '실장', '김상경', '살인의뢰'],
#  ['방송', '화제', '실종느와르 M', '포인트', '리얼'],
#  ['실종', '느와르', '강하늘', '변신'],
#  ['실종', '느와르', '두뇌', '싸움', '향연', '진짜가 나타났다'],
#  ['도박', '머니', '게임'],
#  ['방송', '화제', '실종느와르 M', '리얼'],
#  ['여아', '성추행', '경비원', '항소심', '징역', '2년', '6월', '감형'],
#  ['대법원', '위헌', '소지', '적용', '판결', '파기', '환송'],
#  ['도박', '업자', '뇌물', '혐의', '경찰', '간부', '수사'],
#  ['도봉산', '인근', '컨테이너', '방산', '비리', '자료'],
#  ['모두', '저먼윙스', '기장', '문제', '발견', '정신', '질환자', '차별', '우려', '증폭'],
#  ['여자', '어린이', '성추행', '경비원', '항소심', '징역', '2년', '6월', '감형'],
#  ['편집국', '박종철', '박종우', '박상옥', '권태호'],
#  ['아침', '돼지'],
#  ['동국제강', '압수수색', '장세주', '회장', '출국', '금지'],
#  ['기고', '사행', '산업', '감독', '브러더'],
#  ['이대로', '기밀', '불량', '부품', '패망', '직전', '남군'],
#  ['방송', '핫이슈', '실종느와르 M', '리얼'],
#  ['북한', '탈북자', '고향'],
#  ['아베', '위안부', '인신매매', '희생자', '책임', '회피', '꼼수'],
#  ['관계', '여성', '신체', '촬영', '집행유예', '벌금'],
#  ['범죄', '단속', '주민', '모두', '참여'],
#  ['성범죄', '공무원', '벌금형', '퇴출'],
#  ['주말', '하이라이트'],
#  ['독자', '소리', '강제', '전학', '근절', '대책', '주원', '군산경찰서', '여성', '청소년', '계장', '경감'],
#  ['뉴스', '분석', '아베', '위안부', '인신매매', '가슴'],
#  ['아베', '멍석', '경제', '실리', '밀월'],
#  ['20대', '기사', '운전', '교습', '여관'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴출'],
#  ['간통', '위헌', '결정', '도내', '무죄', '선고'],
#  ['도내', '동시', '검문검색'],
#  ['국내외', '공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['상습', '도범', '장발장', '위헌', '결정', '구제'],
#  ['성추행', '성폭행', '범죄자', '퇴출', '성희롱', '진급', '금지'],
#  ['밀반입', '대마', '재배', '흡입', '우즈', '불법체류', '구속'],
#  ['맞춤', '보이스', '피싱'],
#  ['사회', '진통', '부부', '가족', '실패'],
#  ['2015년', '주목', '신기술', '사물', '인터넷'],
#  ['법원', '사고', '신고', '후 현', '이탈', '뺑소니'],
#  ['터키', '게양', '국기', '제거', '청년', '개월'],
#  ['헌재', '간통', '위헌', '결정', '강원', '재심', '무죄', '선고'],
#  ['장성택', '처형', '국제법', '위반', '유엔', '답변', '요구'],
#  ['간첩', '혐의', '국민', '자체', '처벌', '10년', '이상', '노동', '교화', '예상'],
#  ['김정은', '비자금', '관리', '정찰', '총국', '공작원', '프랑스', '추방', '강력', '비판'],
#  ['보육', '교사', '훈련', '기록', '조작', '국가', '보조금', '평생', '교육원'],
#  ['성폭력', '군인', '공무원', '스트라이크', '아웃', '정부', '성폭력', '근절', '대책', '발표'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴출'],
#  ['무장', '경찰', '시민'],
#  ['경찰', '리포트', '관수', '남대문', '경찰서장', '서울역', '노숙', '재활', '집회', '마찰', '최소'],
#  ['경찰', '리포트', '나이지리아', '메일', '중기'],
#  ['복지', '권리', '주머니', '강요', '자선'],
#  ['공무원', '군인', '성범죄', '중징계', '벌금형', '퇴직', '추진'],
#  ['사건', '사고', '음성경찰서', '상습', '가정폭력', '행사', '검거'],
#  ['간통', '위헌', '결정', '이후', '강원도', '재심', '재판', '무죄', '판결'],
#  ['유엔', '북한', '장성택', '처형', '국제법', '위반'],
#  ['법원', '신고', '후 현', '뺑소니'],
#  ['장성택', '처형', '국제법', '위반', '유엔', '인권', '이사회', '규정'],
#  ['유엔', '장성택', '처형', '국제법', '위반'],
#  ['부모', '안녕하십니까', '어르신', '금융', '사기', '활개'],
#  ['교통사고', '가해자', '신고', '후 현', '이탈', '뺑소니', '아냐'],
#  ['혐오', '레즈비언', '살인', '경감', '사유'],
#  ['동작구', '주민', '참여', '범죄', '마을'],
#  ['간통', '위헌', '결정', '강원', '재심', '무죄', '선고'],
#  ['유엔', '북한', '장성택', '처형', '국제법', '위반'],
#  ['공무원', '군인', '성폭력', '지위'],
#  ['권력', '성폭력', '공무원', '군인', '벌금형', '퇴출'],
#  ['공무원', '군인', '성범죄', '벌금형', '영구', '퇴출'],
#  ['관계', '모습', '여성', '치마', '촬영', '재판'],
#  ['은둔', '외톨이', '묻지마 범죄', '공통점'],
#  ['유엔', '북한', '장성택', '처형', '국제법', '위반'],
#  ['아베', '위안부', '인신매매', '희생자', '가해자', '언급', '생략'],
#  ['측근', '고위급', '겨냥', '정권', '수사'],
#  ['베트남', '신부', '결혼', '정보', '업체'],
#  ['간통', '위헌', '결정', '강원', '재심', '무죄', '선고'],
#  ['공무원', '군인', '성폭력', '범죄', '퇴직', '교사', '교단', '퇴출'],
#  ['사설', '아베', '의회', '연설', '우경화', '망동', '사과'],
#  ['공무원', '군인', '성폭력', '범죄', '벌금형', '선고', '퇴직', '교사', '퇴출'],
#  ['독자', '투고', '신종', '신용카드', '위조', '대책'],
#  ['프리즘', '조영택', '요양보호사', '처우', '개선'],
#  ['독자', '투고', '산림', '절도', '범죄'],
#  ['검찰', '담양', '화재', '피해자', '생계비', '지원'],
#  ['슈퍼', '리치', '제임스 패터슨', '댄 브라운', '인세', '갑부'],
#  ['순창', '파출소', '농축산물', '도난', '예방', '일제', '점검'],
#  ['진안', '경찰', '보이스', '피싱', '대처', '적극', '홍보'],
#  ['주차', '문제', '야구', '방망이', '위협', '징역형'],
#  ['김제경찰서', '부정부패', '척결', '구성'],
#  ['검찰', '보훈', '급여', '부정', '수급', '기소'],
#  ['포토', '중랑구', '범죄', '피해자', '보호', '지원', '업무', '협약', '체결'],
#  ['울산', '부서', '신고', '스쿨', '폴리스', '학교'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴출'],
#  ['우월', '지위', '이용', '성범죄', '이상', '관용'],
#  ['공무원', '군인', '성폭력', '근절', '대책', '실시', '벌금형', '고시', '퇴직'],
#  ['사설', '권력', '성범죄', '관용'],
#  ['보육', '교사', '출석부', '조작', '국가', '보조금'],
#  ['고생', '영업', '중인', '대형', '마트', '화장실', '중생', '성폭행'],
#  ['아동', '등장', '음란물', '대학교', '외국인', '영어', '강사'],
#  ['성폭력', '공무원', '군인', '벌금형', '퇴출'],
#  ['투자', '사기', '황장엽', '수양딸', '징역'],
#  ['귀걸이', '30대', '징역', '2년', '6월'],
#  ['김태촌', '양아들', '기업', '사냥', '변신', '전횡', '덜미'],
#  ['투자', '사기', '황장엽', '수양딸', '징역', '확정'],
#  ['방산', '비리', '일광', '공영', '직원', '영장'],
#  ['음주', '단속', '경찰관', '군무원', '구속'],
#  ['뉴스', '브리핑', '프로', '야구', '개막전', '암표', '거래', '집중', '단속'],
#  ['성범죄', '가해자', '퇴출', '진급', '금지', '제대', '군인', '복지', '박탈'],
#  ['인천지검', '세무조사', '편의', '수뢰', '국세청', '공무원', '기소'],
#  ['슈퍼', '리치', '살인', '사기', '횡령', '법정', '갑부', '추락', '순간'],
#  ['집중', '취재', '모바일', '금융', '혁신', '핀테크'],
#  ['경찰', '북한산', '송이', '버섯', '밀수', '혐의', '조총련', '의장', '압수수색'],
#  ['만원', '흉터', '보험금', '차별'],
#  ['쇼핑몰', '중생', '성폭행', '매장', '고장', '관리', '소홀'],
#  ['현장', '행정', '돈의동', '방촌', '행복', '희망'],
#  ['격동', '70년', '위안부', '문제 해결', '관건', '정상회담', '연대', '극복'],
#  ['군인', '공무원', '성범죄', '대응', '벌금형', '퇴출'],
#  ['남한', '간첩', '체포', '정부', '간첩', '송환'],
#  ['성범죄', '공직자', '벌금형', '퇴출'],
#  ['군대', '대학', '성폭력', '범죄자', '벌금형', '퇴출'],
#  ['아베', '총리', '4월 29일', '사상', '하원', '합동', '연설'],
#  ['추적', '자전거 도둑', '경찰'],
#  ['강동성심병원', '강동', '경찰서', '업무', '협약', '체결'],
#  ['포토', '뉴스', '해피', '메신저', '정기', '간담회'],
#  ['괴물', '구원'],
#  ['충주', '노인', '대상', '전화', '금융', '사기', '발생', '피해', '예방', '활동'],
#  ['음성', '경찰', '동료', '지갑', '휴대폰', '절취', '피의자', '구속'],
#  ['상습', '가정폭력', '행사', '검거'],
#  ['제천경찰서', '세명대학교', '캠퍼스', '지킴이', '대식'],
#  ['북한', '남한', '간첩', '체포', '극악', '테러', '분자'],
#  ['공무원', '벌금형', '퇴직', '권력', '범죄', '뿌리'],
#  ['공무원', '벌금형', '퇴직', '권력', '범죄', '뿌리'],
#  ['대대적', '단속', '매매', '여성', '자립', '지원'],
#  ['대대적', '단속', '매매', '여성', '자립', '지원'],
#  ['교수', '공무원', '범죄', '스트라이크', '아웃'],
#  ['교수', '공무원', '범죄', '스트라이크', '아웃'],
#  ['투자', '사기', '혐의', '황장엽', '수양딸', '징역', '확정'],
#  ['보조금', '어린이집', '원장', '무더기', '적발'],
#  ['담양', '화재', '유족', '광주지검'],
#  ['속초', '범죄', '피해자', '지원', '센터', '간담회'],
#  ['사진', '뉴스', '해피', '메신저', '정기', '간담회'],
#  ['시간', '지배', '경찰', '범죄', '제압'],
#  ['투고', '통장', '수갑'],
#  ['투고', '통장', '수갑'],
#  ['최보경', '교사', '산청', '간디', '학교', '국보', '위반', '굴레'],
#  ['산청', '간디', '학교', '최보경', '교사', '국보', '굴레'],
#  ['최보경', '교사', '국가보안법', '굴레'],
#  ['열린', '마당', '린치', '맞춤', '순찰', '안전', '제주'],
#  ['공무원', '성범죄', '벌금형', '퇴직', '추진'],
#  ['동정', '시택', '예천경찰서'],
#  ['친절', '기자', '실연', '여성', '자살', '과정', '중계', '생명', '불감증', '확산'],
#  ['국정원', '매수', '정보', '제공', '남한', '간첩', '체포', '주장'],
#  ['아동', '음란', '동영상', '유포', '외국인', '영어', '강사', '입건'],
#  ['투자', '사기', '황장엽', '수양딸', '징역', '확정'],
#  ['대형', '마트', '화장실', '고교', '중생', '성폭행'],
#  ['황장엽', '수양딸', '징역'],
#  ['정부', '우월', '지위', '이용한', '성범죄', '처벌', '강화'],
#  ['성폭행', '군인', '아웃', '퇴출', '성희롱', '가해자', '진급', '금지'],
#  ['예멘', '규모', '공습', '지상전', '임박'],
#  ['표현의 자유', '한국', '사법', '파쇼', '토론회'],
#  ['단독', '세월호', '디지털', '사람'],
#  ['유리창', '가지', '이야기'],
#  ['공무원', '군인', '성폭력', '범죄', '퇴출', '교원', '적용'],
#  ['구청', '브리프', '서울', '동작구', '주민', '참여', '범죄', '청정', '마을'],
#  ['북한', '남한', '간첩', '체포', '발표', '극악', '테러', '분자', '주장'],
#  ['기자', '코너', '사람'],
#  ['아동', '청소년', '음란물', '유포', '부산', '사립대', '영어', '강사', '검거'],
#  ['공무원', '군인', '성범죄', '벌금형', '고시', '퇴직', '추진'],
#  ['성폭력', '군인', '공무원', '벌금형', '퇴직'],
#  ['북한', '남한', '간첩', '체포', '국정원', '매수'],
#  ['안중근', '10월 26일', '총성'],
#  ['성추행', '성폭행', '범죄자', '퇴출', '성희롱', '진급', '금지'],
#  ['소말리아', '해적', '피랍', '위험', '선박', '한국', '태국'],
#  ['섹시', '레이디 가가', '노출', '중동'],
#  ['유병언', '벽장', '이규태', '회장', '비밀'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['울산', '부서', '신고', '스쿨', '폴리스', '학교'],
#  ['아동', '음란', '동영상', '유포', '외국인', '강사', '입건'],
#  ['북한', '남한', '간첩', '체포', '극악', '테러', '분자'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직'],
#  ['창원', '아파트', '매매', '창원', '시내', '전세', '가로', '마련', '아파트'],
#  ['공정위', '대기업', '불공', '행위', '감시', '강화'],
#  ['남한', '몰이', '북한', '간첩', '몰이'],
#  ['성폭력', '공직자', '벌금형', '퇴출'],
#  ['북한', '남한', '간첩', '체포', '보위부', '주장', '국정원', '간첩', '기자회견'],
#  ['해수', '소말리아', '해적', '피랍', '위험', '선박', '한국', '태국'],
#  ['11번가', '아이디어', '기획전', '최대', '할인', '보너스', '할인', '쿠폰', '발급'],
#  ['성추행', '성폭행', '가해자', '퇴출', '성희롱', '가해자', '진급', '금지'],
#  ['2015년 3월', '27', '일자', '전국', '신문', '사설'],
#  ['마약', '중계', '밀수', '신종', '마약', '밀수', '차단', '강화'],
#  ['자본', '기업', '사냥', '김태촌', '양아들', '구속'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['마약', '혐의', '김성민', '구속', '기소', '재판', '미정'],
#  ['북한', '남한', '간첩', '체포', '진술서', '시인'],
#  ['성범죄', '공무원', '군인', '벌금형', '퇴출'],
#  ['검찰', '좌석', '승급', '특혜', '국토부', '공무원', '가성', '여부', '수사', '착수'],
#  ['군인', '공무원', '성폭력', '벌금형', '퇴출'],
#  ['공무원', '군인', '성폭력', '범죄', '퇴출'],
#  ['군인', '공무원', '지위', '악용', '성폭력', '벌금형', '퇴출'],
#  ['갑지', '성폭행', '군인', '공무원', '벌금형', '퇴출'],
#  ['군인', '공무원', '성폭력', '벌금형', '퇴출'],
#  ['남한', '간첩', '체포', '정부', '주장', '송환'],
#  ['사람',
#   '안성',
#   'NH농협은행',
#   '전화',
#   '사기',
#   '예방',
#   '환급',
#   '팀장',
#   '창구',
#   '직원',
#   '반복',
#   '교육',
#   '대포통장',
#   '근절'],
#  ['성폭력', '벌금형', '군인', '공무원', '스트라이크', '아웃'],
#  ['대형', '마트', '화장실', '중생', '성폭행', '친구사이', '고교'],
#  ['대법', '황장엽', '수양딸', '투자', '사기', '징역'],
#  ['성폭행', '퇴출'],
#  ['성범죄', '공무원', '군인', '벌금형', '퇴직'],
#  ['시장', '사무소', '관계자', '항소심', '사부로', '배정'],
#  ['수렵', '유배', '얘기'],
#  ['베트남', '신부', '결혼', '정보', '업체'],
#  ['남한', '간첩', '체포', '송환'],
#  ['청소', '업체', '위탁', '횡령', '천안시', '책임', '대두'],
#  ['범죄', '피해자'],
#  ['홍성', '경찰', '이동', '경찰서', '운영'],
#  ['스포츠', '토토', '잘못', '명칭', '불법', '스포츠', '도박', '조심'],
#  ['기고', '주민등록증', '간직'],
#  ['성폭력', '군인', '공무원', '퇴출'],
#  ['북한', '남한', '간첩', '체포', '극악', '테러', '분자'],
#  ['사물', '인터넷', '활용', '스마트', '무인', '경비', '솔루션', '이지', '워치'],
#  ['법원', '보유', '주식', '의결권', '제한'],
#  ['만삭', '소녀', '납치', '성추행', '10대', '구속'],
#  ['세탁기', '파손', '분쟁', '조성진', '사장', '재판', '내달', '연기'],
#  ['이규태', '비리', '증거', '인멸', '일광', '공영', '직원', '영장'],
#  ['군인', '공무원', '성범죄', '벌금형', '공직', '영구', '퇴출'],
#  ['한국', '간첩', '체포', '주장', 'CNN', '국정원', '사실', '부인'],
#  ['황장엽', '수양딸', '투자', '사기', '혐의', '징역', '확정'],
#  ['음주', '단속', '경찰', '차로', '군무원', '구속'],
#  ['성추행', '성폭행', '범죄자', '퇴출', '성범죄', '묵인', '방관', '처벌'],
#  ['공무원', '군인', '성폭력', '벌금형', '선고', '퇴출'],
#  ['공무원', '군인', '성폭력', '범죄', '절차'],
#  ['성폭행', '공무원', '군인', '절차'],
#  ['세무조사', '편의', '수뢰', '국세청', '공무원', '기소'],
#  ['어린이집', '보조금', '적발'],
#  ['군인', '공무원', '범죄', '벌금형', '퇴출'],
#  ['박범훈', '수석', '압수수색', '겨냥'],
#  ['박범훈', '수석', '압수수색', '겨냥'],
#  ['박범훈', '수석', '압수수색', '겨냥'],
#  ['힐스테이트', '기흥', '규모', '복합', '커뮤니티'],
#  ['소말리아', '해적', '피랍', '위험', '선박', '한국', '태국'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['관세청', '전국', '세관', '마약', '수사', '정보', '교류'],
#  ['공무원', '군인', '성범죄', '벌금형', '퇴직', '추진'],
#  ['한번', '성폭력', '성추행', '퇴출'],
#  ['성폭력', '근절', '종합', '대책', '발표', '성추행', '성폭행', '범죄자', '퇴출'],
#  ['성폭행', '군인', '공무원', '벌금형', '퇴출'],
#  ['북한', '남한', '간첩', '체포', '극악', '테러', '분자'],
#  ['어린이집', '원장', '교육원', '국고', '보조금'],
#  ['투자', '사기', '황장엽', '수양딸', '징역'],
#  ['권력', '성폭력', '공무원', '군인', '벌금형', '퇴출'],
#  ['권력', '성폭행', '벌금형', '선고', '퇴직'],
#  ['공무원', '군인', '성범죄', '벌금형', '영구', '퇴출'],
#  ['은둔', '외톨이', '묻지마 범죄', '공통점'],
#  ['이규태', '회장', '증거', '인멸', '일광', '공영', '직원', '구속영장'],
#  ['천황', '주의자', '아버지', '소설'],
#  ['성추행', '성폭행', '가해자', '퇴출', '원칙'],
#  ['세무', '컨설팅', '용역', '세무조사', '편의', '수뢰', '국세청', '공무원', '기소'],
#  ['친구', '도박', '유명', '입시', '업체', '대표'],
#  ['흉터', '보험금', '남녀', '차별'],
#  ['중국', '4월', '부패', '스카이넷', '작전', '개시'],
#  ['국가', '보조금', '횡령', '평생', '교육원', '어린이집', '원장', '무더기', '적발'],
#  ['측근', '고위급', '겨냥', '정권', '수사'],
#  ['필중', '임옥희', '경희대', '마니', '타스', '칼리지', '교수', '지금', '페미니즘'],
#  ['측근', '고위급', '겨냥', '정권', '수사'],
#  ['투자', '사기', '황장엽', '수양딸', '징역', '확정'],
#  ['북한', '남한', '간첩', '체포', '극악', '테러', '분자'],
#  ['자본', '기업', '사냥', '김태촌', '양아들', '구속'],
#  ['한국', '간첩', '체포', '기자회견'],
#  ['사설', '보이스', '피싱', '이체', '지연', '시간'],
#  ['사무장', '병원', '요양', '급여', '부정', '수급'],
#  ['공유', '문화', '외국인', '범죄', '사회부', '김해', '본부장'],
#  ['진해경찰서', '중고', '봉사단', '여명', '담벼락', '희망'],
#  ['범죄', '피해자', '경제', '지원'],
#  ['만우절', '허위', '장난', '신고'],
#  ['회장', '압수수색', '방해', '일광', '공영', '직원', '영장'],
#  ['사감', '전자', '카드', '도입', '불법', '사행', '산업', '근절', '중점'],
#  ['경찰', '장난', '전화', '위급', '생명'],
#  ['옥천', '경찰', '문화', '센터'],
#  ['홍성', '범피', '센터', '사랑', '집수리', '봉사'],
#  ['이희', '총재', '세계'],
#  ['청소', '업체', '대표', '징역'],
#  ['쿠바', '공무원', '부패', '달걀', '무더기', '중형'],
#  ['김영란', '입법', '과정', '정치', '한계', '지적'],
#  ['레이디 가가', '중동', '버전', '이미지', '보니'],
#  ['저먼윙스', '사고기', '미스터리', '시나리오', '반론'],
#  ['마을', '신부', '선데이', '서울로', '그때', '시절'],
#  ['자전거 도둑', '경찰', '추적'],
#  ['월세', '독촉', '주인집', '구속'],
#  ['경찰병원', '전화', '착시', '전환', '보이스', '피싱', '경찰', '수사'],
#  ['일본', '경찰', '조선', '총련', '의장', '자택', '압수수색'],
#  ['아침', '신문', '보기', '코스닥', '간의', '질주'],
#  ['음주', '단속', '피해', '시속', '킬로미터', '도주'],
#  ['이슈', '투데이', '노인', '대상', '사기', '범죄'],
#  ['음주', '단속', '피해', '시속', '킬로미터', '도주'],
#  ['알몸', '채팅', '함정'],
#  ['강원', '포럼', '안함', '주기', '안보', '의식', '정립'],
#  ['충북', '경찰청', '교육'],
#  ['충북', '교육청', '부패', '척결', '계획', '방안', '추진'],
#  ['술집', '박사', '대전', '유성구', '성범죄', '위험', '도시 자치구'],
#  ['범죄', '피해자', '경제', '지원', '담양', '화재', '피해자', '만원'],
#  ['세상', '만사', '나라', '대마초', '불법체류'],
#  ['카드', '복제', '설치', '중국', '동포', '구속'],
#  ['사설', '태극기', '이벤트', '정신', '강화', '계기'],
#  ['사설', '대통령', '의지', '권력', '기관'],
#  ['자전거', '도둑', '더 독', '경찰'],
#  ['복지', '사각지대', '경제', '약자', '탈출구'],
#  ['김천경찰서', '주민', '현장', '간담회', '호응'],
#  ['동두천경찰서', '중앙', '성모병원', '범죄', '피해자', '치료', '업무', '협약'],
#  ['평창경찰서', '해피', '메신저', '위촉', '간담회', '사진'],
#  ['원주', '초등', '방과', '안전사고'],
#  ['기고', '블랙박스', '장점', '단점'],
#  ['기고', '블랙박스', '장점', '단점'],
#  ['도로', '주소', '응급', '상황', '생명'],
#  ['교통사고', '보험', '사기', '직장인', '가담'],
#  ['대구', '경찰', '대마', '재배', '흡입', '우즈베키스탄', '구속'],
#  ['친절', '기자', '생명', '불감증', '확산', '우려', '기독교', '윤리', '교육', '적극'],
#  ['폭로', '여성', '죄수', '교도소', '상납', '보고서'],
#  ['일본', '경찰', '북한산', '송이', '불법', '수입', '관련', '조총련', '허종만', '의장', '자택', '압수수색'],
#  ['하루', '명도', '교도소', '죄수', '상납', '다반사', '모범수', '상납'],
#  ['일본', '경찰', '조선', '총련', '의장', '자택', '압수수색', '송이', '불법', '수입', '사건', '관련'],
#  ['지구', '기세', '자전거', '도둑', '경찰'],
#  ['저먼윙스', '자살비행', '부각', '조종사', '조종실', '이탈'],
#  ['서울', '국세청', '일선', '세무서', '동시', '다발', '압수수색'],
#  ['윗선', '지시', '비자금', '조성', '전달', '포스코건설', '베트남', '법인', '진술', '확보'],
#  ['대한민국', '명품', '브랜드', '대상', '해외', '명품', '문구', '인정', '제품 개발'],
#  ['안함', '주기', '북한', '미군', '잠수함', '충돌', '음모론', '제기'],
#  ['안함', '주기', '남북', '관계', '북한', '반응'],
#  ['천종호', '부장', '판사', '소년', '생각', '만사', '소년', '별명'],
#  ['독일', '여객기', '추락', '조종사', '이탈', '자살비행', '제기'],
#  ['범죄', '피해자', '경제', '보상', '검찰', '주민', '단체'],
#  ['장난꾸러기', '매력', '발산', '반항아', '김우빈'],
#  ['브리핑', '영도', '범죄', '피해자', '안심', '귀가', '협약'],
#  ['창원', '사무장', '병원', '불법', '요양', '급여'],
#  ['구리경찰서', '실종', '수색', '골든타임', '확보', '전국'],
#  ['부지', '매각', '뒷돈', '학교', '이사장', '항소심', '실형'],
#  ['렌터카', '이용', '불법', '운송', '무더기', '검거'],
#  ['대전', '유성구', '성범죄', '위험', '안전', '도시'],
#  ['보험', '사기', '공화국', '특별법', '해외'],
#  ['시론', '유령', '수술', '근절'],
#  ['보험', '사기', '공화국', '특별법', '범죄', '사회'],
#  ['일본', '경찰', '조총련', '의장', '자택', '압수수색'],
#  ['한국', '어선', '소말리아', '해적', '피랍', '위험'],
#  ['환전상', '피싱', '조직', '가담', '환치'],
#  ['서경', '하우', '페어', '두산건설', '가지', '기술', '에너지', '절감', '휴먼', '아파트'],
#  ['조종사', '이탈', '독일', '여객기', '자살비행', '부각'],
#  ['정치인', '사칭', '착시', '전환', '보이스', '피싱'],
#  ['권력', '성범죄', '4년'],
#  ['여주경찰서', '재학', '신임', '대장', '소통', '화합', '범죄', '도약'],
#  ['간통', '위헌', '판결', '무죄', '선고'],
#  ['국세청', '직원', '여명', '뇌물', '수수', '리스트'],
#  ['단독', '한국인', '미사일', '부품', '이란', '밀매'],
#  ['대청도', '도박판', '공무원', '검거'],
#  ['시만텍', '사이버 범죄', '수사', '협력', '시스템', '구축'],
#  ['누리', '작명', '소장', '영향력', '인기', '작명', '가로', '선정'],
#  ['온주완', '조보아', '드라마', '실종', '느와르', '배역'],
#  ['천안시', '위탁', '횡령', '청소', '업체', '대표', '징역'],
#  ['백석', '천안', '경찰', '협력', '체결'],
#  ['수렵', '유배', '얘기'],
#  ['김태촌', '양아들', '횡령', '혐의', '구속'],
#  ['이규태', '회장', '비자금', '창구', '의혹', '교회', '건물', '추가', '압수수색'],
#  ['독일', '여객기', '추락', '사고', '자살비행', '제기'],
#  ['국가보안법', '위반', '혐의', '간디', '학교', '교사', '무죄', '확정'],
#  ['보이스', '피싱', '원천', '봉쇄'],
#  ['아이', '학교'],
#  ['군인', '성매매', '처벌', '수위', '진다'],
#  ['살인', '성폭력', '장기', '미제', '해결'],
#  ['음향', '기기', '개인', '감상', '음향', '마니아', '입건'],
#  ['중국', '해커', '도스', '공격', '방어', '업체', '대표'],
#  ['9호선', '단계', '논현', '종합운동장', '운행'],
#  ['그리스', '포르투갈', '재정', '위기', '검은돈'],
#  ...]

# %%
fin_lst=[]
for n in transaction:
    two_lst = []
    for i in n:
        if len(i)<=1:
            pass
        else:
            two_lst.append(i)
    fin_lst.append(two_lst)
fin_lst

# %%
#명사리스트로
# nouns = []
for i in fin_lst:
    for n in i:
        nouns.append(n)
len(nouns)
# Out:
# 460698

# %%
#명사형용사 빈도분석그래프
tokens = nouns
vocab = nltk.Text(tokens)
plt.figure(figsize=(16,4))
plt.title('빈도분석(제목명사추출)')
vocab.plot(50)

# %% [markdown]
# ## -키워드로빈도분석

# %%
type(범죄뉴스.키워드), type(tokens)
#token:: 한word가 한elem인 list
#df.키워드.tolist():: 한 기사내 단어가 쉼표로 구분된 스트링.이 한elem인 list
# Out:
# (pandas.core.series.Series, list)

# %%
if type(tokens)==list:
    print('된다')
else:
    print('인식불가')
# Out:
# 된다

# %%
wordfrequencygraph(nouns)
# Out:
# make list to token
# token: wordlist with 460698words

# %%
#wordfrequencygraph
#시리즈를 넣으면 빈도분석그래프를 그리는 함수
#keywordseries2list
#시리즈(한elem이 한기사내의 단어string)-->리스트(한단어가 한elem) 즉, token
def keywordseries2list(series):
    kwlst = list(series)
    wordlist=[]
    for i in range(len(kwlst)):
        wordlist += str(kwlst[i]).split(",")
    print(f'token: wordlist with {len(wordlist)}words')
    return wordlist
    #'float' object has no attribute 'split' : 숫자만 들어있는게 있나봐
def wordfrequencygraph(seriesorlist):
    if type(seriesorlist)==list:
        print('make list to token')
        print(f'token: wordlist with {len(seriesorlist)}words')
        tokens = seriesorlist
    if type(seriesorlist)==pd.core.series.Series:
        print('make series to token')
        tokens = keywordseries2list(seriesorlist)
    vocab = nltk.Text(tokens)
    plt.figure(figsize=(16,4))
    plt.title('빈도분석')
    vocab.plot(50)
    plt.show()

# %%
#키워드열로 빈도분석
wordfrequencygraph(범죄뉴스.키워드)
# Out:
# make series to token
# token: wordlist with 12178741words

# %%
#특성추출열로 빈도분석
wordfrequencygraph(범죄뉴스.특성추출)
# Out:
# make series to token
# token: wordlist with 1996510words

# %% [markdown]
# # 필터링해서 빈도분석
# 사회문제가 미성년범죄인 카테고리에 한해서

# %%
# 사회>사회문제>미성년범죄
# 특정 사건사고분류가 담긴 인덱스를 가져온다.
indexlist=[]
for j in range(3):
    row = '사건/사고 분류'+f'{j+1}'
    print(row)
    for i in range(len(범죄뉴스)):
        if str(범죄뉴스[row][i])[8:] == '미성년범죄':
            #print(str(범죄뉴스['사건/사고 분류1'][i])[8:])
            indexlist.append(i)
len(indexlist)
# Out:
# 사건/사고 분류1
# 사건/사고 분류2
# 사건/사고 분류3
# 681

# %%
#전체데이터프레임에서 조건에 해당하는 뉴스행만 뽑는다.
범죄뉴스_미성년범죄 = 범죄뉴스.loc[범죄뉴스.index.isin(indexlist)==True]

# %%
#필터링된 뉴스로 빈도분석그래프를 그린다.
wordfrequencygraph(범죄뉴스_미성년범죄.키워드)
# Out:
# make series to token
# token: wordlist with 128270words

# %%
#범죄뉴스(전체데이터프레임)과 필터링할분류(미성년범죄), 필터링시작점(8)을 넣으면
#해당뉴스를 반환하는 함수  분류종류(사건사고분류/ 통합 분류)
# df=범죄뉴스, filt='사건/사고 분류'or'통합 분류', k=8, keyword ='미성년범죄'
def classifyfilter(df,filt,k,keyword):
    # 특정 사건사고분류가 담긴 인덱스를 가져온다.
    indexlist=[]
    for j in range(3):
        row = filt+f'{j+1}'
        print(row)
        for i in range(len(df)):
            if str(df[row][i])[k:] == keyword:
                #print(str(범죄뉴스['사건/사고 분류1'][i])[8:])
                indexlist.append(i)
    print(f'{len(indexlist)} news filtered')
    #전체데이터프레임에서 조건에 해당하는 뉴스행만 뽑는다.
    return df.loc[df.index.isin(indexlist)==True]

# %%
범죄뉴스_미성년범죄 = classifyfilter(범죄뉴스,'사건/사고 분류',8,'미성년범죄')
# Out:
# 사건/사고 분류1
# 사건/사고 분류2
# 사건/사고 분류3
# 681 news filtered

# %%
wordfrequencygraph(범죄뉴스_미성년범죄.키워드)
# Out:
# make series to token
# token: wordlist with 128270words

# %%
wordfrequencygraph(범죄뉴스_미성년범죄.특성추출)
# Out:
# make series to token
# token: wordlist with 17308words
