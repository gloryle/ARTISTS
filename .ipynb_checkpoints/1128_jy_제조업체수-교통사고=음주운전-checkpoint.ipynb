# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import numpy  as np
import seaborn as sns
# %matplotlib inline

path = './data/'
pd.options.display.max_rows = 150
pd.options.display.max_columns = 350
plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
sigungu = pd.read_csv(path+'sigungu_imp_10.csv', encoding='cp949')
sigungu_3 = pd.read_csv(path+'시군구별지역안전지표_2015.csv', encoding='cp949')

# %%
y_bin = sigungu.iloc[:,-7:] #등급(binary) - 15년, 14년도 
y_deci = sigungu_3.iloc[:,-7:] #등급(1-5) - 15년
X = sigungu.iloc[:,4:-7] #독립변수X - 15년 
name = sigungu.iloc[:,:4] #이름 - 15년
y_bin.columns = ['fire','transport','disaster','crime','accident','suicide','infection']

# %%
#전국 산업단지(2015)
전국산업단지 = pd.read_csv(path+'전국산업단지현황_정지연.csv', encoding='cp949')
신규산업단지 = pd.read_csv(path+'신규지정산업단지_정지연.csv', encoding='cp949')

# %%
신규산업단지
# Out:
#     시도   시군                 단지명
# 0   경기  용인시            통삼일반산업단지
# 1   경기  양주시          서울우유일반산업단지
# 2   충남  아산시            탕정일반산업단지
# 3   울산   북구         모바일테크일반산업단지
# 4   경기  양주시             원일반산업단지
# 5   경기  안성시            강문일반산업단지
# 6   경북  안동시       경북바이오2차일반산업단지
# 7   경남  김해시  이지(Eco-Zone)일반산업단지
# 8   강원  원주시            포진일반산업단지
# 9   충북  충주시       충주인프라시티일반산업단지
# 10  경남  김해시          미래테크일반산업단지
# 11  경남  김해시        AM하이테크일반산업단지

# %%
전국산업단지 = 전국산업단지.loc[전국산업단지.조성상태=='완료']
전국산업단지
# Out:
#       유형  시도    시군           단지명 조성상태  지정면적  관리면적  전체면적  분양대상    분양  미분양  \
# 0     국가  서울   구로구        한국수출산업   완료  1922  1922  1446  1446  1446    0
# 1     국가  서울   구로구         서울디지탈   완료  1922  1922  1446  1446  1446    0
# 2     국가  부산   강서구         명지,녹산   완료  8841  8814  4317  4317  4317    0
# 3     국가  부산   강서구        ??명지지구   완료  1843  1843     0     0     0    0
# 4     국가  부산   강서구  ??녹산지구(산업단지)   완료  6998  6971  4317  4317  4317    0
# ...   ..  ..   ...           ...  ...   ...   ...   ...   ...   ...  ...
# 1201  농공  경남   합천군            적중   완료    94    94    79    79    79    0
# 1203  농공  경남   함양군        함양중방전문   완료    99    99    61    61    61    0
# 1207  농공  제주  서귀포시            대정   완료   115   115    94    94    94    0
# 1208  농공  제주   제주시            구좌   완료    67    67    49    49    49    0
# 1209  농공  제주   제주시            금능   완료   130   130    97    97    97    0
#
#         분양률  입주업체  가동업체 고용현황(남) 고용현황(여) 고용현황(계) 누계생산(백만원) 누계수출(천달러)
# ...

# %%
import re
stop_words_lst = set(['앵커', '기자'])

for i in 전국산업단지.단지명:
    try:
        전국산업단지.단지명[i] = re.sub(' ','',전국산업단지.단지명[i])
    except KeyError:
        pass

# %%
전국산업단지['단지명']=전국산업단지['단지명'].str.replace('??','')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-52-1fc16fbce833> in <module>()
# ----> 1 전국산업단지['단지명']=전국산업단지['단지명'].str.replace('??','')
#
# C:\Anaconda3\lib\site-packages\pandas\core\strings.py in wrapper(self, *args, **kwargs)
#    1841                 )
#    1842                 raise TypeError(msg)
# -> 1843             return func(self, *args, **kwargs)
#    1844
#    1845         wrapper.__name__ = func_name
#
# C:\Anaconda3\lib\site-packages\pandas\core\strings.py in replace(self, pat, repl, n, case, flags, regex)
#    2714     def replace(self, pat, repl, n=-1, case=None, flags=0, regex=True):
#    2715         result = str_replace(
# -> 2716             self._parent, pat, repl, n=n, case=case, flags=flags, regex=regex
#    2717         )
#    2718         return self._wrap_result(result)
#
# ...
