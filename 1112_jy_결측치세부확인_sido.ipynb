# %%
import pandas as pd
path = './data/'

# %%
sido_all = pd.read_csv(path+'sido_wide.csv', encoding='cp949')

# %%
sido_all
# Out:
#        년도       시도            지역       1인가구수  5대범죄 발생건수       가로등수  가스공급설비 면적  \
# 0    2008      강원도      2008_강원도         NaN        NaN  337.70313    4.83781
# 1    2008      경기도      2008_경기도         NaN        NaN  243.18014   26.34827
# 2    2008     경상남도     2008_경상남도         NaN        NaN  367.58438   12.35899
# 3    2008     경상북도     2008_경상북도         NaN        NaN  348.39731    4.75662
# 4    2008    광주광역시    2008_광주광역시         NaN        NaN  254.85269   45.63080
# ..    ...      ...           ...         ...        ...        ...        ...
# 127  2015     전라남도     2015_전라남도  1034.13825   96.18109        NaN    6.98780
# 128  2015     전라북도     2015_전라북도   935.18776   99.41439        NaN    6.78658
# 129  2015  제주특별자치도  2015_제주특별자치도   740.86270  172.06008        NaN    4.71108
# 130  2015     충청남도     2015_충청남도   936.94191  104.31694        NaN   41.88548
# 131  2015     충청북도     2015_충청북도   952.89034  108.76966        NaN    3.13792
#
# ...
