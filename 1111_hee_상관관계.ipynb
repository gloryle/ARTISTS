# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import numpy  as np
import seaborn as sns
pd.options.display.max_rows = 150
pd.options.display.max_columns = 350
plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

path = './data/'

# %%
sido = pd.read_csv(path+'시도별지역안전지표_2015.csv', encoding='cp949', engine='python')
sido
# Out:
#       년도       시도            지역       1인가구수  5대범죄 발생건수  가로등수   가스공급설비 면적  \
# 0   2015      강원도      2015_강원도  1006.53181  106.70520   NaN     6.58064
# 1   2015      경기도      2015_경기도   629.04248  103.94220   NaN    36.71902
# 2   2015     경상남도     2015_경상남도   855.11350  103.36819   NaN    11.54976
# 3   2015     경상북도     2015_경상북도  1072.66234   91.96555   NaN     5.10991
# 4   2015    광주광역시    2015_광주광역시   830.05168  145.64153   NaN    71.63525
# 5   2015    대구광역시    2015_대구광역시   771.96799  117.89766   NaN   106.44678
# 6   2015    대전광역시    2015_대전광역시   880.90617  123.63160   NaN   158.50487
# 7   2015    부산광역시    2015_부산광역시   826.56679  127.03014   NaN    43.33497
# 8   2015    서울특별시    2015_서울특별시   845.87379  129.33781   NaN   281.37178
# 9   2015  세종특별자치시  2015_세종특별자치시   554.17134   64.30745   NaN    78.00861
# 10  2015    울산광역시    2015_울산광역시   663.77338  119.23246   NaN    10.17959
# 11  2015    인천광역시    2015_인천광역시   657.62239   95.57956   NaN  1511.33800
# ...

# %%
#널값 삭제한 데이터 프레임 만들기
sido_null_drop=sido.dropna(axis=1)
len(sido_null_drop.columns)
# Out:
# 163

# %%
#삭제된 컬럼수 : 331-163 = 168
len(sido.columns)-len(sido_null_drop.columns)
# Out:
# 168

# %%
sido_null_drop
# Out:
#       년도       시도            지역       1인가구수  5대범죄 발생건수   가스공급설비 면적  가스사고발생건수  \
# 0   2015      강원도      2015_강원도  1006.53181  106.70520     6.58064   0.05180
# 1   2015      경기도      2015_경기도   629.04248  103.94220    36.71902   0.03399
# 2   2015     경상남도     2015_경상남도   855.11350  103.36819    11.54976   0.04477
# 3   2015     경상북도     2015_경상북도  1072.66234   91.96555     5.10991   0.07405
# 4   2015    광주광역시    2015_광주광역시   830.05168  145.64153    71.63525   0.02033
# 5   2015    대구광역시    2015_대구광역시   771.96799  117.89766   106.44678   0.00401
# 6   2015    대전광역시    2015_대전광역시   880.90617  123.63160   158.50487   0.03264
# 7   2015    부산광역시    2015_부산광역시   826.56679  127.03014    43.33497   0.02557
# 8   2015    서울특별시    2015_서울특별시   845.87379  129.33781   281.37178   0.01287
# 9   2015  세종특별자치시  2015_세종특별자치시   554.17134   64.30745    78.00861   0.00000
# 10  2015    울산광역시    2015_울산광역시   663.77338  119.23246    10.17959   0.05144
# ...

# %% [markdown]
# ### 각 y값에 대한 상관계수 보기
#
# - 결측값 있어도 상관계수는 계산됨, 현재 코드는 null값 하나라도 있는 열은 다 빼고 만든 코드

# %%
#상관계수 보기

y_lst = ['화재', '교통', '자연재해', '범죄', '안전사고', '자살', '감염병']

plt.figure(figsize = (20,35))

for i, y in enumerate(y_lst):
    orig=pd.concat((sido_null_drop.iloc[:,3:-7],sido_null_drop[y]), axis=1)
    data = pd.DataFrame(orig.corr()[y]).sort_values(by='{}'.format(y), ascending=False)
    plt.subplot(1,7,i+1); sns.heatmap(data = data, annot=True, fmt = '.2f', linewidths=.5, cmap='Reds')
    plt.title(y, fontsize=15)
    plt.tight_layout(pad=0.3, w_pad=6)
    
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   if sys.path[0] == '':

# %%
# plt.figure(figsize = (1,80))

# y='화재'

# orig=pd.concat((sido.iloc[:,3:-7],sido[y]), axis=1)
# data = pd.DataFrame(orig.corr()[y]).sort_values(by='{}'.format(y), ascending=False)
# sns.heatmap(data = data, annot=True, fmt = '.2f', linewidths=.5, cmap='Reds')
# plt.title(y, fontsize=15)
    
# plt.show()

# %%
# data
# data.dropna(axis=0, inplace=True)
# len(data.index)
# Out:
# 186

# %%
# orig=pd.concat((sido_null_drop.iloc[:,3:-7],sido_null_drop[y]), axis=1)
# data1 = pd.DataFrame(orig.corr()[y]).sort_values(by='{}'.format(y), ascending=False)
# len(data1.index)
# Out:
# 154

# %% [markdown]
# ### feature_importance보기 (대충)

# %%
X=sido_null_drop.iloc[:,3:-7]
화재=sido_null_drop.iloc[:,-7]

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=10).fit(X, 화재)
feature_importance_rf = pd.DataFrame(data=np.c_[X.columns.values, rf.feature_importances_],
                                    columns=['feature', 'importance'])

# %%
feature_importance_rf.sort_values("importance", ascending=False, inplace=True)

# %%
feature_importance_rf
# Out:
#                    feature  importance
# 71           어린이 교통사고 부상자수      0.0958
# 14                공무원수(정원)   0.0563693
# 80                위험물 제조소수   0.0553127
# 17               교통사고 발생건수    0.054594
# 125              지역안전도(등급)   0.0480588
# 16                  교통문화지수   0.0471218
# 51                  보행사상자수   0.0468027
# 141              학교수(고등학교)    0.036315
# 79                   월간음주율   0.0337662
# 73           어린이 식품안전보호구역수   0.0322088
# 70        양호한 주관적 건강수준 인지율    0.032197
# 52           보행자전용·우선도로 면적   0.0321937
# 140                   하천연장   0.0290598
# 53           보행자전용·우선도로 연장   0.0288799
# 98               일반주거지역 면적   0.0281997
# 119                 주민등록인구   0.0271061
# 86          음식점 및 주점업 종사자수   0.0261826
# 116                제조업 업체수   0.0234873
# 43              범죄발생건수(마약)   0.0233945
# 151              화재사망자(환산)   0.0227446
# 114                   제방면적   0.0198853
# 72           어린이 교통사고 사망자수   0.0190816
# 13          공공질서 및 안전예산 비율   0.0186763
# ...
