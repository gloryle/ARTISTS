# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
path = 'C:/Users/COM/python_work/data/'
import matplotlib.pyplot as plt
import missingno as msno
import numpy  as np
import seaborn as sns
# %matplotlib inline

from sklearn.ensemble import RandomForestClassifier
path = './data/'
pd.options.display.max_rows = 150
pd.options.display.max_columns = 350
plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

pd.options.display.max_rows = 999

# %%
sido = pd.read_csv(path+'sido.csv', encoding='cp949')
sigungu = pd.read_csv(path+'시군구별지역안전지표_2015.csv', encoding='cp949')

# %% [markdown]
# ## 데이터모양확인 및 split

# %%
#sido.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# array([[2015, '강원도', '2015_강원도', ..., 1, 1, 0],
#        [2015, '경기도', '2015_경기도', ..., 0, 0, 0],
#        [2015, '경상남도', '2015_경상남도', ..., 0, 0, 0],
#        ...,
#        [2015, '제주특별자치도', '2015_제주특별자치도', ..., 1, 0, 0],
#        [2015, '충청남도', '2015_충청남도', ..., 0, 1, 0],
#        [2015, '충청북도', '2015_충청북도', ..., 0, 0, 0]], dtype=object)

# %%
sido.shape, sigungu.shape
# Out:
# ((17, 173), (226, 310))

# %%
sido_y = sido.iloc[:,-7:]
sido_x = sido.iloc[:,3:-7]
sido_name = sido.iloc[:,:3]
sigungu_y= sigungu.iloc[:,-7:]
sigungu_x= sigungu.iloc[:,3:-7]
sigungu_name = sido.iloc[:,:3]

# %%
sido_y.shape, sido_x.shape,sido_name.shape
# Out:
# ((17, 7), (17, 165), (17, 3))

# %%
sigungu_y.shape, sigungu_x.shape, sigungu_name.shape
# Out:
# ((226, 7), (226, 300), (17, 3))

# %% [markdown]
# ## 표준화 (MinmaxScaler)
# * 다른 스케일러 robust_scale(), maxabs_scale(), scale(),
# * minmaxscaler() 범위조정(0,1)
# * 로 만들어진 데이터셋도 시도해봐야한다.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1)) #범위 임의지정했는데 괜?
#독립변수에 일괄적용
sido_x_scaled = scaler.fit_transform(sido_x)
#sigungu_x_scaled = scaler.fit_transform(sigungu_x)

# %%
#scale결과 array를 데이터프레임으로 만들고 열이름을 새로 지정해준다.
#sigungu_x_scaled = pd.DataFrame(data = sigungu_x_scaled)
#sigungu_x_scaled.columns = sigungu_x.columns
sido_x_scaled = pd.DataFrame(data = sido_x_scaled)
sido_x_scaled.columns = sido_x.columns

# %%
sido_x_scaled.shape#, sigungu_x_scaled.shape
# Out:
# (17, 163)

# %% [markdown]
# ## Feature Importance

# %%
rf = RandomForestClassifier(n_estimators=10).fit(sido_x_scaled, sido.화재)
feature_importance_rf = pd.DataFrame(data=np.c_[sido_x_scaled.columns.values,rf.feature_importances_],
                                     columns=['feature','importance'])
feature_importance_rf.sort_values('importance',ascending=False,inplace=True)
feature_importance_rf
# Out:
#                    feature importance
# 123                제조업 업체수    0.15641
# 161               화재피해 경감액   0.129683
# 87                위험물 제조소수  0.0950183
# 76        양호한 주관적 건강수준 인지율  0.0779221
# 42                 방화지구 면적  0.0738462
# 21                    구거면적  0.0696429
# 153                행정구역 면적  0.0515152
# 145              폐기물 처리시설수  0.0514286
# 71                식중독 발생건수  0.0485714
# 33                   대기오염도  0.0484848
# 77           어린이 교통사고 부상자수   0.037585
# 65                 스트레스인지율  0.0354308
# 40            무면허교통사고 발생건수  0.0303571
# 99                   의료보험료  0.0269841
# 12                   고령인구수  0.0261538
# 11                   경찰관서수  0.0220779
# 13          공공질서 및 안전예산 비율  0.0188889
# 117                  재난약자수          0
# 108                자살 사망자수          0
# 118                  재정자립도          0
# 109       자연재해 발생건수(10년평균)          0
# 110              자연재해 사망자수          0
# 111       자연재해 사망자수(10년평균)          0
# 115                   장애인수          0
# 116              재난심리지원센터수          0
# 112        자연재해 피해액(10년평균)          0
# 113       자연재해 피해자수(10년평균)          0
# 114              자원봉사자 등록률          0
# 107                자동차등록대수          0
# 0                    1인가구수          0
# 101                   이혼건수          0
# 106                  임야 면적          0
# 105              일반주거지역 면적          0
# 89                    유지면적          0
# 90                 유지면적 비율          0
# 91                   유치원생수          0
# 92           음식점 및 주점업 업체수          0
# 93          음식점 및 주점업 종사자수          0
# 94             음주교통사고 발생건수          0
# 95             의료기관수(요양기관)          0
# 96           의료보장 공.교 가입자수          0
# 97           의료보장 근로자 사업장수          0
# 98               의료보장 사업장수          0
# 100                   의료인력          0
# 120               전기화재발생건수          0
# 102                   익사자수          0
# 103                   인구밀도          0
# 104            인플루엔자 예방접종률          0
# 119                  재정자주도          0
# 127                 주민등록인구          0
# 121                   제방면적          0
# 142                  총전입자수          0
# 144                특수의료장비수          0
# 146          폐수배출시설 점검 위반율          0
# 147                   하천면적          0
# 148                하천면적 비율          0
# 149                   하천연장          0
# 150              학교수(고등학교)          0
# 151               학교수(중학교)          0
# 152              학교수(초등학교)          0
# 154                 혼인귀화자수          0
# 155                화재 발생건수          0
# 156                화재 사망자수          0
# 157                 화재 피해액          0
# 158                화재 피해자수          0
# 159                 화재구조실적          0
# 160              화재사망자(환산)          0
# 143                추락 사망자수          0
# 141                 총 사업체수          0
# 122                제방면적 비율          0
# 140                  초등학생수          0
# 124               제조업 종사자수          0
# 125                 주간인구지수          0
# 126                주거지역 면적          0
# 128          주민등록인구(14세이하)          0
# 129          주민등록인구(60세이상)          0
# 130             주민등록인구(여자)          0
# 131            주민등록인구(청소년)          0
# 132              지역별 부도업체수          0
# 133            지역안전도(관리능력)          0
# 134              지역안전도(등급)          0
# 135            지역안전도(방재성능)          0
# 136            지역안전도(위험환경)          0
# 137              지역안전도(점수)          0
# 138  질병이환 및 사망외인으로 인한 사망자수          0
# 139     창고 및 운송관련 서비스업 업체수          0
# 88          유류저장 및 송유설비 면적          0
# 81                  어린이 천식          0
# 86                   월간음주율          0
# 23                  구급발생건수          0
# 25                 구조구급대원수          0
# 26                  구조발생건수          0
# 27                  기초수급자수          0
# 28           기초수급자수(65세이상)          0
# 29            노인 교통사고 부상자수          0
# 30            노인 교통사고 사망자수          0
# 31                 다중이용업소수          0
# 32           대기배출시설 점검 위반율          0
# 34                    도로면적          0
# 35                 도로면적 비율          0
# 36                    도로연장          0
# 37                 도시지역 면적          0
# 38              도시지역 면적 비율          0
# 39                   독거노인수          0
# 41                 방재지구 면적          0
# 24               구조구급 발생건수          0
# 22                 구거면적 비율          0
# 44              범죄발생건수(강도)          0
# 20          교통사고사망자수(고속도로)          0
# 2                가스공급설비 면적          0
# 3                 가스사고발생건수          0
# 4              가해(타살) 사망자수          0
# 5                 감염병 발생건수          0
# 6                 감염병 사망자수          0
# 7                 건강보험급여실적          0
# 8                  건설업 업체수          0
# 9                 건설업 종사자수          0
# 10                 건축용지 면적          0
# 14                공무원수(정원)          0
# 15                 공업지역 면적          0
# 16                  교통문화지수          0
# 17               교통사고 발생건수          0
# 18               교통사고 부상자수          0
# 19               교통사고 사망자수          0
# 43         범죄발생건수(강간.강제추행)          0
# 45              범죄발생건수(도박)          0
# 85            운전시 안전벨트 착용률          0
# 64                   순이동자수          0
# 67               시군구내 전입자수          0
# 68               시군구외 전입자수          0
# 69                시도간 전입자수          0
# 70           시도내-시군구간 전입자수          0
# 72                식중독 발생자수          0
# 73           식품제조가공업체 위반건수          0
# 74                     실업률          0
# 75                   야간인구수          0
# 78           어린이 교통사고 사망자수          0
# 79           어린이 식품안전보호구역수          0
# 80                 어린이 아토피          0
# 1                5대범죄 발생건수          0
# 82                열공급설비 면적          0
# 83                    외국인수          0
# 84                  우울감경험률          0
# 66                    시가화율          0
# 63                성폭력 발생건수          0
# 46              범죄발생건수(마약)          0
# 62                 상업지역 면적          0
# 47              범죄발생건수(방화)          0
# 48              범죄발생건수(살인)          0
# 49           범죄발생건수(약취.유인)          0
# 50              범죄발생건수(절도)          0
# 51              범죄발생건수(폭력)          0
# 52                     병상수          0
# 53     보건업 및 사회복지서비스업 종사자수          0
# 54                  보행사상자수          0
# 55           보행자전용·우선도로 면적          0
# 56           보행자전용·우선도로 연장          0
# 57                     빈집수          0
# 58                    산림면적          0
# 59                 산림면적 비율          0
# 60                  산불발생건수          0
# 61                  산불피해면적          0
# 162                황사 발생건수          0

# %% [markdown]
# # RFE

# %%
from sklearn.feature_selection import RFE
select = RFE(RandomForestClassifier(n_estimators=10),n_features_to_select =5)
select.fit(sido_x_scaled, sido.화재)
feature_importance_rfe = pd.DataFrame(data=np.c_[sido_x_scaled.columns.values,select.get_support()],
                                     columns=['feature','importance'])
feature_importance_rfe.sort_values('importance',ascending=False,inplace=True)
feature_importance_rfe
# Out:
#                    feature importance
# 132              지역별 부도업체수       True
# 145              폐기물 처리시설수       True
# 108                자살 사망자수       True
# 155                화재 발생건수       True
# 112        자연재해 피해액(10년평균)       True
# 0                    1인가구수      False
# 104            인플루엔자 예방접종률      False
# 105              일반주거지역 면적      False
# 106                  임야 면적      False
# 107                자동차등록대수      False
# 109       자연재해 발생건수(10년평균)      False
# 110              자연재해 사망자수      False
# 111       자연재해 사망자수(10년평균)      False
# 102                   익사자수      False
# 113       자연재해 피해자수(10년평균)      False
# 114              자원봉사자 등록률      False
# 115                   장애인수      False
# 116              재난심리지원센터수      False
# 117                  재난약자수      False
# 118                  재정자립도      False
# 119                  재정자주도      False
# 103                   인구밀도      False
# 101                   이혼건수      False
# 121                   제방면적      False
# 91                   유치원생수      False
# 84                  우울감경험률      False
# 85            운전시 안전벨트 착용률      False
# 86                   월간음주율      False
# 87                위험물 제조소수      False
# 88          유류저장 및 송유설비 면적      False
# 89                    유지면적      False
# 90                 유지면적 비율      False
# 92           음식점 및 주점업 업체수      False
# 100                   의료인력      False
# 93          음식점 및 주점업 종사자수      False
# 94             음주교통사고 발생건수      False
# 95             의료기관수(요양기관)      False
# 96           의료보장 공.교 가입자수      False
# 97           의료보장 근로자 사업장수      False
# 98               의료보장 사업장수      False
# 99                   의료보험료      False
# 120               전기화재발생건수      False
# 123                제조업 업체수      False
# 122                제방면적 비율      False
# 152              학교수(초등학교)      False
# 144                특수의료장비수      False
# 146          폐수배출시설 점검 위반율      False
# 147                   하천면적      False
# 148                하천면적 비율      False
# 149                   하천연장      False
# 150              학교수(고등학교)      False
# 151               학교수(중학교)      False
# 153                행정구역 면적      False
# 82                열공급설비 면적      False
# 154                 혼인귀화자수      False
# 156                화재 사망자수      False
# 157                 화재 피해액      False
# 158                화재 피해자수      False
# 159                 화재구조실적      False
# 160              화재사망자(환산)      False
# 161               화재피해 경감액      False
# 143                추락 사망자수      False
# 142                  총전입자수      False
# 141                 총 사업체수      False
# 140                  초등학생수      False
# 124               제조업 종사자수      False
# 125                 주간인구지수      False
# 126                주거지역 면적      False
# 127                 주민등록인구      False
# 128          주민등록인구(14세이하)      False
# 129          주민등록인구(60세이상)      False
# 130             주민등록인구(여자)      False
# 131            주민등록인구(청소년)      False
# 133            지역안전도(관리능력)      False
# 134              지역안전도(등급)      False
# 135            지역안전도(방재성능)      False
# 136            지역안전도(위험환경)      False
# 137              지역안전도(점수)      False
# 138  질병이환 및 사망외인으로 인한 사망자수      False
# 139     창고 및 운송관련 서비스업 업체수      False
# 83                    외국인수      False
# 81                  어린이 천식      False
# 1                5대범죄 발생건수      False
# 40            무면허교통사고 발생건수      False
# 22                 구거면적 비율      False
# 23                  구급발생건수      False
# 24               구조구급 발생건수      False
# 25                 구조구급대원수      False
# 26                  구조발생건수      False
# 27                  기초수급자수      False
# 28           기초수급자수(65세이상)      False
# 29            노인 교통사고 부상자수      False
# 30            노인 교통사고 사망자수      False
# 31                 다중이용업소수      False
# 32           대기배출시설 점검 위반율      False
# 33                   대기오염도      False
# 34                    도로면적      False
# 35                 도로면적 비율      False
# 36                    도로연장      False
# 37                 도시지역 면적      False
# 38              도시지역 면적 비율      False
# 21                    구거면적      False
# 20          교통사고사망자수(고속도로)      False
# 19               교통사고 사망자수      False
# 9                 건설업 종사자수      False
# 2                가스공급설비 면적      False
# 3                 가스사고발생건수      False
# 4              가해(타살) 사망자수      False
# 5                 감염병 발생건수      False
# 6                 감염병 사망자수      False
# 7                 건강보험급여실적      False
# 8                  건설업 업체수      False
# 10                 건축용지 면적      False
# 18               교통사고 부상자수      False
# 11                   경찰관서수      False
# 12                   고령인구수      False
# 13          공공질서 및 안전예산 비율      False
# 14                공무원수(정원)      False
# 15                 공업지역 면적      False
# 16                  교통문화지수      False
# 17               교통사고 발생건수      False
# 39                   독거노인수      False
# 41                 방재지구 면적      False
# 80                 어린이 아토피      False
# 42                 방화지구 면적      False
# 63                성폭력 발생건수      False
# 64                   순이동자수      False
# 65                 스트레스인지율      False
# 66                    시가화율      False
# 67               시군구내 전입자수      False
# 68               시군구외 전입자수      False
# 69                시도간 전입자수      False
# 70           시도내-시군구간 전입자수      False
# 71                식중독 발생건수      False
# 72                식중독 발생자수      False
# 73           식품제조가공업체 위반건수      False
# 74                     실업률      False
# 75                   야간인구수      False
# 76        양호한 주관적 건강수준 인지율      False
# 77           어린이 교통사고 부상자수      False
# 78           어린이 교통사고 사망자수      False
# 79           어린이 식품안전보호구역수      False
# 62                 상업지역 면적      False
# 61                  산불피해면적      False
# 60                  산불발생건수      False
# 50              범죄발생건수(절도)      False
# 43         범죄발생건수(강간.강제추행)      False
# 44              범죄발생건수(강도)      False
# 45              범죄발생건수(도박)      False
# 46              범죄발생건수(마약)      False
# 47              범죄발생건수(방화)      False
# 48              범죄발생건수(살인)      False
# 49           범죄발생건수(약취.유인)      False
# 51              범죄발생건수(폭력)      False
# 59                 산림면적 비율      False
# 52                     병상수      False
# 53     보건업 및 사회복지서비스업 종사자수      False
# 54                  보행사상자수      False
# 55           보행자전용·우선도로 면적      False
# 56           보행자전용·우선도로 연장      False
# 57                     빈집수      False
# 58                    산림면적      False
# 162                황사 발생건수      False

# %% [markdown]
# # Logistic Regression
# regression coefficient

# %%
from sklearn.linear_model import LinearRegression
model_fire = LinearRegression().fit(sido_x_scaled, sido.화재)

# %%
feature_importance_lr = pd.DataFrame(np.c_[sido_x_scaled.columns.values,model_fire.coef_.ravel()],
                                    columns=['feature','coef'])
feature_importance_lr.sort_values('coef', ascending=False, inplace=True)
feature_importance_lr
# Out:
#                    feature        coef
# 156                화재 사망자수    0.238133
# 133            지역안전도(관리능력)    0.227567
# 160              화재사망자(환산)     0.22249
# 104            인플루엔자 예방접종률    0.202478
# 155                화재 발생건수    0.193108
# 76        양호한 주관적 건강수준 인지율    0.185086
# 137              지역안전도(점수)    0.148537
# 143                추락 사망자수    0.137503
# 15                 공업지역 면적     0.13323
# 74                     실업률     0.13039
# 49           범죄발생건수(약취.유인)    0.123923
# 87                위험물 제조소수    0.123326
# 81                  어린이 천식    0.119729
# 120               전기화재발생건수    0.108736
# 63                성폭력 발생건수    0.108191
# 158                화재 피해자수    0.108001
# 17               교통사고 발생건수   0.0966486
# 29            노인 교통사고 부상자수   0.0941884
# 79           어린이 식품안전보호구역수    0.093377
# 46              범죄발생건수(마약)   0.0933674
# 18               교통사고 부상자수   0.0928122
# 77           어린이 교통사고 부상자수   0.0916979
# 78           어린이 교통사고 사망자수   0.0882744
# 70           시도내-시군구간 전입자수   0.0875126
# 5                 감염병 발생건수    0.082391
# 121                   제방면적   0.0777137
# 122                제방면적 비율   0.0699925
# 7                 건강보험급여실적   0.0688554
# 26                  구조발생건수    0.061695
# 86                   월간음주율   0.0597445
# 57                     빈집수   0.0573621
# 9                 건설업 종사자수   0.0560857
# 108                자살 사망자수   0.0545551
# 99                   의료보험료     0.05433
# 85            운전시 안전벨트 착용률   0.0542294
# 144                특수의료장비수   0.0536849
# 43         범죄발생건수(강간.강제추행)   0.0533028
# 42                 방화지구 면적    0.047469
# 56           보행자전용·우선도로 연장   0.0474372
# 68               시군구외 전입자수   0.0438978
# 71                식중독 발생건수   0.0433025
# 94             음주교통사고 발생건수   0.0420896
# 40            무면허교통사고 발생건수   0.0420896
# 119                  재정자주도   0.0420836
# 19               교통사고 사망자수   0.0414846
# 96           의료보장 공.교 가입자수   0.0371046
# 4              가해(타살) 사망자수   0.0345255
# 131            주민등록인구(청소년)   0.0342387
# 138  질병이환 및 사망외인으로 인한 사망자수   0.0290745
# 148                하천면적 비율   0.0287238
# 124               제조업 종사자수   0.0285946
# 73           식품제조가공업체 위반건수   0.0253661
# 58                    산림면적   0.0243728
# 31                 다중이용업소수   0.0231094
# 95             의료기관수(요양기관)   0.0226994
# 116              재난심리지원센터수   0.0219476
# 100                   의료인력   0.0214797
# 159                 화재구조실적   0.0214214
# 69                시도간 전입자수   0.0214028
# 14                공무원수(정원)   0.0206104
# 25                 구조구급대원수   0.0191682
# 142                  총전입자수   0.0189486
# 106                  임야 면적   0.0187306
# 8                  건설업 업체수   0.0185448
# 147                   하천면적   0.0170843
# 60                  산불발생건수   0.0169845
# 55           보행자전용·우선도로 면적   0.0164571
# 45              범죄발생건수(도박)   0.0160578
# 59                 산림면적 비율   0.0143655
# 64                   순이동자수   0.0137311
# 118                  재정자립도   0.0130758
# 54                  보행사상자수   0.0108032
# 145              폐기물 처리시설수  0.00848639
# 152              학교수(초등학교)  0.00788251
# 10                 건축용지 면적  0.00743036
# 51              범죄발생건수(폭력)  0.00704207
# 48              범죄발생건수(살인)  0.00657941
# 72                식중독 발생자수  0.00638665
# 62                 상업지역 면적   0.0046989
# 66                    시가화율  0.00425032
# 92           음식점 및 주점업 업체수  0.00398957
# 12                   고령인구수 -0.00165689
# 141                 총 사업체수 -0.00214461
# 114              자원봉사자 등록률 -0.00245245
# 93          음식점 및 주점업 종사자수 -0.00334599
# 128          주민등록인구(14세이하)  -0.0054503
# 140                  초등학생수 -0.00702253
# 123                제조업 업체수 -0.00707135
# 129          주민등록인구(60세이상)  -0.0100839
# 24               구조구급 발생건수  -0.0111664
# 21                    구거면적  -0.0129422
# 126                주거지역 면적  -0.0139419
# 90                 유지면적 비율  -0.0152971
# 41                 방재지구 면적  -0.0155639
# 22                 구거면적 비율  -0.0158849
# 34                    도로면적   -0.016518
# 151               학교수(중학교)  -0.0178131
# 36                    도로연장  -0.0178874
# 1                5대범죄 발생건수  -0.0195941
# 107                자동차등록대수  -0.0201223
# 115                   장애인수  -0.0204452
# 101                   이혼건수  -0.0211852
# 35                 도로면적 비율  -0.0244037
# 105              일반주거지역 면적  -0.0247984
# 61                  산불피해면적  -0.0249598
# 89                    유지면적  -0.0251903
# 37                 도시지역 면적  -0.0265955
# 75                   야간인구수  -0.0273497
# 30            노인 교통사고 사망자수  -0.0277158
# 27                  기초수급자수   -0.029259
# 32           대기배출시설 점검 위반율  -0.0295357
# 117                  재난약자수  -0.0296693
# 132              지역별 부도업체수  -0.0307312
# 103                   인구밀도  -0.0318427
# 88          유류저장 및 송유설비 면적  -0.0330381
# 38              도시지역 면적 비율  -0.0363147
# 82                열공급설비 면적  -0.0363163
# 16                  교통문화지수  -0.0369738
# 80                 어린이 아토피   -0.037324
# 146          폐수배출시설 점검 위반율  -0.0386164
# 84                  우울감경험률  -0.0405534
# 91                   유치원생수  -0.0421193
# 44              범죄발생건수(강도)  -0.0436467
# 39                   독거노인수  -0.0445279
# 150              학교수(고등학교)  -0.0447856
# 47              범죄발생건수(방화)  -0.0455755
# 110              자연재해 사망자수  -0.0458297
# 28           기초수급자수(65세이상)  -0.0459587
# 23                  구급발생건수  -0.0462149
# 154                 혼인귀화자수  -0.0464281
# 157                 화재 피해액  -0.0467765
# 139     창고 및 운송관련 서비스업 업체수  -0.0481039
# 127                 주민등록인구  -0.0484856
# 125                 주간인구지수  -0.0534493
# 6                 감염병 사망자수  -0.0548124
# 50              범죄발생건수(절도)   -0.055112
# 134              지역안전도(등급)  -0.0552839
# 2                가스공급설비 면적  -0.0584446
# 113       자연재해 피해자수(10년평균)  -0.0593506
# 149                   하천연장  -0.0608359
# 13          공공질서 및 안전예산 비율  -0.0626012
# 111       자연재해 사망자수(10년평균)  -0.0629153
# 112        자연재해 피해액(10년평균)  -0.0742954
# 53     보건업 및 사회복지서비스업 종사자수  -0.0762297
# 11                   경찰관서수   -0.076968
# 0                    1인가구수  -0.0773959
# 162                황사 발생건수  -0.0824813
# 83                    외국인수  -0.0846026
# 161               화재피해 경감액  -0.0864151
# 102                   익사자수  -0.0903026
# 98               의료보장 사업장수  -0.0915168
# 97           의료보장 근로자 사업장수  -0.0916905
# 153                행정구역 면적  -0.0994671
# 65                 스트레스인지율  -0.0997435
# 130             주민등록인구(여자)   -0.119126
# 3                 가스사고발생건수   -0.119737
# 52                     병상수   -0.120504
# 67               시군구내 전입자수   -0.126746
# 109       자연재해 발생건수(10년평균)    -0.14009
# 20          교통사고사망자수(고속도로)   -0.156596
# 136            지역안전도(위험환경)   -0.157785
# 33                   대기오염도   -0.185677
# 135            지역안전도(방재성능)   -0.194786

# %% [markdown]
# # SelectKBest

# %%
from sklearn.feature_selection import SelectKBest, chi2
X = SelectKBest(chi2, k=20).fit_transform(sido_x_scaled, sido.화재)
X.shape #20개 선택됨
feature_importance_k = pd.DataFrame(np.c_[sido_x_scaled.columns.values,model_fire.coef_.ravel()],
                                    columns=['feature','importances'])
feature_importance_k.sort_values('coef', ascending=False, inplace=True)
feature_importance_k
# Out:
# (17, 20)

# %%
#여기서 선택된걸로 모델을 돌리게 됨
