# %% [markdown]
# ### 뉴스내용 크롤링분석

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.common.exceptions import NoSuchElementException
path = './data/'
keyword='비행 청소년 범죄'

# %%
driver=webdriver.Chrome('C:/chromedriver')
driver.get('https://www.bigkinds.or.kr/')
# driver.find_element_by_xpath('//*[@id="contents"]/div[3]/div/div[2]/div/div[2]/button').click()
driver.implicitly_wait(3)
title_data = []
sub_data = []
con_data = []

# %%
driver.find_element_by_id('date-filter-btn').click()
begin_d = driver.find_element_by_id('search-begin-date')
begin_d.send_keys(Keys.HOME)
begin_d.send_keys('2015-01-01')
begin_d.send_keys(Keys.TAB)
end_d = driver.find_element_by_id('search-end-date')
end_d.send_keys(Keys.HOME)
end_d.send_keys('2015-12-31')
begin_d.send_keys(Keys.TAB)
driver.find_element_by_id('date-filter-btn').click()

# %%
#검색어입력
search = driver.find_element_by_id('total-search-key')
search.send_keys(keyword)
search.send_keys(Keys.RETURN)

# %%
def crawl_nextpage(i=3):
    while True:
        address = '//*[@id="news-results-pagination"]/ul/li[' + f'{i}' + ']/a'
        i += 1
        try:
            data= driver.find_elements_by_css_selector('div.news-item__body > h4 ')            
            for r in data:
                #창열기
                r.click()
                #제목 및 부속
                a = driver.find_elements_by_css_selector('h4.modal-title')
                title_data.append(a[7].text)
                time.sleep(0.5)
                b = driver.find_element_by_css_selector('div.pull-left')
                sub_data.append(b.text)
                time.sleep(0.6)
                c = driver.find_element_by_css_selector('div.news-detail__content')
                con_data.append(c.text)   
                #창닫기
                time.sleep(1) 
                driver.find_element_by_xpath('//*[@id="news-detail-modal"]/div/div/div[1]/button').click()
                time.sleep(1)
            time.sleep(0.5) 
            driver.find_element_by_xpath(address).click()
            print('o')
            time.sleep(2.8)
        except NoSuchElementException:
            break;

# %%
while True:
    #페이지갯수
    lst = driver.find_elements_by_css_selector('#news-results-pagination > ul > li')
    len(lst)
    print(len(lst)-3)
    if len(lst)==10:
        crawl_nextpage()
        i=3
        
    else:
        crawl_nextpage()
        break;
# Out:
# 7
# o
# o
# o
# o
# o
# o
# o
# o
# 7
# o
# o
# o
# o
# o
# o
# o
# o
# 7
# o
# o
# o
# o
# o
# o
# o
# o
# 7
# o
# o
# o
# o
# o
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-6-cf01f731e630> in <module>()
#       5     print(len(lst)-3)
#       6     if len(lst)==10:
# ----> 7         crawl_nextpage()
#       8         i=3
#       9
#
# <ipython-input-5-624d79d0ddf5> in crawl_nextpage(i)
#       7             for r in data:
#       8                 #창열기
# ----> 9                 r.click()
#      10                 #제목 및 부속
#      11                 a = driver.find_elements_by_css_selector('h4.modal-title')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <h4 class="news-item__title news-detail" data-newsid="01100701.20150602100000306" onclick="">...</h4> is not clickable at point (554, 438). Other element would receive the click: <div class="news-loader">...</div>
#   (Session info: chrome=78.0.3904.108)

# %% [markdown]
# ### 내용저장하는 과정

# %%
pd.DataFrame(con_data).to_csv(path + f'{keyword}_내용.csv',encoding='utf-8',index=False)

# %%
a = pd.read_csv(path + f'{keyword}_내용.csv',encoding='utf-8')

# %% [markdown]
# ### 데이터프레임 리스트 변환과정

for i in spl_lst:
    i = re.sub('[^0-9a-zA-Zㄱ-힗]', ' ', i) #e.sub() 함수는 문자열에서 매치된 텍스트를 다른 텍스트로 치환할 때 사용
    news_lst.append(i)
# news_lst

# %%
len(news_lst)
# Out:
# 6533

# %%
n_lst = []
for news in news_lst:
    if ('중복' not in news) and ('예외' not in news):
        n_lst.append(news)

# %%
len(n_lst)
# Out:
# 6529

# %% [markdown]
# ### 공백있으면 코모란 안돌아가서 공백 제거해주는 과정

# %%
### 공백있으면 코모란 안돌아가서 공백 제거해주는 과정
nn_lst = []
for i in n_lst:
    if i =='':
        pass
    else:
        nn_lst.append(i)

# %%
len(nn_lst)
# Out:
# 2946

# %%
nn_lst
# Out:
# [' 법무부 4급  승진 법무부 소년과 윤용범 서울보호관찰소 관찰과장 김기환 대전    심선옥 서울소년원 교무과장 이용호 대구    정성수 대구  분류보호과장 이영미 대전    박종국 광주  교무과장 서진남 서울소년분류심사원 분류심사과장 김세훈 전보 법무부 국방대 파견  황진규 서울동부보호관찰소장 정택현 서울남부  최종철 의정부  양봉환 인천보호관찰소 부천지소장 김시종 수원  안산  노근성 수원  천안  노일석 광주소년원장 이영호 제주  유병택 서울소년분류심사원 안산청소년비행예방센터장 김택수 대전보호관찰소 행정지원과장 홍정원 대구    배종상 부산    최성학 광주    이은한 서울소년원   손세헌 부산  교무과장 박준재 부산  분류보호과장 윤일중 광주    김양곤 대전  교무과장 이상운',
#  ' 해양수산부 장관정책보좌관 김희곤 이창호 과장급  장관 비서실장 이경규 창조행정담당관 권순욱 항로표지과장 김영소 부산지방해양수산청 선원해사안전과장 최국일 동해지방해양수산청장 공평식 포항  윤석홍 국립해양조사원 해도수로과장 임채호',
#  ' 문화재청 고위공무원  국립무형유산원장 강경환 과장급  문화재활용국 세계유산팀장 남상범',
#  ' 산림청 과장급  산불방지과장 박도환 산사태  이용권 산림복지시설사업단 기획과장 황인욱 춘천국유림관리소장 김만제',
#  ' 한국전력 1 을 직급  이동 본사 감사실 최병운 홍보실 조기형 에너지신사업단 안규선 임낙송 기획처 이경숙 전력시장처 백선호 경영개선처 이정복 전상귀 재무처 진장호 KINGS파견 조성인 노무처 박형환 자재처 이종우 자산관리처 강덕원 영업처 신기정 전력수급처장 이재우 배전계획처 이준호  운영처 이종환 상생협력처 유현호 민원대책처 김준식 기술기획처 하동혁 ICT기획처 박장범 김용배 품질경영처 김영성 계통계획처 김태옥 송변전건설처 이정원 전석주  운영처 김태익 해외사업개발처 문형일 해외발전기술처 이상국 김재하 정보기술처 한상태 신중진 사업소 서울지역본부 이만근 김준호   성동전력지사장 심정운 남서울지역본부 정익중  영서전력지사장 김상권 인천지역본부 최재흥   김포지사장 허완   제물포  강상훈   시흥  강정호   강화  김완호   인천전력  이기탁 경기북부지역본부 유호탁 홍호웅 김종화   포천지사장 남열우   양평  채준수   동두천  장창균   가평  황성훈   구리전력  권영완 경기지역본부 신용석 정치교   서수원지사장 전재은   안성  고흥원   화성  김유활   광명  허광엽   평택전력  조재형 강원지역본부 윤철호
# ...
#  '경기도의 한 고등학교에 다니는 카말 가명 19 은 외국인 근로자로 한국에 들어온 방글라데시인 부모 사이에서 태어났다  한국에서 태어난 카말은 방글라데시에 대해 아는 바가 없다  그저 부모의 나라라는 인식이 전부다 ',
#  '아버지는 5년 전 불법체류자로 적발돼 고국으로 강제 출국당했고 현재 어머니  여동생과 함께 33㎡ 밖에 되지 않는 좁은 공간에서 살고 있다  이마저도 샌드위치 패널로 만든 조립식 주택인 탓에 안전도 보장할 수 없다  카말은 가족이 모두 잠든 늦은 밤에야 집에 들어오곤 한다 ',
#  '공장 일을 하며 아버지를 대신해 가장 역할을 하고 있는 어머니에게는  학교 친구들과 어울려 놀다 늦었다 고 둘러댄다  카말은 학교에서 이미  문제아  취급을 받은 지 오래다  카말의 어머니는  아들 때문에 교회 목사님이 학교와 경찰서를 수도 없이 불려다녔다 고 털어놨다 ',
#  '이들 가족을 돌보고 있는 목사는  카말이 비행청소년들과 어울려 다니며 문제를 일으키고 있다 며  학교도 자주 빠져서  수없이 타이르기도 했지만 쉽지 않다 고 걱정했다 ',
#  '카말은  한때는 엔지니어가 꿈이었지만  언제 쫓겨날지 모르는 불안한 환경에서 꿈이 무슨 의미가 있느냐 며  이젠 하고 싶은 일도 없고 모든 게 싫다 고 자신을 짓누르는 현실에 무력감을 드러냈다 ',
#  '방황하는 카말은 그래도 나은 편이다  필리핀인 어머니와 미군 아버지 사이에서 태어난 니콜 가명 17 여 은 중학교를 중퇴하고 미군클럽에서 1년 넘게 일했다  무국적자인 그녀는 나이를 속이고 클럽에 들어갔다 ',
#  '신원 정보가 없어 나이는 그저 말하기 나름이라는 게 그녀의 설명이다  최근 자신이 일하는 클럽이 경찰 단속으로 문을 닫자  현재 다른 일자리를 알아보는 중이다 ',
#  '그녀는  학교에도 다닐 수 없고 취업도 할 수 없는데  우리가 일할 곳이 이런 곳밖에 더 있겠느냐 며  돈이라도 벌려면 남자는 정말 고된 막노동판에서  여자는 이런 곳에서 일하는 수밖에 없다  이마저도 안되면 남의 돈을 빼앗는 일 밖에 없다 고 말했다 ',
#  '경기도내 미군기지 주변 유흥업소에는 니콜과 같은 무국적 여성 청소년들이 돈을 벌기 위해 숨어들고 있다 ',
#  '최근 5년간 법무부의 국내 불법체류자 현황 자료에 따르면 불법체류자는 올해 기준 21만3천565명으로 5년 전보다 27 2  늘어난 반면  불법체류자 단속률은 11 1 에서 5 5 로 줄어든 것으로 나타났다  단속률이 떨어진 것은 신원정보를 파악할 수 없는 무국적자의 증가가 주요 원인이라는 분석도 나온다 ',
#  '김복준 한국범죄학연구소 연구위원은  무국적자가 범죄를 저지를 경우 지문이나 신원정보를 확보할 수 없다는 점 때문에 지문 감식이나 DNA 조사 등의 과학수사가 사실상 무의미해 목격자 진술 또는 탐문수사 등에 의존할 수밖에 없는 상황 이라며  이를 개선하기 위해 불법체류자와 무국적자에 처벌유예기간을 주고 자진신고를 유도하는 등 정부의 법률적인 조치가 필요하다 고 조언했다 ',
#  ' 범죄심리학 프로파일러   범죄심리학   프로파일러   프로파일러 표창원 최근 범죄심리학  프로파일러 에 대한 누리꾼들의 관심이 커지고 있다 프로파일러 profiler 는 우리말로 범죄자의 심리를 분석하는  범죄심리 전문가 로 풀이된다 프로파일러가 연쇄범죄 등 중대 범죄수사에서 자주 언급되게 된 것은 최근 부터다  처음 등장한 것은 1972년 미국에서였다 범죄동기를 알 수 없는 연쇄살인사건이 일어나자 미국 연방수사국 FBI 은 프로파일러를 도입했다  이후 여러 나라에서도 이 제도를 도입하면서 범죄심리학이라는 분야가 더욱 성장하게 되었다 범죄심리 라고 하면 흔히들 뭔가 특이한 것을 기대하지만 범죄자의 행동적  심리적 특징을 연구하는 영역이라고 이해하는 것이 보다 정확하다 범죄심리학은 범죄해부학  범죄심리학  공격성  정신병질  청소년비행  정신장애  위험성 평가  성범죄  살인  연쇄살인  프로파일링  테러와 인질협상  가정폭력  배우자 살해  병적 도벽의 심리 등 매우 다양한 분야가 포함된다 국내 범죄심리학 프로파일러로는 표창원범죄과학연구소 소장인 표창원이 대표적이다 범죄심리학 프로파일러 뜻을 접한 네티즌은  범죄심리학 프로파일러 뜻  범죄심리 분석 전문가구나   범죄심리학 프로파일러 뜻  표창원이 대표적이네   범죄심리학 프로파일러 뜻  재밌겠다  등의 반응을 보였다  매경닷컴 오용훈 인턴기자 관련기사서울대 엄친딸 지주연   뇌섹녀 의 볼륨 비키니 몸매 봤더니  입이 쩍  삼성이 택한 3大 미래기술 삼성기술전 2015 넥센  히어로즈  3년 더 넥센타이어와 계약 연장마지막 무대 앞둔 국보 발레리나  은퇴 아쉬움은 전혀 없어요 레이싱걸 송다미  축구공만한  가슴골 에  퐁당  빠지고 파 男心 작렬    매일경제   mk co kr  무단전재 및 재배포 금지 ',
#  ' 범죄심리학 프로파일러의 뜻   범죄심리학   프로파일러   프로파일러 표창원   범죄심리학 프로파일러 범죄 발생률이 날로 증가하면서 범죄심리학에 프로파일러에 대한 관심도 높아지고 있다 그렇다면 범죄심리학 프로파일러의 뜻은 뭘까 범죄심리학 프로파일러는 우리말로 범죄자의 심리를 분석하는  범죄심리 전문가 로 풀이된다 그러나 범죄심리학 프로파일러가 연쇄범죄 등 중대 범죄수사에서 자주 언급된 것은 최근부터다  처음 등장한 것은 1972년 미국에서였다 범죄동기를 알 수 없는 연쇄살인사건이 일어나자 미국 연방수사국 FBI 은 범죄심리학 프로파일러를 도입했다  이후 여러 나라에서도 이 제도를 도입하면서 범죄심리학이라는 분야가 더욱 성장하게 되었다 범죄심리 라고 하면 흔히들 뭔가 특이한 것을 기대하지만 범죄자의 행동적  심리적 특징을 연구하는 영역이라고 이해하는 것이 보다 정확하다 범죄심리학은 범죄해부학  범죄심리학  공격성  정신병질  청소년비행  정신장애  위험성 평가  성범죄  살인  연쇄살인  프로파일링  테러와 인질협상  가정폭력  배우자 살해  병적 도벽의 심리 등 매우 다양한 분야가 포함된다 국내 범죄심리학 프로파일러로는 표창원범죄과학연구소 소장인 표창원이 대표적이다 죄심리학 프로파일러 뜻을 접한 네티즌은  범죄심리학 프로파일러 뜻  범죄심리 분석 전문가구나   범죄심리학 프로파일러 뜻  표창원이 대표적이네   범죄심리학 프로파일러 뜻  재밌겠다  등의 반응을 보였다  매경닷컴 이성구 인턴기자 관련기사서울대 엄친딸 지주연   뇌섹녀 의 볼륨 비키니 몸매 봤더니  입이 쩍  삼성이 택한 3大 미래기술 삼성기술전 2015실전 감각 익혔지만  싱거워서 아쉬운 쿠바전마지막 무대 앞둔 국보 발레리나  은퇴 아쉬움은 전혀 없어요 레이싱걸 송다미  축구공만한  가슴골 에  퐁당  빠지고 파 男心 작렬    매일경제   mk co kr  무단전재 및 재배포 금지 ',
#  ' 범죄심리학 프로파일러의 뜻   범죄심리학   프로파일러   프로파일러 표창원   범죄심리학 프로파일러 범죄 발생률이 날로 증가하면서 범죄심리학에 프로파일러에 대한 관심도 높아지고 있다 그렇다면 범죄심리학 프로파일러의 뜻은 뭘까 범죄심리학 프로파일러는 우리말로 범죄자의 심리를 분석하는  범죄심리 전문가 로 풀이된다 그러나 범죄심리학 프로파일러가 연쇄범죄 등 중대 범죄수사에서 자주 언급된 것은 최근부터다  처음 등장한 것은 1972년 미국에서였다 범죄동기를 알 수 없는 연쇄살인사건이 일어나자 미국 연방수사국 FBI 은 범죄심리학 프로파일러를 도입했다  이후 여러 나라에서도 이 제도를 도입하면서 범죄심리학이라는 분야가 더욱 성장하게 되었다 범죄심리 라고 하면 흔히들 뭔가 특이한 것을 기대하지만 범죄자의 행동적  심리적 특징을 연구하는 영역이라고 이해하는 것이 보다 정확하다 범죄심리학은 범죄해부학  범죄심리학  공격성  정신병질  청소년비행  정신장애  위험성 평가  성범죄  살인  연쇄살인  프로파일링  테러와 인질협상  가정폭력  배우자 살해  병적 도벽의 심리 등 매우 다양한 분야가 포함된다 국내 범죄심리학 프로파일러로는 표창원범죄과학연구소 소장인 표창원이 대표적이다 죄심리학 프로파일러 뜻을 접한 네티즌은  범죄심리학 프로파일러 뜻  범죄심리 분석 전문가구나   범죄심리학 프로파일러 뜻  표창원이 대표적이네   범죄심리학 프로파일러 뜻  재밌겠다  등의 반응을 보였다  매경닷컴 이성구 인턴기자 관련기사서울대 엄친딸 지주연   뇌섹녀 의 볼륨 비키니 몸매 봤더니  입이 쩍  삼성이 택한 3大 미래기술 삼성기술전 2015벤제마 결장 이유 부상만이 아니었다 佛 경찰에 체포마지막 무대 앞둔 국보 발레리나  은퇴 아쉬움은 전혀 없어요 레이싱걸 송다미  축구공만한  가슴골 에  퐁당  빠지고 파 男心 작렬    매일경제   mk co kr  무단전재 및 재배포 금지 ',
#  ' 범죄심리팍 프로파일러의 뜻   범죄심리학   프로파일러   프로파일러 표창원   범죄심리학 프로파일러 범죄 발생률이 날로 증가하면서 범죄심리학에 프로파일러에 대한 관심도 높아지고 있다 그렇다면 범죄심리학 프로파일러의 뜻은 뭘까 범죄심리학 프로파일러는 우리말로 범죄자의 심리를 분석하는  범죄심리 전문가 로 풀이된다 그러나 범죄심리학 프로파일러가 연쇄범죄 등 중대 범죄수사에서 자주 언급된 것은 최근부터다  처음 등장한 것은 1972년 미국에서였다 범죄동기를 알 수 없는 연쇄살인사건이 일어나자 미국 연방수사국 FBI 은 범죄심리학 프로파일러를 도입했다  이후 여러 나라에서도 이 제도를 도입하면서 범죄심리학이라는 분야가 더욱 성장하게 되었다 범죄심리 라고 하면 흔히들 뭔가 특이한 것을 기대하지만 범죄자의 행동적  심리적 특징을 연구하는 영역이라고 이해하는 것이 보다 정확하다 범죄심리학은 범죄해부학  범죄심리학  공격성  정신병질  청소년비행  정신장애  위험성 평가  성범죄  살인  연쇄살인  프로파일링  테러와 인질협상  가정폭력  배우자 살해  병적 도벽의 심리 등 매우 다양한 분야가 포함된다 국내 범죄심리학 프로파일러로는 표창원범죄과학연구소 소장인 표창원이 대표적이다 죄심리학 프로파일러 뜻을 접한 네티즌은  범죄심리학 프로파일러 뜻  범죄심리 분석 전문가구나   범죄심리학 프로파일러 뜻  표창원이 대표적이네   범죄심리학 프로파일러 뜻  재밌겠다  등의 반응을 보였다  매경닷컴 이성구 인턴기자 관련기사서울대 엄친딸 지주연   뇌섹녀 의 볼륨 비키니 몸매 봤더니  입이 쩍  삼성이 택한 3大 미래기술 삼성기술전 2015벤제마 결장 이유 부상만이 아니었다 佛 경찰에 체포마지막 무대 앞둔 국보 발레리나  은퇴 아쉬움은 전혀 없어요 레이싱걸 송다미  축구공만한  가슴골 에  퐁당  빠지고 파 男心 작렬    매일경제   mk co kr  무단전재 및 재배포 금지 ',
#  ' 소년범이나 비행 청소년을 방치하면 나중에 우리 사회가 치러야 할 비용과 부담이 엄청 커지기 때문에 이들에 대한 범사회적 관심과 지원이 절실합니다  ',
#  '지난 3일 서울 양재동 서울가정법원 내 집무실에서 만난 여상훈 사진  서울가정법원장은 범죄와 비행을 저지르거나 그럴 우려가 있는 청소년들에 대해 각별한 애정을 드러냈다  이들 청소년은 대부분 불우한 가정환경이나  위기 가정 에서 자라나 부모 등 가족의 따뜻한 사랑을 받지 못한 데서 비롯된 상처를 안고 있다는 점에서다  여 법원장은  가정에서나 사회에서 우리 아이들이 건강하게 자라나는 게 쉽지 않은 환경이 되고 있는 만큼 잘못을 저지른 청소년의 책임만 물을 게 아니라 그런 행동을 하게 된 원인을 찾아 치유해주는 게 중요하다 고 강조했다 ',
#  '하지만 현실은 여 법원장의 바람과는 거리가 멀어도 한참 멀다 ',
#  '그는 범죄와 비행을 저지른 청소년 중 약물 중독에 빠지거나 정신과적 문제를 안고 있는 청소년들을 치료 선도하는  의료소년원  7호 처분 과 보호자가 없거나 친권자 후견인이 보살피기 어려운 문제 청소년을 보호하는 위탁시설 6호 처분 의 실태를 예로 들었다  여 법원장은  전국에 한 곳뿐인 의료소년원에는 상주하는 의사가 없어 그곳으로 보내져 치료가 시급한 청소년을 보낼 수 없는 경우도 있다 며  6호 처분을 내려 아동복지시설이나 소년보호시설로 보내야 할 청소년들 역시 자리가 턱없이 부족해 다른 처분을 내리는 경우가 적지 않다 고 토로했다 ',
#  '실제 6호 처분을 받은 청소년들을 보호하며 건전한 사회인으로 육성하는  6호 시설 은 정부가 2005년 소년범시설 지원 예산을 지자체에 넘긴 뒤 손에 꼽을 정도로 줄었다  영유아 보육비 지원 등으로 살림이 빡빡해진 지자체들이  문제아들 을 지원할 여력이 없기 때문이다  전국에 남은 6호 시설은 8곳에 불과한 상황에서 최근 경기도 양주에 위치한  나사로의 집 도 재정난으로 정상적인 운영이 어려운 실정이다  여 법원장이  소년범을 방치하면 나중에는 성인 범죄자가 되고 그로 인한 사회적 비용도 늘어난다 며 대책 마련이 시급하다고 강조하는 배경이다  가정법원은 급한 대로 6호 시설을 가출청소년을 보듬는 소규모의  그룹홈  형태로 꾸려 각지에 분포하도록 여성가족부 등 관련부처와 협의 중이다 ',
#  '여 법원장은 법원의 후견적 기능을 강화하기 위해 한 법원에 같은 법원장이 오래 머무는  전문법원장제도 를 도입할 것을 제안하기도 했다  그는   가정법원에서 일할 때 큰 보람을 느꼈다 고 하는 전임 법원장들이 많다 며  가정법원 법관이 전문법관으로 최소 5년을 근무하듯  법원장도 전문법원장과 같은 제도를 운영해 긴 시각으로 가사사건과 소년사건을 다뤄야 한다고 본다 고 말했다  특히 가사사건은 후견적 기능이 필요한 점을 고려해 재판부가 판단에만 머무는 게 아니라 갈등을 치유할 수 있는 여러 역할을 해야 한다고 강조했다 ',
#  '한편 변호사로 일한 경력이 있는 여 법원장은  당시 경험을 통해 재판을 받는 입장에서 본 것이 큰 자산이 됐다  그래서 후배 판사들에게도  재판 당사자 양쪽의 이야기를 모두 주의 깊게 듣고 성실하게 설명해 달라 고 주문한다 며  아마 모든 분야에서 강조되는 덕목일 것이라고 생각한다 고 말했다 ',
#  '정선형 기자 linear segye com',
#  '쫓기는 삶에 지친 사춘기  설익은 꿈  교실밖 내몰리다',
#  '쫓기는 삶에 지친 사춘기  설익은 꿈  교실밖 내몰리다',
#  ' IMG01 ',
#  '학교에선 이미 문제아 낙인',
#  ' 하고싶은 일 없고 다 싫어 ',
#  '여학생은 유흥업소 발 담가',
#  '경기도의 한 고등학교에 다니는 카말 가명 19 은 외국인 근로자로 한국에 들어온 방글라데시인 부모 사이에서 태어났다  한국에서 태어난 카말은 방글라데시에 대해 아는 바가 없다  그저 부모의 나라라는 인식이 전부다 ',
#  '아버지는 5년 전 불법체류자로 적발돼 고국으로 강제 출국당했고 현재 어머니  여동생과 함께 33㎡ 밖에 되지 않는 좁은 공간에서 살고 있다  이마저도 샌드위치 패널로 만든 조립식 주택인 탓에 안전도 보장할 수 없다  카말은 가족이 모두 잠든 늦은 밤에야 집에 들어오곤 한다 ',
#  '공장 일을 하며 아버지를 대신해 가장 역할을 하고 있는 어머니에게는  학교 친구들과 어울려 놀다 늦었다 고 둘러댄다  카말은 학교에서 이미  문제아  취급을 받은 지 오래다  카말의 어머니는  아들 때문에 교회 목사님이 학교와 경찰서를 수도 없이 불려다녔다 고 털어놨다 ',
#  '이들 가족을 돌보고 있는 목사는  카말이 비행청소년들과 어울려 다니며 문제를 일으키고 있다 며  학교도 자주 빠져서  수없이 타이르기도 했지만 쉽지 않다 고 걱정했다 ',
#  '카말은  한때는 엔지니어가 꿈이었지만  언제 쫓겨날지 모르는 불안한 환경에서 꿈이 무슨 의미가 있느냐 며  이젠 하고 싶은 일도 없고 모든 게 싫다 고 자신을 짓누르는 현실에 무력감을 드러냈다 ',
#  '방황하는 카말은 그래도 나은 편이다  필리핀인 어머니와 미군 아버지 사이에서 태어난 니콜 가명 17 여 은 중학교를 중퇴하고 미군클럽에서 1년 넘게 일했다  무국적자인 그녀는 나이를 속이고 클럽에 들어갔다 ',
#  '신원 정보가 없어 나이는 그저 말하기 나름이라는 게 그녀의 설명이다  최근 자신이 일하는 클럽이 경찰 단속으로 문을 닫자  현재 다른 일자리를 알아보는 중이다 ',
#  '그녀는  학교에도 다닐 수 없고 취업도 할 수 없는데  우리가 일할 곳이 이런 곳밖에 더 있겠느냐 며  돈이라도 벌려면 남자는 정말 고된 막노동판에서  여자는 이런 곳에서 일하는 수밖에 없다  이마저도 안되면 남의 돈을 빼앗는 일 밖에 없다 고 말했다 ',
#  '경기도내 미군기지 주변 유흥업소에는 니콜과 같은 무국적 여성 청소년들이 돈을 벌기 위해 숨어들고 있다 ',
#  '최근 5년간 법무부의 국내 불법체류자 현황 자료에 따르면 불법체류자는 올해 기준 21만3천565명으로 5년 전보다 27 2  늘어난 반면  불법체류자 단속률은 11 1 에서 5 5 로 줄어든 것으로 나타났다  단속률이 떨어진 것은 신원정보를 파악할 수 없는 무국적자의 증가가 주요 원인이라는 분석도 나온다 ',
#  '김복준 한국범죄학연구소 연구위원은  무국적자가 범죄를 저지를 경우 지문이나 신원정보를 확보할 수 없다는 점 때문에 지문 감식이나 DNA 조사 등의 과학수사가 사실상 무의미해 목격자 진술 또는 탐문수사 등에 의존할 수밖에 없는 상황 이라며  이를 개선하기 위해 불법체류자와 무국적자에 처벌유예기간을 주고 자진신고를 유도하는 등 정부의 법률적인 조치가 필요하다 고 조언했다 ',
#  ' 이종우 최재훈 황성규기자 cjh kyeongin com',
#  '사진은 제주시 이도2지구에 위치한 공사 중단 건축물로 3년6개월 째 완공되지 못하면서 청소년 탈선은 물론 야생 동물들의 서식지로 활용되고 있다  고경호 기자 건설이 중단된 건축물들이 도심 속  흉물 로 전락하고 있다  4일 제주시 이도2지구를 방문한 결과 공사가 중단된 3층 규모의 공동주택이 확인됐다  해당 건물은 지난 2012년 5월에 착공된 것으로 현재까지 3년6개월째 완공되지 못하고 있다  특히 출입을 막기 위한 펜스에는  유치권 행사 중 이라는 경고문이 부착돼 있는 등 건축주가 대금을 지급하지 못해 공사가 중단된 것으로 추정되고 있다  문제는 수
#  '이를 통해 다문화 탈북 결손 가정 청소년들이 미래의 꿈을 키우고  장기적으로는 기업체가 법사랑위원의 청소년 지원 활동을 정기적으로 후원하는 분위기 조성을 기대하고 있다 ',
#  'GS칼텍스 관계자는  지역 내 다문화 가정 등의 청소년들이 나라를 이끄는 인재로 성장할 수 있도록 지속적으로 후원하겠다 고 말했다 ',
#  ' 나영석 기자 ysn kyunghyang com ',
#  ' 용인 벽돌사건  9살 범인 처벌 해야 하나 우리 사회 숙제',
#  '  경기도 용인에서 9살의 초등학생이 친구들과 아파트 옥상에서 벽돌을 던져 고양이집을 만들고 있던 50대 여성이 사망했고 같이 있던 20대 여성은 중상을 입었다 ',
#  '  강원도 9살의 초등학생이 1년여간 9명의 여학생에게 음란 동영상을 보여주며 옷을 벗기고 성추행하고 남학생 4명에게는  부모가 없는 놈 이라 놀리며 폭력을 휘둘렀다 ',
#  '위 두 사례는 이번 달에 발생하거나 적발된 9세 소년에 의한 범죄행위다  두 사례 모두 충격적인 일이지만  형사처벌 대상이 아니다 ',
#  '가해자인 소년에게 형사처벌을 할 수 없다는 점과 더불어 피해자에 대한 구제책이 사실상 없다는 점은 우리 사법현실에 대한 논란을 낳고 있다 ',
#  ' 형사처벌 불가능한  9세 범죄  처벌 여론 높아',
#  '9세이하 소년은 현행법상 형사처벌은 물론이고  촉법소년 형법에 저촉되는 행위를 한 10 13세  을 대상으로 한  보호처분 조치 대상도 안 된다  1953년 형사법 제정후 9세이하에 대한 형사처벌 미적용은 62년간 바뀌지 않았다   보호처분  하한 연령만 한 차례 12세에서 10세로 내려갔다 ',
#  ' 중력 실험이었다 는 9세 가해자의 진술에 따라  고의성 을 두고 논란이 여전하지만 고의여부는 형사처벌과 관련없다  다만  고의성 은 나중에 민사소송이 벌어진다면 소년의 범죄행위를 입증하는 요소가 될 수 있고 이를 근거로 부모에게 관리책임을 물어 손해배상을 청구할 수 있는 근거가 된다  물론 도덕적 비난가능성도 더 높아질 것이다 ',
#  '범인이 9세 소년으로 밝혀진 지난 16일 개설된  다음 아고라  청원에는 4만 여명이  형사처벌 을 요구하고 있다   리얼미터 가 22일 발표한 여론조사 결과에 따르면 형사처벌 연령 기준 하향에 찬성하는 의견이 62 6   반대가 32  로 찬성이 2배 정도로 나타나고 있다 ',
#  '  처벌이냐 관용이냐  처벌 연령 하향 딜레마',
#  ...]

# %% [markdown]
# ## 연관분석 단계

# %%
import pandas as pd
import nltk
from konlpy.tag import Komoran
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
komoran = Komoran()
plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
# Out:
# C:\Users\COM\Anaconda3\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %% [markdown]
# ### 트랜잭션 만들어주는 과정

# %%
noun_lst = []
tran = []
for n in nn_lst:
    noun_lst = komoran.nouns(n)
    tran.append(noun_lst)
    print('ok')
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ---------------------------------------------------------------------------
# java.lang.NullPointerException            Traceback (most recent call last)
# <ipython-input-22-f44b5f709435> in <module>()
#       2 tran = []
#       3 for n in nn_lst:
# ----> 4     noun_lst = komoran.nouns(n)
#       5     tran.append(noun_lst)
#       6     print('ok')
#
# ~\Anaconda3\lib\site-packages\konlpy\tag\_komoran.py in nouns(self, phrase)
#      79         """Noun extractor."""
#      80
# ---> 81         tagged = self.pos(phrase)
#      82         return [s for s, t in tagged if t.startswith('NN')]
#      83
#
# ~\Anaconda3\lib\site-packages\konlpy\tag\_komoran.py in pos(self, phrase, flatten, join)
#      64
#      65         for sentence in sentences:
# ---> 66             result = self.jki.analyze(sentence).getTokenList()
#      67             result = [(token.getMorph(), token.getPos()) for token in result]
#      68
#
# java.lang.NullPointerException: java.lang.NullPointerException

# %%
tran
# Out:
# [['법무부',
#   '급',
#   '승진',
#   '법무부',
#   '소년',
#   '윤',
#   '용범',
#   '서울보호관찰소',
#   '관찰',
#   '장',
#   '김기환',
#   '대전',
#   '심',
#   '선',
#   '옥',
#   '서울소년원',
#   '교무',
#   '장',
#   '이용호',
#   '대구',
#   '정',
#   '성수',
#   '대구',
#   '분류',
#   '보호',
#   '장',
#   '이영미',
#   '대전',
#   '박종국',
#   '광주',
#   '교무',
#   '장',
#   '서진',
#   '남',
#   '서울소년분류심사원',
#   '분류',
#   '심사',
#   '장',
#   '김세훈',
#   '전보',
#   '법무부',
#   '국방',
#   '대',
#   '파견',
#   '황',
#   '진규',
#   '서울동부보호관찰소',
#   '장',
#   '정택현',
#   '서울',
#   '남부',
#   '최종',
#   '철',
#   '의정부',
#   '양봉화',
#   '인천보호관찰소',
#   '천지',
#   '소장',
#   '김시',
#   '종',
#   '수원',
#   '안산',
#   '노',
#   '근성',
#   '수원',
#   '천안',
#   '노',
#   '일',
#   '석',
#   '광주소년원',
#   '장',
#   '이영호',
#   '제주',
#   '유병',
#   '택',
#   '서울소년분류심사원',
#   '안산청소년비행예방센터',
#   '장',
#   '김택수',
#   '대전보호관찰소',
#   '행정',
#   '지원',
#   '장',
#   '홍',
#   '정원',
#   '대구',
#   '배',
#   '종',
#   '부산',
#   '최',
#   '성학',
#   '광주',
#   '이은하',
#   '서울소년원',
#   '손',
#   '세',
#   '헌',
#   '부산',
#   '교무',
#   '장',
#   '박준',
#   '부산',
#   '분류',
#   '보호',
#   '장',
#   '윤',
#   '일',
#   '중',
#   '광주',
#   '김양곤',
#   '대전',
#   '교무',
#   '장',
#   '이상운'],
#  ['해양수산부',
#   '장관',
#   '정책',
#   '보좌관',
#   '김희',
#   '곤',
#   '이창호',
#   '과장',
#   '급',
#   '장관',
#   '비서실장',
#   '이경규',
#   '창조',
#   '행정',
#   '담당관',
#   '권순욱',
#   '항로',
#   '표지',
#   '장',
#   '김영',
#   '소',
#   '부산지방해양수산청',
#   '선원',
#   '해사',
#   '안전',
#   '장',
#   '최국',
#   '일',
#   '동해지방해양수산청',
#   '장',
#   '공평',
#   '식',
#   '포항',
#   '윤',
#   '석홍',
#   '국립',
#   '해',
#   '양조',
#   '사원',
#   '해도',
#   '수로',
#   '장',
#   '임',
#   '채',
#   '호'],
#  ['문화재',
#   '청',
#   '고위',
#   '공무원',
#   '국립무형유산원',
#   '장',
#   '강경',
#   '과장',
#   '급',
#   '문화',
#   '재활용',
#   '국',
#   '세계유산',
#   '팀장',
#   '남',
#   '범'],
#  ['산림청',
#   '과장',
#   '급',
#   '산불',
#   '방지',
#   '장',
#   '박도',
#   '산사태',
#   '이용',
#   '산림',
#   '복지',
#   '시설',
#   '사업단',
#   '기획',
#   '장',
#   '황인',
#   '천국',
#   '유림',
#   '관리',
#   '소장',
#   '김만제'],
#  ['한국전력',
#   '을',
#   '직급',
#   '이동',
#   '본사',
#   '감',
#   '사실',
#   '최병우',
#   '홍보실',
#   '조기',
#   '에너지',
#   '사업단',
#   '안',
#   '규',
#   '선',
#   '임',
#   '낙',
#   '송',
#   '기획',
#   '처',
#   '이경숙',
#   '전력',
#   '시장',
#   '처',
#   '선호',
#   '경영',
#   '개선',
#   '처',
#   '정복',
#   '상귀',
#   '재무',
#   '처',
#   '장호',
#   '파견',
#   '조성',
#   '노무',
#   '처',
#   '박형',
#   '자재',
#   '처',
#   '이종우',
#   '자산',
#   '관리처',
#   '강덕',
#   '원',
#   '영업',
#   '처',
#   '신기',
#   '정',
#   '전력',
#   '수급',
#   '처장',
#   '이재우',
#   '배전',
#   '계획',
#   '처',
#   '이준호',
#   '운영',
#   '처',
#   '이종환',
#   '상생',
#   '협력',
#   '처',
#   '유현',
#   '호',
#   '민원',
#   '대책',
#   '처',
#   '김준',
#   '식',
#   '기술',
#   '기획',
#   '처',
#   '하',
#   '동혁',
#   '기획',
#   '처',
#   '박장범',
#   '김용배',
#   '품질',
#   '경영',
#   '처',
#   '김',
#   '영성',
#   '계통',
#   '계획',
#   '처',
#   '김',
#   '태',
#   '옥',
#   '송',
#   '변',
#   '전',
#   '건설처',
#   '이정원',
#   '석주',
#   '운영',
#   '처',
#   '김태익',
#   '해외',
#   '사업',
#   '개발',
#   '처',
#   '문',
#   '해외',
#   '발전',
#   '기술처',
#   '이상국',
#   '김',
#   '하',
#   '정보기술',
#   '처',
#   '한상태',
#   '중진',
#   '사업소',
#   '서울',
#   '지역',
#   '본부',
#   '이만근',
#   '김준호',
#   '성동',
#   '전력',
#   '지사',
#   '장',
#   '심',
#   '정운',
#   '남',
#   '서울',
#   '지역',
#   '본부',
#   '정익',
#   '중',
#   '영서',
#   '전력',
#   '지사',
#   '장',
#   '김',
#   '상권',
#   '인천',
#   '지역',
#   '본부',
#   '재흥',
#   '김포',
#   '지사',
#   '장',
#   '허완',
#   '제물포',
#   '강상',
#   '훈',
#   '시흥',
#   '강정호',
#   '강화',
#   '김완',
#   '호',
#   '인천',
#   '전력',
#   '기탁',
#   '경기북부',
#   '지역',
#   '본부',
#   '유호',
#   '탁',
#   '김종화',
#   '포천',
#   '지사',
#   '장',
#   '남',
#   '양평',
#   '채',
#   '준수',
#   '동두천',
#   '장창',
#   '균',
#   '가평',
#   '황',
#   '성훈',
#   '구리',
#   '전력',
#   '권',
#   '영',
#   '경기',
#   '지역',
#   '본부',
#   '신용석',
#   '정치',
#   '교',
#   '서수',
#   '원지',
#   '사장',
#   '전재',
#   '안성',
#   '흥원',
#   '화성',
#   '김',
#   '유화',
#   '광명',
#   '허',
#   '광엽',
#   '평택',
#   '전력',
#   '재형',
#   '강원',
#   '지역',
#   '본부',
#   '윤',
#   '철',
#   '호',
#   '횡성',
#   '지사',
#   '장',
#   '노현',
#   '래',
#   '충북',
#   '지역',
#   '본부',
#   '신영식',
#   '김병헌',
#   '천지',
#   '사장',
#   '임',
#   '찬',
#   '식',
#   '제천',
#   '서재영',
#   '증',
#   '평',
#   '괴산',
#   '남',
#   '상무',
#   '음성',
#   '김용',
#   '훈',
#   '성영',
#   '대전충남',
#   '지역',
#   '본부',
#   '허',
#   '태',
#   '아산',
#   '지사',
#   '장',
#   '김영우',
#   '당진',
#   '김정',
#   '래',
#   '서산',
#   '김홍권',
#   '세종',
#   '최영상',
#   '공주',
#   '김병찬',
#   '예산',
#   '김',
#   '태안',
#   '이재',
#   '중',
#   '홍성',
#   '홍',
#   '선주',
#   '부여',
#   '조원',
#   '장',
#   '금산',
#   '익선',
#   '아산',
#   '전력',
#   '김',
#   '두환',
#   '서산',
#   '전력',
#   '서문',
#   '철',
#   '전북',
#   '지역',
#   '본부',
#   '이태현',
#   '윤상',
#   '천',
#   '박',
#   '종',
#   '명',
#   '남',
#   '전주',
#   '지사',
#   '장',
#   '정',
#   '관영',
#   '고창',
#   '허',
#   '태',
#   '헌',
#   '광주전남',
#   '지역',
#   '본부',
#   '권우',
#   '열',
#   '노',
#   '문',
#   '철',
#   '여수',
#   '지사',
#   '장',
#   '정',
#   '만기',
#   '순천',
#   '권욱',
#   '나주',
#   '박성철',
#   '해남',
#   '고은',
#   '석',
#   '고흥',
#   '노',
#   '상고',
#   '광양',
#   '황',
#   '수환',
#   '영광',
#   '이범익',
#   '순천',
#   '전력',
#   '홍',
#   '봉선',
#   '강진',
#   '전력',
#   '김갑',
#   '덕',
#   '대구경북',
#   '지역',
#   '본부',
#   '진열',
#   '황',
#   '광수',
#   '미지',
#   '사장',
#   '오태석',
#   '포항',
#   '안중',
#   '김천',
#   '김충환',
#   '영천',
#   '김',
#   '강헌',
#   '상주',
#   '김경호',
#   '영주',
#   '최성진',
#   '칠곡',
#   '정상원',
#   '성주',
#   '유',
#   '경종',
#   '의성',
#   '김종희',
#   '예천',
#   '권',
#   '기정',
#   '부산',
#   '울산',
#   '지역',
#   '본부',
#   '이건',
#   '행',
#   '장성',
#   '배',
#   '중부',
#   '산지',
#   '사장',
#   '이병',
#   '곤',
#   '북',
#   '부산',
#   '배',
#   '상달',
#   '울산',
#   '전력',
#   '안',
#   '병고',
#   '부산',
#   '전력',
#   '조성준',
#   '경남',
#   '지역',
#   '본부',
#   '김지현',
#   '마산',
#   '지사',
#   '장',
#   '박무',
#   '흥',
#   '거제',
#   '이명재',
#   '밀양',
#   '이상진',
#   '함안',
#   '김',
#   '영성',
#   '사천',
#   '김근환',
#   '창녕',
#   '정창',
#   '진',
#   '함안',
#   '전력',
#   '이관',
#   '종',
#   '진주',
#   '전력',
#   '강',
#   '승',
#   '배',
#   '제주',
#   '지역',
#   '본부',
#   '김영환',
#   '경인',
#   '건설처',
#   '중구',
#   '최',
#   '유성',
#   '남',
#   '서울',
#   '건설',
#   '지사',
#   '장',
#   '김태용',
#   '경기',
#   '건설',
#   '최준',
#   '식',
#   '중부',
#   '건설처',
#   '송백헌',
#   '충북',
#   '강원',
#   '건설',
#   '지사',
#   '장',
#   '김',
#   '세경',
#   '광주전남',
#   '건설',
#   '김정권',
#   '남부',
#   '건설처',
#   '규',
#   '택',
#   '김양수',
#   '대구경북',
#   '건설',
#   '지사',
#   '장',
#   '양준',
#   '철',
#   '인재',
#   '개발원',
#   '김정환',
#   '교육',
#   '정재완',
#   '전력연구원',
#   '박창용',
#   '자재',
#   '검사',
#   '처장',
#   '설',
#   '규환'],
#  ['한국수자원공사',
#   '상임',
#   '이사',
#   '부사장',
#   '이학수',
#   '경영',
#   '본부장',
#   '김',
#   '병',
#   '하',
#   '수자원',
#   '사업',
#   '차기',
#   '수도',
#   '사업',
#   '이진호'],
#  ['가스',
#   '기술',
#   '공사',
#   '승진',
#   '급',
#   '플랜',
#   '처',
#   '사업',
#   '처',
#   '정해',
#   '복',
#   '신성',
#   '장',
#   '기술',
#   '센터',
#   '이철호',
#   '삼척',
#   '기지',
#   '지사',
#   '조영',
#   '보',
#   '인천',
#   '김상돈',
#   '전북',
#   '김영호',
#   '급',
#   '경영',
#   '기획',
#   '처',
#   '이우재',
#   '총무',
#   '회계',
#   '처',
#   '유진',
#   '설계',
#   '처',
#   '김세윤',
#   '플랜트',
#   '사업',
#   '처',
#   '노',
#   '병',
#   '감',
#   '사실',
#   '이홍열',
#   '평택',
#   '기지',
#   '지사',
#   '이완',
#   '평택',
#   '상환',
#   '인천',
#   '구본화',
#   '충청',
#   '지사',
#   '조현준',
#   '전북',
#   '이국',
#   '진',
#   '대구경북',
#   '전우',
#   '식',
#   '전보',
#   '플랜트',
#   '사업',
#   '단장',
#   '영훈',
#   '총무',
#   '회계',
#   '처장',
#   '이영하',
#   '인사',
#   '노무',
#   '유인',
#   '모',
#   '인재',
#   '육성',
#   '센터',
#   '장',
#   '정종식',
#   '설계',
#   '처장',
#   '이철호',
#   '서울',
#   '지사',
#   '장',
#   '박창순',
#   '경기',
#   '허성',
#   '대',
#   '인천',
#   '우창',
#   '강원',
#   '김상돈',
#   '전북',
#   '영',
#   '광주전남',
#   '김영호',
#   '대구경북',
#   '명',
#   '기현',
#   '부산',
#   '경남',
#   '홍인',
#   '섭',
#   '신성',
#   '장',
#   '기술',
#   '센터',
#   '장',
#   '최형기'],
#  ['가스',
#   '안전',
#   '공사',
#   '기획',
#   '조정실장',
#   '탁',
#   '송수',
#   '인재',
#   '경영',
#   '처장',
#   '김병주',
#   '행정',
#   '지원',
#   '장',
#   '석봉',
#   '홍보실',
#   '장',
#   '문호',
#   '석유화학',
#   '진단',
#   '처장',
#   '노오',
#   '선',
#   '산업',
#   '시설',
#   '영규',
#   '부산',
#   '지역',
#   '본부장',
#   '장',
#   '재경',
#   '인천',
#   '해명',
#   '대전충남',
#   '정환',
#   '규',
#   '강원',
#   '오',
#   '병',
#   '충북',
#   '김한국',
#   '전북',
#   '임호',
#   '석',
#   '서울',
#   '서부',
#   '지사',
#   '장',
#   '문',
#   '석',
#   '서울',
#   '동부',
#   '성',
#   '종규',
#   '부산',
#   '북부',
#   '손',
#   '을',
#   '식',
#   '경북',
#   '동부',
#   '이제관',
#   '전남',
#   '서부',
#   '강',
#   '봉구',
#   '경기',
#   '서부',
#   '오복',
#   '현',
#   '경남',
#   '서부',
#   '정',
#   '원기',
#   '전략',
#   '기획부장',
#   '김',
#   '홍철',
#   '사업',
#   '예산',
#   '임기',
#   '수',
#   '노무',
#   '복지',
#   '심',
#   '이',
#   '섭',
#   '총무',
#   '문',
#   '성',
#   '자산',
#   '관리',
#   '공장',
#   '심사',
#   '추석',
#   '코드',
#   '총괄',
#   '임성근',
#   '전지원',
#   '박성수',
#   '사고',
#   '조사',
#   '조',
#   '완수',
#   '기동',
#   '단속',
#   '김병호',
#   '안전',
#   '기기',
#   '이종국',
#   '제품',
#   '인증',
#   '김현기',
#   '장치',
#   '진단',
#   '박',
#   '원준',
#   '시설',
#   '진단',
#   '이명호',
#   '방식',
#   '진단',
#   '이종',
#   '락',
#   '배관',
#   '진단',
#   '윤영',
#   '굴착',
#   '공사',
#   '정보',
#   '지원',
#   '센터',
#   '장',
#   '형',
#   '원',
#   '중',
#   '교육',
#   '기획부장',
#   '이재용',
#   '기술',
#   '정책',
#   '연구',
#   '허',
#   '윤',
#   '실',
#   '에너지',
#   '안전',
#   '실증',
#   '사업',
#   '단장',
#   '서원석',
#   '방호',
#   '시설',
#   '시험',
#   '부장',
#   '김',
#   '동',
#   '묵',
#   '서울',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '정',
#   '행원',
#   '서울',
#   '서부',
#   '지사',
#   '검사',
#   '부장',
#   '이성희',
#   '서울',
#   '남부',
#   '지사',
#   '방',
#   '효',
#   '중',
#   '서울',
#   '동부',
#   '지사',
#   '문경',
#   '수',
#   '부산',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '김국진',
#   '경북',
#   '북부',
#   '지사',
#   '검사',
#   '부장',
#   '김태일',
#   '인천',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '김',
#   '홍철',
#   '검사',
#   '부장',
#   '이정호',
#   '전남',
#   '동부',
#   '지사',
#   '석유화학',
#   '부장',
#   '손',
#   '근',
#   '대전충남',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '김영섭',
#   '검사',
#   '부장',
#   '정경',
#   '울산',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '이경식',
#   '경기',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '정무',
#   '철',
#   '검사',
#   '부장',
#   '최',
#   '치',
#   '영',
#   '경기북부',
#   '지사',
#   '검사',
#   '부장',
#   '이충',
#   '경',
#   '검사',
#   '부장',
#   '이세정',
#   '경기',
#   '서부',
#   '지사',
#   '한명수',
#   '경기',
#   '동부',
#   '지사',
#   '검사',
#   '부장',
#   '헌',
#   '목',
#   '검사',
#   '부장',
#   '김은정',
#   '경기',
#   '중부',
#   '지사',
#   '김',
#   '유호',
#   '강원',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '최용훈',
#   '강',
#   '원영',
#   '동지사',
#   '검사',
#   '부장',
#   '임',
#   '동주',
#   '전북',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '이영구',
#   '검사',
#   '부장',
#   '박진우',
#   '경남',
#   '지역',
#   '본부',
#   '교육',
#   '홍보',
#   '부장',
#   '태광',
#   '경남',
#   '서부',
#   '지사',
#   '검사',
#   '부장',
#   '강',
#   '대기'],
#  ['한국자산관리공사',
#   '승진',
#   '급',
#   '중소기업인',
#   '지원',
#   '부장',
#   '강남',
#   '석',
#   '자산',
#   '인수',
#   '기획',
#   '신덕',
#   '호',
#   '채권',
#   '인수',
#   '김',
#   '구영',
#   '국유재산',
#   '기획실장',
#   '남',
#   '희지',
#   '교육',
#   '파견',
#   '김',
#   '동어',
#   '진',
#   '효',
#   '림',
#   '급',
#   '감사',
#   '실장',
#   '용호',
#   '종합',
#   '기획부장',
#   '문병',
#   '삼',
#   '인재',
#   '개발원',
#   '관리실장',
#   '근',
#   '영',
#   '국민',
#   '행복',
#   '지원',
#   '부장',
#   '김태수',
#   '투자',
#   '금융',
#   '김',
#   '장권',
#   '공공',
#   '자산',
#   '관리',
#   '박상원',
#   '공공',
#   '자산',
#   '개발',
#   '이치호',
#   '국유',
#   '증권',
#   '실장',
#   '정',
#   '필',
#   '강원',
#   '지역',
#   '본부',
#   '부본부장',
#   '박정희',
#   '서울',
#   '국유재산',
#   '부',
#   '의정부',
#   '지부장',
#   '우',
#   '종',
#   '철',
#   '경남',
#   '지역',
#   '본부',
#   '통영',
#   '조',
#   '철',
#   '강원',
#   '원주',
#   '최용',
#   '종합',
#   '기획부',
#   '배',
#   '원',
#   '섭',
#   '인사부',
#   '태',
#   '동국',
#   '전보',
#   '서민',
#   '금융',
#   '지원',
#   '부장',
#   '권',
#   '남',
#   '주',
#   '서민',
#   '자활',
#   '지원',
#   '문희',
#   '석',
#   '국유재산',
#   '관리',
#   '양기',
#   '영',
#   '서울',
#   '지역',
#   '본부장',
#   '윤효중',
#   '경기',
#   '장성수',
#   '광주전남',
#   '류',
#   '명',
#   '대구경북',
#   '오용',
#   '인천',
#   '신흥',
#   '식',
#   '경남',
#   '문',
#   '영기',
#   '강원',
#   '김',
#   '장래',
#   '충북',
#   '허',
#   '철',
#   '자금',
#   '운용',
#   '실장',
#   '직무',
#   '대행',
#   '박정환',
#   '국유',
#   '건축',
#   '직무',
#   '대행',
#   '조성',
#   '경기',
#   '지역',
#   '본부',
#   '평택',
#   '지부장',
#   '차영',
#   '광주전남',
#   '목포',
#   '김광수',
#   '대구경북',
#   '포항',
#   '경',
#   '래',
#   '강원',
#   '춘천',
#   '김석',
#   '구'],
#  ['무역',
#   '보험',
#   '공사',
#   '승진',
#   '부서장',
#   '급',
#   '조사',
#   '부장',
#   '유승희',
#   '남부',
#   '심사',
#   '실장',
#   '이태희',
#   '팀장',
#   '급',
#   '기금',
#   '예산',
#   '팀장',
#   '김정탁',
#   '전자',
#   '유신',
#   '영업',
#   '지원',
#   '김홍익',
#   '남',
#   '부심',
#   '사실',
#   '책임',
#   '심사',
#   '역',
#   '홍',
#   '종규',
#   '장경영',
#   '반장',
#   '김종직',
#   '전보',
#   '부서장',
#   '급',
#   '전략',
#   '기획부장',
#   '혁',
#   '투자',
#   '금융',
#   '총괄',
#   '김호일',
#   '플랜트',
#   '금융',
#   '류',
#   '동윤',
#   '해외',
#   '투자',
#   '금융',
#   '김필',
#   '리스크',
#   '총괄',
#   '혜성',
#   '영업',
#   '총괄',
#   '김석희',
#   '지사',
#   '장',
#   '손',
#   '지모',
#   '중앙',
#   '박재형',
#   '강남',
#   '한상렬',
#   '충북',
#   '임',
#   '채',
#   '하',
#   '제주',
#   '이학',
#   '록',
#   '팀장',
#   '급',
#   '정보화',
#   '기획',
#   '팀장',
#   '송',
#   '후경',
#   '프로젝트',
#   '기획',
#   '박',
#   '무정',
#   '발전',
#   '담수',
#   '이희',
#   '윤',
#   '중소',
#   '형',
#   '프로젝트',
#   '이종호',
#   '해외',
#   '사업',
#   '김기헌',
#   '미주',
#   '보상',
#   '김경환',
#   '채권',
#   '관리',
#   '기획',
#   '신상',
#   '일',
#   '법제',
#   '김',
#   '평',
#   '감리',
#   '기획',
#   '박성범',
#   '감',
#   '사실',
#   '책임',
#   '검사',
#   '역',
#   '이원석',
#   '특례',
#   '인수',
#   '반장',
#   '최윤',
#   '컨테이너',
#   '팀장',
#   '김영국',
#   '두바이',
#   '지사',
#   '개설',
#   '준비',
#   '위원',
#   '장진',
#   '멕시코시티',
#   '지사',
#   '상봉'],
#  ['전력',
#   '거래소',
#   '시장',
#   '개발',
#   '처장',
#   '김홍근',
#   '주지',
#   '사장',
#   '이건웅',
#   '전력',
#   '경제',
#   '연구실장',
#   '조강',
#   '시장',
#   '감시',
#   '실장',
#   '손',
#   '윤',
#   '태',
#   '경영',
#   '지원',
#   '처',
#   '사옥',
#   '관리',
#   '팀장',
#   '김민',
#   '배',
#   '시장',
#   '개발',
#   '처',
#   '시장',
#   '개발',
#   '김',
#   '중',
#   '정보',
#   '보안',
#   '전략',
#   '실',
#   '비상',
#   '재난',
#   '안전',
#   '팀장',
#   '중선',
#   '정보기술',
#   '처',
#   '정보기술',
#   '팀장',
#   '이진수',
#   '계통',
#   '시스템',
#   '심',
#   '병',
#   '철',
#   '전력',
#   '경제',
#   '연구실',
#   '전력',
#   '경제',
#   '연구부장',
#   '옥',
#   '기여',
#   '중부',
#   '지사',
#   '부장',
#   '이명희'],
#  ['한국소비자원',
#   '승진',
#   '급',
#   '기획',
#   '조정실',
#   '미래',
#   '전략',
#   '팀장',
#   '이정구',
#   '경영',
#   '지원',
#   '실장',
#   '정동영',
#   '빅',
#   '데이터',
#   '사업',
#   '단장',
#   '최은',
#   '실',
#   '시험',
#   '검사국장',
#   '정진',
#   '향',
#   '급',
#   '해구',
#   '제국',
#   '광주',
#   '지원',
#   '장',
#   '이면상',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '팀',
#   '부장',
#   '김종남',
#   '해구',
#   '제국',
#   '운영',
#   '팀',
#   '전재',
#   '범',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '팀',
#   '송',
#   '선덕',
#   '대외',
#   '협력',
#   '팀장',
#   '경태',
#   '해구',
#   '제국',
#   '전지원',
#   '장',
#   '김선화',
#   '기획',
#   '조정실',
#   '기획',
#   '예산',
#   '팀장',
#   '이상훈',
#   '정책',
#   '연구실',
#   '법제',
#   '연구',
#   '팀장',
#   '지',
#   '광석',
#   '시험',
#   '검사',
#   '국',
#   '전기',
#   '전자',
#   '팀장',
#   '양종철',
#   '전보',
#   '부서장',
#   '기획',
#   '조정실장',
#   '문',
#   '성기',
#   '대외',
#   '홍보',
#   '권',
#   '익',
#   '정책',
#   '연구',
#   '이득',
#   '연',
#   '소비자',
#   '정보',
#   '국장',
#   '박',
#   '재구',
#   '소비자',
#   '안전',
#   '국장',
#   '박정',
#   '서울',
#   '지원',
#   '장',
#   '김정',
#   '옥',
#   '경기',
#   '배',
#   '윤',
#   '팀장',
#   '기획',
#   '조정실',
#   '성과',
#   '평가',
#   '팀장',
#   '신국',
#   '범',
#   '경영',
#   '지원',
#   '실',
#   '운영',
#   '지원',
#   '김',
#   '병법',
#   '정보화',
#   '전략',
#   '박',
#   '태학',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '팀장',
#   '최윤선',
#   '기업',
#   '협력',
#   '박',
#   '현주',
#   '정책',
#   '연구실',
#   '소비자',
#   '시장',
#   '연구',
#   '팀장',
#   '황은',
#   '해구',
#   '제국',
#   '피해',
#   '구제',
#   '총괄',
#   '팀장',
#   '윤영',
#   '빈',
#   '의료',
#   '팀장',
#   '김',
#   '경례',
#   '운영',
#   '팀장',
#   '김대중',
#   '시장',
#   '조사국',
#   '거래',
#   '조사',
#   '팀장',
#   '장은',
#   '경',
#   '약관',
#   '광고',
#   '한성준',
#   '국제',
#   '거래',
#   '지원',
#   '팀장',
#   '박두현',
#   '소비자',
#   '권익',
#   '증진',
#   '팀장',
#   '이기헌',
#   '소비자',
#   '정보국',
#   '소비자',
#   '정보',
#   '팀장',
#   '상식',
#   '교육',
#   '기획',
#   '팀장',
#   '이진숙',
#   '서비스',
#   '비교',
#   '팀장',
#   '여',
#   '엽',
#   '소비자',
#   '안전국',
#   '생활',
#   '안전',
#   '팀장',
#   '난',
#   '주',
#   '식',
#   '의약',
#   '안전',
#   '팀',
#   '홍',
#   '배',
#   '안전',
#   '감시',
#   '팀장',
#   '윤경',
#   '천',
#   '시험',
#   '검사',
#   '국',
#   '시험',
#   '기획',
#   '이상호',
#   '식품',
#   '미생물',
#   '정',
#   '현희',
#   '화학',
#   '섬유',
#   '팀장',
#   '은주',
#   '기계',
#   '금속',
#   '이용주',
#   '분쟁',
#   '조정',
#   '사무국',
#   '조정',
#   '팀장',
#   '원',
#   '혜',
#   '조정',
#   '선동',
#   '서울',
#   '지원',
#   '금융',
#   '보험',
#   '팀장',
#   '황기',
#   '서비스',
#   '팀장',
#   '홍인',
#   '수',
#   '섬유',
#   '식품',
#   '팀장',
#   '장인',
#   '영',
#   '경기',
#   '지원',
#   '자동차',
#   '팀장',
#   '김현유',
#   '주택',
#   '공산품',
#   '팀장',
#   '승',
#   '실',
#   '해구',
#   '제국',
#   '부산',
#   '지원',
#   '장',
#   '이경진',
#   '대구',
#   '박',
#   '윤하',
#   '강원',
#   '이선화',
#   '제주',
#   '여행',
#   '소비자',
#   '권익',
#   '증진',
#   '센터',
#   '장',
#   '오',
#   '흥'],
#  ['국립산림과학원',
#   '과장',
#   '급',
#   '연구',
#   '기획',
#   '장',
#   '구교',
#   '산림',
#   '생태',
#   '연구',
#   '김경하',
#   '화학',
#   '미생물',
#   '성숙',
#   '산림생산기술연구소',
#   '장',
#   '성주'],
#  ['한국기계산업진흥회',
#   '상무이사',
#   '승진',
#   '진흥',
#   '본부장',
#   '정경',
#   '수',
#   '기술',
#   '교육원장',
#   '이은',
#   '수 공제',
#   '본부장',
#   '봉',
#   '전'],
#  ['한국전시산업진흥회',
#   '승진',
#   '교육',
#   '홍보',
#   '팀장',
#   '김은희',
#   '전시',
#   '지원',
#   '전보',
#   '경영',
#   '기획',
#   '김용구'],
#  ['한국세라믹기술원',
#   '선임',
#   '본부장',
#   '서원',
#   '선',
#   '에너지',
#   '환경',
#   '소재',
#   '김영희',
#   '전자',
#   '융합',
#   '소재',
#   '황종희',
#   '기업',
#   '지원',
#   '김경자',
#   '이천',
#   '분원',
#   '장',
#   '김형태',
#   '경영',
#   '기획',
#   '본부장',
#   '임태영',
#   '융합',
#   '연구',
#   '사업',
#   '단장',
#   '서원',
#   '선',
#   '에너지',
#   '소재',
#   '센터',
#   '장',
#   '이명현',
#   '에코',
#   '복합',
#   '소재',
#   '추',
#   '식',
#   '전자',
#   '소재',
#   '부품',
#   '정호',
#   '광',
#   '디스플레이',
#   '소재',
#   '나노',
#   '융합',
#   '소재',
#   '효',
#   '순',
#   '기업',
#   '협력',
#   '박',
#   '주석',
#   '분석',
#   '인증',
#   '시뮬레이션',
#   '김현식',
#   '수도권',
#   '시험',
#   '분석',
#   '기업',
#   '지원',
#   '도자',
#   '세라믹',
#   '조우석',
#   '엔지니어링',
#   '세라믹',
#   '이성민',
#   '세라믹',
#   '섬유',
#   '복합',
#   '재',
#   '임',
#   '형',
#   '미',
#   '융합',
#   '바이오',
#   '세라믹',
#   '소재',
#   '장',
#   '정호',
#   '감사',
#   '실장',
#   '현주',
#   '연구',
#   '기획',
#   '김형준',
#   '경영',
#   '지원',
#   '박경원',
#   '전략',
#   '기획',
#   '류',
#   '동수',
#   '연구',
#   '지원',
#   '팀장',
#   '정철',
#   '운영',
#   '지원',
#   '홍',
#   '명식'],
#  ['한국금융연구원',
#   '승진',
#   '연구',
#   '위원',
#   '노',
#   '형식',
#   '보직',
#   '발령',
#   '기획',
#   '협력',
#   '실장',
#   '이명',
#   '활',
#   '은행',
#   '보험',
#   '연구',
#   '서정호',
#   '국제',
#   '금융',
#   '연구',
#   '이윤석',
#   '해외',
#   '금융',
#   '협력',
#   '지원',
#   '센터',
#   '장',
#   '상제'],
#  ['대한건설협회',
#   '전보',
#   '산업',
#   '본부장',
#   '안',
#   '광',
#   '섭',
#   '회원',
#   '서',
#   '만석',
#   '정책',
#   '직무',
#   '대리',
#   '조준현',
#   '정보',
#   '관리실장',
#   '최',
#   '상근',
#   '기술',
#   '정책실장',
#   '최',
#   '균',
#   '시장',
#   '개척',
#   '박승화',
#   '총무',
#   '지원',
#   '직무',
#   '대리',
#   '황',
#   '승현',
#   '파견',
#   '건설',
#   '산업',
#   '사회',
#   '공헌',
#   '재단',
#   '실장',
#   '진장'],
#  ['생명보험협회',
#   '승진',
#   '상무',
#   '보',
#   '대우',
#   '시장',
#   '자율',
#   '관리',
#   '본부장',
#   '김홍',
#   '중',
#   '부서장',
#   '시',
#   '장지원',
#   '부장',
#   '최성',
#   '림',
#   '보험',
#   '범죄',
#   '방지',
#   '실장',
#   '채',
#   '한기',
#   '고령',
#   '화지',
#   '원',
#   '최종윤',
#   '정보',
#   '시스템',
#   '허주',
#   '팀장',
#   '기획부',
#   '대외',
#   '협력',
#   '팀장',
#   '정문',
#   '일',
#   '자율',
#   '관리부',
#   '자격',
#   '관리',
#   '경',
#   '규',
#   '총무',
#   '부',
#   '총무',
#   '경리',
#   '김치',
#   '국',
#   '사회',
#   '공헌',
#   '센터',
#   '시회',
#   '공헌',
#   '재',
#   '정보',
#   '시스템',
#   '실',
#   '정보',
#   '서비스',
#   '여창',
#   '사회',
#   '공헌',
#   '센터',
#   '교육',
#   '김희',
#   '경',
#   '시',
#   '장지원',
#   '부',
#   '채널',
#   '전략',
#   '이주',
#   '학',
#   '전보',
#   '부서장',
#   '감사',
#   '실장',
#   '이재우',
#   '사회',
#   '공헌',
#   '센터',
#   '장',
#   '지',
#   '정훈',
#   '호남',
#   '지역',
#   '본부',
#   '장 현',
#   '순',
#   '영남',
#   '박',
#   '배철',
#   '총무부장',
#   '박병권',
#   '자율',
#   '관리부장',
#   '장승',
#   '록',
#   '수도권',
#   '지역',
#   '본부장',
#   '황영',
#   '팀장',
#   '시',
#   '장지원',
#   '부',
#   '계약',
#   '정보',
#   '지원',
#   '팀장',
#   '홍',
#   '성화',
#   '자율',
#   '관리부',
#   '모집',
#   '질서',
#   '김관철',
#   '원주',
#   '지부장',
#   '민',
#   '병현'],
#  ['플러스',
#   '기획',
#   '경영',
#   '본부',
#   '기획',
#   '센터',
#   '장',
#   '이동',
#   '연',
#   '방송',
#   '본부',
#   '편성',
#   '센터',
#   '장',
#   '김윤주',
#   '방송',
#   '사업',
#   '본부',
#   '제작',
#   '센터',
#   '장',
#   '박성호',
#   '사업',
#   '센터',
#   '장',
#   '김태성',
#   '기획',
#   '경영',
#   '본부',
#   '기획',
#   '센터',
#   '홍보',
#   '마케팅',
#   '팀',
#   '팀장',
#   '재연',
#   '광고',
#   '본부',
#   '광고',
#   '센터',
#   '광고',
#   '전략',
#   '팀',
#   '박',
#   '종',
#   '열',
#   '방송',
#   '사업',
#   '본부',
#   '제작',
#   '센터',
#   '콘텐츠',
#   '팀',
#   '조범',
#   '뮤직',
#   '센터',
#   '뮤직',
#   '사업',
#   '팀',
#   '홍',
#   '윤혁',
#   '사업',
#   '센터',
#   '글로벌',
#   '사업',
#   '팀',
#   '경선',
#   '스포츠',
#   '본부',
#   '스포츠',
#   '센터',
#   '스포츠',
#   '마케팅',
#   '팀',
#   '이상인',
#   '광고',
#   '본부',
#   '광고',
#   '센터',
#   '광고',
#   '팀',
#   '장',
#   '세종',
#   '방송',
#   '사업',
#   '본부',
#   '편성',
#   '센터',
#   '에브리',
#   '원',
#   '뮤직',
#   '편성',
#   '팀',
#   '백',
#   '교',
#   '제작',
#   '센터',
#   '에브리',
#   '원',
#   '제작',
#   '팀',
#   '홍철'],
#  ['중앙일보',
#   '승격',
#   '기자',
#   '직',
#   '부국장',
#   '복지',
#   '전문',
#   '기자',
#   '신성',
#   '식',
#   '부장',
#   '대우',
#   '한경화',
#   '서',
#   '회',
#   '이은주',
#   '강찬호',
#   '정',
#   '제원',
#   '장세정',
#   '봉',
#   '김',
#   '창',
#   '우',
#   '전형',
#   '철',
#   '선임',
#   '디자이너',
#   '최종윤'],
#  ['승격',
#   '기자',
#   '직',
#   '국장',
#   '대우',
#   '이규연',
#   '부국장',
#   '대우',
#   '차',
#   '진용',
#   '부장',
#   '대우',
#   '정',
#   '상경',
#   '이상복',
#   '장기하',
#   '임종',
#   '주',
#   '부국장',
#   '여운',
#   '혁',
#   '경영',
#   '직',
#   '부장',
#   '권',
#   '방지',
#   '현',
#   '석호'],
#  ['중앙미디어네트워크', '승격', '수석', '부장', '안성호', '부장', '이상우'],
#  ['제이',
#   '콘텐트',
#   '리',
#   '승격',
#   '경영',
#   '직',
#   '수석',
#   '부장',
#   '안',
#   '호',
#   '엽',
#   '곽도',
#   '훈',
#   '부장',
#   '유상규',
#   '이경',
#   '문',
#   '박',
#   '현석',
#   '강용',
#   '택',
#   '정',
#   '명동'],
#  ['가천',
#   '대',
#   '외부',
#   '총장',
#   '김충식',
#   '국제',
#   '최',
#   '도성',
#   '대학원장',
#   '강민',
#   '식',
#   '간호',
#   '대학원',
#   '장',
#   '조경숙',
#   '교육',
#   '허',
#   '혜경',
#   '행정',
#   '이희선',
#   '산업',
#   '환경',
#   '박상준',
#   '게임',
#   '황보',
#   '택',
#   '근',
#   '사회과학',
#   '대학',
#   '장',
#   '승현',
#   '바이오나',
#   '노',
#   '강종',
#   '백',
#   '한의',
#   '김연',
#   '섭',
#   '예술',
#   '김',
#   '광구',
#   '가천',
#   '리버럴',
#   '아츠',
#   '칼리지',
#   '이영미',
#   '중앙도서관',
#   '장',
#   '교무',
#   '처장',
#   '박종현',
#   '연구',
#   '윤영수',
#   '대학',
#   '평가',
#   '채',
#   '대외',
#   '협력',
#   '이희성',
#   '국제',
#   '교류',
#   '최경진',
#   '취업',
#   '진로',
#   '한기',
#   '태',
#   '신문',
#   '방송국',
#   '장',
#   '오대',
#   '영'],
#  ['강동', '경희대병원', '의대', '병원장', '정', '호연', '고준', '석'],
#  ['순천향대',
#   '중앙',
#   '의료원',
#   '의무',
#   '부총장',
#   '황',
#   '경호',
#   '중앙',
#   '의료원',
#   '기획',
#   '조정실장',
#   '이정재',
#   '순천향대',
#   '의과대학',
#   '의과대학',
#   '장',
#   '최',
#   '태',
#   '윤',
#   '순천향대',
#   '서울',
#   '병원',
#   '병원장',
#   '서유',
#   '부원',
#   '장',
#   '변동',
#   '원',
#   '순천향대',
#   '부천',
#   '병원',
#   '병원장',
#   '이문',
#   '진료부',
#   '원장',
#   '응',
#   '진',
#   '대외',
#   '협력',
#   '부원',
#   '장',
#   '임',
#   '수재',
#   '순천향대',
#   '안병원',
#   '병원장',
#   '이문수',
#   '부원',
#   '장',
#   '박상',
#   '흠',
#   '순천향대',
#   '구미',
#   '병원',
#   '병원장',
#   '박',
#   '래',
#   '부원',
#   '장',
#   '이태일'],
#  ['하나금융투자',
#   '승진',
#   '부사장',
#   '부문',
#   '장',
#   '진혁',
#   '상무',
#   '실',
#   '담당',
#   '정',
#   '강남',
#   'WM',
#   '센터',
#   '지점장',
#   '이만수',
#   '상무',
#   '보',
#   '영남',
#   '지역',
#   '본부장',
#   '김인규',
#   '분당',
#   '중앙',
#   '지점장',
#   '이성훈',
#   '훼',
#   '미리',
#   '광주',
#   '리테일',
#   '마케팅',
#   '실장',
#   '경식',
#   '채권',
#   '금융',
#   '강순',
#   '국',
#   '이택주',
#   '사보',
#   '잠실',
#   '지점장',
#   '시',
#   '헌',
#   '영업',
#   '부장',
#   '이형',
#   '오',
#   '서',
#   '청주',
#   '지점장',
#   '조창',
#   '묵',
#   '수원',
#   '조시',
#   '연',
#   '미금역',
#   '전',
#   '훈',
#   '신촌',
#   '조일환',
#   '압구정',
#   '장윤석',
#   '실',
#   '김민수',
#   '실',
#   '이희',
#   '철',
#   '선임',
#   '문장',
#   '부문',
#   '장',
#   '전영',
#   '배',
#   '법인',
#   '영업',
#   '조호',
#   '신명호',
#   '본부장',
#   '자본',
#   '시장',
#   '본부장',
#   '이윤형',
#   '충청',
#   '호남',
#   '지역',
#   '윤병구'],
#  ['투자',
#   '증권',
#   '임원',
#   '승진',
#   '전무',
#   '강남',
#   '금융',
#   '센터',
#   '이한',
#   '태',
#   '상무',
#   '비서실',
#   '정영철',
#   '기업',
#   '금융',
#   '센터',
#   '이영재',
#   '상무',
#   '보',
#   '리서치',
#   '센터',
#   '지윤',
#   '기업',
#   '금융',
#   '팀',
#   '대호',
#   '법인',
#   '영업',
#   '팀',
#   '허형',
#   '구조',
#   '금융',
#   '팀',
#   '김대현'],
#  ['KB손해보험',
#   '승진',
#   '전무',
#   '개인',
#   '영업부',
#   '문장',
#   '김강현',
#   '상무',
#   '법인',
#   '영업부',
#   '문장',
#   '박',
#   '희재',
#   '경영',
#   '전략',
#   '본부장',
#   '김대현',
#   '신규',
#   '선임',
#   '상무',
#   '고객',
#   '부문',
#   '장',
#   '영산',
#   '상무',
#   '보',
#   '법인',
#   '영업',
#   '본부장',
#   '남',
#   '상주',
#   '본부장',
#   '개인',
#   '마케팅',
#   '본부장',
#   '이승배',
#   '장기',
#   '보험',
#   '전략',
#   '김재현',
#   '박명',
#   '식',
#   '해외',
#   '사업',
#   '최',
#   '창수',
#   '법인',
#   '영업',
#   '홍건표',
#   '임원',
#   '본부장',
#   '전보',
#   '전략',
#   '영업부',
#   '문장',
#   '전무',
#   '윤경',
#   '수',
#   '다이렉',
#   '부장',
#   '상무',
#   '보',
#   '평로',
#   '박경희',
#   '임원',
#   '실',
#   '조',
#   '흠',
#   '호남',
#   '본부장',
#   '장형'],
#  ['KB투자증권',
#   '임원',
#   '승진',
#   '부사장',
#   '총괄',
#   '김성현',
#   '전무',
#   '기업',
#   '금융',
#   '본부장',
#   '박성원',
#   '상무',
#   '경영',
#   '지원',
#   '본부장',
#   '남',
#   '훈',
#   '신규',
#   '임원',
#   '상무',
#   '기획실장',
#   '정민규',
#   '직원',
#   '승진',
#   '이사',
#   '팀',
#   '이상오',
#   '팀',
#   '민정',
#   '식',
#   '팀',
#   '김민수',
#   '부장',
#   '금융',
#   '상품',
#   '영업',
#   '팀',
#   '권',
#   '태우',
#   '영업',
#   '기획',
#   '팀',
#   '최성필',
#   '스마트',
#   '금융',
#   '팀',
#   '예',
#   '태',
#   '훈',
#   '경영',
#   '관리',
#   '팀',
#   '장동건',
#   '기획',
#   '실',
#   '김현수',
#   '부서장',
#   '보직',
#   '업무',
#   '개발',
#   '팀장',
#   '우경',
#   '민',
#   '증권',
#   '업무',
#   '이순정',
#   '금융',
#   '소비자보호',
#   '황',
#   '창',
#   '식',
#   '스마트',
#   '금융',
#   '예',
#   '태',
#   '훈'],
#  ['헌법재판소',
#   '겸임',
#   '공보관',
#   '배',
#   '보유',
#   '공',
#   '동부',
#   '부장',
#   '연구관',
#   '사관',
#   '승진',
#   '심판',
#   '사무국장',
#   '김성수',
#   '국장',
#   '신임',
#   '정보',
#   '자료',
#   '국장',
#   '황병일',
#   '부이사관',
#   '승진',
#   '헌법재판소',
#   '장',
#   '비서관',
#   '김희',
#   '인사',
#   '관리과장',
#   '김기호',
#   '자료',
#   '총괄',
#   '장',
#   '윤용',
#   '오',
#   '과장',
#   '전보',
#   '기획',
#   '감사',
#   '장',
#   '유식',
#   '심판',
#   '민원',
#   '전',
#   '득',
#   '심판',
#   '사무',
#   '하',
#   '정수',
#   '심판',
#   '제도',
#   '상보',
#   '도서',
#   '정보',
#   '남궁',
#   '황',
#   '파견',
#   '국방',
#   '대',
#   '이성환',
#   '통일교육원',
#   '최준',
#   '수',
#   '과장',
#   '신임',
#   '홍보',
#   '담당관',
#   '이영일',
#   '국제',
#   '협력',
#   '장',
#   '신승훈',
#   '서기관',
#   '전보',
#   '재판관',
#   '비서관',
#   '윤',
#   '성',
#   '진 하',
#   '태',
#   '진',
#   '홍보',
#   '담당관',
#   '실',
#   '이범',
#   '원',
#   '인사',
#   '관리',
#   '정영주',
#   '서기관',
#   '승진',
#   '정보화',
#   '기획',
#   '박민수'],
#  ['법무부',
#   '승진',
#   '급',
#   '법무부',
#   '소년',
#   '윤',
#   '용범',
#   '서울보호관찰소',
#   '관찰',
#   '장',
#   '김기환',
#   '대전보호관찰소',
#   '심',
#   '선',
#   '옥',
#   '서울소년원',
#   '교무',
#   '장',
#   '이용호',
#   '대구소년원',
#   '정',
#   '성수',
#   '대구소년원',
#   '분류',
#   '보호',
#   '장',
#   '이영미',
#   '대전소년원',
#   '박종국',
#   '광주소년원',
#   '교무',
#   '장',
#   '서진',
#   '남',
#   '서울소년분류심사원',
#   '분류',
#   '심사',
#   '김세훈',
#   '전보',
#   '급',
#   '법무부',
#   '국방',
#   '대',
#   '파견',
#   '황',
#   '진규',
#   '서울동부보호관찰소',
#   '장',
#   '정택현',
#   '서울',
#   '남부',
#   '최종',
#   '철',
#   '의정부',
#   '양봉화',
#   '인천보호관찰소',
#   '천지',
#   '소장',
#   '김시',
#   '종',
#   '수원보호관찰소',
#   '안산',
#   '노',
#   '근성',
#   '수원보호관찰소',
#   '천안',
#   '노',
#   '일',
#   '석',
#   '광주소년원',
#   '장',
#   '이영호',
#   '제주',
#   '소년',
#   '유병',
#   '택',
#   '서울소년분류심사원',
#   '안산청소년비행예방센터',
#   '장',
#   '김택수',
#   '대전보호관찰소',
#   '행정',
#   '지원',
#   '장',
#   '홍',
#   '정원',
#   '대구보호관찰소',
#   '배',
#   '종',
#   '부산보호관찰소',
#   '최',
#   '성학',
#   '광주보호관찰소',
#   '이은하',
#   '서울소년원',
#   '손',
#   '세',
#   '헌',
#   '대전소년원',
#   '교무',
#   '장',
#   '이상운',
#   '부산소년원',
#   '박준',
#   '부산소년원',
#   '분류',
#   '보호',
#   '장',
#   '윤',
#   '일',
#   '중',
#   '광주소년원',
#   '김양곤'],
#  ['산림청',
#   '과장',
#   '산불',
#   '방지',
#   '박도',
#   '산사태',
#   '방지',
#   '이용',
#   '산림',
#   '복지',
#   '시설',
#   '사업단',
#   '기획',
#   '황인',
#   '천국',
#   '유림',
#   '관리',
#   '소장',
#   '김만제'],
#  ['문화재',
#   '청',
#   '고위',
#   '공무원',
#   '국립무형유산원',
#   '장',
#   '강경',
#   '과장',
#   '급',
#   '문화',
#   '재활용',
#   '국',
#   '세계유산',
#   '팀장',
#   '남',
#   '범'],
#  ['국립생태원',
#   '지역',
#   '생태',
#   '협력',
#   '단장',
#   '윤',
#   '남',
#   '호',
#   '실장',
#   '창조',
#   '협업',
#   '조정',
#   '임',
#   '순',
#   '호',
#   '협력',
#   '사업',
#   '서',
#   '대수',
#   '경영',
#   '지원',
#   '김태식',
#   '융합',
#   '연구',
#   '서창',
#   '생태',
#   '보전',
#   '연구',
#   '박은진',
#   '생태',
#   '평가',
#   '연구',
#   '차',
#   '진열',
#   '식물',
#   '관리',
#   '연구',
#   '하연',
#   '동물',
#   '관리',
#   '연구',
#   '배',
#   '근',
#   '전시',
#   '교육',
#   '방의석',
#   '감사',
#   '김웅',
#   '호',
#   '관리',
#   '추',
#   '경진',
#   '생태',
#   '기반',
#   '연구',
#   '정길상',
#   '생태',
#   '조사',
#   '연구',
#   '이중효',
#   '부장',
#   '총괄',
#   '조정',
#   '이재덕',
#   '인재',
#   '경영',
#   '김',
#   '창술',
#   '지역',
#   '협력',
#   '나기정',
#   '생태',
#   '협력',
#   '희천',
#   '기획',
#   '진철',
#   '정운용',
#   '김성중',
#   '총무',
#   '임',
#   '주',
#   '흥',
#   '홍보',
#   '양호',
#   '온실',
#   '식물',
#   '주광',
#   '영',
#   '야외',
#   '식물',
#   '윤필용',
#   '동물병원',
#   '김영준',
#   '전시',
#   '교육',
#   '기획',
#   '진규',
#   '전시',
#   '운영',
#   '차',
#   '소란',
#   '교육',
#   '운영',
#   '생태',
#   '지식',
#   '문화',
#   '김웅',
#   '식',
#   '시설',
#   '안전',
#   '박',
#   '술',
#   '현',
#   '동물',
#   '관리',
#   '장',
#   '지덕'],
#  ['한국기계산업진흥회',
#   '상무이사',
#   '진흥',
#   '본부장',
#   '정경',
#   '수 공제',
#   '봉',
#   '전',
#   '기술',
#   '교육원장',
#   '이은수'],
#  ['한국전시산업진흥회',
#   '승진',
#   '교육',
#   '홍보',
#   '팀장',
#   '김은희',
#   '전시',
#   '지원',
#   '전보',
#   '경영',
#   '기획',
#   '팀장',
#   '김용구'],
#  ['한국금융연구원',
#   '승진',
#   '연구',
#   '위원',
#   '노',
#   '형식',
#   '전보',
#   '실장',
#   '기획',
#   '협력',
#   '이명',
#   '활',
#   '은행',
#   '보험',
#   '연구',
#   '서정호',
#   '국제',
#   '금융',
#   '연구',
#   '이윤석',
#   '해외',
#   '금융',
#   '협력',
#   '지원',
#   '센터',
#   '장',
#   '상제'],
#  ['국립산림과학원',
#   '과장',
#   '연구',
#   '기획',
#   '구교',
#   '산림',
#   '생태',
#   '연구',
#   '김경하',
#   '화학',
#   '미생물',
#   '성숙',
#   '산림생산기술연구소',
#   '장',
#   '성주'],
#  ['한국소비자원',
#   '승진',
#   '급',
#   '기획',
#   '조정실',
#   '미래',
#   '전략',
#   '팀장',
#   '이정구',
#   '경영',
#   '지원',
#   '실장',
#   '정동영',
#   '빅',
#   '데이터',
#   '사업',
#   '단장',
#   '최은',
#   '실',
#   '시험',
#   '검사국장',
#   '정진',
#   '향',
#   '급',
#   '해구',
#   '제국',
#   '광주',
#   '지원',
#   '장',
#   '이면상',
#   '대전',
#   '김선화',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '팀',
#   '부장',
#   '김종남',
#   '송',
#   '선덕',
#   '해구',
#   '제국',
#   '운영',
#   '팀',
#   '전재',
#   '범',
#   '대외',
#   '홍보실',
#   '대외',
#   '협력',
#   '팀장',
#   '경태',
#   '기획',
#   '조정실',
#   '기획',
#   '예산',
#   '이상훈',
#   '정책',
#   '연구실',
#   '법제',
#   '연구',
#   '지',
#   '광석',
#   '시험',
#   '검사',
#   '국',
#   '전기',
#   '전자',
#   '양종철',
#   '전보',
#   '부서장',
#   '기획',
#   '조정실장',
#   '문',
#   '성기',
#   '대외',
#   '홍보',
#   '권',
#   '익',
#   '정책',
#   '연구',
#   '이득',
#   '연',
#   '소비자',
#   '정보',
#   '국장',
#   '박',
#   '재구',
#   '소비자',
#   '안전',
#   '박정',
#   '서울',
#   '지원',
#   '장',
#   '김정',
#   '옥',
#   '경기',
#   '배',
#   '윤',
#   '팀장',
#   '기획',
#   '조정실',
#   '성과',
#   '평가',
#   '신국',
#   '범',
#   '경영',
#   '지원',
#   '실',
#   '운영',
#   '지원',
#   '김',
#   '병법',
#   '정보화',
#   '전략',
#   '박',
#   '태학',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '최윤선',
#   '기업',
#   '협력',
#   '박',
#   '현주',
#   '정책',
#   '연구실',
#   '소비자',
#   '시장',
#   '연구',
#   '황은',
#   '해구',
#   '제국',
#   '피해',
#   '구제',
#   '총괄',
#   '윤영',
#   '빈',
#   '의료',
#   '김',
#   '경례',
#   '운영',
#   '김대중',
#   '시장',
#   '조사국',
#   '거래',
#   '조사',
#   '장은',
#   '경',
#   '약관',
#   '광고',
#   '한성준',
#   '국제',
#   '거래',
#   '지원',
#   '박두현',
#   '소비자',
#   '권익',
#   '증진',
#   '이기헌',
#   '소비자',
#   '정보국',
#   '소비자',
#   '정보',
#   '상식',
#   '교육',
#   '기획',
#   '이진숙',
#   '서비스',
#   '비교',
#   '여',
#   '엽',
#   '소비자',
#   '안전국',
#   '생활',
#   '안전',
#   '난',
#   '주',
#   '식',
#   '의약',
#   '안전',
#   '팀',
#   '홍',
#   '배',
#   '안전',
#   '감시',
#   '윤경',
#   '천',
#   '시험',
#   '검사',
#   '국',
#   '시험',
#   '기획',
#   '이상호',
#   '식품',
#   '미생물',
#   '정',
#   '현희',
#   '화학',
#   '섬유',
#   '은주',
#   '기계',
#   '금속',
#   '이용주',
#   '분쟁',
#   '조정',
#   '사무국',
#   '조정',
#   '원',
#   '혜',
#   '조정',
#   '선동',
#   '서울',
#   '지원',
#   '금융',
#   '보험',
#   '황기',
#   '서비스',
#   '홍인',
#   '수',
#   '섬유',
#   '식품',
#   '장인',
#   '영',
#   '경기',
#   '지원',
#   '자동차',
#   '김현유',
#   '주택',
#   '공산품',
#   '승',
#   '실',
#   '해구',
#   '제국',
#   '부산',
#   '지원',
#   '장',
#   '이경진',
#   '대구',
#   '박',
#   '윤하',
#   '강원',
#   '이선화',
#   '제주',
#   '여행',
#   '소비자',
#   '권익',
#   '증진',
#   '센터',
#   '장',
#   '오',
#   '흥'],
#  ['한국세라믹기술원',
#   '본부장',
#   '선임',
#   '서원',
#   '선',
#   '에너지',
#   '환경',
#   '소재',
#   '김영희',
#   '전자',
#   '융합',
#   '소재',
#   '황종희',
#   '기업',
#   '지원',
#   '김경자',
#   '경영',
#   '기획',
#   '임태영',
#   '이천',
#   '분원',
#   '장',
#   '김형태',
#   '융합',
#   '연구',
#   '사업',
#   '단장',
#   '서원',
#   '선',
#   '센터',
#   '장',
#   '에너지',
#   '소재',
#   '이명현',
#   '에코',
#   '복합',
#   '소재',
#   '추',
#   '식',
#   '전자',
#   '소재',
#   '부품',
#   '정호',
#   '광',
#   '디스플레이',
#   '소재',
#   '나노',
#   '융합',
#   '소재',
#   '효',
#   '순',
#   '기업',
#   '협력',
#   '박',
#   '주석',
#   '분석',
#   '인증',
#   '시뮬레이션',
#   '김현식',
#   '수도권',
#   '시험',
#   '분석',
#   '기업',
#   '지원',
#   '도자',
#   '세라믹',
#   '조우석',
#   '엔지니어링',
#   '세라믹',
#   '이성민',
#   '세라믹',
#   '섬유',
#   '복합',
#   '재',
#   '임',
#   '형',
#   '미',
#   '융합',
#   '바이오',
#   '세라믹',
#   '소재',
#   '장',
#   '정호',
#   '실장',
#   '감사',
#   '현주',
#   '연구',
#   '기획',
#   '김형준',
#   '경영',
#   '지원',
#   '박경원',
#   '전략',
#   '기획',
#   '류',
#   '동수',
#   '연구',
#   '지원',
#   '팀장',
#   '정철',
#   '운영',
#   '지원',
#   '홍',
#   '명식'],
#  ['가스',
#   '안전',
#   '공사',
#   '전보',
#   '기획',
#   '조정실장',
#   '탁',
#   '송수',
#   '홍보',
#   '문호',
#   '처장',
#   '인재',
#   '경영',
#   '김병주',
#   '행정',
#   '지원',
#   '장',
#   '석봉',
#   '석유화학',
#   '진단',
#   '노오',
#   '선',
#   '산업',
#   '시설',
#   '진단',
#   '영규',
#   '지역',
#   '본부장',
#   '부산',
#   '장',
#   '재경',
#   '인천',
#   '해명',
#   '대전충남',
#   '정환',
#   '규',
#   '강원',
#   '오',
#   '병',
#   '충북',
#   '김한국',
#   '전북',
#   '임호',
#   '석',
#   '지사장',
#   '서울',
#   '서부',
#   '문',
#   '석',
#   '서울',
#   '동부',
#   '성',
#   '종규',
#   '부산',
#   '북부',
#   '손',
#   '을',
#   '식',
#   '경북',
#   '동부',
#   '이제관',
#   '전남',
#   '서부',
#   '강',
#   '봉구',
#   '경기',
#   '서부',
#   '오복',
#   '현',
#   '경남',
#   '서부',
#   '정',
#   '원기',
#   '부장',
#   '전략',
#   '기획',
#   '김',
#   '홍철',
#   '사업',
#   '예산',
#   '임기',
#   '수',
#   '노무',
#   '복지',
#   '심',
#   '이',
#   '섭',
#   '총무',
#   '문',
#   '성',
#   '자산',
#   '관리',
#   '공장',
#   '심사',
#   '추석',
#   '코드',
#   '총괄',
#   '임성근',
#   '전지원',
#   '박성수',
#   '사고',
#   '조사',
#   '조',
#   '완수',
#   '기동',
#   '단속',
#   '김병호',
#   '안전',
#   '기기',
#   '이종국',
#   '제품',
#   '인증',
#   '김현기',
#   '장치',
#   '진단',
#   '박',
#   '원준',
#   '시설',
#   '진단',
#   '이명호',
#   '방식',
#   '진단',
#   '이종',
#   '락',
#   '배관',
#   '진단',
#   '윤영',
#   '교육',
#   '기획',
#   '이재용',
#   '기술',
#   '정책',
#   '연구',
#   '허',
#   '윤',
#   '실',
#   '방호',
#   '시설',
#   '시험',
#   '김',
#   '동',
#   '묵',
#   '서울',
#   '지역',
#   '본부',
#   '검사',
#   '정',
#   '행원',
#   '서울',
#   '서부',
#   '지사',
#   '검사',
#   '이성희',
#   '서울',
#   '남부',
#   '지사',
#   '검사',
#   '방',
#   '효',
#   '중',
#   '서울',
#   '동부',
#   '지사',
#   '검사',
#   '문경',
#   '수',
#   '부산',
#   '지역',
#   '본부',
#   '검사',
#   '김국진',
#   '경북',
#   '북부',
#   '지사',
#   '검사',
#   '김태일',
#   '인천',
#   '지역',
#   '본부',
#   '검사',
#   '김',
#   '홍철',
#   '검사',
#   '이정호',
#   '전남',
#   '동부',
#   '지사',
#   '석유화학',
#   '손',
#   '근',
#   '대전충남',
#   '지역',
#   '본부',
#   '검사',
#   '김영섭',
#   '검사',
#   '정경',
#   '울산',
#   '지역',
#   '본부',
#   '검사',
#   '이경식',
#   '경기',
#   '지역',
#   '본부',
#   '검사',
#   '정무',
#   '철',
#   '검사',
#   '최',
#   '치',
#   '영',
#   '경기북부',
#   '지사',
#   '검사',
#   '이충',
#   '경',
#   '검사',
#   '이세정',
#   '경기',
#   '서부',
#   '지사',
#   '검사',
#   '한명수',
#   '경기',
#   '동부',
#   '지사',
#   '검사',
#   '헌',
#   '목',
#   '검사',
#   '김은정',
#   '경기',
#   '중부',
#   '지사',
#   '검사',
#   '김',
#   '유호',
#   '강원',
#   '지역',
#   '본부',
#   '검사',
#   '최용훈',
#   '강',
#   '원영',
#   '동지사',
#   '검사',
#   '임',
#   '동주',
#   '전북',
#   '지역',
#   '본부',
#   '검사',
#   '이영구',
#   '검사',
#   '박진우',
#   '경남',
#   '지역',
#   '본부',
#   '교육',
#   '홍보',
#   '태광',
#   '경남',
#   '서부',
#   '지사',
#   '검사',
#   '강',
#   '대기',
#   '굴착',
#   '공사',
#   '정보',
#   '지원',
#   '센터',
#   '장',
#   '형',
#   '원',
#   '중',
#   '에너지',
#   '안전',
#   '실증',
#   '사업',
#   '단장',
#   '서원석'],
#  ['무역',
#   '보험',
#   '공사',
#   '승진',
#   '부서장',
#   '급',
#   '조사',
#   '부장',
#   '유승희',
#   '남부',
#   '심사',
#   '실장',
#   '이태희',
#   '팀장',
#   '급',
#   '기금',
#   '예산',
#   '팀장',
#   '김정탁',
#   '전자',
#   '유신',
#   '영업',
#   '지원',
#   '김홍익',
#   '남',
#   '부심',
#   '사실',
#   '책임',
#   '심사',
#   '역',
#   '홍',
#   '종규',
#   '장경영',
#   '반장',
#   '김종직',
#   '전보',
#   '부서장',
#   '급',
#   '전략',
#   '기획부장',
#   '혁',
#   '투자',
#   '금융',
#   '총괄',
#   '김호일',
#   '플랜트',
#   '금융',
#   '류',
#   '동윤',
#   '해외',
#   '투자',
#   '금융',
#   '김필',
#   '리스크',
#   '총괄',
#   '혜성',
#   '영업',
#   '총괄',
#   '김석희',
#   '지사',
#   '장',
#   '손',
#   '지모',
#   '중앙',
#   '박재형',
#   '강남',
#   '한상렬',
#   '충북',
#   '임',
#   '채',
#   '하',
#   '제주',
#   '이학',
#   '록',
#   '팀장',
#   '급',
#   '정보화',
#   '기획',
#   '팀장',
#   '송',
#   '후경',
#   '프로젝트',
#   '기획',
#   '박',
#   '무정',
#   '발전',
#   '담수',
#   '이희',
#   '윤',
#   '중소',
#   '형',
#   '프로젝트',
#   '이종호',
#   '해외',
#   '사업',
#   '김기헌',
#   '미주',
#   '보상',
#   '김경환',
#   '채권',
#   '관리',
#   '기획',
#   '신상',
#   '일',
#   '법제',
#   '김',
#   '평',
#   '감리',
#   '기획',
#   '박성범',
#   '컨테이너',
#   '김영국',
#   '감',
#   '사실',
#   '책임',
#   '검사',
#   '역',
#   '이원석',
#   '특례',
#   '인수',
#   '반장',
#   '최윤',
#   '두바이',
#   '지사',
#   '개설',
#   '준비',
#   '위원',
#   '장진',
#   '멕시코시티',
#   '지사',
#   '상봉'],
#  ['한국전력',
#   '본사',
#   '감',
#   '사실',
#   '최병우',
#   '홍보실',
#   '조기',
#   '에너지',
#   '사업단',
#   '안',
#   '규',
#   '선',
#   '임',
#   '낙',
#   '송',
#   '기획',
#   '처',
#   '이경숙',
#   '전력',
#   '시장',
#   '처',
#   '선호',
#   '경영',
#   '개선',
#   '처',
#   '정복',
#   '상귀',
#   '재무',
#   '처',
#   '장호',
#   '파견',
#   '조성',
#   '노무',
#   '처',
#   '박형',
#   '자재',
#   '처',
#   '이종우',
#   '자산',
#   '관리처',
#   '강덕',
#   '원',
#   '영업',
#   '처',
#   '신기',
#   '정',
#   '전력',
#   '수급',
#   '처장',
#   '이재우',
#   '배전',
#   '계획',
#   '처',
#   '이준호',
#   '배전',
#   '운영',
#   '처',
#   '이종환',
#   '상생',
#   '협력',
#   '처',
#   '유현',
#   '호',
#   '민원',
#   '대책',
#   '처',
#   '김준',
#   '식',
#   '기술',
#   '기획',
#   '처',
#   '하',
#   '동혁',
#   '기획',
#   '처',
#   '박장범',
#   '김용배',
#   '품질',
#   '경영',
#   '처',
#   '김',
#   '영성',
#   '계통',
#   '계획',
#   '처',
#   '김',
#   '태',
#   '옥',
#   '송',
#   '변',
#   '전',
#   '건설처',
#   '이정원',
#   '석주',
#   '송',
#   '변',
#   '전',
#   '운영',
#   '처',
#   '김태익',
#   '해외',
#   '사업',
#   '개발',
#   '처',
#   '문',
#   '해외',
#   '발전',
#   '기술처',
#   '이상국',
#   '김',
#   '하',
#   '정보기술',
#   '처',
#   '한상태',
#   '중진',
#   '사업소',
#   '서울',
#   '지역',
#   '본부',
#   '이만근',
#   '김준호',
#   '성동',
#   '전력',
#   '지사',
#   '장',
#   '심',
#   '정운',
#   '남',
#   '서울',
#   '지역',
#   '본부',
#   '정익',
#   '중',
#   '영서',
#   '전력',
#   '지사',
#   '장',
#   '김',
#   '상권',
#   '인천',
#   '지역',
#   '본부',
#   '재흥',
#   '김포',
#   '지사',
#   '장',
#   '허완',
#   '제물포',
#   '강상',
#   '훈',
#   '시흥',
#   '강정호',
#   '강화',
#   '김완',
#   '호',
#   '인천',
#   '전력',
#   '기탁',
#   '경기북부',
#   '지역',
#   '본부',
#   '유호',
#   '탁',
#   '김종화',
#   '포천',
#   '지사',
#   '장',
#   '남',
#   '양평',
#   '채',
#   '준수',
#   '동두천',
#   '장창',
#   '균',
#   '가평',
#   '황',
#   '성훈',
#   '구리',
#   '전력',
#   '권',
#   '영',
#   '경기',
#   '지역',
#   '본부',
#   '신용석',
#   '정치',
#   '교',
#   '서수',
#   '원지',
#   '사장',
#   '전재',
#   '안성',
#   '흥원',
#   '화성',
#   '김',
#   '유화',
#   '광명',
#   '허',
#   '광엽',
#   '평택',
#   '전력',
#   '재형',
#   '강원',
#   '지역',
#   '본부',
#   '윤',
#   '철',
#   '호',
#   '횡성',
#   '노현',
#   '래',
#   '충북',
#   '지역',
#   '본부',
#   '신영식',
#   '김병헌',
#   '천지',
#   '사장',
#   '임',
#   '찬',
#   '식',
#   '제천',
#   '서재영',
#   '증',
#   '평',
#   '괴산',
#   '남',
#   '상무',
#   '음성',
#   '김용',
#   '훈',
#   '성영',
#   '대전충남',
#   '지역',
#   '본부',
#   '허',
#   '태',
#   '아산',
#   '지사',
#   '장',
#   '김영우',
#   '당진',
#   '김정',
#   '래',
#   '서산',
#   '김홍권',
#   '세종',
#   '최영상',
#   '공주',
#   '김병찬',
#   '예산',
#   '김',
#   '태안',
#   '이재',
#   '중',
#   '홍성',
#   '홍',
#   '선주',
#   '부여',
#   '조원',
#   '장',
#   '금산',
#   '익선',
#   '아산',
#   '전력',
#   '김',
#   '두환',
#   '서산',
#   '전력',
#   '서문',
#   '철',
#   '전북',
#   '지역',
#   '본부',
#   '이태현',
#   '윤상',
#   '천',
#   '박',
#   '종',
#   '명',
#   '남',
#   '전주',
#   '정',
#   '관영',
#   '고창',
#   '허',
#   '태',
#   '헌',
#   '광주전남',
#   '지역',
#   '본부',
#   '권우',
#   '열',
#   '노',
#   '문',
#   '철',
#   '여수',
#   '지사',
#   '장',
#   '정',
#   '만기',
#   '순천',
#   '권욱',
#   '나주',
#   '박성철',
#   '해남',
#   '고은',
#   '석',
#   '고흥',
#   '노',
#   '상고',
#   '광양',
#   '황',
#   '수환',
#   '영광',
#   '이범익',
#   '순천',
#   '전력',
#   '홍',
#   '봉선',
#   '강진',
#   '전력',
#   '김갑',
#   '덕',
#   '대구경북',
#   '지역',
#   '본부',
#   '진열',
#   '황',
#   '광수',
#   '미지',
#   '사장',
#   '오태석',
#   '포항',
#   '안중',
#   '김천',
#   '김충환',
#   '영천',
#   '김',
#   '강헌',
#   '상주',
#   '김경호',
#   '영주',
#   '최성진',
#   '칠곡',
#   '정상원',
#   '성주',
#   '유',
#   '경종',
#   '의성',
#   '김종희',
#   '예천',
#   '권',
#   '기정',
#   '부산',
#   '울산',
#   '지역',
#   '본부',
#   '이건',
#   '행',
#   '장성',
#   '배',
#   '중부',
#   '산지',
#   '사장',
#   '이병',
#   '곤',
#   '북',
#   '부산',
#   '배',
#   '상달',
#   '울산',
#   '전력',
#   '지사',
#   '장',
#   '안',
#   '병고',
#   '부산',
#   '전력',
#   '조성준',
#   '경남',
#   '지역',
#   '본부',
#   '김지현',
#   '마산',
#   '지사',
#   '장',
#   '박무',
#   '흥',
#   '거제',
#   '이명재',
#   '밀양',
#   '이상진',
#   '함안',
#   '김',
#   '영성',
#   '사천',
#   '김근환',
#   '창녕',
#   '정창',
#   '진',
#   '함안',
#   '전력',
#   '이관',
#   '종',
#   '진주',
#   '전력',
#   '강',
#   '승',
#   '배',
#   '제주',
#   '지역',
#   '본부',
#   '김영환',
#   '경인',
#   '건설처',
#   '중구',
#   '최',
#   '유성',
#   '남',
#   '서울',
#   '건설',
#   '지사',
#   '장',
#   '김태용',
#   '경기',
#   '건설',
#   '최준',
#   '식',
#   '중부',
#   '건설처',
#   '송백헌',
#   '충북',
#   '강원',
#   '건설',
#   '지사',
#   '장',
#   '김',
#   '세경',
#   '광주전남',
#   '건설',
#   '김정권',
#   '남부',
#   '건설처',
#   '규',
#   '택',
#   '김양수',
#   '대구경북',
#   '건설',
#   '지사',
#   '장',
#   '양준',
#   '철',
#   '인재',
#   '개발원',
#   '김정환',
#   '인재',
#   '개발원',
#   '교육',
#   '정재완',
#   '전력연구원',
#   '박창용',
#   '자재',
#   '검사',
#   '처장',
#   '설',
#   '규환'],
#  ['전력',
#   '거래소',
#   '전보',
#   '시장',
#   '개발',
#   '처장',
#   '김홍근',
#   '주지',
#   '사장',
#   '이건웅',
#   '전력',
#   '경제',
#   '연구실장',
#   '조강',
#   '시장',
#   '감시',
#   '손',
#   '윤',
#   '태',
#   '팀장',
#   '경영',
#   '지원',
#   '처',
#   '사옥',
#   '관리',
#   '김민',
#   '배',
#   '시장',
#   '개발',
#   '처',
#   '시장',
#   '개발',
#   '김',
#   '중',
#   '정보',
#   '보안',
#   '전략',
#   '실',
#   '비상',
#   '재난',
#   '안전',
#   '중선',
#   '정보기술',
#   '처',
#   '정보기술',
#   '이진수',
#   '계통',
#   '시스템',
#   '심',
#   '병',
#   '철',
#   '전력',
#   '경제',
#   '연구실',
#   '전력',
#   '경제',
#   '연구부장',
#   '옥',
#   '기여',
#   '중부',
#   '지사',
#   '이명희'],
#  ['상임',
#   '이사',
#   '부사장',
#   '이학수',
#   '경영',
#   '본부장',
#   '김',
#   '병',
#   '하',
#   '수자원',
#   '사업',
#   '차기',
#   '수도',
#   '사업',
#   '이진호'],
#  ['경북', '본부장', '이성원', '보도국장', '박', '석현', '동부', '방송', '센터', '장', '박', '석'],
#  ['환경TV',
#   '보도',
#   '제작국',
#   '국장',
#   '유재',
#   '뉴스',
#   '팀장',
#   '신준섭',
#   '뉴',
#   '콘텐츠',
#   '국',
#   '국장',
#   '홍',
#   '종',
#   '선',
#   '뉴',
#   '콘텐츠',
#   '팀장',
#   '정순영',
#   '경',
#   '영기획',
#   '실',
#   '경영',
#   '기획실장',
#   '겸',
#   '사업',
#   '국장',
#   '김영',
#   '보'],
#  ['가천',
#   '대',
#   '외부',
#   '총장',
#   '김충식',
#   '국제',
#   '최',
#   '도성',
#   '원장',
#   '대학',
#   '강민',
#   '식',
#   '간호',
#   '대학',
#   '조경숙',
#   '교육',
#   '대학',
#   '허',
#   '혜경',
#   '행정',
#   '대학',
#   '이희선',
#   '산업',
#   '환경',
#   '대학',
#   '박상준',
#   '게임',
#   '대학',
#   '황보',
#   '택',
#   '근',
#   '학장',
#   '사회과학',
#   '대',
#   '승현',
#   '바이오나',
#   '노',
#   '대',
#   '강종',
#   '백',
#   '의과',
#   '김연',
#   '섭',
#   '예술대',
#   '김',
#   '광구',
#   '가천',
#   '리버럴',
#   '아츠',
#   '칼리지',
#   '대',
#   '이영미',
#   '중앙도서관',
#   '장',
#   '처장',
#   '교무',
#   '박종현',
#   '연구',
#   '윤영수',
#   '대학',
#   '평가',
#   '채',
#   '대외',
#   '협력',
#   '이희성',
#   '국제',
#   '교류',
#   '최경진',
#   '취업',
#   '진로',
#   '한기',
#   '태'],
#  ['경상대', '학장', '법과', '김', '태', '수의', '대', '민원기', '해양', '학대', '김정균'],
#  ['금융',
#   '지주',
#   '승진',
#   '상무',
#   '감',
#   '사실',
#   '이후',
#   '승',
#   '전보',
#   '부장',
#   '글로벌',
#   '전략',
#   '팀',
#   '성기',
#   '정',
#   '전략',
#   '기획',
#   '팀',
#   '선종',
#   '경영',
#   '지원',
#   '팀',
#   '이준혁'],
#  ['KEB하나은행',
#   '승진',
#   '부행장',
#   '자산',
#   '관리',
#   '그룹',
#   '박종영',
#   '글로벌',
#   '사업',
#   '그룹',
#   '유제',
#   '봉',
#   '기업',
#   '고객',
#   '지원',
#   '그룹',
#   '윤규',
#   '선',
#   '영남',
#   '영업',
#   '그룹',
#   '윤석희',
#   '경영',
#   '지원',
#   '그룹',
#   '황',
#   '인산',
#   '전무',
#   '영업',
#   '지원',
#   '그룹',
#   '강성',
#   '묵',
#   '자금시장',
#   '그룹',
#   '강',
#   '창',
#   '훈',
#   '통합',
#   '지원단',
#   '김재영',
#   '변화',
#   '추진',
#   '대외',
#   '협력',
#   '본부',
#   '안영근',
#   '리테일',
#   '사업',
#   '본부',
#   '이형',
#   '일 강',
#   '남',
#   '서초',
#   '영업',
#   '본부',
#   '이호성',
#   '부산',
#   '영업',
#   '본부',
#   '정',
#   '식',
#   '리스크',
#   '관리',
#   '그룹',
#   '황',
#   '효',
#   '본부장',
#   '충남',
#   '영업',
#   '본부',
#   '강',
#   '태희',
#   '외환',
#   '본부',
#   '김선규',
#   '사업',
#   '본부',
#   '김성',
#   '엽',
#   '세종',
#   '충북',
#   '영업',
#   '본부',
#   '김인석',
#   '부산',
#   '울산',
#   '영업',
#   '본부',
#   '김화',
#   '식',
#   '제주',
#   '영업',
#   '본부',
#   '문상',
#   '구로',
#   '영업',
#   '본부',
#   '박',
#   '세거',
#   '인천',
#   '영업',
#   '본부',
#   '박',
#   '수',
#   '영업',
#   '지원',
#   '본부',
#   '박종진',
#   '송파',
#   '영업',
#   '본부',
#   '박하',
#   '고객',
#   '보호',
#   '본부',
#   '백미',
#   '경',
#   '강서',
#   '영업',
#   '본부',
#   '성',
#   '만용',
#   '부천',
#   '안양',
#   '영업',
#   '본부',
#   '송',
#   '여',
#   '익',
#   '본부',
#   '태',
#   '균',
#   '글로벌',
#   '사업',
#   '그룹',
#   '소속',
#   '윤규',
#   '섭',
#   '대전',
#   '영업',
#   '본부',
#   '겸',
#   '충청',
#   '정책',
#   '지',
#   '원부',
#   '윤순',
#   '미래',
#   '금융',
#   '본부',
#   '이병렬',
#   '글로벌',
#   '사업',
#   '그룹',
#   '소속',
#   '이상용',
#   '경',
#   '영기획',
#   '그룹',
#   '이승열',
#   '수원',
#   '안산',
#   '영업',
#   '본부',
#   '정석화',
#   '전보',
#   '부행장',
#   '리테일',
#   '고객',
#   '지원',
#   '그룹',
#   '김정기',
#   '본부장',
#   '글로벌',
#   '사업',
#   '그룹',
#   '소속',
#   '강용',
#   '득',
#   '연금',
#   '사업',
#   '본부',
#   '박병규',
#   '업무',
#   '지원',
#   '본부',
#   '서',
#   '병',
#   '용산',
#   '마포',
#   '영업',
#   '본부',
#   '이선화',
#   '자금',
#   '운용',
#   '본부',
#   '이정욱',
#   '신탁',
#   '본부',
#   '이진형',
#   '검사실장',
#   '조성',
#   '남',
#   '부장',
#   '커뮤니케이션',
#   '부',
#   '김재화',
#   '홍보',
#   '부',
#   '김호',
#   '사회',
#   '공헌',
#   '문화부',
#   '정지연'],
#  ['KB국민카드',
#   '승진',
#   '전무',
#   '미래',
#   '사업',
#   '본부',
#   '정성호',
#   '선임',
#   '상무',
#   '리스크',
#   '관리',
#   '본부',
#   '한동욱',
#   '지원',
#   '본부',
#   '이인호',
#   '본부',
#   '김영찬',
#   '전보',
#   '상무',
#   '전략',
#   '영업',
#   '본부',
#   '재흥',
#   '정보',
#   '보호',
#   '본부',
#   '이철규'],
#  ['하나카드',
#   '승진',
#   '리스크',
#   '관리',
#   '본부',
#   '본부장',
#   '태',
#   '복',
#   '전보',
#   '고객',
#   '관리',
#   '본부',
#   '본부장',
#   '손',
#   '창',
#   '석',
#   '경영',
#   '전략',
#   '본부',
#   '송',
#   '종',
#   '근'],
#  ['생명',
#   '선임',
#   '본부장',
#   '전략',
#   '사업',
#   '이종문',
#   '경영',
#   '기획',
#   '오기',
#   '홍',
#   '고객',
#   '지원',
#   '김대중',
#   '전보',
#   '본부장',
#   '사업',
#   '김세민',
#   '사업',
#   '이병용',
#   '영업',
#   '지원',
#   '유재'],
#  ['동부증권',
#   '승진',
#   '임원',
#   '재경',
#   '지역',
#   '본부',
#   '상무',
#   '김',
#   '우상',
#   '기획',
#   '관리',
#   '팀',
#   '홍헌표',
#   '사업',
#   '부장',
#   '직무',
#   '대리',
#   '강성욱',
#   '준법',
#   '감시인',
#   '서',
#   '배수',
#   '충청',
#   '호남',
#   '지역',
#   '본부장',
#   '이병진',
#   '법인',
#   '영업',
#   '팀장',
#   '이동규',
#   '창원',
#   '지점장',
#   '전성욱',
#   '부산',
#   '위성',
#   '대전',
#   '김창호',
#   '전보',
#   '영업',
#   '부장',
#   '서',
#   '중',
#   '영',
#   '을지로',
#   '금융',
#   '센터',
#   '장',
#   '김성수',
#   '강남',
#   '금융',
#   '최성호',
#   '서초',
#   '지점장',
#   '진영',
#   '용산',
#   '신승',
#   '천안',
#   '이상용'],
#  ['현대증권',
#   '임원',
#   '경영',
#   '관리부',
#   '문장',
#   '성대',
#   '본부장',
#   '서일',
#   '영',
#   '채권',
#   '이병희',
#   '부서장',
#   '대체',
#   '투자',
#   '실',
#   '안',
#   '효',
#   '재',
#   '부동산',
#   '금융',
#   '실장',
#   '박연',
#   '규',
#   '법무',
#   '조용원',
#   '인수',
#   '금융',
#   '양현종',
#   '인재',
#   '개발',
#   '부장',
#   '김건우',
#   '정보',
#   '시스템',
#   '정',
#   '유동',
#   '전구',
#   '택',
#   '지점장',
#   '강동',
#   '배상',
#   '덕',
#   '광명',
#   '김현',
#   '자',
#   '안산',
#   '혜정',
#   '장안',
#   '한형',
#   '충주',
#   '승',
#   '전보',
#   '부서장',
#   '고객',
#   '자산운용',
#   '지원',
#   '부장',
#   '강성훈',
#   '구조',
#   '금융',
#   '실장',
#   '최정한',
#   '금융',
#   '소비자보호',
#   '이해',
#   '근',
#   '이동규',
#   '지점장',
#   '구로',
#   '남현우',
#   '군산',
#   '박',
#   '근',
#   '창',
#   '광산',
#   '오현',
#   '광주',
#   '이홍규',
#   '광화문',
#   '이종승',
#   '목동',
#   '신종',
#   '근',
#   '상계',
#   '김재훈',
#   '익산',
#   '임',
#   '상현',
#   '전주',
#   '김원식',
#   '종로',
#   '강',
#   '길',
#   '원',
#   '용산',
#   'WMC',
#   '장',
#   '상선'],
#  ['SK증권', '채권', '본부장', '이창용'],
#  ['대신',
#   '금융',
#   '그룹',
#   '승진',
#   '대신증권',
#   '급',
#   '부서장',
#   '재무관리',
#   '부이',
#   '재우',
#   '부동산',
#   '관리부',
#   '흥',
#   '탁',
#   '업무',
#   '개발부',
#   '김종선',
#   '연금',
#   '사업',
#   '센터',
#   '이영철',
#   '부',
#   '구준회',
#   '법무',
#   '지원',
#   '실',
#   '박찬',
#   '명',
#   '심사',
#   '분석',
#   '부이',
#   '동수',
#   '홍콩',
#   '현지',
#   '법인',
#   '성',
#   '유열',
#   '급',
#   '지점장',
#   '광명',
#   '센터',
#   '재범',
#   '대림동',
#   '지점',
#   '신봉',
#   '규',
#   '복',
#   '현',
#   '지점',
#   '권',
#   '범',
#   '무거동',
#   '지점',
#   '김경민',
#   '해운대',
#   '지점',
#   '정지윤',
#   '급',
#   '부서장',
#   '상해',
#   '사무소',
#   '신제',
#   '현',
#   '급',
#   '차장',
#   '감',
#   '사실',
#   '양성우',
#   '재무관리',
#   '부',
#   '안수',
#   '인프라',
#   '서비스',
#   '부',
#   '손',
#   '승희',
#   '개발부',
#   '이승택',
#   '온라인',
#   '개발부',
#   '황종률',
#   '글로벌',
#   '마켓',
#   '전략',
#   '실',
#   '김영일',
#   '본부',
#   '고재욱',
#   '스마트',
#   '비즈니스',
#   '부',
#   '오',
#   '법무',
#   '지원',
#   '실',
#   '홍제',
#   '임',
#   '유신',
#   '급',
#   '부장',
#   '광화문',
#   '지점',
#   '강',
#   '명',
#   '철',
#   '신촌',
#   '지점',
#   '철',
#   '우',
#   '미영',
#   '안산',
#   '지점',
#   '정',
#   '중',
#   '일산',
#   '지점',
#   '김남숙',
#   '이촌동',
#   '지점',
#   '전',
#   '헌재',
#   '명일동',
#   '지점',
#   '세경',
#   '수원',
#   '지점',
#   '청담',
#   '지점',
#   '최경희',
#   '진주',
#   '지점',
#   '최',
#   '정연',
#   '동래',
#   '지점',
#   '서',
#   '지애',
#   '군산',
#   '지점',
#   '최',
#   '동화',
#   '청주',
#   '지점',
#   '홍순',
#   '균',
#   '광주',
#   '센터',
#   '문',
#   '유고',
#   '나주',
#   '지점',
#   '이승주',
#   '안산',
#   '지점',
#   '김해심',
#   '상무',
#   '지점',
#   '이선경',
#   '급',
#   '과장',
#   '전략',
#   '기획',
#   '실',
#   '박종희',
#   '정보',
#   '보호',
#   '팀',
#   '김덕',
#   '호',
#   '알파',
#   '리서치',
#   '부',
#   '덕',
#   '승',
#   '신탁',
#   '사업부',
#   '이준석',
#   '랩',
#   '사업부',
#   '김정민',
#   '팀',
#   '조지훈',
#   '리테일',
#   '상품',
#   '팀',
#   '박재영',
#   '본부',
#   '김',
#   '혜',
#   '법인',
#   '금융',
#   '상품',
#   '부',
#   '태원',
#   '금융',
#   '주치의',
#   '전략',
#   '부',
#   '김세옥',
#   '크레온',
#   '영업부',
#   '장',
#   '부',
#   '김민석',
#   '리스크',
#   '관리부',
#   '강석희',
#   '심사',
#   '분석',
#   '부',
#   '김재연',
#   '급',
#   '차장',
#   '압구정',
#   '지점',
#   '이동은',
#   '송탄',
#   '지점',
#   '김미선',
#   '무거동',
#   '지점',
#   '서',
#   '정욱',
#   '해운대',
#   '지점',
#   '전재',
#   '하',
#   '청주',
#   '지점',
#   '정현호',
#   '광양',
#   '지점',
#   '김수찬',
#   '목포',
#   '지점',
#   '성',
#   '울산',
#   '지점',
#   '민경',
#   '순천',
#   '지점',
#   '서지연',
#   '대신',
#   '저축',
#   '은행',
#   '급',
#   '지점장',
#   '남포동',
#   '지점',
#   '양재',
#   '달',
#   '급',
#   '차장',
#   '경영',
#   '기획부',
#   '김진우',
#   '심사부',
#   '유지',
#   '승',
#   '급',
#   '차장',
#   '남포동',
#   '지점',
#   '박정',
#   '급',
#   '과장',
#   '전산',
#   '부',
#   '최',
#   '민',
#   '전략',
#   '금융',
#   '부',
#   '윤',
#   '성준',
#   '대신',
#   '자산운용',
#   '급',
#   '과장',
#   '주식',
#   '운용',
#   '본부',
#   '김종석',
#   '대신',
#   '경제',
#   '연구소',
#   '급',
#   '차장',
#   '금융공학',
#   '실',
#   '배',
#   '성민',
#   '대신',
#   '에프',
#   '앤',
#   '아이',
#   '이사',
#   '투자',
#   '부',
#   '이동석',
#   '투자',
#   '부',
#   '전동',
#   '민',
#   '부부장',
#   '투자',
#   '부',
#   '김태형',
#   '이사',
#   '자산',
#   '관리',
#   '부',
#   '정진철',
#   '자산',
#   '관리',
#   '부',
#   '오',
#   '규',
#   '택',
#   '자산',
#   '관리',
#   '부',
#   '석호',
#   '부부장',
#   '수',
#   '탁',
#   '지',
#   '원부',
#   '예지',
#   '선임',
#   '대신증권',
#   '부서장',
#   '미래',
#   '전략',
#   '실',
#   '강윤',
#   '글로벌',
#   '마켓',
#   '전략',
#   '실',
#   '오승훈',
#   '법인',
#   '금융',
#   '상품',
#   '부',
#   '김형준',
#   '글로벌',
#   '파생상품',
#   '부',
#   '김경훈',
#   '스마트',
#   '비즈니스',
#   '부',
#   '박성현',
#   '본부',
#   '이호철',
#   '지점장',
#   '부평',
#   '지점',
#   '송영',
#   '민',
#   '수지',
#   '지점',
#   '강',
#   '규',
#   '동래',
#   '지점',
#   '권',
#   '현미',
#   '군산',
#   '지점',
#   '영',
#   '직할',
#   '팀장',
#   '모바일',
#   '커뮤니케이션',
#   '팀',
#   '이재훈',
#   '대신',
#   '저축',
#   '은행',
#   '준법',
#   '감시인',
#   '정성',
#   '무',
#   '직할',
#   '팀장',
#   '영업',
#   '추진',
#   '이성재',
#   '전보',
#   '대신증권',
#   '부서장',
#   '금융',
#   '주치의',
#   '전략',
#   '부',
#   '이성근',
#   '고객감동',
#   '센터',
#   '오행',
#   '근',
#   '신탁',
#   '사업부',
#   '이동수',
#   '지점장',
#   '목동',
#   '지점',
#   '정기동',
#   '광화문',
#   '지점',
#   '이연',
#   '미',
#   '노원',
#   '지점',
#   '김',
#   '영천',
#   '평촌',
#   '지점',
#   '진수',
#   '민',
#   '이촌동',
#   '지점',
#   '박성희',
#   '명일동',
#   '지점',
#   '서상',
#   '청주',
#   '지점',
#   '이병용',
#   '산지',
#   '점',
#   '오용',
#   '진',
#   '안산',
#   '지점',
#   '김송',
#   '회',
#   '일산',
#   '지점',
#   '이상덕',
#   '반포',
#   '지점',
#   '이석영',
#   '잠실',
#   '신천지',
#   '점',
#   '이범영',
#   '전주',
#   '지점',
#   '김',
#   '형',
#   '대신',
#   '저축',
#   '은행',
#   '서면',
#   '지점장',
#   '김현우',
#   '직할',
#   '팀장',
#   '감사',
#   '팀',
#   '지',
#   '종수',
#   '팀장',
#   '압구정',
#   '지점',
#   '정',
#   '식',
#   '남포동',
#   '지점',
#   '구본',
#   '운',
#   '청담',
#   '지점',
#   '김',
#   '춘천',
#   '지점',
#   '안제',
#   '현'],
#  ['미래',
#   '에',
#   '그룹',
#   '승진',
#   '미래',
#   '에',
#   '자산운용',
#   '부장',
#   '부동산',
#   '자산',
#   '관리',
#   '본부',
#   '이준',
#   '섭',
#   '마케팅',
#   '본부',
#   '정경',
#   '철',
#   '퇴직',
#   '연금',
#   '마케팅',
#   '본부',
#   '손',
#   '수진',
#   '차장',
#   '운용',
#   '본부',
#   '이창',
#   '헌',
#   '부동산',
#   '투자',
#   '본부',
#   '김태헌',
#   '기금',
#   '자문',
#   '본부',
#   '정성진',
#   '컴플라이언스',
#   '본부',
#   '노',
#   '종언',
#   '상품',
#   '전략',
#   '본부',
#   '김형민',
#   '본부',
#   '김재훈',
#   '투자',
#   '본부',
#   '정준택',
#   '미래에셋증권',
#   '부장',
#   '기금',
#   '컨설팅',
#   '팀',
#   '김성수',
#   '기업',
#   '금융',
#   '팀',
#   '김진태',
#   '기업',
#   'RM',
#   '부문',
#   '본부',
#   '팀',
#   '정',
#   '진성',
#   '강남',
#   '파이낸스',
#   '센터',
#   '조원태',
#   '차장',
#   '광',
#   '나루',
#   '지점',
#   '김미숙',
#   '범어동',
#   '지점',
#   '김희',
#   '코리아리서치센터',
#   '총무',
#   '팀',
#   '이종민',
#   '미래',
#   '에',
#   '벤처',
#   '투자',
#   '벤처',
#   '투자',
#   '본부',
#   '부장',
#   '김경모',
#   '미래',
#   '에',
#   '펀드',
#   '서비스',
#   '개발',
#   '본부',
#   '개발',
#   '팀',
#   '부장',
#   '방희',
#   '미래',
#   '에',
#   '피탈',
#   '감사',
#   '팀',
#   '부장',
#   '정종',
#   '균',
#   '부동산',
#   '114',
#   '서비스',
#   '본부',
#   '부장',
#   '정',
#   '세련',
#   '서비스',
#   '본부',
#   '공',
#   '유추',
#   '리서치',
#   '센터',
#   '차장',
#   '김은지'],
#  ['BNK금융그룹',
#   '급',
#   '승진',
#   '전략',
#   '기획부',
#   '문',
#   '경호',
#   '급',
#   '승진',
#   '재무',
#   '기획부',
#   '서정우',
#   '급',
#   '승진',
#   '리스크',
#   '관리부',
#   '김문',
#   '일',
#   '부산은행',
#   '급',
#   '승진',
#   '영업부',
#   '박연',
#   '섭',
#   '내',
#   '골',
#   '지점',
#   '허영',
#   '선',
#   '인사부',
#   '정영주',
#   '광안동',
#   '지점',
#   '김정훈',
#   '경영',
#   '기획부',
#   '강종',
#   '훈',
#   '삼계',
#   '동지',
#   '점',
#   '이우',
#   '광',
#   '녹',
#   '산',
#   '공단',
#   '지점',
#   '노상',
#   '헌',
#   '검사부',
#   '정',
#   '성재',
#   '감전동',
#   '지점',
#   '손강',
#   '신탁',
#   '사업단',
#   '노',
#   '종',
#   '근',
#   '카드',
#   '사업단',
#   '김종구',
#   '여신',
#   '기획부',
#   '손',
#   '대진',
#   '금사',
#   '공단',
#   '지점',
#   '박선호',
#   '개발부',
#   '김영규',
#   '급',
#   '승진',
#   '당감동',
#   '지점',
#   '김동욱',
#   '금정',
#   '지점',
#   '송철호',
#   '수',
#   '안동',
#   '지점',
#   '이정용',
#   '양정동',
#   '지점',
#   '박',
#   '순조',
#   '남',
#   '지점',
#   '이한창',
#   '총무',
#   '부',
#   '김진영',
#   '포항',
#   '지점',
#   '김형수',
#   '언양',
#   '지점',
#   '김',
#   '오',
#   '부평',
#   '누리',
#   '지점',
#   '강',
#   '삼',
#   '훈',
#   '용',
#   '당',
#   '지점',
#   '박',
#   '문',
#   '근',
#   '재송동',
#   '지점',
#   '윤',
#   '석홍',
#   '광',
#   '남',
#   '지점',
#   '정상',
#   '팔송',
#   '지점',
#   '정',
#   '순',
#   '탁',
#   '금곡동',
#   '지점',
#   '임',
#   '대학',
#   '제니스',
#   '파크',
#   '지점',
#   '금민',
#   '수',
#   '우정동',
#   '지점',
#   '수',
#   '양산',
#   '공단',
#   '지점',
#   '김용식',
#   '삼산동',
#   '지점',
#   '상태',
#   '문현동',
#   '지점',
#   '기화',
#   '연천',
#   '지점',
#   '이병수',
#   '자금',
#   '증권',
#   '부',
#   '김해수',
#   '인사부',
#   '남',
#   '경화',
#   '인사부',
#   '조사',
#   '역',
#   '황',
#   '창',
#   '호',
#   '강석',
#   '래',
#   '서면',
#   '지점',
#   '김해',
#   '화전',
#   '공단',
#   '지점',
#   '정철',
#   '여신',
#   '감리',
#   '부',
#   '임호',
#   '검사부',
#   '정성영',
#   '금융',
#   '시장',
#   '지',
#   '원부',
#   '정희',
#   '정',
#   '개발부',
#   '이홍기'],
#  ['생명보험협회',
#   '승진',
#   '상무',
#   '보',
#   '대우',
#   '시장',
#   '자율',
#   '관리',
#   '본부장',
#   '김홍',
#   '중',
#   '부서장',
#   '시',
#   '장지원',
#   '부장',
#   '최성',
#   '림',
#   '보험',
#   '범죄',
#   '방지',
#   '실장',
#   '채',
#   '한기',
#   '고령',
#   '화지',
#   '원',
#   '최종윤',
#   '정보',
#   '시스템',
#   '허주',
#   '팀장',
#   '기획부',
#   '대외',
#   '협력',
#   '정문',
#   '일',
#   '자율',
#   '관리부',
#   '자격',
#   '관리',
#   '경',
#   '규',
#   '총무',
#   '부',
#   '총무',
#   '경리',
#   '김치',
#   '국',
#   '사회',
#   '공헌',
#   '센터',
#   '시회',
#   '공헌',
#   '재',
#   '정보',
#   '시스템',
#   '실',
#   '정보',
#   '서비스',
#   '여창',
#   '사회',
#   '공헌',
#   '센터',
#   '교육',
#   '김희',
#   '경',
#   '시',
#   '장지원',
#   '부',
#   '채널',
#   '전략',
#   '이주',
#   '학',
#   '전보',
#   '부서장',
#   '감사',
#   '실장',
#   '이재우',
#   '사회',
#   '공헌',
#   '센터',
#   '장',
#   '지',
#   '정훈',
#   '호남',
#   '지역',
#   '본부',
#   '장 현',
#   '순',
#   '영남',
#   '박',
#   '배철',
#   '수도권',
#   '황영',
#   '총무부장',
#   '박병권',
#   '자율',
#   '관리',
#   '장승',
#   '록',
#   '전보',
#   '팀장',
#   '시',
#   '장지원',
#   '부',
#   '계약',
#   '정보',
#   '지원',
#   '홍',
#   '성화',
#   '자율',
#   '관리부',
#   '모집',
#   '질서',
#   '김관철',
#   '원주',
#   '지부장',
#   '민',
#   '병현'],
#  ['동아',
#   '그룹',
#   '승진',
#   '전무이사',
#   '경영',
#   '관리',
#   '본부',
#   '채',
#   '홍기',
#   '전무',
#   '연구',
#   '본부',
#   '손',
#   '문호',
#   '상무',
#   '혁신',
#   '신약',
#   '연구소',
#   '윤태영',
#   '이사',
#   '대우',
#   '경영',
#   '기획',
#   '팀',
#   '정경운',
#   '추진단',
#   '정철',
#   '승',
#   '인재',
#   '개발원',
#   '김풍',
#   '국',
#   '국내',
#   '법무',
#   '팀',
#   '김',
#   '권',
#   '해외',
#   '법무',
#   '팀',
#   '김',
#   '형',
#   '헌',
#   '분자',
#   '약리',
#   '연구',
#   '팀',
#   '신준호',
#   '동아',
#   'ST',
#   '전무',
#   '연구',
#   '기획',
#   '관리실',
#   '손',
#   '미원',
# ...
#   '행동',
#   '심리',
#   '특징',
#   '연구',
#   '영역',
#   '이해',
#   '것',
#   '범죄심리학',
#   '범죄',
#   '해부학',
#   '범죄심리학',
#   '공격성',
#   '정신병',
#   '청소년',
#   '비행',
#   '정신',
#   '장애',
#   '위험성',
#   '평가',
#   '성범죄',
#   '살인',
#   '연쇄살인',
#   '프로파일링',
#   '테러',
#   '인질',
#   '협상',
#   '가정폭력',
#   '배우자',
#   '살해',
#   '병',
#   '도벽',
#   '심리',
#   '등',
#   '분야',
#   '포함',
#   '국내',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '범죄',
#   '과학',
#   '연구소',
#   '소장',
#   '표창원',
#   '대표',
#   '죄',
#   '심리학',
#   '프로파일러',
#   '뜻',
#   '네티즌',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '범죄',
#   '심리',
#   '분석',
#   '전문가',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '등',
#   '반응',
#   '매경닷컴',
#   '이성구',
#   '인턴',
#   '기자',
#   '관련',
#   '기사',
#   '서울대',
#   '엄친',
#   '딸',
#   '지주연',
#   '의',
#   '볼륨',
#   '비키니',
#   '몸매',
#   '입',
#   '삼성',
#   '미래',
#   '기술',
#   '삼성',
#   '기술',
#   '전',
#   '실전',
#   '감각',
#   '쿠바',
#   '전',
#   '마지막',
#   '무대',
#   '국보',
#   '발레리나',
#   '은퇴',
#   '아쉬움',
#   '레이싱',
#   '송',
#   '다',
#   '미',
#   '축구공',
#   '만',
#   '가슴골',
#   '파',
#   '매일',
#   '경제',
#   '무단',
#   '전재',
#   '배포',
#   '금지'],
#  ['범죄심리학',
#   '프로파일러',
#   '뜻',
#   '범죄심리학',
#   '프로파일러',
#   '프로파일러',
#   '표창원',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '발생',
#   '증가',
#   '범죄심리학',
#   '프로파일러',
#   '관심',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '범죄심리학',
#   '프로파일러',
#   '범죄자',
#   '심리',
#   '분석',
#   '범죄',
#   '심리',
#   '전문가',
#   '로',
#   '풀이',
#   '범죄심리학',
#   '프로파일러',
#   '연쇄',
#   '범죄',
#   '등',
#   '중대',
#   '범죄',
#   '수사',
#   '언급',
#   '것',
#   '최근',
#   '처음',
#   '등장',
#   '것',
#   '년',
#   '미국',
#   '범죄',
#   '동기',
#   '수',
#   '연쇄살인',
#   '사건',
#   '미국',
#   '연방수사국',
#   '은',
#   '범죄심리학',
#   '프로파일러',
#   '도입',
#   '이후',
#   '나라',
#   '제도',
#   '도입',
#   '범죄심리학',
#   '분야',
#   '성장',
#   '범죄',
#   '심리',
#   '라고',
#   '것',
#   '기대',
#   '범죄자',
#   '행동',
#   '심리',
#   '특징',
#   '연구',
#   '영역',
#   '이해',
#   '것',
#   '범죄심리학',
#   '범죄',
#   '해부학',
#   '범죄심리학',
#   '공격성',
#   '정신병',
#   '청소년',
#   '비행',
#   '정신',
#   '장애',
#   '위험성',
#   '평가',
#   '성범죄',
#   '살인',
#   '연쇄살인',
#   '프로파일링',
#   '테러',
#   '인질',
#   '협상',
#   '가정폭력',
#   '배우자',
#   '살해',
#   '병',
#   '도벽',
#   '심리',
#   '등',
#   '분야',
#   '포함',
#   '국내',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '범죄',
#   '과학',
#   '연구소',
#   '소장',
#   '표창원',
#   '대표',
#   '죄',
#   '심리학',
#   '프로파일러',
#   '뜻',
#   '네티즌',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '범죄',
#   '심리',
#   '분석',
#   '전문가',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '등',
#   '반응',
#   '매경닷컴',
#   '이성구',
#   '인턴',
#   '기자',
#   '관련',
#   '기사',
#   '서울대',
#   '엄친',
#   '딸',
#   '지주연',
#   '의',
#   '볼륨',
#   '비키니',
#   '몸매',
#   '입',
#   '삼성',
#   '미래',
#   '기술',
#   '삼성',
#   '기술',
#   '전',
#   '벤',
#   '마',
#   '결장',
#   '이유',
#   '부상',
#   '만',
#   '경찰',
#   '체포',
#   '마지막',
#   '무대',
#   '국보',
#   '발레리나',
#   '은퇴',
#   '아쉬움',
#   '레이싱',
#   '송',
#   '다',
#   '미',
#   '축구공',
#   '만',
#   '가슴골',
#   '파',
#   '매일',
#   '경제',
#   '무단',
#   '전재',
#   '배포',
#   '금지'],
#  ['범죄',
#   '심리',
#   '프로파일러',
#   '뜻',
#   '범죄심리학',
#   '프로파일러',
#   '프로파일러',
#   '표창원',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '발생',
#   '증가',
#   '범죄심리학',
#   '프로파일러',
#   '관심',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '범죄심리학',
#   '프로파일러',
#   '범죄자',
#   '심리',
#   '분석',
#   '범죄',
#   '심리',
#   '전문가',
#   '로',
#   '풀이',
#   '범죄심리학',
#   '프로파일러',
#   '연쇄',
#   '범죄',
#   '등',
#   '중대',
#   '범죄',
#   '수사',
#   '언급',
#   '것',
#   '최근',
#   '처음',
#   '등장',
#   '것',
#   '년',
#   '미국',
#   '범죄',
#   '동기',
#   '수',
#   '연쇄살인',
#   '사건',
#   '미국',
#   '연방수사국',
#   '은',
#   '범죄심리학',
#   '프로파일러',
#   '도입',
#   '이후',
#   '나라',
#   '제도',
#   '도입',
#   '범죄심리학',
#   '분야',
#   '성장',
#   '범죄',
#   '심리',
#   '라고',
#   '것',
#   '기대',
#   '범죄자',
#   '행동',
#   '심리',
#   '특징',
#   '연구',
#   '영역',
#   '이해',
#   '것',
#   '범죄심리학',
#   '범죄',
#   '해부학',
#   '범죄심리학',
#   '공격성',
#   '정신병',
#   '청소년',
#   '비행',
#   '정신',
#   '장애',
#   '위험성',
#   '평가',
#   '성범죄',
#   '살인',
#   '연쇄살인',
#   '프로파일링',
#   '테러',
#   '인질',
#   '협상',
#   '가정폭력',
#   '배우자',
#   '살해',
#   '병',
#   '도벽',
#   '심리',
#   '등',
#   '분야',
#   '포함',
#   '국내',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '범죄',
#   '과학',
#   '연구소',
#   '소장',
#   '표창원',
#   '대표',
#   '죄',
#   '심리학',
#   '프로파일러',
#   '뜻',
#   '네티즌',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '범죄',
#   '심리',
#   '분석',
#   '전문가',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '등',
#   '반응',
#   '매경닷컴',
#   '이성구',
#   '인턴',
#   '기자',
#   '관련',
#   '기사',
#   '서울대',
#   '엄친',
#   '딸',
#   '지주연',
#   '의',
#   '볼륨',
#   '비키니',
#   '몸매',
#   '입',
#   '삼성',
#   '미래',
#   '기술',
#   '삼성',
#   '기술',
#   '전',
#   '벤',
#   '마',
#   '결장',
#   '이유',
#   '부상',
#   '만',
#   '경찰',
#   '체포',
#   '마지막',
#   '무대',
#   '국보',
#   '발레리나',
#   '은퇴',
#   '아쉬움',
#   '레이싱',
#   '송',
#   '다',
#   '미',
#   '축구공',
#   '만',
#   '가슴골',
#   '파',
#   '매일',
#   '경제',
#   '무단',
#   '전재',
#   '배포',
#   '금지'],
#  ['소년범', '비행', '청소년', '방치', '나중', '사회', '비용', '부담', '때문', '사회', '관심', '지원'],
#  ['일',
#   '서울',
#   '양재동',
#   '서울가정법원',
#   '집무실',
#   '여상',
#   '훈',
#   '사진',
#   '서울가정법원',
#   '장',
#   '범죄',
#   '비행',
#   '우려',
#   '청소년',
#   '애정',
#   '청소년',
#   '대부분',
#   '불우',
#   '가정환경',
#   '위기',
#   '가정',
#   '부모',
#   '등',
#   '가족',
#   '사랑',
#   '데',
#   '상처',
#   '안고',
#   '점',
#   '여',
#   '법원장',
#   '가정',
#   '사회',
#   '아이들',
#   '건강',
#   '게',
#   '환경',
#   '만큼',
#   '잘못',
#   '청소년',
#   '책임',
#   '물',
#   '게',
#   '행동',
#   '원인',
#   '치유',
#   '해주',
#   '게',
#   '강조'],
#  ['현실', '여', '법원장', '바람', '거리', '한참'],
#  ['범죄',
#   '비행',
#   '청소년',
#   '중',
#   '약물 중독',
#   '정신과',
#   '문제',
#   '안고',
#   '청소년',
#   '치료',
#   '선도',
#   '의료',
#   '소년원',
#   '호',
#   '처분',
#   '과',
#   '보호자',
#   '친권자',
#   '후견인',
#   '문제',
#   '청소년',
#   '보호',
#   '위탁',
#   '시설',
#   '6호',
#   '처분',
#   '의',
#   '실태',
#   '예',
#   '여',
#   '법원장',
#   '전국',
#   '곳',
#   '뿐',
#   '의료',
#   '소년원',
#   '상주',
#   '의사',
#   '치료',
#   '청소년',
#   '수',
#   '경우',
#   '6호',
#   '처분',
#   '아동',
#   '복지',
#   '시설',
#   '소년',
#   '보호',
#   '시설',
#   '청소년',
#   '자리',
#   '부족',
#   '처분',
#   '경우',
#   '토로'],
#  ['실제',
#   '6호',
#   '처분',
#   '청소년',
#   '보호',
#   '사회인',
#   '육성',
#   '6호',
#   '시설',
#   '은',
#   '정부',
#   '년',
#   '소년범',
#   '시설',
#   '지원',
#   '예산',
#   '지자체',
#   '뒤',
#   '손',
#   '정도',
#   '영유아',
#   '보육',
#   '비',
#   '지원',
#   '등',
#   '살림',
#   '지자체',
#   '문제',
#   '아들',
#   '을',
#   '지원',
#   '여력',
#   '때문',
#   '전국',
#   '남은',
#   '6호',
#   '시설',
#   '곳',
#   '상황',
#   '최근',
#   '경기도',
#   '양주',
#   '위치',
#   '나사',
#   '집',
#   '도',
#   '재정난',
#   '정상',
#   '운영',
#   '실정',
#   '여',
#   '법원장',
#   '소년범',
#   '방치',
#   '나중',
#   '성인',
#   '범죄자',
#   '사회',
#   '비용',
#   '대책',
#   '마련',
#   '강조',
#   '배경',
#   '가정법원',
#   '대로',
#   '6호',
#   '시설',
#   '가출',
#   '청소년',
#   '규모',
#   '그룹',
#   '홈',
#   '형태',
#   '각지',
#   '분포',
#   '여성',
#   '가족',
#   '부',
#   '등',
#   '관련',
#   '부처',
#   '협의',
#   '중'],
#  ['여',
#   '법원장',
#   '법원',
#   '후견',
#   '기능',
#   '강화',
#   '법원',
#   '법원장',
#   '전문',
#   '법원',
#   '장제',
#   '도입',
#   '것',
#   '제안',
#   '가정법원',
#   '일',
#   '때',
#   '보람',
#   '전임',
#   '법원장',
#   '가정법원',
#   '법관',
#   '전문',
#   '법관',
#   '최소',
#   '년',
#   '근무',
#   '법원장',
#   '전문',
#   '법원',
#   '장과',
#   '제도',
#   '운영',
#   '시각',
#   '가사',
#   '사건',
#   '소년',
#   '사건',
#   '말',
#   '가사',
#   '사건',
#   '후견',
#   '기능',
#   '필요',
#   '점',
#   '고려',
#   '재판부',
#   '판단',
#   '게',
#   '갈등',
#   '치유',
#   '수',
#   '역할',
#   '강조'],
#  ['한편',
#   '변호사',
#   '일',
#   '경력',
#   '여',
#   '법원장',
#   '당시',
#   '경험',
#   '재판',
#   '입장',
#   '것',
#   '자산',
#   '후배',
#   '판사',
#   '재판',
#   '당사자',
#   '양쪽',
#   '이야기',
#   '주의',
#   '성실',
#   '설명',
#   '주문',
#   '분야',
#   '강조',
#   '덕목',
#   '것',
#   '생각',
#   '말'],
#  ['정', '선형', '기자'],
#  ['삶', '사춘기', '꿈', '교실', '밖'],
#  ['삶', '사춘기', '꿈', '교실', '밖'],
#  ['01'],
#  ['학교', '문제아', '낙인'],
#  ['일'],
#  ['여학생', '유흥업소', '발'],
#  ['경기도',
#   '고등학교',
#   '카',
#   '말',
#   '가명',
#   '은',
#   '외국인',
#   '근로자',
#   '한국',
#   '방글라데시',
#   '부모',
#   '사이에서',
#   '한국',
#   '카',
#   '말',
#   '방글라데시',
#   '바가',
#   '부모',
#   '나라',
#   '인식',
#   '전부'],
#  ['아버지',
#   '년',
#   '불법체류',
#   '자로',
#   '적발',
#   '고국',
#   '강제',
#   '출국',
#   '어머니',
#   '여동생',
#   '밖',
#   '공간',
#   '샌드위치',
#   '패널',
#   '조립식',
#   '주택',
#   '탓',
#   '안전',
#   '보장',
#   '수',
#   '카',
#   '말',
#   '가족',
#   '밤',
#   '집'],
#  ['공장',
#   '일',
#   '아버지',
#   '대신',
#   '역할',
#   '어머니',
#   '학교',
#   '친구',
#   '카',
#   '말',
#   '학교',
#   '문제아',
#   '취급',
#   '지',
#   '카',
#   '말',
#   '어머니',
#   '아들',
#   '때문',
#   '교회',
#   '목사',
#   '학교',
#   '경찰서',
#   '수'],
#  ['가족', '목사', '카', '말', '비행', '청소년', '문제', '학교', '걱정'],
#  ['카',
#   '말',
#   '한때',
#   '엔지니어',
#   '꿈',
#   '불안',
#   '환경',
#   '꿈',
#   '의미',
#   '이제',
#   '일',
#   '게',
#   '자신',
#   '현실',
#   '무력감'],
#  ['방황',
#   '카',
#   '말',
#   '편',
#   '필리핀인',
#   '어머니',
#   '미군',
#   '아버지',
#   '사이에서',
#   '니콜',
#   '가명',
#   '여',
#   '은',
#   '중학교',
#   '중퇴',
#   '미군',
#   '클럽',
#   '년',
#   '일',
#   '무국적',
#   '자인',
#   '나이',
#   '클럽'],
#  ['신원',
#   '정보',
#   '말',
#   '나름',
#   '게',
#   '설명',
#   '최근',
#   '자신',
#   '일',
#   '클럽',
#   '경찰',
#   '단속',
#   '문',
#   '일자리',
#   '중'],
#  ['학교',
#   '수',
#   '취업',
#   '수',
#   '일',
#   '곳',
#   '곳',
#   '돈',
#   '남자',
#   '막',
#   '노동판',
#   '여자',
#   '곳',
#   '일',
#   '수',
#   '안',
#   '남',
#   '돈',
#   '일',
#   '밖',
#   '말'],
#  ['경기도', '내', '미군', '기지', '주변', '유흥업소', '니콜', '무국적', '여성', '청소년', '돈'],
#  ['최근',
#   '5년',
#   '간',
#   '법무부',
#   '국내',
#   '불법체류',
#   '자 현',
#   '황',
#   '자료',
#   '불법체류',
#   '자',
#   '올해',
#   '기준',
#   '명',
#   '년',
#   '전',
#   '반면',
#   '불법체류',
#   '자',
#   '단속',
#   '로',
#   '것',
#   '단속',
#   '것',
#   '신원',
#   '정보',
#   '파악',
#   '수',
#   '무국',
#   '적자',
#   '증가',
#   '원인',
#   '분석'],
#  ['김',
#   '복',
#   '한국',
#   '범죄학',
#   '연구소',
#   '연구',
#   '위원',
#   '무국',
#   '적자',
#   '범죄',
#   '경우',
#   '지문',
#   '신원',
#   '정보',
#   '확보',
#   '수',
#   '점',
#   '때문',
#   '지문',
#   '감식',
#   '조사',
#   '등',
#   '과학',
#   '수사',
#   '사실',
#   '의미',
#   '목격자',
#   '진술',
#   '탐',
#   '문수사',
#   '등',
#   '의존',
#   '수',
#   '상황',
#   '개선',
#   '불법체류',
#   '자와',
#   '무국적',
#   '자',
#   '처벌',
#   '유예',
#   '기간',
#   '자진',
#   '신고',
#   '유도',
#   '등',
#   '정부',
#   '법률',
#   '조치',
#   '필요',
#   '조언'],
#  ['이종우', '최재훈', '황성', '규', '기자'],
#  ['사진',
#   '제주시',
#   '이도',
#   '지구',
#   '위치',
#   '공사',
#   '중단',
#   '건축물',
#   '년',
#   '개월',
#   '완공',
#   '청소년',
#   '탈선',
#   '야생',
#   '동물',
#   '서식지',
#   '활용',
#   '경호',
#   '기자',
#   '건설',
#   '중단',
#   '건축물',
#   '도심',
#   '속',
#   '흉물',
#   '로',
#   '전락',
#   '일',
#   '제주시',
#   '이도',
#   '지구',
#   '방문',
#   '결과',
#   '공사',
#   '중단',
#   '규모',
#   '공동',
#   '주택',
#   '확인',
#   '해당',
#   '건물',
#   '2012년 5월',
#   '착공',
#   '것',
#   '현재',
#   '년',
#   '개월',
#   '완공',
#   '출입',
#   '펜스',
#   '유치권',
#   '행사',
#   '중',
#   '경고',
#   '문',
#   '부착',
#   '등',
#   '건축주',
#   '대금',
#   '지급',
#   '공사',
#   '중단',
#   '것',
#   '추정',
#   '문제',
#   '수년',
#   '완공',
#   '채',
#   '방치',
#   '청소년',
#   '탈선',
#   '야생',
#   '동물',
#   '서식지',
#   '활용',
#   '등',
#   '인근',
#   '주민',
#   '민원',
#   '인근',
#   '주민',
#   '비행',
#   '청소년',
#   '흡연',
#   '음주',
#   '목격',
#   '최근',
#   '길고양이',
#   '서식',
#   '범죄',
#   '우려',
#   '동네',
#   '미관',
#   '저해',
#   '주민',
#   '불만',
#   '토로',
#   '공사',
#   '중단',
#   '건축물',
#   '인해',
#   '미관',
#   '저해',
#   '민원',
#   '발생',
#   '행정',
#   '관리',
#   '실정',
#   '현행법',
#   '행정',
#   '착공',
#   '준공',
#   '허가',
#   '담당',
#   '뿐',
#   '건설',
#   '중단',
#   '건축물',
#   '관리',
#   '민원',
#   '접수',
#   '현장',
#   '점검',
#   '확인',
#   '후',
#   '때문',
#   '사정',
#   '제주시',
#   '년',
#   '이상',
#   '장기',
#   '공사',
#   '중단',
#   '건축물',
#   '곳',
#   '파악',
#   '건설업',
#   '수',
#   '건축물',
#   '공사',
#   '중단',
#   '입장',
#   '건설업',
#   '관계자',
#   '최근',
#   '건설',
#   '경기',
#   '호황',
#   '공사',
#   '대금',
#   '미',
#   '지급',
#   '건축주',
#   '시공사',
#   '불화',
#   '등',
#   '건설',
#   '중단',
#   '건축물',
#   '지속',
#   '발생',
#   '공사',
#   '중단',
#   '경우',
#   '행정',
#   '신고',
#   '등',
#   '제도',
#   '개선',
#   '필요',
#   '말',
#   '경호',
#   '기자'],
#  ['범죄심리학',
#   '프로파일러',
#   '범죄심리학',
#   '프로파일러',
#   '프로파일러',
#   '표창원',
#   '최근',
#   '범죄심리학',
#   '프로파일러',
#   '누리꾼',
#   '관심',
#   '프로파일러',
#   '범죄자',
#   '심리',
#   '분석',
#   '범죄',
#   '심리',
#   '전문가',
#   '로',
#   '풀이',
#   '프로파일러',
#   '연쇄',
#   '범죄',
#   '등',
#   '중대',
#   '범죄',
#   '수사',
#   '언급',
#   '것',
#   '최근',
#   '처음',
#   '등장',
#   '것',
#   '년',
#   '미국',
#   '범죄',
#   '동기',
#   '수',
#   '연쇄살인',
#   '사건',
#   '미국',
#   '연방수사국',
#   '은',
#   '프로파일러',
#   '도입',
#   '이후',
#   '나라',
#   '제도',
#   '도입',
#   '범죄심리학',
#   '분야',
#   '성장',
#   '범죄',
#   '심리',
#   '라고',
#   '것',
#   '기대',
#   '범죄자',
#   '행동',
#   '심리',
#   '특징',
#   '연구',
#   '영역',
#   '이해',
#   '것',
#   '범죄심리학',
#   '범죄',
#   '해부학',
#   '범죄심리학',
#   '공격성',
#   '정신병',
#   '청소년',
#   '비행',
#   '정신',
#   '장애',
#   '위험성',
#   '평가',
#   '성범죄',
#   '살인',
#   '연쇄살인',
#   '프로파일링',
#   '테러',
#   '인질',
#   '협상',
#   '가정폭력',
#   '배우자',
#   '살해',
#   '병',
#   '도벽',
#   '심리',
#   '등',
#   '분야',
#   '포함',
#   '국내',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '범죄',
#   '과학',
#   '연구소',
#   '소장',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '네티즌',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '범죄',
#   '심리',
#   '분석',
#   '전문가',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '뜻',
#   '등',
#   '반응',
#   '매경닷컴',
#   '오용',
#   '훈',
#   '인턴',
#   '기자',
#   '관련',
#   '기사',
#   '서울대',
#   '엄친',
#   '딸',
#   '지주연',
#   '의',
#   '볼륨',
#   '비키니',
#   '몸매',
#   '입',
#   '삼성',
#   '미래',
#   '기술',
#   '삼성',
#   '기술',
#   '전',
#   '재활',
#   '류현진',
#   '일',
#   '입국',
#   '예정',
#   '금속',
#   '탐지기',
#   '중세',
#   '은화',
#   '땅',
#   '동전',
#   '레이싱',
#   '송',
#   '다',
#   '미',
#   '축구공',
#   '만',
#   '가슴골',
#   '파',
#   '매일',
#   '경제',
#   '무단',
#   '전재',
#   '배포',
#   '금지'],
#  ['법', '사랑', '연합회', '청소년', '초청', '행사'],
#  ['GS칼텍스',
#   '법무부',
#   '산하',
#   '법',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '지난달',
#   '일',
#   '개최',
#   '법',
#   '사랑',
#   '청소년',
#   '문화',
#   '나들',
#   '행사',
#   '후원',
#   '일'],
#  ['이번',
#   '행사',
#   '법',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '기존',
#   '비행',
#   '청소년',
#   '사후',
#   '단기',
#   '선도',
#   '범죄',
#   '우려',
#   '다',
#   '문화',
#   '가정',
#   '등',
#   '청소년',
#   '상대로',
#   '선제',
#   '장기',
#   '후원',
#   '기획'],
#  ['법',
#   '사랑',
#   '연합회',
#   '민간',
#   '범죄',
#   '예방',
#   '자원봉사',
#   '자인',
#   '법',
#   '사랑',
#   '위원',
#   '들로',
#   '구성',
#   '법정',
#   '단체',
#   '전남',
#   '동부',
#   '지역',
#   '각계각층',
#   '선정',
#   '법',
#   '사랑',
#   '위원',
#   '명',
#   '구성'],
#  ['법',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '이날',
#   '범죄',
#   '노출',
#   '우려',
#   '다',
#   '문화',
#   '북',
#   '결손',
#   '가정',
#   '등',
#   '청소년',
#   '여명',
#   '초청',
#   '직업',
#   '탐방',
#   '예술',
#   '공연',
#   '관람',
#   '등',
#   '실시',
#   '청소년',
#   '법',
#   '사랑',
#   '위원',
#   '대화',
#   'GS칼텍스',
#   '여수',
#   '공장',
#   '견학',
#   '등',
#   '진행'],
#  ['이날',
#   '오후',
#   '여수시',
#   '시전동',
#   'GS칼텍스',
#   '예',
#   '울',
#   '마루',
#   '극장',
#   '뮤지컬',
#   '명성황후',
#   '주년',
#   '기념',
#   '공연',
#   '을',
#   '관람',
#   '광복',
#   '주년',
#   '의미',
#   '역사',
#   '의식',
#   '기회',
#   '경험'],
#  ['법',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '관계자',
#   '앞으로',
#   'GS칼텍스',
#   '등',
#   '관내',
#   '기업체',
#   '후원',
#   '해당',
#   '기업',
#   '견학',
#   '지역',
#   '출신',
#   '예술인',
#   '공연',
#   '관람',
#   '강연',
#   '프로그램',
#   '등',
#   '진행',
#   '방침',
#   '말'],
#  ['GS칼텍스',
#   '관계자',
#   '지역',
#   '다',
#   '문화',
#   '가정',
#   '등',
#   '청소년',
#   '나라',
#   '인재',
#   '성장',
#   '수',
#   '지속',
#   '후원',
#   '방침',
#   '말'],
#  ['여수', '경기', '기자'],
#  ['GS칼텍스',
#   '대표',
#   '이사',
#   '허진',
#   '수',
#   '부회장',
#   '전남',
#   '동부',
#   '지역',
#   '청소년',
#   '선도',
#   '활동',
#   '적극',
#   '기여',
#   '기업',
#   '시민',
#   '책임'],
#  ['GS칼텍스',
#   '법무부',
#   '산하',
#   '법',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '일',
#   '개최',
#   '법',
#   '사랑',
#   '청소년',
#   '문화',
#   '나들',
#   '행사',
#   '후원',
#   '일'],
#  ['법',
#   '사랑',
#   '연합회',
#   '민간',
#   '범죄',
#   '예방',
#   '자원봉사',
#   '자인',
#   '법',
#   '사랑',
#   '위원',
#   '들로',
#   '구성',
#   '법정',
#   '단체'],
#  ['법',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '전남',
#   '동부',
#   '지역',
#   '각계각층',
#   '선정',
#   '법',
#   '사랑',
#   '위원',
#   '명',
#   '참여'],
#  ['법',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '이날',
#   '범죄',
#   '노출',
#   '우려',
#   '다',
#   '문화',
#   '북',
#   '결손',
#   '가정',
#   '등',
#   '청소년',
#   '여명',
#   '초청',
#   '직업',
#   '탐방',
#   '예술',
#   '공연',
#   '관람',
#   '등',
#   '실시'],
#  ['법',
#   '사랑',
#   '위원회',
#   '청소년',
#   '대화',
#   'GS칼텍스',
#   '여수',
#   '공장',
#   '견학',
#   '등',
#   '주선',
#   '적성',
#   '후원'],
#  ['이날',
#   '오후',
#   '여수시',
#   '시전동',
#   'GS칼텍스',
#   '예',
#   '울',
#   '마루',
#   '극장',
#   '뮤지컬',
#   '명성황후',
#   '주년',
#   '기념',
#   '공연',
#   '을',
#   '관람',
#   '광복',
#   '주년',
#   '의미',
#   '역사',
#   '의식'],
#  ['행사',
#   '법',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '기존',
#   '비행',
#   '청소년',
#   '사후',
#   '단기',
#   '처방',
#   '선도',
#   '범죄',
#   '우려',
#   '다',
#   '문화',
#   '가정',
#   '등',
#   '청소년',
#   '상대로',
#   '선제',
#   '장기',
#   '후원',
#   '기획'],
#  ['법',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   'GS칼텍스',
#   '등',
#   '관내',
#   '기업체',
#   '후원',
#   '해당',
#   '기업',
#   '견학',
#   '지역',
#   '출신',
#   '예술인',
#   '공연',
#   '관람',
#   '강연',
#   '프로그램',
#   '등',
#   '진행',
#   '예정'],
#  ['다',
#   '문화',
#   '북',
#   '결손',
#   '가정',
#   '청소년',
#   '미래',
#   '꿈',
#   '장기',
#   '기업체',
#   '법',
#   '사랑',
#   '위원',
#   '청소년',
#   '지원 활동',
#   '정기',
#   '후원',
#   '분위기',
#   '조성',
#   '기대'],
#  ['GS칼텍스',
#   '관계자',
#   '지역',
#   '다',
#   '문화',
#   '가정',
#   '등',
#   '청소년',
#   '나라',
#   '인재',
#   '성장',
#   '수',
#   '지속',
#   '후원',
#   '말'],
#  ['나영석', '기자'],
#  ['용인', '벽돌', '사건', '살', '범인', '처벌', '사회', '숙제'],
#  ['경기도',
#   '용인',
#   '살',
#   '초등학생',
#   '친구',
#   '아파트',
#   '옥상',
#   '벽돌',
#   '고양이',
#   '집',
#   '대',
#   '여성',
#   '사망',
#   '20대',
#   '여성',
#   '중상'],
#  ['강원도',
#   '살',
#   '초등학생',
#   '년',
#   '명',
#   '여학생',
#   '음란',
#   '동영상',
#   '옷',
#   '성추행',
#   '남학생',
#   '명',
#   '부모',
#   '놈',
#   '폭력'],
#  ['위',
#   '사례',
#   '이번',
#   '달',
#   '발생',
#   '적발',
#   '세',
#   '소년',
#   '범죄',
#   '행위',
#   '사례',
#   '충격',
#   '일',
#   '형사',
#   '처벌',
#   '대상'],
#  ['가해자',
#   '소년',
#   '형사',
#   '처벌',
#   '수',
#   '점',
#   '피해자',
#   '구제',
#   '책',
#   '사실',
#   '점',
#   '사법',
#   '현실',
#   '논란'],
#  ['형사', '처벌', '세', '범죄', '처벌', '여론'],
#  ['세',
#   '이하',
#   '소년',
#   '현행법',
#   '형사',
#   '처벌',
#   '물론',
#   '촉법소년',
#   '형법',
#   '저촉',
#   '행위',
#   '세',
#   '을',
#   '대상',
#   '보호처분',
#   '조치',
#   '대상',
#   '년',
#   '형사법',
#   '제정',
#   '후',
#   '세',
#   '이하',
#   '형사',
#   '처벌',
#   '미',
#   '적용',
#   '62년',
#   '간',
#   '보호처분',
#   '하',
#   '연령',
#   '차례',
#   '세',
#   '세로'],
#  ['중력',
#   '실험',
#   '세',
#   '가해자',
#   '진술',
#   '고의',
#   '을',
#   '논란',
#   '고의',
#   '여부',
#   '형사',
#   '처벌',
#   '관련',
#   '고의',
#   '은',
#   '나중',
#   '민사',
#   '소송',
#   '소년',
#   '범죄',
#   '행위',
#   '입증',
#   '요소',
#   '수',
#   '근거',
#   '부모',
#   '관리',
#   '책임',
#   '손해배상',
#   '청구',
#   '수',
#   '근거',
#   '도덕',
#   '비난',
#   '것'],
#  ['범인',
#   '세',
#   '소년',
#   '일',
#   '개설',
#   '다음',
#   '아고라',
#   '청원',
#   '여명',
#   '형사',
#   '처벌',
#   '을',
#   '요구',
#   '리얼미터',
#   '일',
#   '발표',
#   '여론',
#   '조사',
#   '결과',
#   '형사',
#   '처벌',
#   '연령',
#   '기준',
#   '하향',
#   '찬성',
#   '의견',
#   '반대',
#   '로',
#   '찬성',
#   '배',
#   '정도'],
#  ['처벌', '관용', '처벌', '연령', '하향', '딜레마'],
#  ...]

# %% [markdown]
# ### 한글자 이하인 단어들 없애주는 과정

# %%
fin_lst=[]
for n in tran:
    two_lst = []
    for i in n:
        if len(i)<=1:
            pass
        else:
            two_lst.append(i)
    fin_lst.append(two_lst)

# %%
fin_lst
# Out:
# [['법무부',
#   '승진',
#   '법무부',
#   '소년',
#   '용범',
#   '서울보호관찰소',
#   '관찰',
#   '김기환',
#   '대전',
#   '서울소년원',
#   '교무',
#   '이용호',
#   '대구',
#   '성수',
#   '대구',
#   '분류',
#   '보호',
#   '이영미',
#   '대전',
#   '박종국',
#   '광주',
#   '교무',
#   '서진',
#   '서울소년분류심사원',
#   '분류',
#   '심사',
#   '김세훈',
#   '전보',
#   '법무부',
#   '국방',
#   '파견',
#   '진규',
#   '서울동부보호관찰소',
#   '정택현',
#   '서울',
#   '남부',
#   '최종',
#   '의정부',
#   '양봉화',
#   '인천보호관찰소',
#   '천지',
#   '소장',
#   '김시',
#   '수원',
#   '안산',
#   '근성',
#   '수원',
#   '천안',
#   '광주소년원',
#   '이영호',
#   '제주',
#   '유병',
#   '서울소년분류심사원',
#   '안산청소년비행예방센터',
#   '김택수',
#   '대전보호관찰소',
#   '행정',
#   '지원',
#   '정원',
#   '대구',
#   '부산',
#   '성학',
#   '광주',
#   '이은하',
#   '서울소년원',
#   '부산',
#   '교무',
#   '박준',
#   '부산',
#   '분류',
#   '보호',
#   '광주',
#   '김양곤',
#   '대전',
#   '교무',
#   '이상운'],
#  ['해양수산부',
#   '장관',
#   '정책',
#   '보좌관',
#   '김희',
#   '이창호',
#   '과장',
#   '장관',
#   '비서실장',
#   '이경규',
#   '창조',
#   '행정',
#   '담당관',
#   '권순욱',
#   '항로',
#   '표지',
#   '김영',
#   '부산지방해양수산청',
#   '선원',
#   '해사',
#   '안전',
#   '최국',
#   '동해지방해양수산청',
#   '공평',
#   '포항',
#   '석홍',
#   '국립',
#   '양조',
#   '사원',
#   '해도',
#   '수로'],
#  ['문화재', '고위', '공무원', '국립무형유산원', '강경', '과장', '문화', '재활용', '세계유산', '팀장'],
#  ['산림청',
#   '과장',
#   '산불',
#   '방지',
#   '박도',
#   '산사태',
#   '이용',
#   '산림',
#   '복지',
#   '시설',
#   '사업단',
#   '기획',
#   '황인',
#   '천국',
#   '유림',
#   '관리',
#   '소장',
#   '김만제'],
#  ['한국전력',
#   '직급',
#   '이동',
#   '본사',
#   '사실',
#   '최병우',
#   '홍보실',
#   '조기',
#   '에너지',
#   '사업단',
#   '기획',
#   '이경숙',
#   '전력',
#   '시장',
#   '선호',
#   '경영',
#   '개선',
#   '정복',
#   '상귀',
#   '재무',
#   '장호',
#   '파견',
#   '조성',
#   '노무',
#   '박형',
#   '자재',
#   '이종우',
#   '자산',
#   '관리처',
#   '강덕',
#   '영업',
#   '신기',
#   '전력',
#   '수급',
#   '처장',
#   '이재우',
#   '배전',
#   '계획',
#   '이준호',
#   '운영',
#   '이종환',
#   '상생',
#   '협력',
#   '유현',
#   '민원',
#   '대책',
#   '김준',
#   '기술',
#   '기획',
#   '동혁',
#   '기획',
#   '박장범',
#   '김용배',
#   '품질',
#   '경영',
#   '영성',
#   '계통',
#   '계획',
#   '건설처',
#   '이정원',
#   '석주',
#   '운영',
#   '김태익',
#   '해외',
#   '사업',
#   '개발',
#   '해외',
#   '발전',
#   '기술처',
#   '이상국',
#   '정보기술',
#   '한상태',
#   '중진',
#   '사업소',
#   '서울',
#   '지역',
#   '본부',
#   '이만근',
#   '김준호',
#   '성동',
#   '전력',
#   '지사',
#   '정운',
#   '서울',
#   '지역',
#   '본부',
#   '정익',
#   '영서',
#   '전력',
#   '지사',
#   '상권',
#   '인천',
#   '지역',
#   '본부',
#   '재흥',
#   '김포',
#   '지사',
#   '허완',
#   '제물포',
#   '강상',
#   '시흥',
#   '강정호',
#   '강화',
#   '김완',
#   '인천',
#   '전력',
#   '기탁',
#   '경기북부',
#   '지역',
#   '본부',
#   '유호',
#   '김종화',
#   '포천',
#   '지사',
#   '양평',
#   '준수',
#   '동두천',
#   '장창',
#   '가평',
#   '성훈',
#   '구리',
#   '전력',
#   '경기',
#   '지역',
#   '본부',
#   '신용석',
#   '정치',
#   '서수',
#   '원지',
#   '사장',
#   '전재',
#   '안성',
#   '흥원',
#   '화성',
#   '유화',
#   '광명',
#   '광엽',
#   '평택',
#   '전력',
#   '재형',
#   '강원',
#   '지역',
#   '본부',
#   '횡성',
#   '지사',
#   '노현',
#   '충북',
#   '지역',
#   '본부',
#   '신영식',
#   '김병헌',
#   '천지',
#   '사장',
#   '제천',
#   '서재영',
#   '괴산',
#   '상무',
#   '음성',
#   '김용',
#   '성영',
#   '대전충남',
#   '지역',
#   '본부',
#   '아산',
#   '지사',
#   '김영우',
#   '당진',
#   '김정',
#   '서산',
#   '김홍권',
#   '세종',
#   '최영상',
#   '공주',
#   '김병찬',
#   '예산',
#   '태안',
#   '이재',
#   '홍성',
#   '선주',
#   '부여',
#   '조원',
#   '금산',
#   '익선',
#   '아산',
#   '전력',
#   '두환',
#   '서산',
#   '전력',
#   '서문',
#   '전북',
#   '지역',
#   '본부',
#   '이태현',
#   '윤상',
#   '전주',
#   '지사',
#   '관영',
#   '고창',
#   '광주전남',
#   '지역',
#   '본부',
#   '권우',
#   '여수',
#   '지사',
#   '만기',
#   '순천',
#   '권욱',
#   '나주',
#   '박성철',
#   '해남',
#   '고은',
#   '고흥',
#   '상고',
#   '광양',
#   '수환',
#   '영광',
#   '이범익',
#   '순천',
#   '전력',
#   '봉선',
#   '강진',
#   '전력',
#   '김갑',
#   '대구경북',
#   '지역',
#   '본부',
#   '진열',
#   '광수',
#   '미지',
#   '사장',
#   '오태석',
#   '포항',
#   '안중',
#   '김천',
#   '김충환',
#   '영천',
#   '강헌',
#   '상주',
#   '김경호',
#   '영주',
#   '최성진',
#   '칠곡',
#   '정상원',
#   '성주',
#   '경종',
#   '의성',
#   '김종희',
#   '예천',
#   '기정',
#   '부산',
#   '울산',
#   '지역',
#   '본부',
#   '이건',
#   '장성',
#   '중부',
#   '산지',
#   '사장',
#   '이병',
#   '부산',
#   '상달',
#   '울산',
#   '전력',
#   '병고',
#   '부산',
#   '전력',
#   '조성준',
#   '경남',
#   '지역',
#   '본부',
#   '김지현',
#   '마산',
#   '지사',
#   '박무',
#   '거제',
#   '이명재',
#   '밀양',
#   '이상진',
#   '함안',
#   '영성',
#   '사천',
#   '김근환',
#   '창녕',
#   '정창',
#   '함안',
#   '전력',
#   '이관',
#   '진주',
#   '전력',
#   '제주',
#   '지역',
#   '본부',
#   '김영환',
#   '경인',
#   '건설처',
#   '중구',
#   '유성',
#   '서울',
#   '건설',
#   '지사',
#   '김태용',
#   '경기',
#   '건설',
#   '최준',
#   '중부',
#   '건설처',
#   '송백헌',
#   '충북',
#   '강원',
#   '건설',
#   '지사',
#   '세경',
#   '광주전남',
#   '건설',
#   '김정권',
#   '남부',
#   '건설처',
#   '김양수',
#   '대구경북',
#   '건설',
#   '지사',
#   '양준',
#   '인재',
#   '개발원',
#   '김정환',
#   '교육',
#   '정재완',
#   '전력연구원',
#   '박창용',
#   '자재',
#   '검사',
#   '처장',
#   '규환'],
#  ['한국수자원공사',
#   '상임',
#   '이사',
#   '부사장',
#   '이학수',
#   '경영',
#   '본부장',
#   '수자원',
#   '사업',
#   '차기',
#   '수도',
#   '사업',
#   '이진호'],
#  ['가스',
#   '기술',
#   '공사',
#   '승진',
#   '플랜',
#   '사업',
#   '정해',
#   '신성',
#   '기술',
#   '센터',
#   '이철호',
#   '삼척',
#   '기지',
#   '지사',
#   '조영',
#   '인천',
#   '김상돈',
#   '전북',
#   '김영호',
#   '경영',
#   '기획',
#   '이우재',
#   '총무',
#   '회계',
#   '유진',
#   '설계',
#   '김세윤',
#   '플랜트',
#   '사업',
#   '사실',
#   '이홍열',
#   '평택',
#   '기지',
#   '지사',
#   '이완',
#   '평택',
#   '상환',
#   '인천',
#   '구본화',
#   '충청',
#   '지사',
#   '조현준',
#   '전북',
#   '이국',
#   '대구경북',
#   '전우',
#   '전보',
#   '플랜트',
#   '사업',
#   '단장',
#   '영훈',
#   '총무',
#   '회계',
#   '처장',
#   '이영하',
#   '인사',
#   '노무',
#   '유인',
#   '인재',
#   '육성',
#   '센터',
#   '정종식',
#   '설계',
#   '처장',
#   '이철호',
#   '서울',
#   '지사',
#   '박창순',
#   '경기',
#   '허성',
#   '인천',
#   '우창',
#   '강원',
#   '김상돈',
#   '전북',
#   '광주전남',
#   '김영호',
#   '대구경북',
#   '기현',
#   '부산',
#   '경남',
#   '홍인',
#   '신성',
#   '기술',
#   '센터',
#   '최형기'],
#  ['가스',
#   '안전',
#   '공사',
#   '기획',
#   '조정실장',
#   '송수',
#   '인재',
#   '경영',
#   '처장',
#   '김병주',
#   '행정',
#   '지원',
#   '석봉',
#   '홍보실',
#   '문호',
#   '석유화학',
#   '진단',
#   '처장',
#   '노오',
#   '산업',
#   '시설',
#   '영규',
#   '부산',
#   '지역',
#   '본부장',
#   '재경',
#   '인천',
#   '해명',
#   '대전충남',
#   '정환',
#   '강원',
#   '충북',
#   '김한국',
#   '전북',
#   '임호',
#   '서울',
#   '서부',
#   '지사',
#   '서울',
#   '동부',
#   '종규',
#   '부산',
#   '북부',
#   '경북',
#   '동부',
#   '이제관',
#   '전남',
#   '서부',
#   '봉구',
#   '경기',
#   '서부',
#   '오복',
#   '경남',
#   '서부',
#   '원기',
#   '전략',
#   '기획부장',
#   '홍철',
#   '사업',
#   '예산',
#   '임기',
#   '노무',
#   '복지',
#   '총무',
#   '자산',
#   '관리',
#   '공장',
#   '심사',
#   '추석',
#   '코드',
#   '총괄',
#   '임성근',
#   '전지원',
#   '박성수',
#   '사고',
#   '조사',
#   '완수',
#   '기동',
#   '단속',
#   '김병호',
#   '안전',
#   '기기',
#   '이종국',
#   '제품',
#   '인증',
#   '김현기',
#   '장치',
#   '진단',
#   '원준',
#   '시설',
#   '진단',
#   '이명호',
#   '방식',
#   '진단',
#   '이종',
#   '배관',
#   '진단',
#   '윤영',
#   '굴착',
#   '공사',
#   '정보',
#   '지원',
#   '센터',
#   '교육',
#   '기획부장',
#   '이재용',
#   '기술',
#   '정책',
#   '연구',
#   '에너지',
#   '안전',
#   '실증',
#   '사업',
#   '단장',
#   '서원석',
#   '방호',
#   '시설',
#   '시험',
#   '부장',
#   '서울',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '행원',
#   '서울',
#   '서부',
#   '지사',
#   '검사',
#   '부장',
#   '이성희',
#   '서울',
#   '남부',
#   '지사',
#   '서울',
#   '동부',
#   '지사',
#   '문경',
#   '부산',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '김국진',
#   '경북',
#   '북부',
#   '지사',
#   '검사',
#   '부장',
#   '김태일',
#   '인천',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '홍철',
#   '검사',
#   '부장',
#   '이정호',
#   '전남',
#   '동부',
#   '지사',
#   '석유화학',
#   '부장',
#   '대전충남',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '김영섭',
#   '검사',
#   '부장',
#   '정경',
#   '울산',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '이경식',
#   '경기',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '정무',
#   '검사',
#   '부장',
#   '경기북부',
#   '지사',
#   '검사',
#   '부장',
#   '이충',
#   '검사',
#   '부장',
#   '이세정',
#   '경기',
#   '서부',
#   '지사',
#   '한명수',
#   '경기',
#   '동부',
#   '지사',
#   '검사',
#   '부장',
#   '검사',
#   '부장',
#   '김은정',
#   '경기',
#   '중부',
#   '지사',
#   '유호',
#   '강원',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '최용훈',
#   '원영',
#   '동지사',
#   '검사',
#   '부장',
#   '동주',
#   '전북',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '이영구',
#   '검사',
#   '부장',
#   '박진우',
#   '경남',
#   '지역',
#   '본부',
#   '교육',
#   '홍보',
#   '부장',
#   '태광',
#   '경남',
#   '서부',
#   '지사',
#   '검사',
#   '부장',
#   '대기'],
#  ['한국자산관리공사',
#   '승진',
#   '중소기업인',
#   '지원',
#   '부장',
#   '강남',
#   '자산',
#   '인수',
#   '기획',
#   '신덕',
#   '채권',
#   '인수',
#   '구영',
#   '국유재산',
#   '기획실장',
#   '희지',
#   '교육',
#   '파견',
#   '동어',
#   '감사',
#   '실장',
#   '용호',
#   '종합',
#   '기획부장',
#   '문병',
#   '인재',
#   '개발원',
#   '관리실장',
#   '국민',
#   '행복',
#   '지원',
#   '부장',
#   '김태수',
#   '투자',
#   '금융',
#   '장권',
#   '공공',
#   '자산',
#   '관리',
#   '박상원',
#   '공공',
#   '자산',
#   '개발',
#   '이치호',
#   '국유',
#   '증권',
#   '실장',
#   '강원',
#   '지역',
#   '본부',
#   '부본부장',
#   '박정희',
#   '서울',
#   '국유재산',
#   '의정부',
#   '지부장',
#   '경남',
#   '지역',
#   '본부',
#   '통영',
#   '강원',
#   '원주',
#   '최용',
#   '종합',
#   '기획부',
#   '인사부',
#   '동국',
#   '전보',
#   '서민',
#   '금융',
#   '지원',
#   '부장',
#   '서민',
#   '자활',
#   '지원',
#   '문희',
#   '국유재산',
#   '관리',
#   '양기',
#   '서울',
#   '지역',
#   '본부장',
#   '윤효중',
#   '경기',
#   '장성수',
#   '광주전남',
#   '대구경북',
#   '오용',
#   '인천',
#   '신흥',
#   '경남',
#   '영기',
#   '강원',
#   '장래',
#   '충북',
#   '자금',
#   '운용',
#   '실장',
#   '직무',
#   '대행',
#   '박정환',
#   '국유',
#   '건축',
#   '직무',
#   '대행',
#   '조성',
#   '경기',
#   '지역',
#   '본부',
#   '평택',
#   '지부장',
#   '차영',
#   '광주전남',
#   '목포',
#   '김광수',
#   '대구경북',
#   '포항',
#   '강원',
#   '춘천',
#   '김석'],
#  ['무역',
#   '보험',
#   '공사',
#   '승진',
#   '부서장',
#   '조사',
#   '부장',
#   '유승희',
#   '남부',
#   '심사',
#   '실장',
#   '이태희',
#   '팀장',
#   '기금',
#   '예산',
#   '팀장',
#   '김정탁',
#   '전자',
#   '유신',
#   '영업',
#   '지원',
#   '김홍익',
#   '부심',
#   '사실',
#   '책임',
#   '심사',
#   '종규',
#   '장경영',
#   '반장',
#   '김종직',
#   '전보',
#   '부서장',
#   '전략',
#   '기획부장',
#   '투자',
#   '금융',
#   '총괄',
#   '김호일',
#   '플랜트',
#   '금융',
#   '동윤',
#   '해외',
#   '투자',
#   '금융',
#   '김필',
#   '리스크',
#   '총괄',
#   '혜성',
#   '영업',
#   '총괄',
#   '김석희',
#   '지사',
#   '지모',
#   '중앙',
#   '박재형',
#   '강남',
#   '한상렬',
#   '충북',
#   '제주',
#   '이학',
#   '팀장',
#   '정보화',
#   '기획',
#   '팀장',
#   '후경',
#   '프로젝트',
#   '기획',
#   '무정',
#   '발전',
#   '담수',
#   '이희',
#   '중소',
#   '프로젝트',
#   '이종호',
#   '해외',
#   '사업',
#   '김기헌',
#   '미주',
#   '보상',
#   '김경환',
#   '채권',
#   '관리',
#   '기획',
#   '신상',
#   '법제',
#   '감리',
#   '기획',
#   '박성범',
#   '사실',
#   '책임',
#   '검사',
#   '이원석',
#   '특례',
#   '인수',
#   '반장',
#   '최윤',
#   '컨테이너',
#   '팀장',
#   '김영국',
#   '두바이',
#   '지사',
#   '개설',
#   '준비',
#   '위원',
#   '장진',
#   '멕시코시티',
#   '지사',
#   '상봉'],
#  ['전력',
#   '거래소',
#   '시장',
#   '개발',
#   '처장',
#   '김홍근',
#   '주지',
#   '사장',
#   '이건웅',
#   '전력',
#   '경제',
#   '연구실장',
#   '조강',
#   '시장',
#   '감시',
#   '실장',
#   '경영',
#   '지원',
#   '사옥',
#   '관리',
#   '팀장',
#   '김민',
#   '시장',
#   '개발',
#   '시장',
#   '개발',
#   '정보',
#   '보안',
#   '전략',
#   '비상',
#   '재난',
#   '안전',
#   '팀장',
#   '중선',
#   '정보기술',
#   '정보기술',
#   '팀장',
#   '이진수',
#   '계통',
#   '시스템',
#   '전력',
#   '경제',
#   '연구실',
#   '전력',
#   '경제',
#   '연구부장',
#   '기여',
#   '중부',
#   '지사',
#   '부장',
#   '이명희'],
#  ['한국소비자원',
#   '승진',
#   '기획',
#   '조정실',
#   '미래',
#   '전략',
#   '팀장',
#   '이정구',
#   '경영',
#   '지원',
#   '실장',
#   '정동영',
#   '데이터',
#   '사업',
#   '단장',
#   '최은',
#   '시험',
#   '검사국장',
#   '정진',
#   '해구',
#   '제국',
#   '광주',
#   '지원',
#   '이면상',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '부장',
#   '김종남',
#   '해구',
#   '제국',
#   '운영',
#   '전재',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '선덕',
#   '대외',
#   '협력',
#   '팀장',
#   '경태',
#   '해구',
#   '제국',
#   '전지원',
#   '김선화',
#   '기획',
#   '조정실',
#   '기획',
#   '예산',
#   '팀장',
#   '이상훈',
#   '정책',
#   '연구실',
#   '법제',
#   '연구',
#   '팀장',
#   '광석',
#   '시험',
#   '검사',
#   '전기',
#   '전자',
#   '팀장',
#   '양종철',
#   '전보',
#   '부서장',
#   '기획',
#   '조정실장',
#   '성기',
#   '대외',
#   '홍보',
#   '정책',
#   '연구',
#   '이득',
#   '소비자',
#   '정보',
#   '국장',
#   '재구',
#   '소비자',
#   '안전',
#   '국장',
#   '박정',
#   '서울',
#   '지원',
#   '김정',
#   '경기',
#   '팀장',
#   '기획',
#   '조정실',
#   '성과',
#   '평가',
#   '팀장',
#   '신국',
#   '경영',
#   '지원',
#   '운영',
#   '지원',
#   '병법',
#   '정보화',
#   '전략',
#   '태학',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '팀장',
#   '최윤선',
#   '기업',
#   '협력',
#   '현주',
#   '정책',
#   '연구실',
#   '소비자',
#   '시장',
#   '연구',
#   '팀장',
#   '황은',
#   '해구',
#   '제국',
#   '피해',
#   '구제',
#   '총괄',
#   '팀장',
#   '윤영',
#   '의료',
#   '팀장',
#   '경례',
#   '운영',
#   '팀장',
#   '김대중',
#   '시장',
#   '조사국',
#   '거래',
#   '조사',
#   '팀장',
#   '장은',
#   '약관',
#   '광고',
#   '한성준',
#   '국제',
#   '거래',
#   '지원',
#   '팀장',
#   '박두현',
#   '소비자',
#   '권익',
#   '증진',
#   '팀장',
#   '이기헌',
#   '소비자',
#   '정보국',
#   '소비자',
#   '정보',
#   '팀장',
#   '상식',
#   '교육',
#   '기획',
#   '팀장',
#   '이진숙',
#   '서비스',
#   '비교',
#   '팀장',
#   '소비자',
#   '안전국',
#   '생활',
#   '안전',
#   '팀장',
#   '의약',
#   '안전',
#   '안전',
#   '감시',
#   '팀장',
#   '윤경',
#   '시험',
#   '검사',
#   '시험',
#   '기획',
#   '이상호',
#   '식품',
#   '미생물',
#   '현희',
#   '화학',
#   '섬유',
#   '팀장',
#   '은주',
#   '기계',
#   '금속',
#   '이용주',
#   '분쟁',
#   '조정',
#   '사무국',
#   '조정',
#   '팀장',
#   '조정',
#   '선동',
#   '서울',
#   '지원',
#   '금융',
#   '보험',
#   '팀장',
#   '황기',
#   '서비스',
#   '팀장',
#   '홍인',
#   '섬유',
#   '식품',
#   '팀장',
#   '장인',
#   '경기',
#   '지원',
#   '자동차',
#   '팀장',
#   '김현유',
#   '주택',
#   '공산품',
#   '팀장',
#   '해구',
#   '제국',
#   '부산',
#   '지원',
#   '이경진',
#   '대구',
#   '윤하',
#   '강원',
#   '이선화',
#   '제주',
#   '여행',
#   '소비자',
#   '권익',
#   '증진',
#   '센터'],
#  ['국립산림과학원',
#   '과장',
#   '연구',
#   '기획',
#   '구교',
#   '산림',
#   '생태',
#   '연구',
#   '김경하',
#   '화학',
#   '미생물',
#   '성숙',
#   '산림생산기술연구소',
#   '성주'],
#  ['한국기계산업진흥회',
#   '상무이사',
#   '승진',
#   '진흥',
#   '본부장',
#   '정경',
#   '기술',
#   '교육원장',
#   '이은',
#   '수 공제',
#   '본부장'],
#  ['한국전시산업진흥회',
#   '승진',
#   '교육',
#   '홍보',
#   '팀장',
#   '김은희',
#   '전시',
#   '지원',
#   '전보',
#   '경영',
#   '기획',
#   '김용구'],
#  ['한국세라믹기술원',
#   '선임',
#   '본부장',
#   '서원',
#   '에너지',
#   '환경',
#   '소재',
#   '김영희',
#   '전자',
#   '융합',
#   '소재',
#   '황종희',
#   '기업',
#   '지원',
#   '김경자',
#   '이천',
#   '분원',
#   '김형태',
#   '경영',
#   '기획',
#   '본부장',
#   '임태영',
#   '융합',
#   '연구',
#   '사업',
#   '단장',
#   '서원',
#   '에너지',
#   '소재',
#   '센터',
#   '이명현',
#   '에코',
#   '복합',
#   '소재',
#   '전자',
#   '소재',
#   '부품',
#   '정호',
#   '디스플레이',
#   '소재',
#   '나노',
#   '융합',
#   '소재',
#   '기업',
#   '협력',
#   '주석',
#   '분석',
#   '인증',
#   '시뮬레이션',
#   '김현식',
#   '수도권',
#   '시험',
#   '분석',
#   '기업',
#   '지원',
#   '도자',
#   '세라믹',
#   '조우석',
#   '엔지니어링',
#   '세라믹',
#   '이성민',
#   '세라믹',
#   '섬유',
#   '복합',
#   '융합',
#   '바이오',
#   '세라믹',
#   '소재',
#   '정호',
#   '감사',
#   '실장',
#   '현주',
#   '연구',
#   '기획',
#   '김형준',
#   '경영',
#   '지원',
#   '박경원',
#   '전략',
#   '기획',
#   '동수',
#   '연구',
#   '지원',
#   '팀장',
#   '정철',
#   '운영',
#   '지원',
#   '명식'],
#  ['한국금융연구원',
#   '승진',
#   '연구',
#   '위원',
#   '형식',
#   '보직',
#   '발령',
#   '기획',
#   '협력',
#   '실장',
#   '이명',
#   '은행',
#   '보험',
#   '연구',
#   '서정호',
#   '국제',
#   '금융',
#   '연구',
#   '이윤석',
#   '해외',
#   '금융',
#   '협력',
#   '지원',
#   '센터',
#   '상제'],
#  ['대한건설협회',
#   '전보',
#   '산업',
#   '본부장',
#   '회원',
#   '만석',
#   '정책',
#   '직무',
#   '대리',
#   '조준현',
#   '정보',
#   '관리실장',
#   '상근',
#   '기술',
#   '정책실장',
#   '시장',
#   '개척',
#   '박승화',
#   '총무',
#   '지원',
#   '직무',
#   '대리',
#   '승현',
#   '파견',
#   '건설',
#   '산업',
#   '사회',
#   '공헌',
#   '재단',
#   '실장',
#   '진장'],
#  ['생명보험협회',
#   '승진',
#   '상무',
#   '대우',
#   '시장',
#   '자율',
#   '관리',
#   '본부장',
#   '김홍',
#   '부서장',
#   '장지원',
#   '부장',
#   '최성',
#   '보험',
#   '범죄',
#   '방지',
#   '실장',
#   '한기',
#   '고령',
#   '화지',
#   '최종윤',
#   '정보',
#   '시스템',
#   '허주',
#   '팀장',
#   '기획부',
#   '대외',
#   '협력',
#   '팀장',
#   '정문',
#   '자율',
#   '관리부',
#   '자격',
#   '관리',
#   '총무',
#   '총무',
#   '경리',
#   '김치',
#   '사회',
#   '공헌',
#   '센터',
#   '시회',
#   '공헌',
#   '정보',
#   '시스템',
#   '정보',
#   '서비스',
#   '여창',
#   '사회',
#   '공헌',
#   '센터',
#   '교육',
#   '김희',
#   '장지원',
#   '채널',
#   '전략',
#   '이주',
#   '전보',
#   '부서장',
#   '감사',
#   '실장',
#   '이재우',
#   '사회',
#   '공헌',
#   '센터',
#   '정훈',
#   '호남',
#   '지역',
#   '본부',
#   '장 현',
#   '영남',
#   '배철',
#   '총무부장',
#   '박병권',
#   '자율',
#   '관리부장',
#   '장승',
#   '수도권',
#   '지역',
#   '본부장',
#   '황영',
#   '팀장',
#   '장지원',
#   '계약',
#   '정보',
#   '지원',
#   '팀장',
#   '성화',
#   '자율',
#   '관리부',
#   '모집',
#   '질서',
#   '김관철',
#   '원주',
#   '지부장',
#   '병현'],
#  ['플러스',
#   '기획',
#   '경영',
#   '본부',
#   '기획',
#   '센터',
#   '이동',
#   '방송',
#   '본부',
#   '편성',
#   '센터',
#   '김윤주',
#   '방송',
#   '사업',
#   '본부',
#   '제작',
#   '센터',
#   '박성호',
#   '사업',
#   '센터',
#   '김태성',
#   '기획',
#   '경영',
#   '본부',
#   '기획',
#   '센터',
#   '홍보',
#   '마케팅',
#   '팀장',
#   '재연',
#   '광고',
#   '본부',
#   '광고',
#   '센터',
#   '광고',
#   '전략',
#   '방송',
#   '사업',
#   '본부',
#   '제작',
#   '센터',
#   '콘텐츠',
#   '조범',
#   '뮤직',
#   '센터',
#   '뮤직',
#   '사업',
#   '윤혁',
#   '사업',
#   '센터',
#   '글로벌',
#   '사업',
#   '경선',
#   '스포츠',
#   '본부',
#   '스포츠',
#   '센터',
#   '스포츠',
#   '마케팅',
#   '이상인',
#   '광고',
#   '본부',
#   '광고',
#   '센터',
#   '광고',
#   '세종',
#   '방송',
#   '사업',
#   '본부',
#   '편성',
#   '센터',
#   '에브리',
#   '뮤직',
#   '편성',
#   '제작',
#   '센터',
#   '에브리',
#   '제작',
#   '홍철'],
#  ['중앙일보',
#   '승격',
#   '기자',
#   '부국장',
#   '복지',
#   '전문',
#   '기자',
#   '신성',
#   '부장',
#   '대우',
#   '한경화',
#   '이은주',
#   '강찬호',
#   '제원',
#   '장세정',
#   '전형',
#   '선임',
#   '디자이너',
#   '최종윤'],
#  ['승격',
#   '기자',
#   '국장',
#   '대우',
#   '이규연',
#   '부국장',
#   '대우',
#   '진용',
#   '부장',
#   '대우',
#   '상경',
#   '이상복',
#   '장기하',
#   '임종',
#   '부국장',
#   '여운',
#   '경영',
#   '부장',
#   '방지',
#   '석호'],
#  ['중앙미디어네트워크', '승격', '수석', '부장', '안성호', '부장', '이상우'],
#  ['제이',
#   '콘텐트',
#   '승격',
#   '경영',
#   '수석',
#   '부장',
#   '곽도',
#   '부장',
#   '유상규',
#   '이경',
#   '현석',
#   '강용',
#   '명동'],
#  ['가천',
#   '외부',
#   '총장',
#   '김충식',
#   '국제',
#   '도성',
#   '대학원장',
#   '강민',
#   '간호',
#   '대학원',
#   '조경숙',
#   '교육',
#   '혜경',
#   '행정',
#   '이희선',
#   '산업',
#   '환경',
#   '박상준',
#   '게임',
#   '황보',
#   '사회과학',
#   '대학',
#   '승현',
#   '바이오나',
#   '강종',
#   '한의',
#   '김연',
#   '예술',
#   '광구',
#   '가천',
#   '리버럴',
#   '아츠',
#   '칼리지',
#   '이영미',
#   '중앙도서관',
#   '교무',
#   '처장',
#   '박종현',
#   '연구',
#   '윤영수',
#   '대학',
#   '평가',
#   '대외',
#   '협력',
#   '이희성',
#   '국제',
#   '교류',
#   '최경진',
#   '취업',
#   '진로',
#   '한기',
#   '신문',
#   '방송국',
#   '오대'],
#  ['강동', '경희대병원', '의대', '병원장', '호연', '고준'],
#  ['순천향대',
#   '중앙',
#   '의료원',
#   '의무',
#   '부총장',
#   '경호',
#   '중앙',
#   '의료원',
#   '기획',
#   '조정실장',
#   '이정재',
#   '순천향대',
#   '의과대학',
#   '의과대학',
#   '순천향대',
#   '서울',
#   '병원',
#   '병원장',
#   '서유',
#   '부원',
#   '변동',
#   '순천향대',
#   '부천',
#   '병원',
#   '병원장',
#   '이문',
#   '진료부',
#   '원장',
#   '대외',
#   '협력',
#   '부원',
#   '수재',
#   '순천향대',
#   '안병원',
#   '병원장',
#   '이문수',
#   '부원',
#   '박상',
#   '순천향대',
#   '구미',
#   '병원',
#   '병원장',
#   '부원',
#   '이태일'],
#  ['하나금융투자',
#   '승진',
#   '부사장',
#   '부문',
#   '진혁',
#   '상무',
#   '담당',
#   '강남',
#   'WM',
#   '센터',
#   '지점장',
#   '이만수',
#   '상무',
#   '영남',
#   '지역',
#   '본부장',
#   '김인규',
#   '분당',
#   '중앙',
#   '지점장',
#   '이성훈',
#   '미리',
#   '광주',
#   '리테일',
#   '마케팅',
#   '실장',
#   '경식',
#   '채권',
#   '금융',
#   '강순',
#   '이택주',
#   '사보',
#   '잠실',
#   '지점장',
#   '영업',
#   '부장',
#   '이형',
#   '청주',
#   '지점장',
#   '조창',
#   '수원',
#   '조시',
#   '미금역',
#   '신촌',
#   '조일환',
#   '압구정',
#   '장윤석',
#   '김민수',
#   '이희',
#   '선임',
#   '문장',
#   '부문',
#   '전영',
#   '법인',
#   '영업',
#   '조호',
#   '신명호',
#   '본부장',
#   '자본',
#   '시장',
#   '본부장',
#   '이윤형',
#   '충청',
#   '호남',
#   '지역',
#   '윤병구'],
#  ['투자',
#   '증권',
#   '임원',
#   '승진',
#   '전무',
#   '강남',
#   '금융',
#   '센터',
#   '이한',
#   '상무',
#   '비서실',
#   '정영철',
#   '기업',
#   '금융',
#   '센터',
#   '이영재',
#   '상무',
#   '리서치',
#   '센터',
#   '지윤',
#   '기업',
#   '금융',
#   '대호',
#   '법인',
#   '영업',
#   '허형',
#   '구조',
#   '금융',
#   '김대현'],
#  ['KB손해보험',
#   '승진',
#   '전무',
#   '개인',
#   '영업부',
#   '문장',
#   '김강현',
#   '상무',
#   '법인',
#   '영업부',
#   '문장',
#   '희재',
#   '경영',
#   '전략',
#   '본부장',
#   '김대현',
#   '신규',
#   '선임',
#   '상무',
#   '고객',
#   '부문',
#   '영산',
#   '상무',
#   '법인',
#   '영업',
#   '본부장',
#   '상주',
#   '본부장',
#   '개인',
#   '마케팅',
#   '본부장',
#   '이승배',
#   '장기',
#   '보험',
#   '전략',
#   '김재현',
#   '박명',
#   '해외',
#   '사업',
#   '창수',
#   '법인',
#   '영업',
#   '홍건표',
#   '임원',
#   '본부장',
#   '전보',
#   '전략',
#   '영업부',
#   '문장',
#   '전무',
#   '윤경',
#   '다이렉',
#   '부장',
#   '상무',
#   '평로',
#   '박경희',
#   '임원',
#   '호남',
#   '본부장',
#   '장형'],
#  ['KB투자증권',
#   '임원',
#   '승진',
#   '부사장',
#   '총괄',
#   '김성현',
#   '전무',
#   '기업',
#   '금융',
#   '본부장',
#   '박성원',
#   '상무',
#   '경영',
#   '지원',
#   '본부장',
#   '신규',
#   '임원',
#   '상무',
#   '기획실장',
#   '정민규',
#   '직원',
#   '승진',
#   '이사',
#   '이상오',
#   '민정',
#   '김민수',
#   '부장',
#   '금융',
#   '상품',
#   '영업',
#   '태우',
#   '영업',
#   '기획',
#   '최성필',
#   '스마트',
#   '금융',
#   '경영',
#   '관리',
#   '장동건',
#   '기획',
#   '김현수',
#   '부서장',
#   '보직',
#   '업무',
#   '개발',
#   '팀장',
#   '우경',
#   '증권',
#   '업무',
#   '이순정',
#   '금융',
#   '소비자보호',
#   '스마트',
#   '금융'],
#  ['헌법재판소',
#   '겸임',
#   '공보관',
#   '보유',
#   '동부',
#   '부장',
#   '연구관',
#   '사관',
#   '승진',
#   '심판',
#   '사무국장',
#   '김성수',
#   '국장',
#   '신임',
#   '정보',
#   '자료',
#   '국장',
#   '황병일',
#   '부이사관',
#   '승진',
#   '헌법재판소',
#   '비서관',
#   '김희',
#   '인사',
#   '관리과장',
#   '김기호',
#   '자료',
#   '총괄',
#   '윤용',
#   '과장',
#   '전보',
#   '기획',
#   '감사',
#   '유식',
#   '심판',
#   '민원',
#   '심판',
#   '사무',
#   '정수',
#   '심판',
#   '제도',
#   '상보',
#   '도서',
#   '정보',
#   '남궁',
#   '파견',
#   '국방',
#   '이성환',
#   '통일교육원',
#   '최준',
#   '과장',
#   '신임',
#   '홍보',
#   '담당관',
#   '이영일',
#   '국제',
#   '협력',
#   '신승훈',
#   '서기관',
#   '전보',
#   '재판관',
#   '비서관',
#   '진 하',
#   '홍보',
#   '담당관',
#   '이범',
#   '인사',
#   '관리',
#   '정영주',
#   '서기관',
#   '승진',
#   '정보화',
#   '기획',
#   '박민수'],
#  ['법무부',
#   '승진',
#   '법무부',
#   '소년',
#   '용범',
#   '서울보호관찰소',
#   '관찰',
#   '김기환',
#   '대전보호관찰소',
#   '서울소년원',
#   '교무',
#   '이용호',
#   '대구소년원',
#   '성수',
#   '대구소년원',
#   '분류',
#   '보호',
#   '이영미',
#   '대전소년원',
#   '박종국',
#   '광주소년원',
#   '교무',
#   '서진',
#   '서울소년분류심사원',
#   '분류',
#   '심사',
#   '김세훈',
#   '전보',
#   '법무부',
#   '국방',
#   '파견',
#   '진규',
#   '서울동부보호관찰소',
#   '정택현',
#   '서울',
#   '남부',
#   '최종',
#   '의정부',
#   '양봉화',
#   '인천보호관찰소',
#   '천지',
#   '소장',
#   '김시',
#   '수원보호관찰소',
#   '안산',
#   '근성',
#   '수원보호관찰소',
#   '천안',
#   '광주소년원',
#   '이영호',
#   '제주',
#   '소년',
#   '유병',
#   '서울소년분류심사원',
#   '안산청소년비행예방센터',
#   '김택수',
#   '대전보호관찰소',
#   '행정',
#   '지원',
#   '정원',
#   '대구보호관찰소',
#   '부산보호관찰소',
#   '성학',
#   '광주보호관찰소',
#   '이은하',
#   '서울소년원',
#   '대전소년원',
#   '교무',
#   '이상운',
#   '부산소년원',
#   '박준',
#   '부산소년원',
#   '분류',
#   '보호',
#   '광주소년원',
#   '김양곤'],
#  ['산림청',
#   '과장',
#   '산불',
#   '방지',
#   '박도',
#   '산사태',
#   '방지',
#   '이용',
#   '산림',
#   '복지',
#   '시설',
#   '사업단',
#   '기획',
#   '황인',
#   '천국',
#   '유림',
#   '관리',
#   '소장',
#   '김만제'],
#  ['문화재', '고위', '공무원', '국립무형유산원', '강경', '과장', '문화', '재활용', '세계유산', '팀장'],
#  ['국립생태원',
#   '지역',
#   '생태',
#   '협력',
#   '단장',
#   '실장',
#   '창조',
#   '협업',
#   '조정',
#   '협력',
#   '사업',
#   '대수',
#   '경영',
#   '지원',
#   '김태식',
#   '융합',
#   '연구',
#   '서창',
#   '생태',
#   '보전',
#   '연구',
#   '박은진',
#   '생태',
#   '평가',
#   '연구',
#   '진열',
#   '식물',
#   '관리',
#   '연구',
#   '하연',
#   '동물',
#   '관리',
#   '연구',
#   '전시',
#   '교육',
#   '방의석',
#   '감사',
#   '김웅',
#   '관리',
#   '경진',
#   '생태',
#   '기반',
#   '연구',
#   '정길상',
#   '생태',
#   '조사',
#   '연구',
#   '이중효',
#   '부장',
#   '총괄',
#   '조정',
#   '이재덕',
#   '인재',
#   '경영',
#   '창술',
#   '지역',
#   '협력',
#   '나기정',
#   '생태',
#   '협력',
#   '희천',
#   '기획',
#   '진철',
#   '정운용',
#   '김성중',
#   '총무',
#   '홍보',
#   '양호',
#   '온실',
#   '식물',
#   '주광',
#   '야외',
#   '식물',
#   '윤필용',
#   '동물병원',
#   '김영준',
#   '전시',
#   '교육',
#   '기획',
#   '진규',
#   '전시',
#   '운영',
#   '소란',
#   '교육',
#   '운영',
#   '생태',
#   '지식',
#   '문화',
#   '김웅',
#   '시설',
#   '안전',
#   '동물',
#   '관리',
#   '지덕'],
#  ['한국기계산업진흥회', '상무이사', '진흥', '본부장', '정경', '수 공제', '기술', '교육원장', '이은수'],
#  ['한국전시산업진흥회',
#   '승진',
#   '교육',
#   '홍보',
#   '팀장',
#   '김은희',
#   '전시',
#   '지원',
#   '전보',
#   '경영',
#   '기획',
#   '팀장',
#   '김용구'],
#  ['한국금융연구원',
#   '승진',
#   '연구',
#   '위원',
#   '형식',
#   '전보',
#   '실장',
#   '기획',
#   '협력',
#   '이명',
#   '은행',
#   '보험',
#   '연구',
#   '서정호',
#   '국제',
#   '금융',
#   '연구',
#   '이윤석',
#   '해외',
#   '금융',
#   '협력',
#   '지원',
#   '센터',
#   '상제'],
#  ['국립산림과학원',
#   '과장',
#   '연구',
#   '기획',
#   '구교',
#   '산림',
#   '생태',
#   '연구',
#   '김경하',
#   '화학',
#   '미생물',
#   '성숙',
#   '산림생산기술연구소',
#   '성주'],
#  ['한국소비자원',
#   '승진',
#   '기획',
#   '조정실',
#   '미래',
#   '전략',
#   '팀장',
#   '이정구',
#   '경영',
#   '지원',
#   '실장',
#   '정동영',
#   '데이터',
#   '사업',
#   '단장',
#   '최은',
#   '시험',
#   '검사국장',
#   '정진',
#   '해구',
#   '제국',
#   '광주',
#   '지원',
#   '이면상',
#   '대전',
#   '김선화',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '부장',
#   '김종남',
#   '선덕',
#   '해구',
#   '제국',
#   '운영',
#   '전재',
#   '대외',
#   '홍보실',
#   '대외',
#   '협력',
#   '팀장',
#   '경태',
#   '기획',
#   '조정실',
#   '기획',
#   '예산',
#   '이상훈',
#   '정책',
#   '연구실',
#   '법제',
#   '연구',
#   '광석',
#   '시험',
#   '검사',
#   '전기',
#   '전자',
#   '양종철',
#   '전보',
#   '부서장',
#   '기획',
#   '조정실장',
#   '성기',
#   '대외',
#   '홍보',
#   '정책',
#   '연구',
#   '이득',
#   '소비자',
#   '정보',
#   '국장',
#   '재구',
#   '소비자',
#   '안전',
#   '박정',
#   '서울',
#   '지원',
#   '김정',
#   '경기',
#   '팀장',
#   '기획',
#   '조정실',
#   '성과',
#   '평가',
#   '신국',
#   '경영',
#   '지원',
#   '운영',
#   '지원',
#   '병법',
#   '정보화',
#   '전략',
#   '태학',
#   '대외',
#   '홍보실',
#   '홍보',
#   '법무',
#   '최윤선',
#   '기업',
#   '협력',
#   '현주',
#   '정책',
#   '연구실',
#   '소비자',
#   '시장',
#   '연구',
#   '황은',
#   '해구',
#   '제국',
#   '피해',
#   '구제',
#   '총괄',
#   '윤영',
#   '의료',
#   '경례',
#   '운영',
#   '김대중',
#   '시장',
#   '조사국',
#   '거래',
#   '조사',
#   '장은',
#   '약관',
#   '광고',
#   '한성준',
#   '국제',
#   '거래',
#   '지원',
#   '박두현',
#   '소비자',
#   '권익',
#   '증진',
#   '이기헌',
#   '소비자',
#   '정보국',
#   '소비자',
#   '정보',
#   '상식',
#   '교육',
#   '기획',
#   '이진숙',
#   '서비스',
#   '비교',
#   '소비자',
#   '안전국',
#   '생활',
#   '안전',
#   '의약',
#   '안전',
#   '안전',
#   '감시',
#   '윤경',
#   '시험',
#   '검사',
#   '시험',
#   '기획',
#   '이상호',
#   '식품',
#   '미생물',
#   '현희',
#   '화학',
#   '섬유',
#   '은주',
#   '기계',
#   '금속',
#   '이용주',
#   '분쟁',
#   '조정',
#   '사무국',
#   '조정',
#   '조정',
#   '선동',
#   '서울',
#   '지원',
#   '금융',
#   '보험',
#   '황기',
#   '서비스',
#   '홍인',
#   '섬유',
#   '식품',
#   '장인',
#   '경기',
#   '지원',
#   '자동차',
#   '김현유',
#   '주택',
#   '공산품',
#   '해구',
#   '제국',
#   '부산',
#   '지원',
#   '이경진',
#   '대구',
#   '윤하',
#   '강원',
#   '이선화',
#   '제주',
#   '여행',
#   '소비자',
#   '권익',
#   '증진',
#   '센터'],
#  ['한국세라믹기술원',
#   '본부장',
#   '선임',
#   '서원',
#   '에너지',
#   '환경',
#   '소재',
#   '김영희',
#   '전자',
#   '융합',
#   '소재',
#   '황종희',
#   '기업',
#   '지원',
#   '김경자',
#   '경영',
#   '기획',
#   '임태영',
#   '이천',
#   '분원',
#   '김형태',
#   '융합',
#   '연구',
#   '사업',
#   '단장',
#   '서원',
#   '센터',
#   '에너지',
#   '소재',
#   '이명현',
#   '에코',
#   '복합',
#   '소재',
#   '전자',
#   '소재',
#   '부품',
#   '정호',
#   '디스플레이',
#   '소재',
#   '나노',
#   '융합',
#   '소재',
#   '기업',
#   '협력',
#   '주석',
#   '분석',
#   '인증',
#   '시뮬레이션',
#   '김현식',
#   '수도권',
#   '시험',
#   '분석',
#   '기업',
#   '지원',
#   '도자',
#   '세라믹',
#   '조우석',
#   '엔지니어링',
#   '세라믹',
#   '이성민',
#   '세라믹',
#   '섬유',
#   '복합',
#   '융합',
#   '바이오',
#   '세라믹',
#   '소재',
#   '정호',
#   '실장',
#   '감사',
#   '현주',
#   '연구',
#   '기획',
#   '김형준',
#   '경영',
#   '지원',
#   '박경원',
#   '전략',
#   '기획',
#   '동수',
#   '연구',
#   '지원',
#   '팀장',
#   '정철',
#   '운영',
#   '지원',
#   '명식'],
#  ['가스',
#   '안전',
#   '공사',
#   '전보',
#   '기획',
#   '조정실장',
#   '송수',
#   '홍보',
#   '문호',
#   '처장',
#   '인재',
#   '경영',
#   '김병주',
#   '행정',
#   '지원',
#   '석봉',
#   '석유화학',
#   '진단',
#   '노오',
#   '산업',
#   '시설',
#   '진단',
#   '영규',
#   '지역',
#   '본부장',
#   '부산',
#   '재경',
#   '인천',
#   '해명',
#   '대전충남',
#   '정환',
#   '강원',
#   '충북',
#   '김한국',
#   '전북',
#   '임호',
#   '지사장',
#   '서울',
#   '서부',
#   '서울',
#   '동부',
#   '종규',
#   '부산',
#   '북부',
#   '경북',
#   '동부',
#   '이제관',
#   '전남',
#   '서부',
#   '봉구',
#   '경기',
#   '서부',
#   '오복',
#   '경남',
#   '서부',
#   '원기',
#   '부장',
#   '전략',
#   '기획',
#   '홍철',
#   '사업',
#   '예산',
#   '임기',
#   '노무',
#   '복지',
#   '총무',
#   '자산',
#   '관리',
#   '공장',
#   '심사',
#   '추석',
#   '코드',
#   '총괄',
#   '임성근',
#   '전지원',
#   '박성수',
#   '사고',
#   '조사',
#   '완수',
#   '기동',
#   '단속',
#   '김병호',
#   '안전',
#   '기기',
#   '이종국',
#   '제품',
#   '인증',
#   '김현기',
#   '장치',
#   '진단',
#   '원준',
#   '시설',
#   '진단',
#   '이명호',
#   '방식',
#   '진단',
#   '이종',
#   '배관',
#   '진단',
#   '윤영',
#   '교육',
#   '기획',
#   '이재용',
#   '기술',
#   '정책',
#   '연구',
#   '방호',
#   '시설',
#   '시험',
#   '서울',
#   '지역',
#   '본부',
#   '검사',
#   '행원',
#   '서울',
#   '서부',
#   '지사',
#   '검사',
#   '이성희',
#   '서울',
#   '남부',
#   '지사',
#   '검사',
#   '서울',
#   '동부',
#   '지사',
#   '검사',
#   '문경',
#   '부산',
#   '지역',
#   '본부',
#   '검사',
#   '김국진',
#   '경북',
#   '북부',
#   '지사',
#   '검사',
#   '김태일',
#   '인천',
#   '지역',
#   '본부',
#   '검사',
#   '홍철',
#   '검사',
#   '이정호',
#   '전남',
#   '동부',
#   '지사',
#   '석유화학',
#   '대전충남',
#   '지역',
#   '본부',
#   '검사',
#   '김영섭',
#   '검사',
#   '정경',
#   '울산',
#   '지역',
#   '본부',
#   '검사',
#   '이경식',
#   '경기',
#   '지역',
#   '본부',
#   '검사',
#   '정무',
#   '검사',
#   '경기북부',
#   '지사',
#   '검사',
#   '이충',
#   '검사',
#   '이세정',
#   '경기',
#   '서부',
#   '지사',
#   '검사',
#   '한명수',
#   '경기',
#   '동부',
#   '지사',
#   '검사',
#   '검사',
#   '김은정',
#   '경기',
#   '중부',
#   '지사',
#   '검사',
#   '유호',
#   '강원',
#   '지역',
#   '본부',
#   '검사',
#   '최용훈',
#   '원영',
#   '동지사',
#   '검사',
#   '동주',
#   '전북',
#   '지역',
#   '본부',
#   '검사',
#   '이영구',
#   '검사',
#   '박진우',
#   '경남',
#   '지역',
#   '본부',
#   '교육',
#   '홍보',
#   '태광',
#   '경남',
#   '서부',
#   '지사',
#   '검사',
#   '대기',
#   '굴착',
#   '공사',
#   '정보',
#   '지원',
#   '센터',
#   '에너지',
#   '안전',
#   '실증',
#   '사업',
#   '단장',
#   '서원석'],
#  ['무역',
#   '보험',
#   '공사',
#   '승진',
#   '부서장',
#   '조사',
#   '부장',
#   '유승희',
#   '남부',
#   '심사',
#   '실장',
#   '이태희',
#   '팀장',
#   '기금',
#   '예산',
#   '팀장',
#   '김정탁',
#   '전자',
#   '유신',
#   '영업',
#   '지원',
#   '김홍익',
#   '부심',
#   '사실',
#   '책임',
#   '심사',
#   '종규',
#   '장경영',
#   '반장',
#   '김종직',
#   '전보',
#   '부서장',
#   '전략',
#   '기획부장',
#   '투자',
#   '금융',
#   '총괄',
#   '김호일',
#   '플랜트',
#   '금융',
#   '동윤',
#   '해외',
#   '투자',
#   '금융',
#   '김필',
#   '리스크',
#   '총괄',
#   '혜성',
#   '영업',
#   '총괄',
#   '김석희',
#   '지사',
#   '지모',
#   '중앙',
#   '박재형',
#   '강남',
#   '한상렬',
#   '충북',
#   '제주',
#   '이학',
#   '팀장',
#   '정보화',
#   '기획',
#   '팀장',
#   '후경',
#   '프로젝트',
#   '기획',
#   '무정',
#   '발전',
#   '담수',
#   '이희',
#   '중소',
#   '프로젝트',
#   '이종호',
#   '해외',
#   '사업',
#   '김기헌',
#   '미주',
#   '보상',
#   '김경환',
#   '채권',
#   '관리',
#   '기획',
#   '신상',
#   '법제',
#   '감리',
#   '기획',
#   '박성범',
#   '컨테이너',
#   '김영국',
#   '사실',
#   '책임',
#   '검사',
#   '이원석',
#   '특례',
#   '인수',
#   '반장',
#   '최윤',
#   '두바이',
#   '지사',
#   '개설',
#   '준비',
#   '위원',
#   '장진',
#   '멕시코시티',
#   '지사',
#   '상봉'],
#  ['한국전력',
#   '본사',
#   '사실',
#   '최병우',
#   '홍보실',
#   '조기',
#   '에너지',
#   '사업단',
#   '기획',
#   '이경숙',
#   '전력',
#   '시장',
#   '선호',
#   '경영',
#   '개선',
#   '정복',
#   '상귀',
#   '재무',
#   '장호',
#   '파견',
#   '조성',
#   '노무',
#   '박형',
#   '자재',
#   '이종우',
#   '자산',
#   '관리처',
#   '강덕',
#   '영업',
#   '신기',
#   '전력',
#   '수급',
#   '처장',
#   '이재우',
#   '배전',
#   '계획',
#   '이준호',
#   '배전',
#   '운영',
#   '이종환',
#   '상생',
#   '협력',
#   '유현',
#   '민원',
#   '대책',
#   '김준',
#   '기술',
#   '기획',
#   '동혁',
#   '기획',
#   '박장범',
#   '김용배',
#   '품질',
#   '경영',
#   '영성',
#   '계통',
#   '계획',
#   '건설처',
#   '이정원',
#   '석주',
#   '운영',
#   '김태익',
#   '해외',
#   '사업',
#   '개발',
#   '해외',
#   '발전',
#   '기술처',
#   '이상국',
#   '정보기술',
#   '한상태',
#   '중진',
#   '사업소',
#   '서울',
#   '지역',
#   '본부',
#   '이만근',
#   '김준호',
#   '성동',
#   '전력',
#   '지사',
#   '정운',
#   '서울',
#   '지역',
#   '본부',
#   '정익',
#   '영서',
#   '전력',
#   '지사',
#   '상권',
#   '인천',
#   '지역',
#   '본부',
#   '재흥',
#   '김포',
#   '지사',
#   '허완',
#   '제물포',
#   '강상',
#   '시흥',
#   '강정호',
#   '강화',
#   '김완',
#   '인천',
#   '전력',
#   '기탁',
#   '경기북부',
#   '지역',
#   '본부',
#   '유호',
#   '김종화',
#   '포천',
#   '지사',
#   '양평',
#   '준수',
#   '동두천',
#   '장창',
#   '가평',
#   '성훈',
#   '구리',
#   '전력',
#   '경기',
#   '지역',
#   '본부',
#   '신용석',
#   '정치',
#   '서수',
#   '원지',
#   '사장',
#   '전재',
#   '안성',
#   '흥원',
#   '화성',
#   '유화',
#   '광명',
#   '광엽',
#   '평택',
#   '전력',
#   '재형',
#   '강원',
#   '지역',
#   '본부',
#   '횡성',
#   '노현',
#   '충북',
#   '지역',
#   '본부',
#   '신영식',
#   '김병헌',
#   '천지',
#   '사장',
#   '제천',
#   '서재영',
#   '괴산',
#   '상무',
#   '음성',
#   '김용',
#   '성영',
#   '대전충남',
#   '지역',
#   '본부',
#   '아산',
#   '지사',
#   '김영우',
#   '당진',
#   '김정',
#   '서산',
#   '김홍권',
#   '세종',
#   '최영상',
#   '공주',
#   '김병찬',
#   '예산',
#   '태안',
#   '이재',
#   '홍성',
#   '선주',
#   '부여',
#   '조원',
#   '금산',
#   '익선',
#   '아산',
#   '전력',
#   '두환',
#   '서산',
#   '전력',
#   '서문',
#   '전북',
#   '지역',
#   '본부',
#   '이태현',
#   '윤상',
#   '전주',
#   '관영',
#   '고창',
#   '광주전남',
#   '지역',
#   '본부',
#   '권우',
#   '여수',
#   '지사',
#   '만기',
#   '순천',
#   '권욱',
#   '나주',
#   '박성철',
#   '해남',
#   '고은',
#   '고흥',
#   '상고',
#   '광양',
#   '수환',
#   '영광',
#   '이범익',
#   '순천',
#   '전력',
#   '봉선',
#   '강진',
#   '전력',
#   '김갑',
#   '대구경북',
#   '지역',
#   '본부',
#   '진열',
#   '광수',
#   '미지',
#   '사장',
#   '오태석',
#   '포항',
#   '안중',
#   '김천',
#   '김충환',
#   '영천',
#   '강헌',
#   '상주',
#   '김경호',
#   '영주',
#   '최성진',
#   '칠곡',
#   '정상원',
#   '성주',
#   '경종',
#   '의성',
#   '김종희',
#   '예천',
#   '기정',
#   '부산',
#   '울산',
#   '지역',
#   '본부',
#   '이건',
#   '장성',
#   '중부',
#   '산지',
#   '사장',
#   '이병',
#   '부산',
#   '상달',
#   '울산',
#   '전력',
#   '지사',
#   '병고',
#   '부산',
#   '전력',
#   '조성준',
#   '경남',
#   '지역',
#   '본부',
#   '김지현',
#   '마산',
#   '지사',
#   '박무',
#   '거제',
#   '이명재',
#   '밀양',
#   '이상진',
#   '함안',
#   '영성',
#   '사천',
#   '김근환',
#   '창녕',
#   '정창',
#   '함안',
#   '전력',
#   '이관',
#   '진주',
#   '전력',
#   '제주',
#   '지역',
#   '본부',
#   '김영환',
#   '경인',
#   '건설처',
#   '중구',
#   '유성',
#   '서울',
#   '건설',
#   '지사',
#   '김태용',
#   '경기',
#   '건설',
#   '최준',
#   '중부',
#   '건설처',
#   '송백헌',
#   '충북',
#   '강원',
#   '건설',
#   '지사',
#   '세경',
#   '광주전남',
#   '건설',
#   '김정권',
#   '남부',
#   '건설처',
#   '김양수',
#   '대구경북',
#   '건설',
#   '지사',
#   '양준',
#   '인재',
#   '개발원',
#   '김정환',
#   '인재',
#   '개발원',
#   '교육',
#   '정재완',
#   '전력연구원',
#   '박창용',
#   '자재',
#   '검사',
#   '처장',
#   '규환'],
#  ['전력',
#   '거래소',
#   '전보',
#   '시장',
#   '개발',
#   '처장',
#   '김홍근',
#   '주지',
#   '사장',
#   '이건웅',
#   '전력',
#   '경제',
#   '연구실장',
#   '조강',
#   '시장',
#   '감시',
#   '팀장',
#   '경영',
#   '지원',
#   '사옥',
#   '관리',
#   '김민',
#   '시장',
#   '개발',
#   '시장',
#   '개발',
#   '정보',
#   '보안',
#   '전략',
#   '비상',
#   '재난',
#   '안전',
#   '중선',
#   '정보기술',
#   '정보기술',
#   '이진수',
#   '계통',
#   '시스템',
#   '전력',
#   '경제',
#   '연구실',
#   '전력',
#   '경제',
#   '연구부장',
#   '기여',
#   '중부',
#   '지사',
#   '이명희'],
#  ['상임', '이사', '부사장', '이학수', '경영', '본부장', '수자원', '사업', '차기', '수도', '사업', '이진호'],
#  ['경북', '본부장', '이성원', '보도국장', '석현', '동부', '방송', '센터'],
#  ['환경TV',
#   '보도',
#   '제작국',
#   '국장',
#   '유재',
#   '뉴스',
#   '팀장',
#   '신준섭',
#   '콘텐츠',
#   '국장',
#   '콘텐츠',
#   '팀장',
#   '정순영',
#   '영기획',
#   '경영',
#   '기획실장',
#   '사업',
#   '국장',
#   '김영'],
#  ['가천',
#   '외부',
#   '총장',
#   '김충식',
#   '국제',
#   '도성',
#   '원장',
#   '대학',
#   '강민',
#   '간호',
#   '대학',
#   '조경숙',
#   '교육',
#   '대학',
#   '혜경',
#   '행정',
#   '대학',
#   '이희선',
#   '산업',
#   '환경',
#   '대학',
#   '박상준',
#   '게임',
#   '대학',
#   '황보',
#   '학장',
#   '사회과학',
#   '승현',
#   '바이오나',
#   '강종',
#   '의과',
#   '김연',
#   '예술대',
#   '광구',
#   '가천',
#   '리버럴',
#   '아츠',
#   '칼리지',
#   '이영미',
#   '중앙도서관',
#   '처장',
#   '교무',
#   '박종현',
#   '연구',
#   '윤영수',
#   '대학',
#   '평가',
#   '대외',
#   '협력',
#   '이희성',
#   '국제',
#   '교류',
#   '최경진',
#   '취업',
#   '진로',
#   '한기'],
#  ['경상대', '학장', '법과', '수의', '민원기', '해양', '학대', '김정균'],
#  ['금융',
#   '지주',
#   '승진',
#   '상무',
#   '사실',
#   '이후',
#   '전보',
#   '부장',
#   '글로벌',
#   '전략',
#   '성기',
#   '전략',
#   '기획',
#   '선종',
#   '경영',
#   '지원',
#   '이준혁'],
#  ['KEB하나은행',
#   '승진',
#   '부행장',
#   '자산',
#   '관리',
#   '그룹',
#   '박종영',
#   '글로벌',
#   '사업',
#   '그룹',
#   '유제',
#   '기업',
#   '고객',
#   '지원',
#   '그룹',
#   '윤규',
#   '영남',
#   '영업',
#   '그룹',
#   '윤석희',
#   '경영',
#   '지원',
#   '그룹',
#   '인산',
#   '전무',
#   '영업',
#   '지원',
#   '그룹',
#   '강성',
#   '자금시장',
#   '그룹',
#   '통합',
#   '지원단',
#   '김재영',
#   '변화',
#   '추진',
#   '대외',
#   '협력',
#   '본부',
#   '안영근',
#   '리테일',
#   '사업',
#   '본부',
#   '이형',
#   '일 강',
#   '서초',
#   '영업',
#   '본부',
#   '이호성',
#   '부산',
#   '영업',
#   '본부',
#   '리스크',
#   '관리',
#   '그룹',
#   '본부장',
#   '충남',
#   '영업',
#   '본부',
#   '태희',
#   '외환',
#   '본부',
#   '김선규',
#   '사업',
#   '본부',
#   '김성',
#   '세종',
#   '충북',
#   '영업',
#   '본부',
#   '김인석',
#   '부산',
#   '울산',
#   '영업',
#   '본부',
#   '김화',
#   '제주',
#   '영업',
#   '본부',
#   '문상',
#   '구로',
#   '영업',
#   '본부',
#   '세거',
#   '인천',
#   '영업',
#   '본부',
#   '영업',
#   '지원',
#   '본부',
#   '박종진',
#   '송파',
#   '영업',
#   '본부',
#   '박하',
#   '고객',
#   '보호',
#   '본부',
#   '백미',
#   '강서',
#   '영업',
#   '본부',
#   '만용',
#   '부천',
#   '안양',
#   '영업',
#   '본부',
#   '본부',
#   '글로벌',
#   '사업',
#   '그룹',
#   '소속',
#   '윤규',
#   '대전',
#   '영업',
#   '본부',
#   '충청',
#   '정책',
#   '원부',
#   '윤순',
#   '미래',
#   '금융',
#   '본부',
#   '이병렬',
#   '글로벌',
#   '사업',
#   '그룹',
#   '소속',
#   '이상용',
#   '영기획',
#   '그룹',
#   '이승열',
#   '수원',
#   '안산',
#   '영업',
#   '본부',
#   '정석화',
#   '전보',
#   '부행장',
#   '리테일',
#   '고객',
#   '지원',
#   '그룹',
#   '김정기',
#   '본부장',
#   '글로벌',
#   '사업',
#   '그룹',
#   '소속',
#   '강용',
#   '연금',
#   '사업',
#   '본부',
#   '박병규',
#   '업무',
#   '지원',
#   '본부',
#   '용산',
#   '마포',
#   '영업',
#   '본부',
#   '이선화',
#   '자금',
#   '운용',
#   '본부',
#   '이정욱',
#   '신탁',
#   '본부',
#   '이진형',
#   '검사실장',
#   '조성',
#   '부장',
#   '커뮤니케이션',
#   '김재화',
#   '홍보',
#   '김호',
#   '사회',
#   '공헌',
#   '문화부',
#   '정지연'],
#  ['KB국민카드',
#   '승진',
#   '전무',
#   '미래',
#   '사업',
#   '본부',
#   '정성호',
#   '선임',
#   '상무',
#   '리스크',
#   '관리',
#   '본부',
#   '한동욱',
#   '지원',
#   '본부',
#   '이인호',
#   '본부',
#   '김영찬',
#   '전보',
#   '상무',
#   '전략',
#   '영업',
#   '본부',
#   '재흥',
#   '정보',
#   '보호',
#   '본부',
#   '이철규'],
#  ['하나카드',
#   '승진',
#   '리스크',
#   '관리',
#   '본부',
#   '본부장',
#   '전보',
#   '고객',
#   '관리',
#   '본부',
#   '본부장',
#   '경영',
#   '전략',
#   '본부'],
#  ['생명',
#   '선임',
#   '본부장',
#   '전략',
#   '사업',
#   '이종문',
#   '경영',
#   '기획',
#   '오기',
#   '고객',
#   '지원',
#   '김대중',
#   '전보',
#   '본부장',
#   '사업',
#   '김세민',
#   '사업',
#   '이병용',
#   '영업',
#   '지원',
#   '유재'],
#  ['동부증권',
#   '승진',
#   '임원',
#   '재경',
#   '지역',
#   '본부',
#   '상무',
#   '우상',
#   '기획',
#   '관리',
#   '홍헌표',
#   '사업',
#   '부장',
#   '직무',
#   '대리',
#   '강성욱',
#   '준법',
#   '감시인',
#   '배수',
#   '충청',
#   '호남',
#   '지역',
#   '본부장',
#   '이병진',
#   '법인',
#   '영업',
#   '팀장',
#   '이동규',
#   '창원',
#   '지점장',
#   '전성욱',
#   '부산',
#   '위성',
#   '대전',
#   '김창호',
#   '전보',
#   '영업',
#   '부장',
#   '을지로',
#   '금융',
#   '센터',
#   '김성수',
#   '강남',
#   '금융',
#   '최성호',
#   '서초',
#   '지점장',
#   '진영',
#   '용산',
#   '신승',
#   '천안',
#   '이상용'],
#  ['현대증권',
#   '임원',
#   '경영',
#   '관리부',
#   '문장',
#   '성대',
#   '본부장',
#   '서일',
#   '채권',
#   '이병희',
#   '부서장',
#   '대체',
#   '투자',
#   '부동산',
#   '금융',
#   '실장',
#   '박연',
#   '법무',
#   '조용원',
#   '인수',
#   '금융',
#   '양현종',
#   '인재',
#   '개발',
#   '부장',
#   '김건우',
#   '정보',
#   '시스템',
#   '유동',
#   '전구',
#   '지점장',
#   '강동',
#   '배상',
#   '광명',
#   '김현',
#   '안산',
#   '혜정',
#   '장안',
#   '한형',
#   '충주',
#   '전보',
#   '부서장',
#   '고객',
#   '자산운용',
#   '지원',
#   '부장',
#   '강성훈',
#   '구조',
#   '금융',
#   '실장',
#   '최정한',
#   '금융',
#   '소비자보호',
#   '이해',
#   '이동규',
#   '지점장',
#   '구로',
#   '남현우',
#   '군산',
#   '광산',
#   '오현',
#   '광주',
#   '이홍규',
#   '광화문',
#   '이종승',
#   '목동',
#   '신종',
#   '상계',
#   '김재훈',
#   '익산',
#   '상현',
#   '전주',
#   '김원식',
#   '종로',
#   '용산',
#   'WMC',
#   '상선'],
#  ['SK증권', '채권', '본부장', '이창용'],
#  ['대신',
#   '금융',
#   '그룹',
#   '승진',
#   '대신증권',
#   '부서장',
#   '재무관리',
#   '부이',
#   '재우',
#   '부동산',
#   '관리부',
#   '업무',
#   '개발부',
#   '김종선',
#   '연금',
#   '사업',
#   '센터',
#   '이영철',
#   '구준회',
#   '법무',
#   '지원',
#   '박찬',
#   '심사',
#   '분석',
#   '부이',
#   '동수',
#   '홍콩',
#   '현지',
#   '법인',
#   '유열',
#   '지점장',
#   '광명',
#   '센터',
#   '재범',
#   '대림동',
#   '지점',
#   '신봉',
#   '지점',
#   '무거동',
#   '지점',
#   '김경민',
#   '해운대',
#   '지점',
#   '정지윤',
#   '부서장',
#   '상해',
#   '사무소',
#   '신제',
#   '차장',
#   '사실',
#   '양성우',
#   '재무관리',
#   '안수',
#   '인프라',
#   '서비스',
#   '승희',
#   '개발부',
#   '이승택',
#   '온라인',
#   '개발부',
#   '황종률',
#   '글로벌',
#   '마켓',
#   '전략',
#   '김영일',
#   '본부',
#   '고재욱',
#   '스마트',
#   '비즈니스',
#   '법무',
#   '지원',
#   '홍제',
#   '유신',
#   '부장',
#   '광화문',
#   '지점',
#   '신촌',
#   '지점',
#   '미영',
#   '안산',
#   '지점',
#   '일산',
#   '지점',
#   '김남숙',
#   '이촌동',
#   '지점',
#   '헌재',
#   '명일동',
#   '지점',
#   '세경',
#   '수원',
#   '지점',
#   '청담',
#   '지점',
#   '최경희',
#   '진주',
#   '지점',
#   '정연',
#   '동래',
#   '지점',
#   '지애',
#   '군산',
#   '지점',
#   '동화',
#   '청주',
#   '지점',
#   '홍순',
#   '광주',
#   '센터',
#   '유고',
#   '나주',
#   '지점',
#   '이승주',
#   '안산',
#   '지점',
#   '김해심',
#   '상무',
#   '지점',
#   '이선경',
#   '과장',
#   '전략',
#   '기획',
#   '박종희',
#   '정보',
#   '보호',
#   '김덕',
#   '알파',
#   '리서치',
#   '신탁',
#   '사업부',
#   '이준석',
#   '사업부',
#   '김정민',
#   '조지훈',
#   '리테일',
#   '상품',
#   '박재영',
#   '본부',
#   '법인',
#   '금융',
#   '상품',
#   '태원',
#   '금융',
#   '주치의',
#   '전략',
#   '김세옥',
#   '크레온',
#   '영업부',
#   '김민석',
#   '리스크',
#   '관리부',
#   '강석희',
#   '심사',
#   '분석',
#   '김재연',
#   '차장',
#   '압구정',
#   '지점',
#   '이동은',
#   '송탄',
#   '지점',
#   '김미선',
#   '무거동',
#   '지점',
#   '정욱',
#   '해운대',
#   '지점',
#   '전재',
#   '청주',
#   '지점',
#   '정현호',
#   '광양',
#   '지점',
#   '김수찬',
#   '목포',
#   '지점',
#   '울산',
#   '지점',
#   '민경',
#   '순천',
#   '지점',
#   '서지연',
#   '대신',
#   '저축',
#   '은행',
#   '지점장',
#   '남포동',
#   '지점',
#   '양재',
#   '차장',
#   '경영',
#   '기획부',
#   '김진우',
#   '심사부',
#   '유지',
#   '차장',
#   '남포동',
#   '지점',
#   '박정',
#   '과장',
#   '전산',
#   '전략',
#   '금융',
#   '성준',
#   '대신',
#   '자산운용',
#   '과장',
#   '주식',
#   '운용',
#   '본부',
#   '김종석',
#   '대신',
#   '경제',
#   '연구소',
#   '차장',
#   '금융공학',
#   '성민',
#   '대신',
#   '에프',
#   '아이',
#   '이사',
#   '투자',
#   '이동석',
#   '투자',
#   '전동',
#   '부부장',
#   '투자',
#   '김태형',
#   '이사',
#   '자산',
#   '관리',
#   '정진철',
#   '자산',
#   '관리',
#   '자산',
#   '관리',
#   '석호',
#   '부부장',
#   '원부',
#   '예지',
#   '선임',
#   '대신증권',
#   '부서장',
#   '미래',
#   '전략',
#   '강윤',
#   '글로벌',
#   '마켓',
#   '전략',
#   '오승훈',
#   '법인',
#   '금융',
#   '상품',
#   '김형준',
#   '글로벌',
#   '파생상품',
#   '김경훈',
#   '스마트',
#   '비즈니스',
#   '박성현',
#   '본부',
#   '이호철',
#   '지점장',
#   '부평',
#   '지점',
#   '송영',
#   '수지',
#   '지점',
#   '동래',
#   '지점',
#   '현미',
#   '군산',
#   '지점',
#   '직할',
#   '팀장',
#   '모바일',
#   '커뮤니케이션',
#   '이재훈',
#   '대신',
#   '저축',
#   '은행',
#   '준법',
#   '감시인',
#   '정성',
#   '직할',
#   '팀장',
#   '영업',
#   '추진',
#   '이성재',
#   '전보',
#   '대신증권',
#   '부서장',
#   '금융',
#   '주치의',
#   '전략',
#   '이성근',
#   '고객감동',
#   '센터',
#   '오행',
#   '신탁',
#   '사업부',
#   '이동수',
#   '지점장',
#   '목동',
#   '지점',
#   '정기동',
#   '광화문',
#   '지점',
#   '이연',
#   '노원',
#   '지점',
#   '영천',
#   '평촌',
#   '지점',
#   '진수',
#   '이촌동',
#   '지점',
#   '박성희',
#   '명일동',
#   '지점',
#   '서상',
#   '청주',
#   '지점',
#   '이병용',
#   '산지',
#   '오용',
#   '안산',
#   '지점',
#   '김송',
#   '일산',
#   '지점',
#   '이상덕',
#   '반포',
#   '지점',
#   '이석영',
#   '잠실',
#   '신천지',
#   '이범영',
#   '전주',
#   '지점',
#   '대신',
#   '저축',
#   '은행',
#   '서면',
#   '지점장',
#   '김현우',
#   '직할',
#   '팀장',
#   '감사',
#   '종수',
#   '팀장',
#   '압구정',
#   '지점',
#   '남포동',
#   '지점',
#   '구본',
#   '청담',
#   '지점',
#   '춘천',
#   '지점',
#   '안제'],
#  ['미래',
#   '그룹',
#   '승진',
#   '미래',
#   '자산운용',
#   '부장',
#   '부동산',
#   '자산',
#   '관리',
#   '본부',
#   '이준',
#   '마케팅',
#   '본부',
#   '정경',
#   '퇴직',
#   '연금',
#   '마케팅',
#   '본부',
#   '수진',
#   '차장',
#   '운용',
#   '본부',
#   '이창',
#   '부동산',
#   '투자',
#   '본부',
#   '김태헌',
#   '기금',
#   '자문',
#   '본부',
#   '정성진',
#   '컴플라이언스',
#   '본부',
#   '종언',
#   '상품',
#   '전략',
#   '본부',
#   '김형민',
#   '본부',
#   '김재훈',
#   '투자',
#   '본부',
#   '정준택',
#   '미래에셋증권',
#   '부장',
#   '기금',
#   '컨설팅',
#   '김성수',
#   '기업',
#   '금융',
#   '김진태',
#   '기업',
#   'RM',
#   '부문',
#   '본부',
#   '진성',
#   '강남',
#   '파이낸스',
#   '센터',
#   '조원태',
#   '차장',
#   '나루',
#   '지점',
#   '김미숙',
#   '범어동',
#   '지점',
#   '김희',
#   '코리아리서치센터',
#   '총무',
#   '이종민',
#   '미래',
#   '벤처',
#   '투자',
#   '벤처',
#   '투자',
#   '본부',
#   '부장',
#   '김경모',
#   '미래',
#   '펀드',
#   '서비스',
#   '개발',
#   '본부',
#   '개발',
#   '부장',
#   '방희',
#   '미래',
#   '피탈',
#   '감사',
#   '부장',
#   '정종',
#   '부동산',
#   '114',
#   '서비스',
#   '본부',
#   '부장',
#   '세련',
#   '서비스',
#   '본부',
#   '유추',
#   '리서치',
#   '센터',
#   '차장',
#   '김은지'],
#  ['BNK금융그룹',
#   '승진',
#   '전략',
#   '기획부',
#   '경호',
#   '승진',
#   '재무',
#   '기획부',
#   '서정우',
#   '승진',
#   '리스크',
#   '관리부',
#   '김문',
#   '부산은행',
#   '승진',
#   '영업부',
#   '박연',
#   '지점',
#   '허영',
#   '인사부',
#   '정영주',
#   '광안동',
#   '지점',
#   '김정훈',
#   '경영',
#   '기획부',
#   '강종',
#   '삼계',
#   '동지',
#   '이우',
#   '공단',
#   '지점',
#   '노상',
#   '검사부',
#   '성재',
#   '감전동',
#   '지점',
#   '손강',
#   '신탁',
#   '사업단',
#   '카드',
#   '사업단',
#   '김종구',
#   '여신',
#   '기획부',
#   '대진',
#   '금사',
#   '공단',
#   '지점',
#   '박선호',
#   '개발부',
#   '김영규',
#   '승진',
#   '당감동',
#   '지점',
#   '김동욱',
#   '금정',
#   '지점',
#   '송철호',
#   '안동',
#   '지점',
#   '이정용',
#   '양정동',
#   '지점',
#   '순조',
#   '지점',
#   '이한창',
#   '총무',
#   '김진영',
#   '포항',
#   '지점',
#   '김형수',
#   '언양',
#   '지점',
#   '부평',
#   '누리',
#   '지점',
#   '지점',
#   '재송동',
#   '지점',
#   '석홍',
#   '지점',
#   '정상',
#   '팔송',
#   '지점',
#   '금곡동',
#   '지점',
#   '대학',
#   '제니스',
#   '파크',
#   '지점',
#   '금민',
#   '우정동',
#   '지점',
#   '양산',
#   '공단',
#   '지점',
#   '김용식',
#   '삼산동',
#   '지점',
#   '상태',
#   '문현동',
#   '지점',
#   '기화',
#   '연천',
#   '지점',
#   '이병수',
#   '자금',
#   '증권',
#   '김해수',
#   '인사부',
#   '경화',
#   '인사부',
#   '조사',
#   '강석',
#   '서면',
#   '지점',
#   '김해',
#   '화전',
#   '공단',
#   '지점',
#   '정철',
#   '여신',
#   '감리',
#   '임호',
#   '검사부',
#   '정성영',
#   '금융',
#   '시장',
#   '원부',
#   '정희',
#   '개발부',
#   '이홍기'],
#  ['생명보험협회',
#   '승진',
#   '상무',
#   '대우',
#   '시장',
#   '자율',
#   '관리',
#   '본부장',
#   '김홍',
#   '부서장',
#   '장지원',
#   '부장',
#   '최성',
#   '보험',
#   '범죄',
#   '방지',
#   '실장',
#   '한기',
#   '고령',
#   '화지',
#   '최종윤',
#   '정보',
#   '시스템',
#   '허주',
#   '팀장',
#   '기획부',
#   '대외',
#   '협력',
#   '정문',
#   '자율',
#   '관리부',
#   '자격',
#   '관리',
#   '총무',
#   '총무',
#   '경리',
#   '김치',
#   '사회',
#   '공헌',
#   '센터',
#   '시회',
#   '공헌',
#   '정보',
#   '시스템',
#   '정보',
#   '서비스',
#   '여창',
#   '사회',
#   '공헌',
#   '센터',
#   '교육',
#   '김희',
#   '장지원',
#   '채널',
#   '전략',
#   '이주',
#   '전보',
#   '부서장',
#   '감사',
#   '실장',
#   '이재우',
#   '사회',
#   '공헌',
#   '센터',
#   '정훈',
#   '호남',
#   '지역',
#   '본부',
#   '장 현',
#   '영남',
#   '배철',
#   '수도권',
#   '황영',
#   '총무부장',
#   '박병권',
#   '자율',
#   '관리',
#   '장승',
#   '전보',
#   '팀장',
#   '장지원',
#   '계약',
#   '정보',
#   '지원',
#   '성화',
#   '자율',
#   '관리부',
#   '모집',
#   '질서',
#   '김관철',
#   '원주',
#   '지부장',
#   '병현'],
#  ['동아',
#   '그룹',
#   '승진',
#   '전무이사',
#   '경영',
#   '관리',
#   '본부',
#   '홍기',
#   '전무',
#   '연구',
#   '본부',
#   '문호',
#   '상무',
#   '혁신',
#   '신약',
#   '연구소',
#   '윤태영',
#   '이사',
#   '대우',
#   '경영',
#   '기획',
#   '정경운',
#   '추진단',
#   '정철',
#   '인재',
#   '개발원',
#   '김풍',
#   '국내',
#   '법무',
#   '해외',
#   '법무',
#   '분자',
#   '약리',
#   '연구',
#   '신준호',
#   '동아',
#   'ST',
#   '전무',
#   '연구',
#   '기획',
#   '관리실',
#   '미원',
#   '생산',
#   '본부',
#   '이주섭',
#   '영업',
#   '본부',
#   '김학',
#   '상무',
#   '경영',
#   '지원',
#   '이종',
#   '학술',
#   '약실',
#   '유석',
#   '병원',
#   '사업부',
#   '용승',
#   '신약',
#   '연구소',
#   '원빈',
#   '이사',
#   '대우',
#   '개발',
#   '지원',
#   '박인수',
#   '개발',
#   '기획',
#   '철수',
#   '임상',
#   '오태영',
#   '달성',
#   '공장',
#   '호준',
#   '종합병원',
#   '사업부',
#   '서울',
#   '지점',
#   '경기',
#   '지점',
#   '해룡',
#   '강원',
#   '지점',
#   '승주',
#   '제품',
#   '개발',
#   '연구소',
#   '장선우',
#   '동아제약',
#   '상무',
#   '박카스',
#   '사업부',
#   '박정우',
#   '이사',
#   '대우',
#   '달성',
#   '공장',
#   '김진구',
#   '약국',
#   '지점',
#   '김용운',
#   '동아오츠카',
#   '상무',
#   '커뮤니케이션',
#   '이진숙',
#   '이사',
#   '대우',
#   '경영',
#   '전략',
#   '유통',
#   'SU',
#   '홍성호',
#   '용마로지스',
#   '상무이사',
#   '영업',
#   '본부',
#   '중식',
#   '상무',
#   '운영',
#   '본부',
#   '이종철',
#   '스티',
#   '전무',
#   '구부',
#   '정경',
#   '합성',
#   '연구부',
#   '김경진',
#   '상무',
#   '경영',
#   '지원',
#   '동렬',
#   '이사',
#   '대우',
#   '최경',
#   '수석',
#   '상무',
#   '관리부',
#   '윤경',
#   '호진',
#   '이사',
#   '대우',
#   '총무',
#   '이사',
#   '대우',
#   '총무',
#   '권오길',
#   '장철'],
#  ['중흥',
#   '건설',
#   '승진',
#   '전무이사',
#   '건축',
#   '장세',
#   '상무이사',
#   '건축',
#   '진용',
#   '토목',
#   '고지후',
#   '안전부',
#   '서우진',
#   '기획부',
#   '신경식',
#   '공관',
#   '문영미',
#   '상무이사',
#   '대우',
#   '건축',
#   '상규',
#   '경리부',
#   '박해정'],
#  ['동부하이텍', '승진', '부사장', '조기석', '선임', '상무'],
#  ['홈플러스', '대표', '이사', '김상현'],
#  ['대표', '이사', '한가지'],
#  ['헌법재판소',
#   '겸임',
#   '공보관',
#   '보유',
#   '사관',
#   '승진',
#   '심판',
#   '사무국장',
#   '김성수',
#   '국장',
#   '신규',
#   '정보',
#   '자료',
#   '국장',
#   '황병일',
#   '부이사관',
#   '승진',
#   '헌재',
#   '소장',
#   '비서관',
#   '김희',
#   '인사',
#   '관리과장',
#   '김기호',
#   '자료',
#   '총괄',
#   '윤용',
#   '과장',
#   '전보',
#   '기획',
#   '감사',
#   '유식',
#   '심판',
#   '민원',
#   '심판',
#   '사무',
#   '정수',
#   '심판',
#   '제도',
#   '상보',
#   '도서',
#   '정보',
#   '남궁',
#   '국방',
#   '파견',
#   '이성환',
#   '통일교육원',
#   '최준',
#   '과장',
#   '신규',
#   '홍보',
#   '담당관',
#   '이영일',
#   '국제',
#   '협력',
#   '신승훈',
#   '서기관',
#   '전보',
#   '재판관',
#   '비서관',
#   '진 하',
#   '홍보',
#   '담당관',
#   '이범',
#   '인사',
#   '관리',
#   '정영주',
#   '서기관',
#   '승진',
#   '정보화',
#   '기획',
#   '박민수'],
#  ['법무부',
#   '승진',
#   '소년',
#   '용범',
#   '서울보호관찰소',
#   '관찰',
#   '김기환',
#   '대전',
#   '서울소년원',
#   '교무',
#   '이용호',
#   '대구',
#   '성수',
#   '광주',
#   '서진',
#   '대구소년원',
#   '분류',
#   '보호',
#   '이영미',
#   '대전',
#   '박종국',
#   '서울소년분류심사원',
#   '분류',
#   '심사',
#   '김세훈',
#   '전보',
#   '국방',
#   '파견',
#   '진규',
#   '서울동부보호관찰소',
#   '정택현',
#   '서울',
#   '남부',
#   '최종',
#   '의정부',
#   '양봉화',
#   '인천보호관찰소',
#   '천지',
#   '소장',
#   '김시',
#   '수원',
#   '안산',
#   '근성',
#   '수원',
#   '천안',
#   '광주소년원',
#   '이영호',
#   '제주',
#   '유병',
#   '서울소년분류심사원',
#   '안산청소년비행예방센터',
#   '김택수',
#   '대전보호관찰소',
#   '행정',
#   '지원',
#   '정원',
#   '대구',
#   '부산',
#   '성학',
#   '광주',
#   '이은하',
#   '서울소년원',
#   '행정',
#   '지원',
#   '부산소년원',
#   '교무',
#   '박준',
#   '대전',
#   '이상운',
#   '부산소년원',
#   '분류',
#   '보호',
#   '광주',
#   '김양곤'],
#  ['해양수산부',
#   '장관',
#   '정책',
#   '보좌관',
#   '김희',
#   '이창호',
#   '과장',
#   '전보',
#   '장관',
#   '비서실장',
#   '이경규',
#   '창조',
#   '행정',
#   '담당관',
#   '권순욱',
#   '항로',
#   '표지',
#   '김영',
#   '부산지방해양수산청',
#   '선원',
#   '해사',
#   '안전',
#   '최국',
#   '동해지방해양수산청',
#   '공평',
#   '포항',
#   '지방',
#   '석홍',
#   '국립',
#   '양조',
#   '사원',
#   '해도',
#   '수로'],
#  ['문화재', '전보', '고위', '공무원', '국립무형유산원', '강경', '과장', '문화', '재활용', '세계유산', '팀장'],
#  ['국립산림과학원',
#   '과장',
#   '연구',
#   '기획',
#   '구교',
#   '산림',
#   '생태',
#   '연구',
#   '김경하',
#   '화학',
#   '미생물',
#   '성숙',
#   '산림생산기술연구소',
#   '성주'],
#  ['한국금융연구원',
#   '승진',
#   '연구',
#   '위원',
#   '형식',
#   '보직',
#   '발령',
#   '기획',
#   '협력',
#   '실장',
#   '이명',
#   '은행',
#   '보험',
#   '연구',
#   '서정호',
#   '국제',
#   '금융',
#   '연구',
#   '이윤석',
#   '해외',
#   '금융',
#   '협력',
#   '지원',
#   '센터',
#   '상제'],
#  ['한국석유관리원',
#   '전보',
#   '처장',
#   '사업',
#   '관리',
#   '김진우',
#   '수급',
#   '정보',
#   '승현',
#   '본부장',
#   '대전충남',
#   '김동길',
#   '충북',
#   '김완',
#   '영남',
#   '강동'],
#  ['상임', '이사', '부사장', '이학수', '경영', '본부장', '수자원', '사업', '차기', '수도', '사업', '이진호'],
#  ['한국전력공사',
#   '전보',
#   '사실',
#   '최병우',
#   '홍보실',
#   '조기',
#   '에너지',
#   '사업단',
#   '기획',
#   '이경숙',
#   '전력',
#   '시장',
#   '선호',
#   '경영',
#   '개선',
#   '정복',
#   '상귀',
#   '재무',
#   '장호',
#   '파견',
#   '조성',
#   '노무',
#   '박형',
#   '자재',
#   '이종우',
#   '자산',
#   '관리처',
#   '강덕',
#   '영업',
#   '신기',
#   '전력',
#   '수급',
#   '처장',
#   '이재우',
#   '배전',
#   '계획',
#   '이준호',
#   '배전',
#   '운영',
#   '이종환',
#   '상생',
#   '협력',
#   '유현',
#   '민원',
#   '대책',
#   '김준',
#   '기술',
#   '기획',
#   '동혁',
#   '기획',
#   '박장범',
#   '김용배',
#   '품질',
#   '경영',
#   '영성',
#   '계통',
#   '계획',
#   '건설처',
#   '이정원',
#   '석주',
#   '운영',
#   '김태익',
#   '해외',
#   '사업',
#   '개발',
#   '해외',
#   '발전',
#   '기술처',
#   '이상국',
#   '정보기술',
#   '한상태',
#   '중진',
#   '서울',
#   '지역',
#   '본부',
#   '이만근',
#   '김준호',
#   '성동',
#   '전력',
#   '지사',
#   '정운',
#   '서울',
#   '지역',
#   '본부',
#   '정익',
#   '영서',
#   '전력',
#   '지사',
#   '상권',
#   '인천',
#   '지역',
#   '본부',
#   '재흥',
#   '김포',
#   '지사',
#   '허완',
#   '제물포',
#   '지사',
#   '강상',
#   '시흥',
#   '지사',
#   '강정호',
#   '강화',
#   '지사장',
#   '김완',
#   '인천',
#   '전력',
#   '지사',
#   '기탁',
#   '경기북부',
#   '지역',
#   '본부',
#   '유호',
#   '김종화',
#   '포천',
#   '지사',
#   '양평',
#   '지사',
#   '준수',
#   '동두천',
#   '지사',
#   '장창',
#   '가평',
#   '지사',
#   '성훈',
#   '구리',
#   '전력',
#   '지사',
#   '경기',
#   '지역',
#   '본부',
#   '신용석',
#   '정치',
#   '서수',
#   '원지',
#   '사장',
#   '전재',
#   '성지',
#   '사장',
#   '흥원',
#   '화성',
#   '지사',
#   '유화',
#   '광명',
#   '지사',
#   '광엽',
#   '평택',
#   '전력',
#   '지사',
#   '재형',
#   '강원',
#   '지역',
#   '본부',
#   '횡성',
#   '지사',
#   '노현',
#   '충북',
#   '지역',
#   '본부',
#   '신영식',
#   '김병헌',
#   '천지',
#   '사장',
#   '천지',
#   '사장',
#   '서재영',
#   '괴산',
#   '지사',
#   '상무',
#   '음성',
#   '지사',
#   '김용',
#   '지사',
#   '성영',
#   '대전충남',
#   '지역',
#   '본부',
#   '아산',
#   '지사',
#   '김영우',
#   '진지',
#   '사장',
#   '김정',
#   '서산',
#   '지사',
#   '김홍권',
#   '세종',
#   '지사',
#   '최영상',
#   '공주',
#   '지사',
#   '김병찬',
#   '예산',
#   '지사',
#   '태안',
#   '지사',
#   '이재',
#   '홍성지',
#   '사장',
#   '선주',
#   '부여',
#   '지사',
#   '조원',
#   '금산',
#   '지사',
#   '익선',
#   '아산',
#   '전력',
#   '지사',
#   '두환',
#   '서산',
#   '전력',
#   '지사',
#   '서문',
#   '전북',
#   '지역',
#   '본부',
#   '이태현',
#   '윤상',
#   '전주',
#   '지사',
#   '관영',
#   '고창',
#   '지사',
#   '광주전남',
#   '지역',
#   '본부',
#   '권우',
#   '여수',
#   '지사',
#   '만기',
#   '순천',
#   '지사',
#   '권욱',
#   '나주',
#   '지사',
#   '박성철',
#   '해남',
#   '지사',
#   '고은',
#   '고흥',
#   '지사',
#   '상고',
#   '광양',
#   '지사',
#   '수환',
#   '영광',
#   '지사',
#   '이범익',
#   '순천',
#   '전력',
#   '지사',
#   '봉선',
#   '강진',
#   '전력',
#   '지사',
#   '김갑',
#   '대구경북',
#   '지역',
#   '본부',
#   '진열',
#   '광수',
#   '미지',
#   '사장',
#   '오태석',
#   '포항',
#   '지사',
#   '안중',
#   '천지',
#   '사장',
#   '김충환',
#   '영천',
#   '지사',
#   '강헌',
#   '상주',
#   '지사',
#   '김경호',
#   '영주',
#   '지사',
#   '최성진',
#   '칠곡',
#   '지사',
#   '정상원',
#   '성주',
#   '지사',
#   '경종',
#   '의성',
#   '지사',
#   '김종희',
#   '천지',
#   '사장',
#   '기정',
#   '부산',
#   '울산',
#   '지역',
#   '본부',
#   '이건',
#   '장성',
#   '중부',
#   '산지',
#   '사장',
#   '이병',
#   '북부',
#   '산지',
#   '사장',
#   '상달',
#   '울산',
#   '전력',
#   '지사',
#   '병고',
#   '부산',
#   '전력',
#   '지사',
#   '조성준',
#   '경남',
#   '지역',
#   '본부',
#   '김지현',
#   '마산',
#   '지사',
#   '박무',
#   '제지',
#   '사장',
#   '이명재',
#   '밀양',
#   '지사',
#   '이상진',
#   '함안',
#   '지사',
#   '영성',
#   '사천',
#   '지사',
#   '김근환',
#   '창녕',
#   '지사',
#   '정창',
#   '함안',
#   '전력',
#   '지사',
#   '이관',
#   '진주',
#   '전력',
#   '지사',
#   '제주',
#   '지역',
#   '본부',
#   '김영환',
#   '경인',
#   '건설처',
#   '중구',
#   '유성',
#   '서울',
#   '건설',
#   '지사',
#   '김태용',
#   '경기',
#   '건설',
#   '지사',
#   '최준',
#   '중부',
#   '건설처',
#   '송백헌',
#   '충북',
#   '강원',
#   '건설',
#   '지사',
#   '세경',
#   '광주전남',
#   '건설',
#   '지사',
#   '김정권',
#   '남부',
#   '건설처',
#   '김양수',
#   '대구경북',
#   '건설',
#   '지사',
#   '양준',
#   '인재',
#   '개발원',
#   '김정환',
#   '교육',
#   '정재완',
#   '전력연구원',
#   '박창용',
#   '자재',
#   '검사',
#   '처장',
#   '규환'],
#  ['가스',
#   '안전',
#   '공사',
#   '전보',
#   '기획',
#   '조정실장',
#   '송수',
#   '인재',
#   '경영',
#   '처장',
#   '김병주',
#   '행정',
#   '지원',
#   '석봉',
#   '홍보실',
#   '문호',
#   '석유화학',
#   '진단',
#   '처장',
#   '노오',
#   '산업',
#   '시설',
#   '진단',
#   '영규',
#   '부산',
#   '지역',
#   '본부장',
#   '재경',
#   '인천',
#   '지역',
#   '해명',
#   '대전충남',
#   '지역',
#   '정환',
#   '강원',
#   '지역',
#   '충북',
#   '지역',
#   '김한국',
#   '전북',
#   '지역',
#   '임호',
#   '서울',
#   '서부',
#   '지사',
#   '서울',
#   '동부',
#   '종규',
#   '부산',
#   '북부',
#   '경북',
#   '동부',
#   '이제관',
#   '전남',
#   '서부',
#   '봉구',
#   '경기',
#   '서부',
#   '오복',
#   '경남',
#   '서부',
#   '원기',
#   '전략',
#   '기획부장',
#   '홍철',
#   '사업',
#   '예산',
#   '임기',
#   '노무',
#   '복지',
#   '총무',
#   '자산',
#   '관리',
#   '공장',
#   '심사',
#   '추석',
#   '코드',
#   '총괄',
#   '임성근',
#   '전지원',
#   '박성수',
#   '사고',
#   '조사',
#   '완수',
#   '기동',
#   '단속',
#   '김병호',
#   '안전',
#   '기기',
#   '이종국',
#   '제품',
#   '인증',
#   '김현기',
#   '장치',
#   '진단',
#   '원준',
#   '시설',
#   '진단',
#   '이명호',
#   '방식',
#   '진단',
#   '이종',
#   '배관',
#   '진단',
#   '윤영',
#   '굴착',
#   '공사',
#   '정보',
#   '지원',
#   '센터',
#   '교육',
#   '기획부장',
#   '이재용',
#   '기술',
#   '정책',
#   '연구',
#   '에너지',
#   '안전',
#   '실증',
#   '사업',
#   '단장',
#   '서원석',
#   '방호',
#   '시설',
#   '시험',
#   '부장',
#   '서울',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '행원',
#   '서울',
#   '서부',
#   '지사',
#   '검사',
#   '부장',
#   '이성희',
#   '서울',
#   '남부',
#   '지사',
#   '서울',
#   '동부',
#   '지사',
#   '문경',
#   '부산',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '김국진',
#   '경북',
#   '북부',
#   '지사',
#   '검사',
#   '부장',
#   '김태일',
#   '인천',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '홍철',
#   '검사',
#   '부장',
#   '이정호',
#   '전남',
#   '동부',
#   '지사',
#   '석유화학',
#   '부장',
#   '대전충남',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '김영섭',
#   '검사',
#   '부장',
#   '정경',
#   '울산',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '이경식',
#   '경기',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '정무',
#   '검사',
#   '부장',
#   '경기북부',
#   '지사',
#   '검사',
#   '부장',
#   '이충',
#   '검사',
#   '부장',
#   '이세정',
#   '경기',
#   '서부',
#   '지사',
#   '검사',
#   '부장',
#   '한명수',
#   '경기',
#   '동부',
#   '지사',
#   '검사',
#   '부장',
#   '검사',
#   '부장',
#   '김은정',
#   '경기',
#   '중부',
#   '지사',
#   '검사',
#   '부장',
#   '유호',
#   '강원',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '최용훈',
#   '원영',
#   '동지사',
#   '검사',
#   '부장',
#   '동주',
#   '전북',
#   '지역',
#   '본부',
#   '검사',
#   '부장',
#   '이영구',
#   '검사',
#   '부장',
#   '박진우',
#   '경남',
#   '지역',
#   '본부',
#   '교육',
#   '홍보',
#   '부장',
#   '태광',
#   '경남',
#   '서부',
#   '지사',
#   '검사',
#   '부장',
#   '대기'],
#  ['한국동서발전',
#   '전보',
#   '처장',
#   '인재',
#   '경영',
#   '김진원',
#   '상생',
#   '조달',
#   '동주',
#   '안전',
#   '품질',
#   '승화',
#   '기술',
#   '정보',
#   '조상기',
#   '당진',
#   '화력',
#   '본부',
#   '발전',
#   '김종규',
#   '발전',
#   '장수',
#   '기술',
#   '관리',
#   '김용화',
#   '울산',
#   '화력',
#   '본부',
#   '경영',
#   '관리',
#   '표영준',
#   '복합',
#   '발전',
#   '실장',
#   '국내',
#   '사업',
#   '정영철',
#   '해외',
#   '사업',
#   '본부장',
#   '호남',
#   '화력',
#   '창희',
#   '일산',
#   '화력',
#   '남진'],
#  ['전력',
#   '거래소',
#   '전보',
#   '처장',
#   '시장',
#   '개발',
#   '김홍근',
#   '지사장',
#   '제주',
#   '이건웅',
#   '실장',
#   '전력',
#   '경제',
#   '연구',
#   '조강',
#   '시장',
#   '감시'],
#  ['한국무역보험공사',
#   '승진',
#   '부장',
#   '조사',
#   '유승희',
#   '실장',
#   '남부',
#   '심사',
#   '이태희',
#   '전보',
#   '부장',
#   '전략',
#   '기획',
#   '투자',
#   '금융',
#   '총괄',
#   '김호일',
#   '플랜트',
#   '금융',
#   '동윤',
#   '해외',
#   '투자',
#   '금융',
#   '김필',
#   '리스크',
#   '총괄',
#   '혜성',
#   '영업',
#   '총괄',
#   '김석희',
#   '지사장',
#   '지모',
#   '중앙',
#   '박재형',
#   '강남',
#   '한상렬',
#   '충북',
#   '제주',
#   '이학'],
# ...
#   '출신',
#   '예술인',
#   '공연',
#   '관람',
#   '강연',
#   '프로그램',
#   '진행',
#   '방침'],
#  ['GS칼텍스', '관계자', '지역', '문화', '가정', '청소년', '나라', '인재', '성장', '지속', '후원', '방침'],
#  ['여수', '경기', '기자'],
#  ['아시아',
#   '경제',
#   '이광호',
#   '기자',
#   '육군',
#   '장병',
#   '감성',
#   '치유',
#   '지원',
#   '충남',
#   '계룡시',
#   '위치',
#   '육군',
#   '본부',
#   '복이',
#   '사장',
#   '장준규',
#   '육군',
#   '참모총장',
#   '참석',
#   '가운데',
#   '만원',
#   '상당',
#   '오디오',
#   '세트',
#   '전달식',
#   '이번',
#   '지원',
#   '오디오',
#   '복무',
#   '부적응',
#   '장병',
#   '심리',
#   '안정',
#   '국방부',
#   '운영',
#   '전국',
#   '그린',
#   '캠프',
#   '국군',
#   '병원',
#   '전달',
#   '캠프',
#   '소자',
#   '부상',
#   '입원',
#   '치료',
#   '장병',
#   '대상',
#   '음악',
#   '감상',
#   '심리',
#   '치료',
#   '예정',
#   '관계자',
#   '복무',
#   '부적응',
#   '때문',
#   '발생',
#   '군대',
#   '사건',
#   '사고',
#   '사기',
#   '사회',
#   '전반',
#   '불안감',
#   '해당',
#   '장병',
#   '심리치료',
#   '복무',
#   '건강',
#   '사회',
#   '일원',
#   '복귀',
#   '법무부',
#   '범죄',
#   '예방',
#   '협조',
#   '보호',
#   '청소년',
#   '사회',
#   '복귀',
#   '지원',
#   '소년원',
#   '청소년',
#   '비행',
#   '예방',
#   '센터',
#   '청소년',
#   '자립생활',
#   '오디오',
#   '세트',
#   '지원'],
#  ['범죄심리학',
#   '프로파일러',
#   '범죄심리학',
#   '프로파일러',
#   '프로파일러',
#   '표창원',
#   '최근',
#   '범죄심리학',
#   '프로파일러',
#   '누리꾼',
#   '관심',
#   '프로파일러',
#   '범죄자',
#   '심리',
#   '분석',
#   '범죄',
#   '심리',
#   '전문가',
#   '풀이',
#   '프로파일러',
#   '연쇄',
#   '범죄',
#   '중대',
#   '범죄',
#   '수사',
#   '언급',
#   '최근',
#   '처음',
#   '등장',
#   '미국',
#   '범죄',
#   '동기',
#   '연쇄살인',
#   '사건',
#   '미국',
#   '연방수사국',
#   '프로파일러',
#   '도입',
#   '이후',
#   '나라',
#   '제도',
#   '도입',
#   '범죄심리학',
#   '분야',
#   '성장',
#   '범죄',
#   '심리',
#   '라고',
#   '기대',
#   '범죄자',
#   '행동',
#   '심리',
#   '특징',
#   '연구',
#   '영역',
#   '이해',
#   '범죄심리학',
#   '범죄',
#   '해부학',
#   '범죄심리학',
#   '공격성',
#   '정신병',
#   '청소년',
#   '비행',
#   '정신',
#   '장애',
#   '위험성',
#   '평가',
#   '성범죄',
#   '살인',
#   '연쇄살인',
#   '프로파일링',
#   '테러',
#   '인질',
#   '협상',
#   '가정폭력',
#   '배우자',
#   '살해',
#   '도벽',
#   '심리',
#   '분야',
#   '포함',
#   '국내',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '범죄',
#   '과학',
#   '연구소',
#   '소장',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '네티즌',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '심리',
#   '분석',
#   '전문가',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '반응',
#   '매경닷컴',
#   '오용',
#   '인턴',
#   '기자',
#   '관련',
#   '기사',
#   '서울대',
#   '엄친',
#   '지주연',
#   '볼륨',
#   '비키니',
#   '몸매',
#   '삼성',
#   '미래',
#   '기술',
#   '삼성',
#   '기술',
#   '넥센 히어로즈',
#   '넥센타이어',
#   '계약',
#   '연장',
#   '마지막',
#   '무대',
#   '국보',
#   '발레리나',
#   '은퇴',
#   '아쉬움',
#   '레이싱',
#   '축구공',
#   '가슴골',
#   '매일',
#   '경제',
#   '무단',
#   '전재',
#   '배포',
#   '금지'],
#  ['범죄심리학',
#   '프로파일러',
#   '범죄심리학',
#   '프로파일러',
#   '프로파일러',
#   '표창원',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '발생',
#   '증가',
#   '범죄심리학',
#   '프로파일러',
#   '관심',
#   '범죄심리학',
#   '프로파일러',
#   '범죄심리학',
#   '프로파일러',
#   '범죄자',
#   '심리',
#   '분석',
#   '범죄',
#   '심리',
#   '전문가',
#   '풀이',
#   '범죄심리학',
#   '프로파일러',
#   '연쇄',
#   '범죄',
#   '중대',
#   '범죄',
#   '수사',
#   '언급',
#   '최근',
#   '처음',
#   '등장',
#   '미국',
#   '범죄',
#   '동기',
#   '연쇄살인',
#   '사건',
#   '미국',
#   '연방수사국',
#   '범죄심리학',
#   '프로파일러',
#   '도입',
#   '이후',
#   '나라',
#   '제도',
#   '도입',
#   '범죄심리학',
#   '분야',
#   '성장',
#   '범죄',
#   '심리',
#   '라고',
#   '기대',
#   '범죄자',
#   '행동',
#   '심리',
#   '특징',
#   '연구',
#   '영역',
#   '이해',
#   '범죄심리학',
#   '범죄',
#   '해부학',
#   '범죄심리학',
#   '공격성',
#   '정신병',
#   '청소년',
#   '비행',
#   '정신',
#   '장애',
#   '위험성',
#   '평가',
#   '성범죄',
#   '살인',
#   '연쇄살인',
#   '프로파일링',
#   '테러',
#   '인질',
#   '협상',
#   '가정폭력',
#   '배우자',
#   '살해',
#   '도벽',
#   '심리',
#   '분야',
#   '포함',
#   '국내',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '범죄',
#   '과학',
#   '연구소',
#   '소장',
#   '표창원',
#   '대표',
#   '심리학',
#   '프로파일러',
#   '네티즌',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '심리',
#   '분석',
#   '전문가',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '반응',
#   '매경닷컴',
#   '이성구',
#   '인턴',
#   '기자',
#   '관련',
#   '기사',
#   '서울대',
#   '엄친',
#   '지주연',
#   '볼륨',
#   '비키니',
#   '몸매',
#   '삼성',
#   '미래',
#   '기술',
#   '삼성',
#   '기술',
#   '실전',
#   '감각',
#   '쿠바',
#   '마지막',
#   '무대',
#   '국보',
#   '발레리나',
#   '은퇴',
#   '아쉬움',
#   '레이싱',
#   '축구공',
#   '가슴골',
#   '매일',
#   '경제',
#   '무단',
#   '전재',
#   '배포',
#   '금지'],
#  ['범죄심리학',
#   '프로파일러',
#   '범죄심리학',
#   '프로파일러',
#   '프로파일러',
#   '표창원',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '발생',
#   '증가',
#   '범죄심리학',
#   '프로파일러',
#   '관심',
#   '범죄심리학',
#   '프로파일러',
#   '범죄심리학',
#   '프로파일러',
#   '범죄자',
#   '심리',
#   '분석',
#   '범죄',
#   '심리',
#   '전문가',
#   '풀이',
#   '범죄심리학',
#   '프로파일러',
#   '연쇄',
#   '범죄',
#   '중대',
#   '범죄',
#   '수사',
#   '언급',
#   '최근',
#   '처음',
#   '등장',
#   '미국',
#   '범죄',
#   '동기',
#   '연쇄살인',
#   '사건',
#   '미국',
#   '연방수사국',
#   '범죄심리학',
#   '프로파일러',
#   '도입',
#   '이후',
#   '나라',
#   '제도',
#   '도입',
#   '범죄심리학',
#   '분야',
#   '성장',
#   '범죄',
#   '심리',
#   '라고',
#   '기대',
#   '범죄자',
#   '행동',
#   '심리',
#   '특징',
#   '연구',
#   '영역',
#   '이해',
#   '범죄심리학',
#   '범죄',
#   '해부학',
#   '범죄심리학',
#   '공격성',
#   '정신병',
#   '청소년',
#   '비행',
#   '정신',
#   '장애',
#   '위험성',
#   '평가',
#   '성범죄',
#   '살인',
#   '연쇄살인',
#   '프로파일링',
#   '테러',
#   '인질',
#   '협상',
#   '가정폭력',
#   '배우자',
#   '살해',
#   '도벽',
#   '심리',
#   '분야',
#   '포함',
#   '국내',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '범죄',
#   '과학',
#   '연구소',
#   '소장',
#   '표창원',
#   '대표',
#   '심리학',
#   '프로파일러',
#   '네티즌',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '심리',
#   '분석',
#   '전문가',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '반응',
#   '매경닷컴',
#   '이성구',
#   '인턴',
#   '기자',
#   '관련',
#   '기사',
#   '서울대',
#   '엄친',
#   '지주연',
#   '볼륨',
#   '비키니',
#   '몸매',
#   '삼성',
#   '미래',
#   '기술',
#   '삼성',
#   '기술',
#   '결장',
#   '이유',
#   '부상',
#   '경찰',
#   '체포',
#   '마지막',
#   '무대',
#   '국보',
#   '발레리나',
#   '은퇴',
#   '아쉬움',
#   '레이싱',
#   '축구공',
#   '가슴골',
#   '매일',
#   '경제',
#   '무단',
#   '전재',
#   '배포',
#   '금지'],
#  ['범죄',
#   '심리',
#   '프로파일러',
#   '범죄심리학',
#   '프로파일러',
#   '프로파일러',
#   '표창원',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '발생',
#   '증가',
#   '범죄심리학',
#   '프로파일러',
#   '관심',
#   '범죄심리학',
#   '프로파일러',
#   '범죄심리학',
#   '프로파일러',
#   '범죄자',
#   '심리',
#   '분석',
#   '범죄',
#   '심리',
#   '전문가',
#   '풀이',
#   '범죄심리학',
#   '프로파일러',
#   '연쇄',
#   '범죄',
#   '중대',
#   '범죄',
#   '수사',
#   '언급',
#   '최근',
#   '처음',
#   '등장',
#   '미국',
#   '범죄',
#   '동기',
#   '연쇄살인',
#   '사건',
#   '미국',
#   '연방수사국',
#   '범죄심리학',
#   '프로파일러',
#   '도입',
#   '이후',
#   '나라',
#   '제도',
#   '도입',
#   '범죄심리학',
#   '분야',
#   '성장',
#   '범죄',
#   '심리',
#   '라고',
#   '기대',
#   '범죄자',
#   '행동',
#   '심리',
#   '특징',
#   '연구',
#   '영역',
#   '이해',
#   '범죄심리학',
#   '범죄',
#   '해부학',
#   '범죄심리학',
#   '공격성',
#   '정신병',
#   '청소년',
#   '비행',
#   '정신',
#   '장애',
#   '위험성',
#   '평가',
#   '성범죄',
#   '살인',
#   '연쇄살인',
#   '프로파일링',
#   '테러',
#   '인질',
#   '협상',
#   '가정폭력',
#   '배우자',
#   '살해',
#   '도벽',
#   '심리',
#   '분야',
#   '포함',
#   '국내',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '범죄',
#   '과학',
#   '연구소',
#   '소장',
#   '표창원',
#   '대표',
#   '심리학',
#   '프로파일러',
#   '네티즌',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '심리',
#   '분석',
#   '전문가',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '반응',
#   '매경닷컴',
#   '이성구',
#   '인턴',
#   '기자',
#   '관련',
#   '기사',
#   '서울대',
#   '엄친',
#   '지주연',
#   '볼륨',
#   '비키니',
#   '몸매',
#   '삼성',
#   '미래',
#   '기술',
#   '삼성',
#   '기술',
#   '결장',
#   '이유',
#   '부상',
#   '경찰',
#   '체포',
#   '마지막',
#   '무대',
#   '국보',
#   '발레리나',
#   '은퇴',
#   '아쉬움',
#   '레이싱',
#   '축구공',
#   '가슴골',
#   '매일',
#   '경제',
#   '무단',
#   '전재',
#   '배포',
#   '금지'],
#  ['소년범', '비행', '청소년', '방치', '나중', '사회', '비용', '부담', '때문', '사회', '관심', '지원'],
#  ['서울',
#   '양재동',
#   '서울가정법원',
#   '집무실',
#   '여상',
#   '사진',
#   '서울가정법원',
#   '범죄',
#   '비행',
#   '우려',
#   '청소년',
#   '애정',
#   '청소년',
#   '대부분',
#   '불우',
#   '가정환경',
#   '위기',
#   '가정',
#   '부모',
#   '가족',
#   '사랑',
#   '상처',
#   '안고',
#   '법원장',
#   '가정',
#   '사회',
#   '아이들',
#   '건강',
#   '환경',
#   '만큼',
#   '잘못',
#   '청소년',
#   '책임',
#   '행동',
#   '원인',
#   '치유',
#   '해주',
#   '강조'],
#  ['현실', '법원장', '바람', '거리', '한참'],
#  ['범죄',
#   '비행',
#   '청소년',
#   '약물 중독',
#   '정신과',
#   '문제',
#   '안고',
#   '청소년',
#   '치료',
#   '선도',
#   '의료',
#   '소년원',
#   '처분',
#   '보호자',
#   '친권자',
#   '후견인',
#   '문제',
#   '청소년',
#   '보호',
#   '위탁',
#   '시설',
#   '6호',
#   '처분',
#   '실태',
#   '법원장',
#   '전국',
#   '의료',
#   '소년원',
#   '상주',
#   '의사',
#   '치료',
#   '청소년',
#   '경우',
#   '6호',
#   '처분',
#   '아동',
#   '복지',
#   '시설',
#   '소년',
#   '보호',
#   '시설',
#   '청소년',
#   '자리',
#   '부족',
#   '처분',
#   '경우',
#   '토로'],
#  ['실제',
#   '6호',
#   '처분',
#   '청소년',
#   '보호',
#   '사회인',
#   '육성',
#   '6호',
#   '시설',
#   '정부',
#   '소년범',
#   '시설',
#   '지원',
#   '예산',
#   '지자체',
#   '정도',
#   '영유아',
#   '보육',
#   '지원',
#   '살림',
#   '지자체',
#   '문제',
#   '아들',
#   '지원',
#   '여력',
#   '때문',
#   '전국',
#   '남은',
#   '6호',
#   '시설',
#   '상황',
#   '최근',
#   '경기도',
#   '양주',
#   '위치',
#   '나사',
#   '재정난',
#   '정상',
#   '운영',
#   '실정',
#   '법원장',
#   '소년범',
#   '방치',
#   '나중',
#   '성인',
#   '범죄자',
#   '사회',
#   '비용',
#   '대책',
#   '마련',
#   '강조',
#   '배경',
#   '가정법원',
#   '대로',
#   '6호',
#   '시설',
#   '가출',
#   '청소년',
#   '규모',
#   '그룹',
#   '형태',
#   '각지',
#   '분포',
#   '여성',
#   '가족',
#   '관련',
#   '부처',
#   '협의'],
#  ['법원장',
#   '법원',
#   '후견',
#   '기능',
#   '강화',
#   '법원',
#   '법원장',
#   '전문',
#   '법원',
#   '장제',
#   '도입',
#   '제안',
#   '가정법원',
#   '보람',
#   '전임',
#   '법원장',
#   '가정법원',
#   '법관',
#   '전문',
#   '법관',
#   '최소',
#   '근무',
#   '법원장',
#   '전문',
#   '법원',
#   '장과',
#   '제도',
#   '운영',
#   '시각',
#   '가사',
#   '사건',
#   '소년',
#   '사건',
#   '가사',
#   '사건',
#   '후견',
#   '기능',
#   '필요',
#   '고려',
#   '재판부',
#   '판단',
#   '갈등',
#   '치유',
#   '역할',
#   '강조'],
#  ['한편',
#   '변호사',
#   '경력',
#   '법원장',
#   '당시',
#   '경험',
#   '재판',
#   '입장',
#   '자산',
#   '후배',
#   '판사',
#   '재판',
#   '당사자',
#   '양쪽',
#   '이야기',
#   '주의',
#   '성실',
#   '설명',
#   '주문',
#   '분야',
#   '강조',
#   '덕목',
#   '생각'],
#  ['선형', '기자'],
#  ['사춘기', '교실'],
#  ['사춘기', '교실'],
#  ['01'],
#  ['학교', '문제아', '낙인'],
#  [],
#  ['여학생', '유흥업소'],
#  ['경기도',
#   '고등학교',
#   '가명',
#   '외국인',
#   '근로자',
#   '한국',
#   '방글라데시',
#   '부모',
#   '사이에서',
#   '한국',
#   '방글라데시',
#   '바가',
#   '부모',
#   '나라',
#   '인식',
#   '전부'],
#  ['아버지',
#   '불법체류',
#   '자로',
#   '적발',
#   '고국',
#   '강제',
#   '출국',
#   '어머니',
#   '여동생',
#   '공간',
#   '샌드위치',
#   '패널',
#   '조립식',
#   '주택',
#   '안전',
#   '보장',
#   '가족'],
#  ['공장',
#   '아버지',
#   '대신',
#   '역할',
#   '어머니',
#   '학교',
#   '친구',
#   '학교',
#   '문제아',
#   '취급',
#   '어머니',
#   '아들',
#   '때문',
#   '교회',
#   '목사',
#   '학교',
#   '경찰서'],
#  ['가족', '목사', '비행', '청소년', '문제', '학교', '걱정'],
#  ['한때', '엔지니어', '불안', '환경', '의미', '이제', '자신', '현실', '무력감'],
#  ['방황',
#   '필리핀인',
#   '어머니',
#   '미군',
#   '아버지',
#   '사이에서',
#   '니콜',
#   '가명',
#   '중학교',
#   '중퇴',
#   '미군',
#   '클럽',
#   '무국적',
#   '자인',
#   '나이',
#   '클럽'],
#  ['신원', '정보', '나름', '설명', '최근', '자신', '클럽', '경찰', '단속', '일자리'],
#  ['학교', '취업', '남자', '노동판', '여자'],
#  ['경기도', '미군', '기지', '주변', '유흥업소', '니콜', '무국적', '여성', '청소년'],
#  ['최근',
#   '5년',
#   '법무부',
#   '국내',
#   '불법체류',
#   '자 현',
#   '자료',
#   '불법체류',
#   '올해',
#   '기준',
#   '반면',
#   '불법체류',
#   '단속',
#   '단속',
#   '신원',
#   '정보',
#   '파악',
#   '무국',
#   '적자',
#   '증가',
#   '원인',
#   '분석'],
#  ['한국',
#   '범죄학',
#   '연구소',
#   '연구',
#   '위원',
#   '무국',
#   '적자',
#   '범죄',
#   '경우',
#   '지문',
#   '신원',
#   '정보',
#   '확보',
#   '때문',
#   '지문',
#   '감식',
#   '조사',
#   '과학',
#   '수사',
#   '사실',
#   '의미',
#   '목격자',
#   '진술',
#   '문수사',
#   '의존',
#   '상황',
#   '개선',
#   '불법체류',
#   '자와',
#   '무국적',
#   '처벌',
#   '유예',
#   '기간',
#   '자진',
#   '신고',
#   '유도',
#   '정부',
#   '법률',
#   '조치',
#   '필요',
#   '조언'],
#  ['이종우', '최재훈', '황성', '기자'],
#  ['사진',
#   '제주시',
#   '이도',
#   '지구',
#   '위치',
#   '공사',
#   '중단',
#   '건축물',
#   '개월',
#   '완공',
#   '청소년',
#   '탈선',
#   '야생',
#   '동물',
#   '서식지',
#   '활용',
#   '경호',
#   '기자',
#   '건설',
#   '중단',
#   '건축물',
#   '도심',
#   '흉물',
#   '전락',
#   '제주시',
#   '이도',
#   '지구',
#   '방문',
#   '결과',
#   '공사',
#   '중단',
#   '규모',
#   '공동',
#   '주택',
#   '확인',
#   '해당',
#   '건물',
#   '2012년 5월',
#   '착공',
#   '현재',
#   '개월',
#   '완공',
#   '출입',
#   '펜스',
#   '유치권',
#   '행사',
#   '경고',
#   '부착',
#   '건축주',
#   '대금',
#   '지급',
#   '공사',
#   '중단',
#   '추정',
#   '문제',
#   '수년',
#   '완공',
#   '방치',
#   '청소년',
#   '탈선',
#   '야생',
#   '동물',
#   '서식지',
#   '활용',
#   '인근',
#   '주민',
#   '민원',
#   '인근',
#   '주민',
#   '비행',
#   '청소년',
#   '흡연',
#   '음주',
#   '목격',
#   '최근',
#   '길고양이',
#   '서식',
#   '범죄',
#   '우려',
#   '동네',
#   '미관',
#   '저해',
#   '주민',
#   '불만',
#   '토로',
#   '공사',
#   '중단',
#   '건축물',
#   '인해',
#   '미관',
#   '저해',
#   '민원',
#   '발생',
#   '행정',
#   '관리',
#   '실정',
#   '현행법',
#   '행정',
#   '착공',
#   '준공',
#   '허가',
#   '담당',
#   '건설',
#   '중단',
#   '건축물',
#   '관리',
#   '민원',
#   '접수',
#   '현장',
#   '점검',
#   '확인',
#   '때문',
#   '사정',
#   '제주시',
#   '이상',
#   '장기',
#   '공사',
#   '중단',
#   '건축물',
#   '파악',
#   '건설업',
#   '건축물',
#   '공사',
#   '중단',
#   '입장',
#   '건설업',
#   '관계자',
#   '최근',
#   '건설',
#   '경기',
#   '호황',
#   '공사',
#   '대금',
#   '지급',
#   '건축주',
#   '시공사',
#   '불화',
#   '건설',
#   '중단',
#   '건축물',
#   '지속',
#   '발생',
#   '공사',
#   '중단',
#   '경우',
#   '행정',
#   '신고',
#   '제도',
#   '개선',
#   '필요',
#   '경호',
#   '기자'],
#  ['범죄심리학',
#   '프로파일러',
#   '범죄심리학',
#   '프로파일러',
#   '프로파일러',
#   '표창원',
#   '최근',
#   '범죄심리학',
#   '프로파일러',
#   '누리꾼',
#   '관심',
#   '프로파일러',
#   '범죄자',
#   '심리',
#   '분석',
#   '범죄',
#   '심리',
#   '전문가',
#   '풀이',
#   '프로파일러',
#   '연쇄',
#   '범죄',
#   '중대',
#   '범죄',
#   '수사',
#   '언급',
#   '최근',
#   '처음',
#   '등장',
#   '미국',
#   '범죄',
#   '동기',
#   '연쇄살인',
#   '사건',
#   '미국',
#   '연방수사국',
#   '프로파일러',
#   '도입',
#   '이후',
#   '나라',
#   '제도',
#   '도입',
#   '범죄심리학',
#   '분야',
#   '성장',
#   '범죄',
#   '심리',
#   '라고',
#   '기대',
#   '범죄자',
#   '행동',
#   '심리',
#   '특징',
#   '연구',
#   '영역',
#   '이해',
#   '범죄심리학',
#   '범죄',
#   '해부학',
#   '범죄심리학',
#   '공격성',
#   '정신병',
#   '청소년',
#   '비행',
#   '정신',
#   '장애',
#   '위험성',
#   '평가',
#   '성범죄',
#   '살인',
#   '연쇄살인',
#   '프로파일링',
#   '테러',
#   '인질',
#   '협상',
#   '가정폭력',
#   '배우자',
#   '살해',
#   '도벽',
#   '심리',
#   '분야',
#   '포함',
#   '국내',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '범죄',
#   '과학',
#   '연구소',
#   '소장',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '네티즌',
#   '범죄심리학',
#   '프로파일러',
#   '범죄',
#   '심리',
#   '분석',
#   '전문가',
#   '범죄심리학',
#   '프로파일러',
#   '표창원',
#   '대표',
#   '범죄심리학',
#   '프로파일러',
#   '반응',
#   '매경닷컴',
#   '오용',
#   '인턴',
#   '기자',
#   '관련',
#   '기사',
#   '서울대',
#   '엄친',
#   '지주연',
#   '볼륨',
#   '비키니',
#   '몸매',
#   '삼성',
#   '미래',
#   '기술',
#   '삼성',
#   '기술',
#   '재활',
#   '류현진',
#   '입국',
#   '예정',
#   '금속',
#   '탐지기',
#   '중세',
#   '은화',
#   '동전',
#   '레이싱',
#   '축구공',
#   '가슴골',
#   '매일',
#   '경제',
#   '무단',
#   '전재',
#   '배포',
#   '금지'],
#  ['사랑', '연합회', '청소년', '초청', '행사'],
#  ['GS칼텍스',
#   '법무부',
#   '산하',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '지난달',
#   '개최',
#   '사랑',
#   '청소년',
#   '문화',
#   '나들',
#   '행사',
#   '후원'],
#  ['이번',
#   '행사',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '기존',
#   '비행',
#   '청소년',
#   '사후',
#   '단기',
#   '선도',
#   '범죄',
#   '우려',
#   '문화',
#   '가정',
#   '청소년',
#   '상대로',
#   '선제',
#   '장기',
#   '후원',
#   '기획'],
#  ['사랑',
#   '연합회',
#   '민간',
#   '범죄',
#   '예방',
#   '자원봉사',
#   '자인',
#   '사랑',
#   '위원',
#   '들로',
#   '구성',
#   '법정',
#   '단체',
#   '전남',
#   '동부',
#   '지역',
#   '각계각층',
#   '선정',
#   '사랑',
#   '위원',
#   '구성'],
#  ['사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '이날',
#   '범죄',
#   '노출',
#   '우려',
#   '문화',
#   '결손',
#   '가정',
#   '청소년',
#   '여명',
#   '초청',
#   '직업',
#   '탐방',
#   '예술',
#   '공연',
#   '관람',
#   '실시',
#   '청소년',
#   '사랑',
#   '위원',
#   '대화',
#   'GS칼텍스',
#   '여수',
#   '공장',
#   '견학',
#   '진행'],
#  ['이날',
#   '오후',
#   '여수시',
#   '시전동',
#   'GS칼텍스',
#   '마루',
#   '극장',
#   '뮤지컬',
#   '명성황후',
#   '주년',
#   '기념',
#   '공연',
#   '관람',
#   '광복',
#   '주년',
#   '의미',
#   '역사',
#   '의식',
#   '기회',
#   '경험'],
#  ['사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '관계자',
#   '앞으로',
#   'GS칼텍스',
#   '관내',
#   '기업체',
#   '후원',
#   '해당',
#   '기업',
#   '견학',
#   '지역',
#   '출신',
#   '예술인',
#   '공연',
#   '관람',
#   '강연',
#   '프로그램',
#   '진행',
#   '방침'],
#  ['GS칼텍스', '관계자', '지역', '문화', '가정', '청소년', '나라', '인재', '성장', '지속', '후원', '방침'],
#  ['여수', '경기', '기자'],
#  ['GS칼텍스',
#   '대표',
#   '이사',
#   '허진',
#   '부회장',
#   '전남',
#   '동부',
#   '지역',
#   '청소년',
#   '선도',
#   '활동',
#   '적극',
#   '기여',
#   '기업',
#   '시민',
#   '책임'],
#  ['GS칼텍스',
#   '법무부',
#   '산하',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '개최',
#   '사랑',
#   '청소년',
#   '문화',
#   '나들',
#   '행사',
#   '후원'],
#  ['사랑',
#   '연합회',
#   '민간',
#   '범죄',
#   '예방',
#   '자원봉사',
#   '자인',
#   '사랑',
#   '위원',
#   '들로',
#   '구성',
#   '법정',
#   '단체'],
#  ['사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '전남',
#   '동부',
#   '지역',
#   '각계각층',
#   '선정',
#   '사랑',
#   '위원',
#   '참여'],
#  ['사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '이날',
#   '범죄',
#   '노출',
#   '우려',
#   '문화',
#   '결손',
#   '가정',
#   '청소년',
#   '여명',
#   '초청',
#   '직업',
#   '탐방',
#   '예술',
#   '공연',
#   '관람',
#   '실시'],
#  ['사랑', '위원회', '청소년', '대화', 'GS칼텍스', '여수', '공장', '견학', '주선', '적성', '후원'],
#  ['이날',
#   '오후',
#   '여수시',
#   '시전동',
#   'GS칼텍스',
#   '마루',
#   '극장',
#   '뮤지컬',
#   '명성황후',
#   '주년',
#   '기념',
#   '공연',
#   '관람',
#   '광복',
#   '주년',
#   '의미',
#   '역사',
#   '의식'],
#  ['행사',
#   '사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   '기존',
#   '비행',
#   '청소년',
#   '사후',
#   '단기',
#   '처방',
#   '선도',
#   '범죄',
#   '우려',
#   '문화',
#   '가정',
#   '청소년',
#   '상대로',
#   '선제',
#   '장기',
#   '후원',
#   '기획'],
#  ['사랑',
#   '전남',
#   '동부',
#   '지역',
#   '연합회',
#   'GS칼텍스',
#   '관내',
#   '기업체',
#   '후원',
#   '해당',
#   '기업',
#   '견학',
#   '지역',
#   '출신',
#   '예술인',
#   '공연',
#   '관람',
#   '강연',
#   '프로그램',
#   '진행',
#   '예정'],
#  ['문화',
#   '결손',
#   '가정',
#   '청소년',
#   '미래',
#   '장기',
#   '기업체',
#   '사랑',
#   '위원',
#   '청소년',
#   '지원 활동',
#   '정기',
#   '후원',
#   '분위기',
#   '조성',
#   '기대'],
#  ['GS칼텍스', '관계자', '지역', '문화', '가정', '청소년', '나라', '인재', '성장', '지속', '후원'],
#  ['나영석', '기자'],
#  ['용인', '벽돌', '사건', '범인', '처벌', '사회', '숙제'],
#  ['경기도',
#   '용인',
#   '초등학생',
#   '친구',
#   '아파트',
#   '옥상',
#   '벽돌',
#   '고양이',
#   '여성',
#   '사망',
#   '20대',
#   '여성',
#   '중상'],
#  ['강원도', '초등학생', '여학생', '음란', '동영상', '성추행', '남학생', '부모', '폭력'],
#  ['사례', '이번', '발생', '적발', '소년', '범죄', '행위', '사례', '충격', '형사', '처벌', '대상'],
#  ['가해자', '소년', '형사', '처벌', '피해자', '구제', '사실', '사법', '현실', '논란'],
#  ['형사', '처벌', '범죄', '처벌', '여론'],
#  ['이하',
#   '소년',
#   '현행법',
#   '형사',
#   '처벌',
#   '물론',
#   '촉법소년',
#   '형법',
#   '저촉',
#   '행위',
#   '대상',
#   '보호처분',
#   '조치',
#   '대상',
#   '형사법',
#   '제정',
#   '이하',
#   '형사',
#   '처벌',
#   '적용',
#   '62년',
#   '보호처분',
#   '연령',
#   '차례',
#   '세로'],
#  ['중력',
#   '실험',
#   '가해자',
#   '진술',
#   '고의',
#   '논란',
#   '고의',
#   '여부',
#   '형사',
#   '처벌',
#   '관련',
#   '고의',
#   '나중',
#   '민사',
#   '소송',
#   '소년',
#   '범죄',
#   '행위',
#   '입증',
#   '요소',
#   '근거',
#   '부모',
#   '관리',
#   '책임',
#   '손해배상',
#   '청구',
#   '근거',
#   '도덕',
#   '비난'],
#  ['범인',
#   '소년',
#   '개설',
#   '다음',
#   '아고라',
#   '청원',
#   '여명',
#   '형사',
#   '처벌',
#   '요구',
#   '리얼미터',
#   '발표',
#   '여론',
#   '조사',
#   '결과',
#   '형사',
#   '처벌',
#   '연령',
#   '기준',
#   '하향',
#   '찬성',
#   '의견',
#   '반대',
#   '찬성',
#   '정도'],
#  ['처벌', '관용', '처벌', '연령', '하향', '딜레마'],
#  ...]

# %% [markdown]
# ### 지지도, 신뢰도 검사단계

# %%
from apyori import apriori
rules = apriori(fin_lst, min_support=0.1, min_confidence=0.1)
#지지도가 너무 작으면 연관분석에 많은 시간이 소요된다.
results= list(rules)

# %%
result_df = pd.DataFrame(None, columns=['lhs','rhs','support','confidence','lift'])
index=0
for result in results:
    support = result[1]
    ordered_statistic = result[2]
    for item in ordered_statistic:
        lhs = ' '.join(x.strip() for x in item[0])
        rhs = ' '.join(x.strip() for x in item[1])
        confidence = item[2]
        lift = item[3]
        result_df.loc[index] = [lhs, rhs, support, confidence, lift]
        index +=1

# %%
pd.DataFrame(result_df).to_csv(path + f'{keyword}_신뢰지지.csv',encoding='cp949',index=False)

# %% [markdown]
# ###
